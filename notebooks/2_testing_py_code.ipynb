# %%
# autoreload
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 0) Testing Tools (Tool functions)

# %%
# Cell 1: Import all tools                                                                                                                                          
import sys                                                                                                                                                          
sys.path.append('..')                                                                                                                                               
                                                                                                                                                                    
from stocks_agent import (    
    get_company_info_basic,                                                                                                                                      
    get_company_info,                                                                                                                                               
    get_eps_trend,                                                                                                                                                  
    get_earnings_dates,                                                                                                                                             
    get_earnings_analysis,                                                                                                                                          
    get_historical_prices,                                                                                                                                          
    get_ticker_news,                                                                                                                                                
    search_news_by_ticker,                                                                                                                                          
    search_news_by_query,                                                                                                                                           
    search_companies,                                                                                                                                               
    get_top_value_companies,                                                                                                                                        
    get_top_growth_companies,                                                                                                                                       
    search_reddit_x_sentiment                                                                                                                                       
)                                                                                                                                                                   
                                                                                                                                                                    
print("✓ All tools imported successfully")
# Out:
# ✓ All tools imported successfully

# %%
# Cell 1.5: FORCE LOAD environment variables from .envrc file - RUN THIS FIRST!
import os

print("🔧 FORCE Loading environment variables from .envrc...")
try:
    with open('../.envrc', 'r') as f:
        for line in f:
            line = line.strip()
            if line.startswith('export ') and '=' in line:
                # Parse export VAR='value' or export VAR=value
                var_assignment = line[7:]  # Remove 'export '
                key, value = var_assignment.split('=', 1)
                # Remove quotes if present
                value = value.strip('"').strip("'")
                os.environ[key] = value
                print(f"✅ {key} loaded")

    print("\n🔑 Environment status:")
    print(f"✓ OPENAI_API_KEY: {'SET' if os.getenv('OPENAI_API_KEY') else 'NOT SET'}")
    print(f"✓ XAI_API_KEY: {'SET' if os.getenv('XAI_API_KEY') else 'NOT SET'}")
    print(f"✓ POLYGON_API_KEY: {'SET' if os.getenv('POLYGON_API_KEY') else 'NOT SET'}")
    
    if not os.getenv('OPENAI_API_KEY'):
        print("\n💥 CRITICAL: OPENAI_API_KEY STILL NOT LOADED!")
        print("🚨 Agents will show 'OPENAI_API_KEY is not set' errors")
        print("✅ SOLUTION: Close VS Code, run 'direnv allow' in terminal, then 'code .'")
    else:
        print("\n✅ SUCCESS: All API keys loaded! Agents will work without errors.")

except Exception as e:
    print(f"❌ Error: {e}")
# Out:
# 🔧 FORCE Loading environment variables from .envrc...
# ✅ OPENAI_API_KEY loaded
# ✅ POLYGON_API_KEY loaded
# ✅ XAI_API_KEY loaded
#
# 🔑 Environment status:
# ✓ OPENAI_API_KEY: SET
# ✓ XAI_API_KEY: SET
# ✓ POLYGON_API_KEY: SET
#
# ✅ SUCCESS: All API keys loaded! Agents will work without errors.

# %%
# Cell 2.0: Test BASIC stats from get_company_info_basic - Extracts 15 fields from 100+ field dict                                                                                           
print("="*80)                                                                                                                                                       
print("1. get_company_info_basic('AAPL')")                                                                                                                                
print("TRANSFORMATION: Extracts 15 key fields from yfinance 100+ field dict")                                                                                       
print("="*80)                                                                                                                                  
info = get_company_info_basic('AAPL')
info
# Out:
# ================================================================================
# 1. get_company_info_basic('AAPL')
# TRANSFORMATION: Extracts 15 key fields from yfinance 100+ field dict
# ================================================================================
# {'ticker': 'AAPL',
#  'name': 'Apple Inc.',
#  'sector': 'Technology',
#  'industry': 'Consumer Electronics',
#  'market_cap': 4222761828352,
#  'pe_ratio': 34.765415,
#  'forward_pe': 30.039297,
#  'peg_ratio': 2.49,
#  'price_to_book': 47.93431,
#  'dividend_yield': 0.38,
#  'beta': 1.065,
#  'current_price': 287.51,
#  'target_price': 303.3762,
#  'recommendation': 'buy',
#  'website': 'https://www.apple.com'}

# %%
# Cell 2.1: Test get_company_info - Extracts 15 fields from 100+ field dict                                                                                           
print("="*80)                                                                                                                                                       
print("1. get_company_info('AAPL')")                                                                                                                                
print("TRANSFORMATION: Extracts 15 key fields from yfinance 100+ field dict")                                                                                       
print("="*80)                                                                                                                                                       
                                                                                                                                                                    
info = get_company_info('AAPL')                                                                                                                                     
info
# Out:
# ================================================================================
# 1. get_company_info('AAPL')
# TRANSFORMATION: Extracts 15 key fields from yfinance 100+ field dict
# ================================================================================
# {'ticker': 'AAPL',
#  'company': {'website': 'https://www.apple.com',
#   'industry': 'Consumer Electronics',
#   'sector': 'Technology',
#   'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple Vision Pro, Apple TV, Apple Watch, Beats products, and HomePod, as well as Apple branded and third-party accessories. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV, which offers exclusive original content and live sports; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers and resellers. The company was formerly known as Apple Computer, Inc. and changed its name to Apple Inc. in January 2007. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.',
#   'fullTimeEmployees': 166000,
#   'companyOfficers': [{'maxAge': 1,
#     'name': 'Mr. Timothy D. Cook',
#     'age': 64,
#     'title': 'CEO & Director',
#     'yearBorn': 1961,
#     'fiscalYear': 2025,
#     'totalPay': 16759518,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Kevan  Parekh',
#     'age': 53,
#     'title': 'Senior VP & CFO',
#     'yearBorn': 1972,
#     'fiscalYear': 2025,
#     'totalPay': 4034174,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Sabih  Khan',
#     'age': 58,
#     'title': 'Senior VP & Chief Operating Officer',
#     'yearBorn': 1967,
#     'fiscalYear': 2025,
#     'totalPay': 5021905,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': "Ms. Deirdre  O'Brien",
#     'age': 58,
#     'title': 'Senior Vice President of Retail & People',
#     'yearBorn': 1967,
#     'fiscalYear': 2025,
#     'totalPay': 5037867,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Katherine L. Adams',
#     'age': 61,
#     'title': 'Senior VP of Government Affairs & Secretary',
#     'yearBorn': 1964,
#     'fiscalYear': 2025,
#     'totalPay': 5022482,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Ben  Borders',
#     'age': 44,
#     'title': 'Principal Accounting Officer',
#     'yearBorn': 1981,
#     'fiscalYear': 2025,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Suhasini  Chandramouli',
#     'title': 'Director of Investor Relations',
#     'fiscalYear': 2025,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Jennifer G. Newstead J.D.',
#     'age': 54,
#     'title': 'Senior VP & General Counsel',
#     'yearBorn': 1971,
#     'fiscalYear': 2025,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Ms. Kristin Huguet Quayle',
#     'title': 'Vice President of Worldwide Communications',
#     'fiscalYear': 2025,
#     'exercisedValue': 0,
#     'unexercisedValue': 0},
#    {'maxAge': 1,
#     'name': 'Mr. Greg  Joswiak',
#     'title': 'Senior Vice President of Worldwide Marketing',
#     'fiscalYear': 2025,
#     'exercisedValue': 0,
#     'unexercisedValue': 0}],
#   'region': 'US',
#   'fullExchangeName': 'NasdaqGS'},
#  'price': {'currentPrice': 287.51,
#   'previousClose': 284.18,
#   'open': 281.915,
#   'dayLow': 281.075,
#   'dayHigh': 288.03,
#   'regularMarketDayRange': '281.075 - 288.03',
#   'fiftyTwoWeekLow': 193.25,
#   'fiftyTwoWeekHigh': 288.62,
#   'fiftyTwoWeekRange': '193.25 - 288.62',
#   'allTimeHigh': 288.62,
#   'allTimeLow': 0.049107},
#  'market': {'marketCap': 4222761828352,
#   'volume': 57498732,
#   'averageVolume': 43998261,
#   'averageVolume10days': 49387280,
#   'beta': 1.065,
#   'trailingPE': 34.765415,
#   'forwardPE': 30.039297,
#   'trailingPegRatio': 2.4891},
#  'averages': {'fiftyDayAverage': 261.8236,
#   'twoHundredDayAverage': 255.88235,
#   'fiftyDayAverageChange': 25.686401,
#   'twoHundredDayAverageChange': 31.627655},
#  'valuation': {'priceToSalesTrailing12Months': 9.353941,
#   'priceToBook': 47.93431,
#   'bookValue': 5.998,
#   'profitMargins': 0.27152002,
#   'grossMargins': 0.47862,
#   'ebitdaMargins': 0.35437,
#   'operatingMargins': 0.32275},
#  'ownership': {'sharesOutstanding': 14687356000,
#   'floatShares': 14662240621,
#   'sharesPercentSharesOut': 0.0092,
#   'heldPercentInsiders': 0.0164,
#   'heldPercentInstitutions': 0.65272003,
#   'sharesShort': 134422787,
#   'shortRatio': 3.24,
#   'shortPercentOfFloat': 0.0092},
#  'earnings': {'trailingEps': 8.27,
#   'forwardEps': 9.57113,
#   'earningsQuarterlyGrowth': 0.194,
#   'earningsGrowth': 0.218,
#   'revenueGrowth': 0.166,
#   'epsTrailingTwelveMonths': 8.27,
#   'epsForward': 9.57113,
#   'epsCurrentYear': 8.76028},
#  'analyst': {'targetHighPrice': 355.0,
#   'targetLowPrice': 215.0,
#   'targetMeanPrice': 303.3762,
#   'targetMedianPrice': 310.0,
#   'recommendationMean': 1.91667,
#   'recommendationKey': 'buy',
#   'numberOfAnalystOpinions': 42,
#   'averageAnalystRating': '1.9 - Buy'},
#  'financial': {'totalCash': 68507000832,
#   'totalCashPerShare': 4.664,
#   'totalDebt': 84710998016,
#   'totalRevenue': 451442016256,
#   'freeCashflow': 101090746368,
#   'operatingCashflow': 140222005248,
#   'returnOnAssets': 0.26229,
#   'returnOnEquity': 1.4147099,
#   'debtToEquity': 79.548,
#   'currentRatio': 1.07,
#   'quickRatio': 0.906}}

# %%
  # Cell 3: Test get_eps_trend - CALCULATES EPS and DERIVES trend                                                                                                     
print("="*80)                                                                                                                                                       
print("2. get_eps_trend('TSLA')")                                                                                                                       
print("TRANSFORMATION: CALCULATES EPS = Net Income / Shares")                                                                                                       
print("                DERIVES trend = compare recent vs older quarters")                                                                                           
print("="*80)                                                                                                                                                       
                                                                                                                                                                    
eps = get_eps_trend('TSLA')                                                                                                                             
eps
# Out:
# ================================================================================
# 2. get_eps_trend('TSLA')
# TRANSFORMATION: CALCULATES EPS = Net Income / Shares
#                 DERIVES trend = compare recent vs older quarters
# ================================================================================
# {'ticker': 'TSLA',
#  'data': [{'current': 0.4523,
#    '7daysAgo': 0.45343,
#    '30daysAgo': 0.45754,
#    '60daysAgo': 0.46147,
#    '90daysAgo': 0.45124,
#    'period': '0q'},
#   {'current': 0.54471,
#    '7daysAgo': 0.55756,
#    '30daysAgo': 0.5385,
#    '60daysAgo': 0.54784,
#    '90daysAgo': 0.54978,
#    'period': '+1q'},
#   {'current': 2.05482,
#    '7daysAgo': 2.10497,
#    '30daysAgo': 2.06564,
#    '60daysAgo': 2.08858,
#    '90daysAgo': 2.11241,
#    'period': '0y'},
#   {'current': 2.53536,
#    '7daysAgo': 2.51448,
#    '30daysAgo': 2.81043,
#    '60daysAgo': 2.80819,
#    '90daysAgo': 2.9078,
#    'period': '+1y'}]}

# %%
# Cell 4: Test get_earnings_dates - Formats dates                                                                                                                   
print("="*80)                                                                                                                                                       
print("3. get_earnings_dates('MSFT')")                                                                                                                              
print("TRANSFORMATION: Formats dates from DataFrame")                                                                                                               
print("="*80)     
dates = get_earnings_dates('MSFT')                                                                                                                                  
dates
# Out:
# ================================================================================
# 3. get_earnings_dates('MSFT')
# TRANSFORMATION: Formats dates from DataFrame
# ================================================================================
# {'ticker': 'MSFT',
#  'data': [{'Earnings Date': '2026-07-29',
#    'EPS Estimate': 4.22,
#    'Reported EPS': nan,
#    'Surprise(%)': nan},
#   {'Earnings Date': '2026-04-29',
#    'EPS Estimate': 4.06,
#    'Reported EPS': 4.27,
#    'Surprise(%)': 5.22},
#   {'Earnings Date': '2026-01-28',
#    'EPS Estimate': 3.92,
#    'Reported EPS': 4.14,
#    'Surprise(%)': 5.69},
#   {'Earnings Date': '2025-10-29',
#    'EPS Estimate': 3.66,
#    'Reported EPS': 3.72,
#    'Surprise(%)': 1.59},
#   {'Earnings Date': '2025-07-30',
#    'EPS Estimate': 3.38,
#    'Reported EPS': 3.65,
#    'Surprise(%)': 8.09},
#   {'Earnings Date': '2025-04-30',
#    'EPS Estimate': 3.22,
#    'Reported EPS': 3.46,
#    'Surprise(%)': 7.4},
#   {'Earnings Date': '2025-01-29',
#    'EPS Estimate': 3.12,
#    'Reported EPS': 3.23,
#    'Surprise(%)': 3.47},
#   {'Earnings Date': '2024-10-30',
#    'EPS Estimate': 3.11,
#    'Reported EPS': 3.3,
#    'Surprise(%)': 6.13},
#   {'Earnings Date': '2024-07-30',
#    'EPS Estimate': 2.94,
#    'Reported EPS': 2.95,
#    'Surprise(%)': 0.23},
#   {'Earnings Date': '2024-04-25',
#    'EPS Estimate': 2.84,
#    'Reported EPS': 2.94,
#    'Surprise(%)': 3.4},
#   {'Earnings Date': '2024-01-30',
#    'EPS Estimate': 2.77,
#    'Reported EPS': 2.93,
#    'Surprise(%)': 5.83},
#   {'Earnings Date': '2023-10-24',
#    'EPS Estimate': 2.65,
#    'Reported EPS': 2.99,
#    'Surprise(%)': 12.85},
#   {'Earnings Date': '2023-07-25',
#    'EPS Estimate': 2.55,
#    'Reported EPS': 2.69,
#    'Surprise(%)': 5.59},
#   {'Earnings Date': '2023-04-25',
#    'EPS Estimate': 2.23,
#    'Reported EPS': 2.45,
#    'Surprise(%)': 9.77},
#   {'Earnings Date': '2023-01-24',
#    'EPS Estimate': 2.32,
#    'Reported EPS': 2.32,
#    'Surprise(%)': 0.21},
#   {'Earnings Date': '2022-10-25',
#    'EPS Estimate': 2.31,
#    'Reported EPS': 2.35,
#    'Surprise(%)': 1.92},
#   {'Earnings Date': '2022-07-26',
#    'EPS Estimate': 2.29,
#    'Reported EPS': 2.23,
#    'Surprise(%)': -2.69},
#   {'Earnings Date': '2022-04-26',
#    'EPS Estimate': 2.2,
#    'Reported EPS': 2.22,
#    'Surprise(%)': 1.06},
#   {'Earnings Date': '2022-01-25',
#    'EPS Estimate': 2.32,
#    'Reported EPS': 2.48,
#    'Surprise(%)': 6.97},
#   {'Earnings Date': '2021-10-26',
#    'EPS Estimate': 2.08,
#    'Reported EPS': 2.27,
#    'Surprise(%)': 9.3},
#   {'Earnings Date': '2021-07-27',
#    'EPS Estimate': 1.93,
#    'Reported EPS': 2.17,
#    'Surprise(%)': 12.71},
#   {'Earnings Date': '2021-04-27',
#    'EPS Estimate': 1.78,
#    'Reported EPS': 1.95,
#    'Surprise(%)': 9.67},
#   {'Earnings Date': '2021-01-26',
#    'EPS Estimate': 1.64,
#    'Reported EPS': 2.03,
#    'Surprise(%)': 23.99},
#   {'Earnings Date': '2020-10-27',
#    'EPS Estimate': 1.55,
#    'Reported EPS': 1.82,
#    'Surprise(%)': 17.72},
#   {'Earnings Date': '2020-07-22',
#    'EPS Estimate': 1.37,
#    'Reported EPS': 1.46,
#    'Surprise(%)': 6.42}]}

# %%
# Cell 5: Test get_earnings_analysis - Extracts analyst fields                                                                                                      
print("="*80)                                                                                                                                                       
print("4. get_earnings_analysis('GOOGL')")                                                                                                                          
print("TRANSFORMATION: Extracts analyst fields from stock.info")                                                                                                    
print("="*80)                                                                                                                                                       
                                                                                                                                                                    
analysis = get_earnings_analysis('GOOGL')                                                                                                                           
analysis
# Out:
# ================================================================================
# 4. get_earnings_analysis('GOOGL')
# TRANSFORMATION: Extracts analyst fields from stock.info
# ================================================================================
# {'ticker': 'GOOG',
#  'basic_analyst_info': {'analyst_count': 18,
#   'recommendation': 'strong_buy',
#   'recommendation_mean': 1.42424,
#   'target_high': 460.0,
#   'target_low': 185.0,
#   'target_mean': 398.05777,
#   'target_median': 412.5,
#   'current_price': 395.14},
#  'earnings_estimates': [{'period': '0q',
#    'avg': 2.88222,
#    'low': 2.6,
#    'high': 3.13,
#    'yearAgoEps': 2.31,
#    'numberOfAnalysts': 40,
#    'growth': 0.2477},
#   {'period': '+1q',
#    'avg': 3.00947,
#    'low': 2.67,
#    'high': 3.72,
#    'yearAgoEps': 2.87,
#    'numberOfAnalysts': 37,
#    'growth': 0.048600003},
#   {'period': '0y',
#    'avg': 13.8551,
#    'low': 11.33,
#    'high': 15.13,
#    'yearAgoEps': 10.81,
#    'numberOfAnalysts': 51,
#    'growth': 0.28170002},
#   {'period': '+1y',
#    'avg': 14.44383,
#    'low': 11.7,
#    'high': 17.18,
#    'yearAgoEps': 13.8551,
#    'numberOfAnalysts': 52,
#    'growth': 0.0425}],
#  'eps_revisions': [{'period': '0q',
#    'upLast7days': 27,
#    'upLast30days': 30,
#    'downLast30days': 2,
#    'downLast7Days': 3},
#   {'period': '+1q',
#    'upLast7days': 26,
#    'upLast30days': 30,
#    'downLast30days': 2,
#    'downLast7Days': 3},
#   {'period': '0y',
#    'upLast7days': 35,
#    'upLast30days': 36,
#    'downLast30days': 0,
#    'downLast7Days': 1},
#   {'period': '+1y',
#    'upLast7days': 33,
#    'upLast30days': 35,
#    'downLast30days': 1,
#    'downLast7Days': 1}],
#  'growth_estimates': [{'period': '0q',
#    'stockTrend': 0.2477,
#    'indexTrend': 0.24610001},
#   {'period': '+1q', 'stockTrend': 0.048600003, 'indexTrend': 0.2124},
#   {'period': '0y', 'stockTrend': 0.28170002, 'indexTrend': 0.2156},
#   {'period': '+1y', 'stockTrend': 0.0425, 'indexTrend': 0.1513},
#   {'period': 'LTG', 'stockTrend': nan, 'indexTrend': 0.122}],
#  'earnings_history': [{'quarter': Timestamp('2025-06-30 00:00:00'),
#    'epsActual': 2.31,
#    'epsEstimate': 2.19807,
#    'epsDifference': 0.11,
#    'surprisePercent': 0.0509},
#   {'quarter': Timestamp('2025-09-30 00:00:00'),
#    'epsActual': 2.87,
#    'epsEstimate': 2.26206,
#    'epsDifference': 0.61,
#    'surprisePercent': 0.2688},
#   {'quarter': Timestamp('2025-12-31 00:00:00'),
#    'epsActual': 2.82,
#    'epsEstimate': 2.64089,
#    'epsDifference': 0.18,
#    'surprisePercent': 0.0678},
#   {'quarter': Timestamp('2026-03-31 00:00:00'),
#    'epsActual': 5.11,
#    'epsEstimate': 2.62989,
#    'epsDifference': 2.48,
#    'surprisePercent': 0.943}]}

# %%
# Cell 6: Test get_historical_prices - CALCULATES distances, DERIVES momentum                                                                                       
print("="*80)                                                                                                                                                       
print("5. get_historical_prices('NVDA', period='3mo')")                                                                                                             
print("TRANSFORMATION: CALCULATES distance_from_high/low_pct")                                                                                                      
print("                DERIVES momentum from MA20 vs MA50")                                                                                                         
print("="*80)  
prices = get_historical_prices('NVDA', period='3mo')                                                                                                                
prices
# Out:
# ================================================================================
# 5. get_historical_prices('NVDA', period='3mo')
# TRANSFORMATION: CALCULATES distance_from_high/low_pct
#                 DERIVES momentum from MA20 vs MA50
# ================================================================================
# {'ticker': 'NVDA',
#  'period': '3mo',
#  'interval': '1d',
#  'current_price': 207.8300018310547,
#  'period_high': 216.8300018310547,
#  'period_low': 164.27000427246094,
#  'distance_from_high_pct': -4.150717116634276,
#  'distance_from_low_pct': 26.51731687201056,
#  'avg_volume': 171144353.59016395,
#  'momentum': 'positive',
#  'data_points': 61}

# %%
# Cell 7: Test get_ticker_news - Flattens nested API structure                                                                                                      
print("="*80)                                                                                                                                                       
print("6. get_ticker_news('TSLA', limit=10)")                                                                                                                        
print("TRANSFORMATION: Flattens nested yfinance structure, extracts key fields")                                                                                    
print("="*80)   
news = get_ticker_news('TSLA', limit=10)                                                                                                                             
print(f"News count: {news['news_count']}\n")                                                                                                                        
for i, item in enumerate(news['news'], 1):                                                                                                                          
    print(f"{i}. {item['title']}")                                                                                                                                  
    print(f"   Publisher: {item['publisher']}")                                                                                                                     
    print(f"   Published: {item['published']}")                                                                                                                     
    print(f"   Link: {item['link'][:60]}...")                                                                                                                       
    if item.get('summary'):                                                                                                                                         
        print(f"   Summary: {item['summary'][:100]}...")                                                                                                            
    print()                                                                                                                                                         
                                                                                                                                                                    
news  # Show full dict
# Out:
# ================================================================================
# 6. get_ticker_news('TSLA', limit=10)
# TRANSFORMATION: Flattens nested yfinance structure, extracts key fields
# ================================================================================
# News count: 10
#
# 1. 'Uber won': Why Instacart might not stand a chance
#    Publisher: Yahoo Finance Video
#    Published: 2026-05-06T20:41:39Z
#    Link: https://finance.yahoo.com/video/uber-won-why-instacart-might...
#    Summary: Uber (UBER) and Maplebear (CART) (Instacart's parent company) both reported quarterly earnings on We...
#
# 2. Elon Musk's SpaceX files initial $55 billion spend for Terafab chip factory in Texas
#    Publisher: Yahoo Finance
#    Published: 2026-05-06T12:03:56Z
#    Link: https://finance.yahoo.com/markets/stocks/article/elon-musks-...
#    Summary: Elon Musk's SpaceX rocket company filed paperwork to build its upcoming Terafab chip fabrication pla...
#
# 3. Prediction: Tesla Stock Is a Buy Before 2029 Due to This $10 Trillion Opportunity
#    Publisher: Motley Fool
#    Published: 2026-05-06T20:25:00Z
#    Link: https://www.fool.com/investing/2026/05/06/prediction-tesla-s...
#    Summary: Tesla's entire business model is ready to evolve....
#
# 4. Tesla Just Recalled Nearly 219,000 Cars. That’s Nothing Compared to Ford and Toyota.
#    Publisher: Barrons.com
#    Published: 2026-05-06T20:21:00Z
#    Link: https://www.barrons.com/articles/tesla-stock-price-recalls-f...
#    Summary: FEATURE   Tesla stock rose Wednesday despit ethe electric-vehicle maker recalling 218,868 cars to co...
#
# 5. Tesla’s Robotics Push And Robotaxis Test Valuation Against Rising Safety Risks
#    Publisher: Simply Wall St.
#    Published: 2026-05-06T20:20:32Z
#    Link: https://finance.yahoo.com/markets/stocks/articles/tesla-robo...
#    Summary: Tesla has started large scale production of its Optimus humanoid robot, which CEO Elon Musk has desc...
#
# 6. Tesla, Meta, Microsoft Investors May Need A 'Self-Destruct' Switch, Not Blind Faith
#    Publisher: Benzinga
#    Published: 2026-05-06T19:30:19Z
#    Link: https://finance.yahoo.com/markets/stocks/articles/tesla-meta...
#    Summary: Investors piling into the AI trade may need something less glamorous than another price target, prod...
#
# 7. Nio Inc (NIO) Goes After Tesla’s Lunch Again
#    Publisher: Insider Monkey
#    Published: 2026-05-06T19:00:14Z
#    Link: https://finance.yahoo.com/markets/stocks/articles/nio-inc-ni...
#    Summary: Nio Inc (NYSE:NIO) is one of the best large cap penny stocks under $10 to buy now. On April 28, Nio ...
#
# 8. Ford Exits EVs As Toyota Move In
#    Publisher: 24/7 Wall St.
#    Published: 2026-05-06T18:43:47Z
#    Link: https://247wallst.com/investing/2026/05/06/ford-exits-evs-as...
#    Summary: Ford (NYSE: F) left the EV business for dead earlier this year. It does appear it will enter again, ...
#
# 9. Insider Alert: Tesla Director Offloads Nearly $10 Million in Stock
#    Publisher: GuruFocus.com
#    Published: 2026-05-06T18:42:20Z
#    Link: https://finance.yahoo.com/markets/stocks/articles/insider-al...
#    Summary: Tesla Governance Activity in Focus After Director Offloads $10 Million Position...
#
# 10. The ‘PayPal Mafia’ built a $1.5 billion fintech pioneer. The company they left behind is on life support
#    Publisher: Fortune
#    Published: 2026-05-06T17:51:02Z
#    Link: https://finance.yahoo.com/markets/stocks/articles/paypal-maf...
#    Summary: Fortune coined the term "PayPal Mafia" in 2007. Two decades later, the mafia is thriving, but PayPal...
# {'ticker': 'TSLA',
#  'news_count': 10,
#  'news': [{'title': "'Uber won': Why Instacart might not stand a chance",
#    'publisher': 'Yahoo Finance Video',
#    'link': 'https://finance.yahoo.com/video/uber-won-why-instacart-might-not-stand-a-chance-204139211.html',
#    'published': '2026-05-06T20:41:39Z',
#    'description': '<p>Uber (<a target="_blank" rel="" class="link" href="https://finance.yahoo.com/quote/UBER/" data-i13n="cpos:1;pos:1">UBER</a>) and Maplebear (<a target="_blank" rel="" class="link" href="https://finance.yahoo.com/quote/CART/" data-i13n="cpos:2;pos:1">CART</a>) (Instacart\'s parent company) both reported quarterly earnings on Wednesday.</p>\n<p>BNP Paribas US large-cap internet equity analyst Nick Jones joins Yahoo Finance\'s Josh Lipton to discuss the key differences between the two companies and why he thinks Uber has much more room to run.</p>',
#    'summary': "Uber (UBER) and Maplebear (CART) (Instacart's parent company) both reported quarterly earnings on Wednesday. BNP Paribas US large-cap internet equity analyst Nick Jones joins Yahoo Finance's Josh Lipton to discuss the key differences between the two companies and why he thinks Uber has much more room to run."},
#   {'title': "Elon Musk's SpaceX files initial $55 billion spend for Terafab chip factory in Texas",
#    'publisher': 'Yahoo Finance',
#    'link': 'https://finance.yahoo.com/markets/stocks/article/elon-musks-spacex-files-initial-55-billion-spend-for-terafab-chip-factory-in-texas-120356588.html',
#    'published': '2026-05-06T12:03:56Z',
#    'description': '',
#    'summary': "Elon Musk's SpaceX rocket company filed paperwork to build its upcoming Terafab chip fabrication plant, with an initial spend of $55 billion."},
#   {'title': 'Prediction: Tesla Stock Is a Buy Before 2029 Due to This $10 Trillion Opportunity',
#    'publisher': 'Motley Fool',
#    'link': 'https://www.fool.com/investing/2026/05/06/prediction-tesla-stock-is-a-buy-before-2029-due-to/',
#    'published': '2026-05-06T20:25:00Z',
#    'description': '',
#    'summary': "Tesla's entire business model is ready to evolve."},
#   {'title': 'Tesla Just Recalled Nearly 219,000 Cars. That’s Nothing Compared to Ford and Toyota.',
#    'publisher': 'Barrons.com',
#    'link': 'https://www.barrons.com/articles/tesla-stock-price-recalls-ford-toyota-f785c767?siteid=yhoof2&yptr=yahoo',
#    'published': '2026-05-06T20:21:00Z',
#    'description': '',
#    'summary': 'FEATURE   Tesla stock rose Wednesday despit ethe electric-vehicle maker recalling 218,868 cars to correct a rearview camera issue. That is the way Tesla stock should react to recall news.  Tesla shares gained 2.'},
#   {'title': 'Tesla’s Robotics Push And Robotaxis Test Valuation Against Rising Safety Risks',
#    'publisher': 'Simply Wall St.',
#    'link': 'https://finance.yahoo.com/markets/stocks/articles/tesla-robotics-push-robotaxis-test-202032615.html',
#    'published': '2026-05-06T20:20:32Z',
#    'description': '',
#    'summary': "Tesla has started large scale production of its Optimus humanoid robot, which CEO Elon Musk has described as potentially the company's biggest product. The company is expanding unsupervised robotaxi operations across Texas, building on its Full Self Driving (FSD) technology. European regulators are reviewing the safety of FSD as Tesla seeks broader deployment in the region. In the U.S., Tesla has recalled more than 218,000 vehicles due to a rearview camera issue. Tesla, NasdaqGS:TSLA, is..."},
#   {'title': "Tesla, Meta, Microsoft Investors May Need A 'Self-Destruct' Switch, Not Blind Faith",
#    'publisher': 'Benzinga',
#    'link': 'https://finance.yahoo.com/markets/stocks/articles/tesla-meta-microsoft-investors-may-193019224.html',
#    'published': '2026-05-06T19:30:19Z',
#    'description': '',
#    'summary': 'Investors piling into the AI trade may need something less glamorous than another price target, product demo or promise about the future: a rule for when to stop trusting their favorite market narrative. That is the central argument from the investing blog Capital Blueprint, helmed by an independent market commentator using the name Jin, who says investors should build what Jin calls a "self-destruct chip" into their AI framework — clear conditions that force them to stop trusting a favorite nar'},
#   {'title': 'Nio Inc (NIO) Goes After Tesla’s Lunch Again',
#    'publisher': 'Insider Monkey',
#    'link': 'https://finance.yahoo.com/markets/stocks/articles/nio-inc-nio-goes-tesla-190014248.html',
#    'published': '2026-05-06T19:00:14Z',
#    'description': '',
#    'summary': 'Nio Inc (NYSE:NIO) is one of the best large cap penny stocks under $10 to buy now. On April 28, Nio Inc (NYSE:NIO) launched its L80 model and immediately opened pre-orders for the car. The L80 is a two-row, 5-seat SUV that runs on battery power like all Nio cars. But the L80 is produced […]'},
#   {'title': 'Ford Exits EVs As Toyota Move In',
#    'publisher': '24/7 Wall St.',
#    'link': 'https://247wallst.com/investing/2026/05/06/ford-exits-evs-as-toyota-move-in/',
#    'published': '2026-05-06T18:43:47Z',
#    'description': '',
#    'summary': 'Ford (NYSE: F) left the EV business for dead earlier this year. It does appear it will enter again, on a small scale, next year. At the same time, Toyota (NYSE: TM), which sells about as many cars in the US as Ford does, is pressing to expand its EV fleet. Someone is making a ... Ford Exits EVs As Toyota Move In'},
#   {'title': 'Insider Alert: Tesla Director Offloads Nearly $10 Million in Stock',
#    'publisher': 'GuruFocus.com',
#    'link': 'https://finance.yahoo.com/markets/stocks/articles/insider-alert-tesla-director-offloads-184220916.html',
#    'published': '2026-05-06T18:42:20Z',
#    'description': '',
#    'summary': 'Tesla Governance Activity in Focus After Director Offloads $10 Million Position'},
#   {'title': 'The ‘PayPal Mafia’ built a $1.5 billion fintech pioneer. The company they left behind is on life support',
#    'publisher': 'Fortune',
#    'link': 'https://finance.yahoo.com/markets/stocks/articles/paypal-mafia-built-1-5-175102356.html',
#    'published': '2026-05-06T17:51:02Z',
#    'description': '',
#    'summary': 'Fortune coined the term "PayPal Mafia" in 2007. Two decades later, the mafia is thriving, but PayPal isn\'t.'}]}

# %%
# Cell 8: Test search_news_by_ticker - Filters by keyword                                                                                                           
print("="*80)                                                                                                                                                       
print("7. search_news_by_ticker('AAPL', query='iPhone')")                                                                                                           
print("TRANSFORMATION: Filters news by keyword query")                                                                                                              
print("="*80)                                                                                                                                                       
                                                                                                                                                                    
filtered = search_news_by_ticker('AAPL', query='iPhone')                                                                                                            
filtered
# Out:
# ================================================================================
# 7. search_news_by_ticker('AAPL', query='iPhone')
# TRANSFORMATION: Filters news by keyword query
# ================================================================================
# Fetching 5000 news articles...
# API calls: 100%|██████████| 5/5 [00:05<00:00,  1.14s/it]
# Preprocessing documents...
# Converting fields: 100%|██████████| 5000/5000 [00:00<00:00, 1470447.34it/s]
# Building search index...
# {'articles_indexed': 5000,
#  'message': 'Index built with 5000 articles',
#  'status': 'success'}
# {'ticker': 'AAPL',
#  'count': 30,
#  'data': [{'id': 'cd7a57827d53aa80fc36bde5ea653032364ff49cb6aae2dc5e7adfb4825428ee',
#    'title': "Is a Foldable iPhone a Reason to Buy Apple's Stock?",
#    'author': 'Geoffrey Seiler',
#    'published_utc': '2026-04-12T13:25:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/12/is-a-foldable-iphone-a-reason-to-buy-apples-stock/?source=iedfolrf0000001',
#    'tickers': 'AAPL',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F864552%2Fappl.png&w=1200&op=resize',
#    'description': "Apple is entering the foldable smartphone market later in 2026 with a device priced over $2,000, seven years after competitors pioneered the technology. While the foldable iPhone could drive sales, particularly in China where such devices are popular, the author argues this alone is not a compelling reason to buy Apple stock. Instead, investors should focus on Apple's strong ecosystem and high-margin services business model as the primary investment thesis.",
#    'keywords': 'foldable iPhone, Apple ecosystem, China market, smartphone innovation, services revenue, digital wallet, customer loyalty',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': "The foldable iPhone launch is viewed as a modest positive for sales growth, particularly in China, but the author emphasizes it is not a primary reason to invest in the stock. The real value lies in Apple's ecosystem lock-in and high-margin services business, not the hardware innovation itself. The company is characterized as a follower rather than a pioneer in technology."}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': '92b348b4e68a00a603a18240a2d1a2afd45ad73cdd70424acd0dfb4c344dd032',
#    'title': 'Apple Makes Its Biggest Bet Since The iPhone: Ternus As CEO',
#    'author': 'Erica Kollmann',
#    'published_utc': '2026-04-21T17:28:42Z',
#    'article_url': 'https://www.benzinga.com/markets/tech/26/04/51949258/apple-makes-its-biggest-bet-since-the-iphone-ternus-as-ceo?utm_source=benzinga_taxonomy&utm_medium=rss_feed_free&utm_content=taxonomy_rss&utm_campaign=channel',
#    'tickers': 'AAPL',
#    'image_url': 'https://cdn.benzinga.com/files/images/story/2026/04/21/Apples-New-Iphone-18-Pro-Presentation-On.jpeg?width=1200&height=800&fit=crop',
#    'description': "Apple announced John Ternus as its next CEO, replacing Tim Cook after 14 years. Analysts view the timing positively, suggesting strength rather than crisis. While Cook's legacy is strong (1,900% stock growth, expanded EBITDA), Ternus faces challenges in AI integration where Apple lags competitors by 2-3 years. The appointment is seen as a hardware-focused strategy for the next-generation AI form factors, with WWDC as the critical test.",
#    'keywords': 'CEO transition, John Ternus, Tim Cook, AI integration, hardware strategy, Apple leadership, WWDC, AR glasses, wearables',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': "Mixed outlook: positive on leadership transition timing and Cook's legacy achievements, but concerns about AI lag (2-3 years behind competitors) and under-monetized advertising business. Stock down 2.46% at announcement. Success depends on Ternus delivering at WWDC and executing AI strategy."}],
#    'publisher.name': 'Benzinga',
#    'publisher.homepage_url': 'https://www.benzinga.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/benzinga.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/benzinga.ico',
#    'amp_url': nan},
#   {'id': '6baf93d62fcf0c2d4579273736250494ce9e8c20046888557370e7e7437c17f8',
#    'title': 'Apple Delivers The Quarter Bulls Were Waiting For — Stock Reaches For New Highs',
#    'author': 'Erica Kollmann',
#    'published_utc': '2026-05-01T18:11:41Z',
#    'article_url': 'https://www.benzinga.com/trading-ideas/movers/26/05/52227219/apple-delivers-quarter-bulls-waiting-stock-reaches-for-new-highs?utm_source=benzinga_taxonomy&utm_medium=rss_feed_free&utm_content=taxonomy_rss&utm_campaign=channel',
#    'tickers': 'AAPL',
#    'image_url': 'https://cdn.benzinga.com/files/images/story/2026/05/01/Cupertino--California--September-25--202.jpeg?width=1200&height=800&fit=crop',
#    'description': "Apple's Q2 results exceeded expectations with accelerating iPhone demand, stronger Services growth, and resilient margins. The company guided for 14-17% fiscal Q3 revenue growth and 47.5-48.5% gross margin, both above Street expectations. Stock rallied 4.3% to $282.95, approaching its 52-week high. Analyst sentiment was mostly positive, though some cautioned about valuation, memory cost headwinds, and supply chain execution risks.",
#    'keywords': 'Q2 earnings, iPhone demand, Services growth, gross margin, guidance, iPhone 17, valuation, supply chain, AI strategy',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Strong Q2 earnings beat with accelerating iPhone demand, robust Services growth, better-than-expected margins, and forward guidance significantly above Street expectations. Stock rallied 4.3% and approached 52-week highs. Most analysts maintained bullish ratings with raised price targets, though some noted valuation concerns at 31x earnings and potential supply chain risks.'}],
#    'publisher.name': 'Benzinga',
#    'publisher.homepage_url': 'https://www.benzinga.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/benzinga.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/benzinga.ico',
#    'amp_url': nan},
#   {'id': 'ba815861fa5b33818e9198480fd3b353f0d6fc2b70b408407d3eb6ad89fe7508',
#    'title': "Apple Posts Double Beat In Q2 As Active Installed Base Hits All-Time High — 'Our Best March Quarter Ever'",
#    'author': 'Adam Eckert',
#    'published_utc': '2026-04-30T20:53:26Z',
#    'article_url': 'https://www.benzinga.com/markets/earnings/26/04/52199329/apple-posts-double-beat-in-q2-as-active-installed-base-hits-all-time-high-our-best-march-quarter?utm_source=benzinga_taxonomy&utm_medium=rss_feed_free&utm_content=taxonomy_rss&utm_campaign=channel',
#    'tickers': 'AAPL',
#    'image_url': 'https://cdn.benzinga.com/files/images/story/2026/04/30/Apple-Logo-On-Apple-Store.jpeg?width=1200&height=800&fit=crop',
#    'description': "Apple reported fiscal Q2 2026 revenue of $111.18 billion and EPS of $2.01, both beating analyst estimates. Revenue grew 17% YoY and EPS climbed 22% YoY, driven by strong iPhone 17 demand and record March quarter performance. The company's active installed base hit all-time highs across all product categories. Apple authorized an additional $100 billion share repurchase program and increased its quarterly dividend by 4%. Despite the strong earnings beat, AAPL stock declined 0.50% in after-hours trading.",
#    'keywords': 'earnings beat, revenue growth, iPhone 17, installed base, share buyback, dividend increase, geographic segments',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Apple delivered a double beat on revenue ($111.18B vs. $109.66B estimate) and EPS ($2.01 vs. $1.94 estimate) with strong 17% revenue growth and 22% EPS growth YoY. The company achieved record March quarter results, all-time high installed base, and announced increased shareholder returns through a $100B buyback authorization and 4% dividend increase. However, the stock declined in after-hours trading, suggesting some investor disappointment despite the strong fundamentals.'}],
#    'publisher.name': 'Benzinga',
#    'publisher.homepage_url': 'https://www.benzinga.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/benzinga.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/benzinga.ico',
#    'amp_url': nan},
#   {'id': '4084ca5bfae764259f2d7297246d3f759fa27a8bb835c519cc5034f16045133b',
#    'title': "Apple Continues to Gain Market Share in China. Here's What It Means for Investors.",
#    'author': 'Danny Vena, Cpa',
#    'published_utc': '2026-04-17T19:26:32Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/17/apple-continues-to-gain-market-share-in-china-here/?source=iedfolrf0000001',
#    'tickers': 'AAPL',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F866284%2Fthe-apple-logo-superimposed-over-an-image-of-a-hand-holding-an-iphone.png&w=1200&op=resize',
#    'description': "Apple is gaining significant market share in China despite overall smartphone market decline, with iPhone shipments surging 20% year-over-year in Q1 2026 and achieving record sales. Wall Street's growth estimates appear conservative, suggesting potential upside for investors, though margin pressures from memory costs and discounts warrant monitoring.",
#    'keywords': 'Apple, China market share, iPhone sales, smartphone market, market growth, investor outlook, artificial intelligence, stock valuation',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Apple is gaining market share in China with 20% iPhone shipment growth despite overall market decline, achieved record Q1 sales, and has conservative analyst growth estimates suggesting upside potential. CEO Tim Cook reported 'staggering' demand and 'best iPhone quarter ever in China.' However, margin pressures from memory costs and discounts present a minor headwind."}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': 'eda711c7e770ec0073f2844c19ab9ff076de2132778c1979ff016a8962a79f48',
#    'title': "1 Reason Apple Is Still My Favorite Stock I'd Hand Down to My Grandkids",
#    'author': 'Dave Kovaleski',
#    'published_utc': '2026-04-30T22:30:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/30/1-reason-apple-is-still-my-favorite-stock-id-hand/?source=iedfolrf0000001',
#    'tickers': 'AAPL',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F866563%2Fgettyimages-2191364916.jpg&w=1200&op=resize',
#    'description': "Apple is highlighted as a long-term 'forever stock' with exceptional historical returns (20% annualized since 1980, 29% over the past decade). While its walled garden ecosystem has driven dominance, the article argues that Apple's strongest competitive advantage is its brand loyalty—with 96.4% of iPhone users planning to upgrade to another iPhone and a 92% customer retention rate. Even if regulatory pressures weaken its ecosystem, the author believes Apple's brand strength will sustain investor confidence and stock performance for decades.",
#    'keywords': 'Apple stock, brand loyalty, walled garden ecosystem, long-term investing, customer retention, iPhone loyalty, forever stocks',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "The article presents Apple as an exceptional long-term investment with outstanding historical returns, strong brand loyalty metrics (96.4% iPhone upgrade intent, 92% retention rate, NPS of 61), and argues that its brand strength will sustain dominance even if regulatory pressures weaken its ecosystem. The author recommends it as a 'forever stock' suitable for generational wealth transfer."}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': 'a4b4577482d4aef84b7a8be5dbf28860ea3e84f58c0b3609478e44ebad9b1d01',
#    'title': 'Why Apple Stock Climbed This Week',
#    'author': 'Joe Tenebruso',
#    'published_utc': '2026-05-02T20:19:30Z',
#    'article_url': 'https://www.fool.com/investing/2026/05/02/why-apple-stock-is-up/?source=iedfolrf0000001',
#    'tickers': 'AAPL',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F868489%2Faapl-stock.png&w=1200&op=resize',
#    'description': "Apple stock rose 3.3% this week following strong fiscal Q2 earnings with 17% revenue growth to $111.2 billion, driven by exceptional iPhone 17 demand (22% sales increase) and the new budget-friendly MacBook Neo. The company's high-margin services revenue grew 16% to $31 billion, while net income jumped 19% to $29.6 billion. Apple announced a 4% dividend increase and approved a new $100 billion stock buyback program.",
#    'keywords': 'Apple earnings, iPhone 17 sales, MacBook Neo, services revenue, stock buyback, dividend increase, Q2 fiscal results',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Strong quarterly earnings with 17% revenue growth, 22% iPhone sales surge, expanding services revenue, record net income growth of 19%, and shareholder-friendly actions including dividend increase and $100 billion buyback program demonstrate robust financial health and market demand.'}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': '8a02d28d0a3210e995fffd2bdca0f9772a935b12c232a52f216353e017c371e2',
#    'title': 'Apple Stock Pops On Strong Q3 Guidance: Details',
#    'author': 'Erica Kollmann',
#    'published_utc': '2026-04-30T22:04:02Z',
#    'article_url': 'https://www.benzinga.com/trading-ideas/movers/26/04/52201788/apple-stock-pops-on-strong-q3-guidance-details?utm_source=benzinga_taxonomy&utm_medium=rss_feed_free&utm_content=taxonomy_rss&utm_campaign=channel',
#    'tickers': 'AAPL',
#    'image_url': 'https://cdn.benzinga.com/files/images/story/2026/04/30/Apple-Inc-.jpeg?width=1200&height=800&fit=crop',
#    'description': 'Apple delivered a strong fiscal Q2 earnings beat with $111.18B in revenue (up 17% YoY) and $2.01 EPS, exceeding expectations. The company guided for June-quarter revenue growth of 14-17%, well ahead of Street expectations of ~9%. Apple also announced a 4% dividend increase, $100B in share repurchases, and signaled a shift away from its net cash-neutral balance sheet strategy. The stock rose 3.59% in after-hours trading.',
#    'keywords': 'earnings beat, Q3 guidance, revenue growth, iPhone revenue, Services revenue, gross margin, dividend increase, share repurchases, capital allocation',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Apple exceeded Q2 revenue and earnings estimates, provided strong forward guidance (14-17% growth vs. 9% expected), maintained healthy gross margins, increased dividends by 4%, authorized $100B in buybacks, and achieved record active installed base. CEO highlighted 'best March quarter ever' with double-digit growth across all geographic segments."}],
#    'publisher.name': 'Benzinga',
#    'publisher.homepage_url': 'https://www.benzinga.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/benzinga.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/benzinga.ico',
#    'amp_url': nan},
#   {'id': 'af7a4ac52009473aae621d1056e513ec72afc13211c61bdd0f3ce995accc8cbd',
#    'title': 'Apple TV On Amazon Prime, Store Closures, Foldable iPhone And More: This Week In Appleverse',
#    'author': 'Mohd Haider',
#    'published_utc': '2026-04-12T11:01:21Z',
#    'article_url': 'https://www.benzinga.com/markets/tech/26/04/51770420/apple-tv-on-amazon-prime-store-closures-foldable-iphone-and-more-this-week-in-appleverse?utm_source=benzinga_taxonomy&utm_medium=rss_feed_free&utm_content=taxonomy_rss&utm_campaign=channel',
#    'tickers': 'AAPL, AMZN',
#    'image_url': 'https://cdn.benzinga.com/files/images/story/2026/04/12/Hong-Kong--China---December-10--2016-App.jpeg?width=1200&height=800&fit=crop',
#    'description': "Apple had a busy week with multiple developments: Apple TV launched on Amazon Prime Video as an add-on service for $9.99/month, the company will close three U.S. retail stores in June due to declining mall conditions, and reports confirm Apple's foldable iPhone remains on track for September debut. Despite a 6% global smartphone shipment decline, Apple maintained a strong 21% market share in Q1 2026.",
#    'keywords': 'Apple TV, Amazon Prime Video, retail store closures, foldable iPhone, smartphone market share, Q1 2026',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Apple demonstrated resilience with 21% market share despite industry headwinds, expanded distribution through Amazon Prime partnership, and confirmed foldable iPhone launch on schedule. Store closures are a minor negative offset by stronger strategic moves.'},
#     {'ticker': 'AMZN',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Amazon expanded its Prime Video ecosystem by adding Apple TV as a premium add-on service, enhancing content offerings and creating new revenue streams from existing subscribers.'}],
#    'publisher.name': 'Benzinga',
#    'publisher.homepage_url': 'https://www.benzinga.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/benzinga.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/benzinga.ico',
#    'amp_url': nan},
#   {'id': 'd8bd0eb75e80478bf69223be7597f1d1cd4fe53c89bd5c49b1a95ee41798f020',
#    'title': 'United States Smart TV Market Report 2026-2034: Rising Demand for Streaming and On-Demand Content and Growing Smart Home Integration and Lifestyle Digitalization Spurs Growth',
#    'author': 'Researchandmarkets.Com',
#    'published_utc': '2026-04-29T09:00:00Z',
#    'article_url': 'https://www.globenewswire.com/news-release/2026/04/29/3283502/28124/en/United-States-Smart-TV-Market-Report-2026-2034-Rising-Demand-for-Streaming-and-On-Demand-Content-and-Growing-Smart-Home-Integration-and-Lifestyle-Digitalization-Spurs-Growth.html',
#    'tickers': 'AAPL',
#    'image_url': 'https://ml.globenewswire.com/Resource/Download/66b0b86b-f5d4-4f3f-95e6-44c1141131cc',
#    'description': 'The U.S. Smart TV market is projected to grow from $61.52 billion in 2025 to $149.27 billion by 2034, with a CAGR of 10.35%. Growth is driven by increasing demand for streaming services, technological advancements in display technology (4K, 8K, OLED, QLED), and smart home integration. However, market saturation, longer replacement cycles, and privacy concerns present challenges.',
#    'keywords': 'Smart TV market, streaming services, 4K/8K displays, OLED/QLED technology, smart home integration, market saturation, privacy concerns, display technology',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'Mentioned as a key player in the market analysis, but no specific strategic advantages or challenges highlighted relative to the market growth drivers.'}],
#    'publisher.name': 'GlobeNewswire Inc.',
#    'publisher.homepage_url': 'https://www.globenewswire.com',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/globenewswire.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/globenewswire.ico',
#    'amp_url': nan},
#   {'id': '9aa23553b0a2ed94f9d04822c65cd40a31cb9598fcc50cc57b42f071eb79d3ff',
#    'title': 'Apple’s Engineering Prodigy Takes the Reins',
#    'author': 'Chris Markoch',
#    'published_utc': '2026-04-23T18:35:00Z',
#    'article_url': 'https://www.investing.com/analysis/apples-engineering-prodigy-takes-the-reins-200679054',
#    'tickers': 'AAPL',
#    'image_url': 'https://i-invdn-com.investing.com/redesign/images/seo/investingcom_analysis_og.jpg',
#    'description': "Tim Cook is stepping down as Apple's CEO in September 2026, with John Ternus, the senior vice president of hardware engineering, taking over. Ternus, a 25-year Apple veteran at age 51, is expected to shift the company's focus toward hardware innovation and custom silicon, particularly in AI devices like smart glasses and wearable products. Cook will remain as executive chairman to manage relationships with the U.S. and China.",
#    'keywords': 'CEO transition, John Ternus, Tim Cook, hardware innovation, AI strategy, custom silicon, private AI, product development',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'The appointment of Ternus, a seasoned hardware engineer with 25 years at Apple, signals a strategic shift toward product innovation and custom silicon development. His youth (51) and track record overseeing major products like iPhone Air and MacBook Neo suggest strong leadership continuity. The focus on hardware-first AI strategy and private AI differentiation positions Apple well for future growth, despite past concerns about waning innovation.'}],
#    'publisher.name': 'Investing.com',
#    'publisher.homepage_url': 'https://www.investing.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/investing.png',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/investing.ico',
#    'amp_url': 'https://m.investing.com/analysis/apples-engineering-prodigy-takes-the-reins-200679054?ampMode=1'},
#   {'id': '90dd9f1131112c376f494990a0bbdcd9fbe0a1e32e7a3a02a6695adf02f9b209',
#    'title': 'Apple Taps Johny Srouji For Chief Hardware Officer As John Ternus Prepares To Become CEO',
#    'author': 'Namrata Sen',
#    'published_utc': '2026-04-21T08:25:52Z',
#    'article_url': 'https://www.benzinga.com/markets/tech/26/04/51931001/apple-taps-johny-srouji-for-chief-hardware-officer-as-john-ternus-prepares-to-become-ceo?utm_source=benzinga_taxonomy&utm_medium=rss_feed_free&utm_content=taxonomy_rss&utm_campaign=channel',
#    'tickers': 'AAPL',
#    'image_url': 'https://cdn.benzinga.com/files/images/story/2026/04/21/West-Bangal--India---April-20--2022--App.jpeg?width=1200&height=800&fit=crop',
#    'description': "Apple announced Johny Srouji as its new Chief Hardware Officer, effective immediately, as part of a major leadership restructuring. John Ternus will become CEO in September, replacing Tim Cook who will transition to Executive Chairman after 15 years leading the company. Srouji, who has been with Apple since 2008, was instrumental in developing Apple's in-house chip strategy.",
#    'keywords': 'Apple leadership change, Chief Hardware Officer, CEO transition, Johny Srouji, John Ternus, Tim Cook, executive restructuring',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': "The leadership transition is presented as a planned succession with experienced executives moving into new roles. While leadership changes can create uncertainty, the article emphasizes continuity with Tim Cook remaining as Executive Chairman and Srouji's long tenure and accomplishments at Apple. The stock showed modest gains (1.04% on the day), suggesting market acceptance of the changes."}],
#    'publisher.name': 'Benzinga',
#    'publisher.homepage_url': 'https://www.benzinga.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/benzinga.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/benzinga.ico',
#    'amp_url': nan},
#   {'id': '505884326cea20ae5caa0af8673514434ba00a054bbd13476691ee32149e38e7',
#    'title': '2 Reasons Investors Should Be Excited for the New Apple CEO',
#    'author': 'Catie Hogan',
#    'published_utc': '2026-04-24T20:24:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/24/reasons-investors-excited-for-new-apple-ceo/?source=iedfolrf0000001',
#    'tickers': 'AAPL',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F866696%2Fapple-logo.png&w=1200&op=resize',
#    'description': "John Ternus, a 25-year Apple veteran and senior vice president of Hardware Engineering, has been named to succeed Tim Cook as Apple's CEO starting in September 2026. The article highlights two reasons for investor optimism: Ternus's extensive engineering expertise and fingerprints on Apple's major products, and his potential to refocus the company on product innovation after criticism of lackluster launches under Cook's financially-focused leadership.",
#    'keywords': 'Apple CEO transition, John Ternus, Tim Cook, hardware engineering, product innovation, leadership change',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "The article expresses optimism about Apple's future under new CEO John Ternus, citing his 25 years of engineering expertise and potential to reinvigorate the company's product innovation strategy. The sentiment suggests investor enthusiasm for the leadership transition and expectations for renewed focus on engineering excellence rather than financial optimization."}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': '427912256831db2ee8c343c48c7a4759f50cb39540dff129b79ebff54c278cd4',
#    'title': 'Apple CEO Tim Cook To Step Down In September, John Ternus Will Take Over',
#    'author': 'Erica Kollmann',
#    'published_utc': '2026-04-20T21:08:52Z',
#    'article_url': 'https://www.benzinga.com/trading-ideas/movers/26/04/51927884/apple-ceo-tim-cook-to-step-down-in-september-john-ternus-will-take-over?utm_source=benzinga_taxonomy&utm_medium=rss_feed_free&utm_content=taxonomy_rss&utm_campaign=channel',
#    'tickers': 'AAPL',
#    'image_url': 'https://cdn.benzinga.com/files/images/story/2026/04/20/Tim-Cook--Chief-Executive-Officer-Of-App.jpeg?width=1200&height=800&fit=crop',
#    'description': "Apple announced that CEO Tim Cook will step down and transition to executive chairman on September 1, 2026, with John Ternus, senior vice president of Hardware Engineering, taking over as CEO. Cook will remain in his current role through the summer to ensure a smooth transition. Under Cook's 14-year leadership, Apple's market cap grew from $350 billion to $4 trillion and annual revenue nearly quadrupled to over $416 billion.",
#    'keywords': 'CEO transition, Tim Cook, John Ternus, executive chairman, Apple leadership, hardware engineering',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "The leadership transition is presented as a planned, orderly succession with a qualified internal candidate. Cook's tenure is highlighted with significant achievements (market cap growth from $350B to $4T, revenue growth, product launches). Ternus is described as a 25-year veteran with strong credentials, suggesting continuity and stability. The stock was up 1.04% in regular trading, indicating investor confidence in the transition."}],
#    'publisher.name': 'Benzinga',
#    'publisher.homepage_url': 'https://www.benzinga.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/benzinga.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/benzinga.ico',
#    'amp_url': nan},
#   {'id': '22e6b6b01f03e7d5e598e5d980de1007e6e165fd72fed49fe3d3292446550426',
#    'title': "Tim Cook Says Apple Employment 'Most Significant Discovery': 5 Things You Might Not Know About Departing CEO",
#    'author': 'Chris Katje',
#    'published_utc': '2026-04-21T15:26:20Z',
#    'article_url': 'https://www.benzinga.com/markets/tech/26/04/51944584/tim-cook-says-apple-employment-most-significant-discovery-5-things-you-might-not-know-about-departin?utm_source=benzinga_taxonomy&utm_medium=rss_feed_free&utm_content=taxonomy_rss&utm_campaign=channel',
#    'tickers': 'AAPL',
#    'image_url': 'https://cdn.benzinga.com/files/images/story/2026/04/21/Los-Angeles---Jul-15-Tim-Cook-Arrives-Fo.jpeg?width=1200&height=800&fit=crop',
#    'description': "Apple announced that longtime CEO Tim Cook will step down and transition to executive chairman on September 1, 2026, to be succeeded by John Ternus. The article highlights five key facts about Cook's career, including his education at Auburn and Duke universities, prior work at IBM and Compaq, his 1998 decision to join Apple when it was near bankruptcy, his 2013 public coming out as gay, and a 1996 misdiagnosis of multiple sclerosis that prompted him to prioritize his health.",
#    'keywords': 'Tim Cook, CEO transition, Apple leadership, John Ternus, executive chairman, career highlights',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': "The leadership transition is presented as a planned succession rather than a crisis. Cook's departure is orderly with a clear successor identified, and the article focuses on his accomplishments in growing Apple to nearly $4 trillion market cap, suggesting stability in the transition."}],
#    'publisher.name': 'Benzinga',
#    'publisher.homepage_url': 'https://www.benzinga.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/benzinga.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/benzinga.ico',
#    'amp_url': nan},
#   {'id': '0e865ccfb6a5519ed2d2838fa54b0c03c64b01b4ff668d6f9de2d27f22dd07f0',
#    'title': "Tim Cook's Apple CEO Exit Is Finally Here — And It Changes Everything",
#    'author': 'Erica Kollmann',
#    'published_utc': '2026-04-20T23:27:11Z',
#    'article_url': 'https://www.benzinga.com/markets/tech/26/04/51928847/tim-cooks-apple-ceo-exit-is-finally-here-and-it-changes-everything?utm_source=benzinga_taxonomy&utm_medium=rss_feed_free&utm_content=taxonomy_rss&utm_campaign=channel',
#    'tickers': 'AAPL',
#    'image_url': 'https://cdn.benzinga.com/files/images/story/2026/04/20/Apple-Ceo-Tim-Cook-Attends-The-Grand-Ope.jpeg?width=1200&height=800&fit=crop',
#    'description': "Tim Cook is stepping down as Apple CEO on September 1, 2026, transitioning to executive chairman after building the company from a $350 billion market cap to $4 trillion. John Ternus, a 25-year Apple veteran and hardware engineer, will succeed him as CEO. While Cook's legacy is substantial, investors are split on whether Ternus will drive a hardware renaissance or maintain steady stewardship, with particular pressure on Apple's AI strategy which has been playing catch-up.",
#    'keywords': 'Tim Cook, CEO transition, John Ternus, Apple leadership, AI strategy, hardware innovation, executive chairman',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': "The article presents a mixed outlook. While Cook's legacy is praised (company grew from $350B to $4T market cap), the transition creates uncertainty. Ternus is seen as a capable successor with strong hardware credentials, but investors are divided on whether he can accelerate Apple's lagging AI efforts. The timing of the leadership change amid major AI strategy shifts adds both opportunity and risk."}],
#    'publisher.name': 'Benzinga',
#    'publisher.homepage_url': 'https://www.benzinga.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/benzinga.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/benzinga.ico',
#    'amp_url': nan},
#   {'id': 'a96dcdab66608bfb0329ea7a3e79ee5753ec709f1590d20e97715cde6a2ea658',
#    'title': 'Apple Stock Analysis: Buy or Sell Before April 30?',
#    'author': 'Parkev Tatevosian, Cfa',
#    'published_utc': '2026-04-25T23:00:52Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/25/apple-stock-analysis-buy-or-sell-before-april-30/?source=iedfolrf0000001',
#    'tickers': 'AAPL',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F867313%2Faerial-photo-of-apple-inc-headquarters-in-cupertino-california.jpg&w=1200&op=resize',
#    'description': "Apple has introduced investors to its next CEO, prompting analysis of the company's stock prospects. The leadership transition has generated investor curiosity about Apple's future direction and performance under new management.",
#    'keywords': 'Apple CEO transition, John Ternus, Tim Cook, stock analysis, leadership change, investor sentiment',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Multiple articles referenced in the piece express optimism about Apple's future under new leadership, with headlines indicating investors should be 'excited' for the new CEO and predicting the stock will 'flourish' and 'soar' under the new helm. The leadership transition is being framed as a positive development for the company."}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': '4c0a29782c5f6f7ef350b51a08408203e2d5bc6b2620b4629ecc1063d061f764',
#    'title': "John Ternus Will Become Apple's New CEO in September. Is Now a Good Time to Buy the Stock?",
#    'author': 'Adria Cimino',
#    'published_utc': '2026-04-26T08:05:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/26/john-ternus-will-become-apples-new-ceo-in-septembe/?source=iedfolrf0000001',
#    'tickers': 'AAPL',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F866872%2Faapl-1.png&w=1200&op=resize',
#    'description': "Apple's current senior vice president of hardware engineering John Ternus will become CEO on September 1, 2026, replacing Tim Cook who will transition to executive chairman. The article suggests this could be a positive transition, as Ternus brings product engineering expertise that may help Apple accelerate its AI strategy and innovation, areas where the company has lagged behind competitors. With Cook remaining as executive chairman, the transition is viewed as low-risk.",
#    'keywords': 'CEO transition, John Ternus, Tim Cook, Apple Intelligence, AI strategy, hardware engineering, product innovation, succession planning',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "The article presents the CEO transition as a low-risk opportunity with potential upside. Ternus's hardware engineering background and focus on product innovation could address Apple's weakness in AI adoption and drive future growth. The thoughtful succession planning and Cook's continued presence as executive chairman reduce transition risk, making it a potentially good time to buy the stock."}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': 'e358f970f33f098c5366e6bb2f0a65a25fb95e61edb157001683b0211e5bb5b2',
#    'title': 'Nasdaq Strength Reflects Rate Relief and Easing Inflation Pressures',
#    'author': 'Fiona Cincotta',
#    'published_utc': '2026-04-17T13:33:00Z',
#    'article_url': 'https://www.investing.com/analysis/nasdaq-strength-reflects-rate-relief-and-easing-inflation-pressures-200678690',
#    'tickers': 'NFLX, AAPL',
#    'image_url': 'https://i-invdn-com.investing.com/redesign/images/seo/investingcom_analysis_og.jpg',
#    'description': 'US stocks are set for higher opens with S&P 500 and Nasdaq near record highs, driven by easing inflation concerns and hopes for Middle East peace resolution. Oil prices fell sharply on ceasefire optimism and potential US-Iran talks. Netflix shares dropped 10% despite beating Q1 earnings due to weak Q2 guidance and leadership transition, while Apple benefited from strong China iPhone shipments.',
#    'keywords': 'Nasdaq strength, rate relief, inflation easing, Middle East ceasefire, oil prices decline, Netflix earnings, Apple China sales, Treasury yields, geopolitical uncertainty',
#    'insights': [{'ticker': 'NFLX',
#      'sentiment': 'negative',
#      'sentiment_reasoning': 'Stock fell 10% premarket despite beating Q1 revenue ($12.25B, +16% YoY) and earnings ($1.23 EPS, nearly doubled). Decline driven by weak Q2 guidance (EPS $0.78, revenue $12.57B below expectations) and news that long-time chairman Reed Hastings is stepping down, marking end of an era.'},
#     {'ticker': 'AAPL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'China shipments jumped 20% in Q1, the strongest growth among major vendors despite broader market contraction. Growth driven by sustained demand for iPhone 17, positioning Apple favorably in a competitive market.'}],
#    'publisher.name': 'Investing.com',
#    'publisher.homepage_url': 'https://www.investing.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/investing.png',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/investing.ico',
#    'amp_url': 'https://m.investing.com/analysis/nasdaq-strength-reflects-rate-relief-and-easing-inflation-pressures-200678690?ampMode=1'},
#   {'id': 'e5ff4aa28a661b3d753ec1d90440f2d14756503adfee22ac0e43cfeed615a884',
#    'title': "Nvidia Could Generate More Cash Than Apple, Microsoft Combined — BofA Says It's Time To Pay Shareholders",
#    'author': 'Erica Kollmann',
#    'published_utc': '2026-04-27T17:13:54Z',
#    'article_url': 'https://www.benzinga.com/markets/tech/26/04/52072549/nvidia-could-generate-more-cash-than-apple-microsoft-combined-bofa-says-its-time-to-pay-shareholders?utm_source=benzinga_taxonomy&utm_medium=rss_feed_free&utm_content=taxonomy_rss&utm_campaign=channel',
#    'tickers': 'NVDA, AAPL, MSFT',
#    'image_url': 'https://cdn.benzinga.com/files/images/story/2026/04/27/Nvidia-Earnings.jpeg?width=1200&height=800&fit=crop',
#    'description': 'Bank of America reiterates a Buy rating on Nvidia with a $300 price target, arguing the chip giant trades at a 50% discount to Magnificent 7 peers despite generating over $400 billion in free cash flow across 2026-2027. BofA suggests Nvidia increase shareholder returns through dividends and buybacks, which could broaden ownership among income-focused funds. The firm expects Nvidia to maintain 70%+ AI value share despite intensifying competition.',
#    'keywords': 'Nvidia valuation, free cash flow, shareholder returns, dividend yield, AI competition, semiconductor, price target',
#    'insights': [{'ticker': 'NVDA',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'BofA reiterates Buy rating with $300 price target (43% upside), highlights attractive valuation at 50% discount to peers, projects $400B+ free cash flow, and expects 70%+ AI market share retention despite competition.'},
#     {'ticker': 'AAPL',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'Mentioned as a peer comparison for valuation multiples and dividend yield; used as a benchmark but not the focus of analysis.'},
#     {'ticker': 'MSFT',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'Mentioned as a peer comparison for valuation multiples and dividend yield; used as a benchmark but not the focus of analysis.'}],
#    'publisher.name': 'Benzinga',
#    'publisher.homepage_url': 'https://www.benzinga.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/benzinga.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/benzinga.ico',
#    'amp_url': nan},
#   {'id': '99399dcb443d9cf6e9554a3ed4818b3895441b9a7f945fbe66ccddc53ea9ada9',
#    'title': "Nvidia's Market Cap Could Reach a Shockingly High Level, According to 1 Metric. But Is This Really Possible?",
#    'author': 'Adria Cimino',
#    'published_utc': '2026-04-18T09:05:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/18/according-to-1-metric-nvidias-market-cap-could-rea/?source=iedfolrf0000001',
#    'tickers': 'NVDA, MSFT, AAPL',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F865838%2Fgettyimages-1482246510-1201x675-128554e.jpg&w=1200&op=resize',
#    'description': "Nvidia, currently the world's largest company with a $4.9 trillion market cap, could theoretically reach $22 trillion according to UBS's HOLT valuation model based on its exceptional 73% cash flow return on investment. However, this would represent over a third of the entire S&P 500's $64 trillion value, making it highly unlikely in the near term. Despite this, Nvidia's strong market position, 72% projected revenue growth, and 23x forward earnings valuation suggest the stock still has significant room to grow.",
#    'keywords': 'AI chips, market capitalization, valuation model, HOLT method, cash flow return on investment, earnings growth, tech stocks',
#    'insights': [{'ticker': 'NVDA',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Nvidia dominates the AI chip market with exceptional financial metrics (73% CFROI, >70% gross margin, 72% projected revenue growth), maintains the world's largest market cap position, and shows strong growth prospects with minimal competition impact. Trading at only 23x forward earnings suggests undervaluation relative to its market position and prospects."},
#     {'ticker': 'MSFT',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'Mentioned as a major tech competitor that previously held the No. 1 market cap position but has been surpassed by Nvidia. No specific positive or negative developments are discussed regarding Microsoft.'},
#     {'ticker': 'AAPL',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'Mentioned as a major tech competitor that previously held the No. 1 market cap position but has been surpassed by Nvidia. No specific positive or negative developments are discussed regarding Apple.'}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': '182735fe1965c84844bf200f76b2e54e13bd8df8425d4bf647c20e0497cefd78',
#    'title': "Netflix Stock Is Down, and It Could Get Worse. Here's Why Shares Could Fall Even More.",
#    'author': 'Daniel Sparks',
#    'published_utc': '2026-04-17T02:21:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/16/netflix-stock-is-down-and-it-could-get-worse-heres/?source=iedfolrf0000001',
#    'tickers': 'NFLX, AAPL',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F866123%2Fnetflix-nflx-stock.jpg&w=1200&op=resize',
#    'description': "Netflix's stock fell after reporting Q1 2026 earnings despite strong profitability, as revenue growth decelerated to 16.2% from 17.6% in the prior quarter. Management forecasts further slowdown with Q2 growth expected at 13.5% and full-year growth of 12-14%. At a 32x P/E ratio, the stock appears overvalued for a maturing business facing intense competition from well-capitalized tech giants. The analyst suggests shares could fall 30% to around $68 if the P/E multiple contracts to a more reasonable 22x, reflecting the company's slowing growth trajectory.",
#    'keywords': 'streaming, revenue growth deceleration, valuation risk, competitive pressure, earnings, content costs, subscriber growth',
#    'insights': [{'ticker': 'NFLX',
#      'sentiment': 'negative',
#      'sentiment_reasoning': "Revenue growth is decelerating (16.2% to 13.5% expected), the stock trades at a premium 32x P/E ratio that leaves no margin of safety, and intensifying competition from well-capitalized rivals threatens margins. The analyst projects potential 30% downside if valuation normalizes, and warns that the company's maturing profile in a crowded market poses significant risk."},
#     {'ticker': 'AAPL',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': "Apple is mentioned as a competitive threat to Netflix, having secured exclusive Formula 1 streaming rights and bundling Apple TV with other services. While this demonstrates Apple's aggressive content strategy, the article does not provide specific investment commentary on Apple itself."}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': 'a9b353bcc8310e27c2fc39a53af8d70135db2ed149436ad3ea82ef0515a7ba30',
#    'title': 'Tesla Margins and Cash Flow Offset Revenue Miss in Q1 Results',
#    'author': 'Itai Smidt',
#    'published_utc': '2026-04-27T17:50:00Z',
#    'article_url': 'https://www.investing.com/analysis/tesla-margins-and-cash-flow-offset-revenue-miss-in-q1-results-200679224',
#    'tickers': 'TSLA, NVDA, AAPL',
#    'image_url': 'https://i-invdn-com.investing.com/redesign/images/seo/investingcom_analysis_og.jpg',
#    'description': 'Tesla missed Q1 revenue expectations at $22.39B vs $22.64B consensus, but impressed with margin expansion to 21.1% GAAP gross margin and strong free cash flow of $1.44B (up 117% YoY). The company raised CapEx guidance to $25B for fiscal 2026 to fund AI infrastructure, Optimus humanoid robot production, and a $2B SpaceX investment. Key catalysts include Optimus Gen 3 mass production starting late July 2026 and expanding Robotaxi operations, though execution risks remain.',
#    'keywords': 'Q1 earnings, gross margin expansion, free cash flow, capital expenditure, Optimus humanoid robot, Robotaxi, energy storage, Full Self-Driving subscriptions, SpaceX investment, AI infrastructure',
#    'insights': [{'ticker': 'TSLA',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Despite missing revenue expectations, Tesla delivered strong profitability metrics with 21.1% GAAP gross margin (up 1 percentage point QoQ), 83% YoY operating cash flow growth, and 117% YoY free cash flow growth. The energy segment showed exceptional 39.5% margins. Key catalysts include Optimus production starting late July 2026 and expanding high-margin recurring revenue streams (FSD subscriptions at 1.3M, $4B deferred revenue). The $25B CapEx increase signals confidence in long-term transformation despite near-term cash flow headwinds.'},
#     {'ticker': 'NVDA',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': "Mentioned only as a comparison point for market cap growth over the past decade, where Tesla ranks second only to Nvidia. No specific analysis of Nvidia's business or performance provided in the article."},
#     {'ticker': 'AAPL',
#      'sentiment': 'neutral',
# ...
#    'author': 'Sweta Killa',
#    'published_utc': '2026-05-05T08:42:38Z',
#    'article_url': 'https://www.benzinga.com/markets/tech/26/05/52273074/apple-eyes-us-chip-production-with-intel-samsung-to-reduce-tsmc-reliance-report?utm_source=benzinga_taxonomy&utm_medium=rss_feed_free&utm_content=taxonomy_rss&utm_campaign=channel',
#    'tickers': 'AAPL, INTC, TSM',
#    'image_url': 'https://cdn.benzinga.com/files/images/story/2026/05/05/New-York---July-21-Apple-Store-On-Fifth-_1.jpeg?width=1200&height=800&fit=crop',
#    'description': "Apple is in early-stage talks with Intel and Samsung to diversify its chip manufacturing away from TSMC dependence. The company has visited Samsung's Texas facility and discussed Intel's foundry services, though no orders have been placed yet. The move is driven by supply chain challenges that affected iPhone sales, though Apple has concerns about reliability and scalability of non-TSMC technologies.",
#    'keywords': 'chip manufacturing, supply chain diversification, foundry services, semiconductor production, US manufacturing',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'Apple is taking proactive steps to address supply chain risks, which is positive, but the talks are preliminary with no confirmed orders. The company reported strong Q2 results and record installed base, but faces ongoing supply constraints.'},
#     {'ticker': 'INTC',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Intel is being considered as a potential foundry partner for Apple's chip production, representing a significant business opportunity if talks progress to actual orders."},
#     {'ticker': 'TSM',
#      'sentiment': 'negative',
#      'sentiment_reasoning': "Apple is actively seeking to reduce its reliance on TSMC as the primary chip supplier, indicating a shift away from the company despite its current dominance in Apple's supply chain."}],
#    'publisher.name': 'Benzinga',
#    'publisher.homepage_url': 'https://www.benzinga.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/benzinga.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/benzinga.ico',
#    'amp_url': nan},
#   {'id': 'acc10ac7a7907e25d7dcba1078dcd0f372ffdc07cdc105fc10268b0e432bd1d0',
#    'title': 'This Is the Smartest Artificial Intelligence (AI) Stock to Buy With $500 Right Now',
#    'author': 'James Hires',
#    'published_utc': '2026-04-11T19:30:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/11/this-is-the-smartest-artificial-intelligence-ai-st/?source=iedfolrf0000001',
#    'tickers': 'GOOG, GOOGL, AAPL, NVDA',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F862136%2Fgettyimages-22212319621.jpg&w=1200&op=resize',
#    'description': "Alphabet is recommended as a comprehensive AI investment option due to its dual presence in both AI software (Google Gemini) and hardware (TPU chips). Gemini has grown from 7% to 21% market share in enterprise LLMs and is expected to overtake ChatGPT. The company's TPU hardware competes with Nvidia's GPUs and powers competitors like Anthropic and OpenAI. With $402.8B in 2025 revenue (15% growth), 32.8% net profit margin, and strong financial health, Alphabet offers a stable, all-in-one AI play.",
#    'keywords': 'artificial intelligence, AI stocks, Google Gemini, TPU hardware, enterprise LLM market, AI investment',
#    'insights': [{'ticker': 'GOOG',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Positioned as a strong all-in-one AI play with competitive advantages in both software (Gemini growing market share) and hardware (TPU chips). Strong financial metrics including 15% revenue growth, 32.8% net profit margin, and low debt-to-equity ratio support stability and profitability.'},
#     {'ticker': 'GOOGL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Positioned as a strong all-in-one AI play with competitive advantages in both software (Gemini growing market share) and hardware (TPU chips). Strong financial metrics including 15% revenue growth, 32.8% net profit margin, and low debt-to-equity ratio support stability and profitability.'},
#     {'ticker': 'AAPL',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'Mentioned as a Magnificent Seven peer that partnered with Alphabet to use Google Gemini for its AI program, converting a potential competitor into a customer.'},
#     {'ticker': 'NVDA',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': "Referenced as the incumbent hardware competitor whose GPU technology is being challenged by Alphabet's TPU chips in the AI infrastructure market."}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': '2107b3444accf88f983110d979e89e0961b3442787525dcf5118834d24a00a8e',
#    'title': 'Apple Earnings Preview: Can It Keep Winning? Cook’s Final Quarter Steals Focus',
#    'author': 'Ali Merchant',
#    'published_utc': '2026-04-30T17:27:00Z',
#    'article_url': 'https://www.investing.com/analysis/apple-earnings-preview-can-it-keep-winning-cooks-final-quarter-steals-focus-200679462',
#    'tickers': 'AAPL, AMZN, META, MSFT, GOOG, GOOGL',
#    'image_url': 'https://i-invdn-com.investing.com/redesign/images/seo/investingcom_analysis_og.jpg',
#    'description': 'Apple reports Q2 2026 earnings on April 30, with Wall Street expecting $109.46B in revenue and $1.95 EPS. Key focus is on whether Apple Intelligence can drive sustained iPhone upgrade cycles and the impact of CEO succession as John Ternus takes over from Tim Cook in September. Services segment growth and iPhone 17 demand, particularly in China, will be closely watched.',
#    'keywords': 'Apple earnings, Q2 2026, CEO succession, Apple Intelligence, iPhone 17, Services segment, Tim Cook, John Ternus',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Strong analyst expectations with Bernstein/SocGen and Evercore ISI maintaining Outperform ratings ($340 and $330 price targets respectively). Expected revenue growth of 14.7% YoY, positive iPhone momentum in China, and high-margin services business showing double-digit growth. Historical seasonality shows May closes up 3.95% on average.'},
#     {'ticker': 'AMZN',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'Mentioned as part of recent tech earnings wave but no specific analysis or commentary provided in the article.'},
#     {'ticker': 'META',
#      'sentiment': 'negative',
#      'sentiment_reasoning': 'Mentioned in context of recent tech earnings and noted in market movers as declining 8.35% with JPM downgrade cited in related headlines regarding rising capex concerns.'},
#     {'ticker': 'MSFT',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'Mentioned as part of recent tech earnings wave but no specific analysis provided. Related headline notes concerns about OpenAI exposure and capex outlook.'},
#     {'ticker': 'GOOG',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Mentioned as part of recent tech earnings and shown in market data with significant gains of 9.79%, with related headline noting AI and cloud boom after earnings beat expectations.'},
#     {'ticker': 'GOOGL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Mentioned as part of recent tech earnings and shown in market data with significant gains of 9.79%, with related headline noting AI and cloud boom after earnings beat expectations.'}],
#    'publisher.name': 'Investing.com',
#    'publisher.homepage_url': 'https://www.investing.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/investing.png',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/investing.ico',
#    'amp_url': 'https://m.investing.com/analysis/apple-earnings-preview-can-it-keep-winning-cooks-final-quarter-steals-focus-200679462?ampMode=1'},
#   {'id': '8a50dc8bf05164f3fbe2cae4e994ef677cd0547094c01fe5de5d443b0b552df8',
#    'title': 'S&P 500 Extends Rally as Market Targets Next Major Milestone',
#    'author': 'Gregor Horvat',
#    'published_utc': '2026-04-23T07:14:00Z',
#    'article_url': 'https://www.investing.com/analysis/sp-500-extends-rally-as-market-targets-next-major-milestone-200679015',
#    'tickers': 'AAPL, NVDA, MSFT, AMZN',
#    'image_url': 'https://i-invdn-com.investing.com/redesign/images/seo/investingcom_analysis_og.jpg',
#    'description': 'The S&P 500 has broken decisively above 6620 and is in a new recovery phase with an impulsive advance pattern suggesting five subwaves. The market has recovered from the 6500 support level, indicating wave four completion, with wave five now in progress targeting 7200. Support levels are at 6,852 and 7,000.',
#    'keywords': 'S&P 500, market rally, technical analysis, wave analysis, support levels, recovery phase',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Stock is up 2.63% with strong trading volume (43.25M), indicating positive market sentiment and participation in the broader market rally.'},
#     {'ticker': 'NVDA',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Stock is up 1.31% with the highest trading volume (107.50M) among listed stocks, showing strong investor interest and participation in the market advance.'},
#     {'ticker': 'MSFT',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Stock is up 2.07% with solid trading volume (29.38M), contributing to the broader market rally.'},
#     {'ticker': 'AMZN',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Stock is up 2.18% with strong trading volume (not specified but listed among top movers), participating in the market's upward momentum."}],
#    'publisher.name': 'Investing.com',
#    'publisher.homepage_url': 'https://www.investing.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/investing.png',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/investing.ico',
#    'amp_url': 'https://m.investing.com/analysis/sp-500-extends-rally-as-market-targets-next-major-milestone-200679015?ampMode=1'},
#   {'id': '4e542033d60c36e45882a93d25090f36543aa88d3426892cdd34fa6ff652a6fe',
#    'title': 'Will Bitcoin Ever Be More Valuable Than Apple? You Might Be Surprised at What Prediction Markets Say.',
#    'author': 'Dominic Basulto',
#    'published_utc': '2026-05-04T06:30:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/05/04/will-bitcoin-ever-be-more-valuable-than-apple-you/?source=iedfolrf0000001',
#    'tickers': 'AAPL, COIN',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F867910%2Finvestor-on-top-of-pile-of-money.jpg&w=1200&op=resize',
#    'description': "Bitcoin ($1.5T) currently lags Apple ($4T) in market cap, with prediction markets giving Bitcoin only a 7% chance of surpassing Apple before 2027. Bitcoin's best path forward involves becoming the cryptocurrency for AI agent micro-transactions using Satoshis. However, competitors like Coinbase's stablecoin on Base blockchain also pursue this use case. The article emphasizes that AI adoption is critical for valuation in the current market.",
#    'keywords': 'Bitcoin, Apple, market cap, AI agents, micro-transactions, prediction markets, cryptocurrency, Satoshis',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'Apple is valued at $4T but faces potential challenges from AI-focused competitors and concerns about incremental innovation post-Tim Cook. The article suggests Apple could lose valuation if it fails to deliver breakthrough AI products, presenting a balanced view of risks and current dominance.'},
#     {'ticker': 'COIN',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Coinbase is highlighted as actively experimenting with stablecoin transactions for AI agents using its proprietary Base blockchain, positioning it as a competitive player in the emerging AI-crypto ecosystem.'}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': '56590b4d6243a2996272b073c5342eb78e075342e3c26baa4f0f858a92817482',
#    'title': 'Apple Just Gave Investors a $100 Billion Reason to Rethink the AI Spending Race',
#    'author': 'Daniel Sparks',
#    'published_utc': '2026-05-04T11:08:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/05/04/apple-just-gave-investors-a-100-billion-reason-to/?source=iedfolrf0000001',
#    'tickers': 'AAPL, AMZN, GOOG, GOOGL, META',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F868559%2Fapple-stock-aapl-2026.jpg&w=1200&op=resize',
#    'description': 'Apple authorized an additional $100 billion share repurchase program while maintaining disciplined capital expenditures of only $4.3 billion in the first half of fiscal 2026. Unlike competitors investing hundreds of billions in AI infrastructure, Apple pursues a less capital-intensive edge-based AI strategy. The company reported strong fiscal Q2 results with 17% revenue growth, 22% EPS growth, and generated $82 billion in operating cash flow, returning $45 billion to shareholders through dividends and buybacks.',
#    'keywords': 'share buyback, capital expenditures, AI infrastructure, free cash flow, shareholder returns, iPhone sales, fiscal Q2 earnings, edge AI, dividend increase',
#    'insights': [{'ticker': 'AAPL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Strong fiscal Q2 results with 17% revenue growth, 22% EPS growth, record iPhone revenue of $57 billion, and record services revenue of $31 billion. Disciplined capital allocation with only $4.3 billion capex while returning $45 billion to shareholders. Broad-based geographic growth including 28% growth in Greater China. Positive forward guidance of 14-17% revenue growth for Q3.'},
#     {'ticker': 'AMZN',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'Mentioned as a competitor planning $200 billion in capital expenditures for 2026 focused on AI infrastructure. No specific performance data provided; mentioned only for comparison of different AI investment strategies.'},
#     {'ticker': 'GOOG',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'Mentioned as a competitor guiding to $180-190 billion in capital expenditures for AI infrastructure. Also noted as a partnership partner with Apple for Gemini-powered Siri. No specific performance data provided; mentioned for comparison of AI spending strategies.'},
#     {'ticker': 'GOOGL',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'Mentioned as a competitor guiding to $180-190 billion in capital expenditures for AI infrastructure. Also noted as a partnership partner with Apple for Gemini-powered Siri. No specific performance data provided; mentioned for comparison of AI spending strategies.'},
#     {'ticker': 'META',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'Mentioned as a competitor anticipating $125-145 billion in capital expenditures for AI infrastructure. No specific performance data provided; mentioned only for comparison of different AI investment strategies.'}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan}]}

# %%
# Cell 9: Test search_news_by_query - Placeholder                                                                                                                   
print("="*80)                                                                                                                                                       
print("8. search_news_by_query('AI stocks')")                                                                                                                       
print("TRANSFORMATION: None - placeholder for NewsAPI/Polygon.io")                                                                                                  
print("="*80)                                                                                                                                                       
                                                                                                                                                                    
query_news = search_news_by_query('AI stocks')                                                                                                                      
query_news
# Out:
# ================================================================================
# 8. search_news_by_query('AI stocks')
# TRANSFORMATION: None - placeholder for NewsAPI/Polygon.io
# ================================================================================
# {'query': 'AI stocks',
#  'count': 30,
#  'data': [{'id': '46cea606c9be0a785c61db3d33cfab3980095a8a2711eafe7a81747813d227de',
#    'title': '5 Stocks to Buy if AI Investing Comes Back Into Style',
#    'author': 'Keithen Drury',
#    'published_utc': '2026-04-15T19:37:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/15/5-stocks-if-ai-investing-comes-back-into-style/?source=iedfolrf0000001',
#    'tickers': 'NVDA, AVGO, TSM, SOUN, SOUNW, NBIS',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F865278%2Fperson-smiling-while-looking-at-a-tablet.jpg&w=1200&op=resize',
#    'description': 'The article identifies five AI stocks positioned to benefit if AI investing regains momentum after a weak start to 2026. The recommended stocks are Nvidia (strong growth projections), Broadcom (custom AI chips), Taiwan Semiconductor (critical supply chain player), SoundHound AI (recovery opportunity), and Nebius (rapid expansion in AI infrastructure).',
#    'keywords': 'AI investing, semiconductor stocks, chip manufacturers, AI infrastructure, growth stocks, technology sector',
#    'insights': [{'ticker': 'NVDA',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Accelerating revenue growth (73% past quarter, 79-85% expected), trading at attractive 23x forward earnings valuation, positioned as top AI investment with strong outlook for 2026.'},
#     {'ticker': 'AVGO',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Custom AI chip partnerships with hyperscalers expected to generate $100B+ annual revenue by end of 2027 (triple current levels), benefiting from same AI tailwinds as Nvidia despite higher valuation.'},
#     {'ticker': 'TSM',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Critical foundry in AI supply chain with March revenue up 45% year-over-year (fastest pace in first three months), demonstrating strong AI infrastructure buildout demand.'},
#     {'ticker': 'SOUN',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Down 70% from all-time high presenting recovery opportunity, revenue rising 58% year-over-year with strong Q4 results, positioned for upside if AI sector rebounds.'},
#     {'ticker': 'SOUNW',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Down 70% from all-time high presenting recovery opportunity, revenue rising 58% year-over-year with strong Q4 results, positioned for upside if AI sector rebounds.'},
#     {'ticker': 'NBIS',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Neocloud company at all-time high with 400%+ gains since 2025, Wall Street expects 522% revenue growth in 2026 and 195% in 2027 driven by massive data center expansion.'}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': 'ab675b0ea45ec16a6683fd95f1bab87debe3d454cadd2841c7c8ad7a89cac995',
#    'title': 'The Smartest Growth Stocks to Invest $1,000 in As Investors Rotate Out of Tech',
#    'author': 'Harsh Chauhan',
#    'published_utc': '2026-04-11T16:25:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/11/the-smartest-growth-stocks-to-invest-1000-in-as-in/?source=iedfolrf0000001',
#    'tickers': 'NVDA, GOOG, GOOGL, META',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F862736%2Fnvidia-headquarters-outside-with-black-nvidia-sign-with-nvidia-logo.jpg&w=1200&op=resize',
#    'description': 'As investors rotate away from tech stocks, the sector has become undervalued according to Morningstar. The article recommends buying Nvidia and Alphabet during this downturn, citing strong AI-driven growth prospects. Nvidia is positioned to benefit from agentic AI and physical AI adoption, while Alphabet is leveraging AI to expand its advertising business in a growing digital ad market.',
#    'keywords': 'tech stocks, AI revolution, agentic AI, physical AI, undervalued stocks, growth stocks, digital advertising',
#    'insights': [{'ticker': 'NVDA',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Stock is down 5% despite strong earnings and AI growth drivers. Trading at attractive 22x forward earnings with 49% upside potential to $265 price target. Positioned to benefit from agentic AI and physical AI market expected to grow 10x by 2032.'},
#     {'ticker': 'GOOG',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Down 5% this year but trading at reasonable 26x forward earnings. Strong AI integration in advertising business with digital ad market expected to reach $1.4 trillion by decade's end. Additional growth opportunities in cloud computing and custom AI processors."},
#     {'ticker': 'GOOGL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Down 5% this year but trading at reasonable 26x forward earnings. Strong AI integration in advertising business with digital ad market expected to reach $1.4 trillion by decade's end. Additional growth opportunities in cloud computing and custom AI processors."},
#     {'ticker': 'META',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'Mentioned as investing in compute capacity for agentic AI systems but not recommended as a primary investment in this article.'}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': 'a78a516150f17825114890af98fd480b05ca287a20edc3823a115b7fb02694af',
#    'title': 'The Nasdaq Is Surging Back Toward All-Time Highs. Is Now the Best Time to Buy Artificial Intelligence (AI) Growth Stocks?',
#    'author': 'Adria Cimino',
#    'published_utc': '2026-04-27T08:05:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/27/the-nasdaq-is-surging-back-toward-all-time-highs-i/?source=iedfolrf0000001',
#    'tickers': 'NVDA, PLTR, TSM',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F865875%2Ftime-to-buy-investing.jpg&w=1200&op=resize',
#    'description': 'The Nasdaq has rebounded to all-time highs after recent market turbulence caused by geopolitical tensions and concerns about tech spending on AI. While AI stocks have reached historically expensive valuations, recent selloffs have created bargain opportunities. With strong demand signals from chip manufacturers and early real-world AI applications emerging, analysts suggest now may be a good time to buy quality AI stocks at reasonable prices.',
#    'keywords': 'Nasdaq, AI stocks, market recovery, valuations, geopolitical uncertainty, AI demand, growth stocks',
#    'insights': [{'ticker': 'NVDA',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Described as 'AI chip leader' with triple-digit gains over years. Recently trading near cheapest level in a year, presenting a bargain opportunity despite strong long-term fundamentals."},
#     {'ticker': 'PLTR',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Highlighted as major AI software winner with quadruple-digit gains. Though valuations reached extreme levels (240x forward earnings), recent market turbulence has created more reasonable entry points.'},
#     {'ticker': 'TSM',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Cited as leading chip manufacturer with direct visibility into strong AI demand from cloud service providers. Recent earnings confirmation of exploding customer demand supports positive AI growth outlook.'}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': '0f08bbeec4424237c5015bc36f4e98992456c092e879ea5e40e6f32a1bf04143',
#    'title': '3 Dividend-Paying AI Stocks for 2026',
#    'author': 'James Brumley',
#    'published_utc': '2026-04-13T18:30:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/13/3-dividend-paying-ai-stocks-for-2026/?source=iedfolrf0000001',
#    'tickers': 'QCOM, ORCL, ORCLpD, BKH, NVDA, CEG',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F861672%2Fai-robot.jpg&w=1200&op=resize',
#    'description': 'The article highlights three AI-related dividend-paying stocks: Qualcomm, which is expanding into mobile AI processors and data centers with a 2.9% dividend yield; Oracle, which is investing heavily in AI infrastructure despite recent stock weakness, with potential for strong future growth; and Black Hills, a utility positioned to benefit from AI data center demand in the Mountain West region with a 3.7% dividend yield.',
#    'keywords': 'AI stocks, dividend stocks, Qualcomm, Oracle, Black Hills, data centers, AI processors, dividend yield',
#    'insights': [{'ticker': 'QCOM',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Company is expanding into AI processor market with Snapdragon mobile processors and data center chips. Expected industry growth of 26% annually through 2034, with 23-year dividend growth streak and 2.9% yield.'},
#     {'ticker': 'ORCL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Despite recent 50% stock decline and heavy $50B infrastructure spending, company has strong long-term growth prospects with revenue expected to grow from $67B to $225B by 2030, driven by AI cloud infrastructure. Dividend has grown 130% over 10 years.'},
#     {'ticker': 'ORCLpD',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Despite recent 50% stock decline and heavy $50B infrastructure spending, company has strong long-term growth prospects with revenue expected to grow from $67B to $225B by 2030, driven by AI cloud infrastructure. Dividend has grown 130% over 10 years.'},
#     {'ticker': 'BKH',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Utility company positioned to benefit from AI data center growth due to geographic advantages in Wyoming/Colorado region with fiber connectivity and cooling capabilities. High 3.7% dividend yield and 56-year dividend increase streak. Upcoming merger with NorthWestern Energy expected to improve efficiency.'},
#     {'ticker': 'NVDA',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'Mentioned as dominant AI hardware player but not recommended as alternative to the three featured stocks in this article.'},
#     {'ticker': 'CEG',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'Mentioned as comparable utility benefiting from AI data center electricity demand but not featured as primary recommendation.'}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': '68ca05551b7d6c07ce344b7b5d1e6e6552a028999b32b404665e90b9243c4663',
#    'title': 'The 4 Best AI Stocks to Buy in May',
#    'author': 'Keithen Drury',
#    'published_utc': '2026-05-01T19:27:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/05/01/the-4-best-ai-stocks-to-buy-in-may/?source=iedfolrf0000001',
#    'tickers': 'NVDA, AVGO, TSM, NBIS',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F867612%2Felder-person-planting-flowers-with-their-grandchild.jpg&w=1200&op=resize',
#    'description': 'The article recommends four AI stocks for May 2026: Nvidia, Broadcom, Taiwan Semiconductor, and Nebius. Nvidia continues to benefit from strong GPU demand with projected 72% revenue growth. Broadcom is seeing massive growth in custom AI chips with its AI division generating $8.4B in Q1. Taiwan Semiconductor expects mid-to-high-50% CAGR growth in AI chips through 2029 and raised full-year guidance to 30%. Nebius, an AI-first cloud computing company, is projected to grow revenue 523% in 2026 and 206% in 2027.',
#    'keywords': 'AI stocks, semiconductor, GPU demand, custom AI chips, cloud computing, data centers, hyperscalers',
#    'insights': [{'ticker': 'NVDA',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Strong growth catalyst with 72% projected revenue growth, high GPU demand from hyperscalers, and attractive valuation at 26x forward earnings. Stock positioned above $5 trillion market cap with years of data center completion ahead.'},
#     {'ticker': 'AVGO',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Massive growth in custom AI chip division with 106% YoY growth in Q1, CEO projects business will exceed $100B in 2027. Positioned as key partner for hyperscalers designing ASICs.'},
#     {'ticker': 'TSM',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Strong beneficiary of AI build-out with mid-to-high-50% CAGR projected for AI chip revenue through 2029. Recently raised full-year 2026 guidance to 30% growth, indicating stronger-than-expected AI demand.'},
#     {'ticker': 'NBIS',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Exceptional growth projections with 523% revenue growth expected in 2026 and 206% in 2027. AI-first cloud computing services gaining rapid adoption, offering maximum upside potential.'}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': 'b6fbde4b955fadb9a1b13aba39396ede1dd3775f0afe6130e8a8ef01487471cc',
#    'title': 'Why This Week Could Be Huge For AI Stocks',
#    'author': 'Jeremy Bowman',
#    'published_utc': '2026-04-28T05:30:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/28/why-this-week-could-be-huge-for-ai-stocks/?source=iedfolrf0000001',
#    'tickers': 'GOOG, GOOGL, MSFT, AMZN, META, AAPL, INTC, NVDA, AMD, TSM, ARM, MU, SOXX',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F867472%2Fman-reading-newspaper.jpg&w=1200&op=resize',
#    'description': "AI stocks surged following Intel's strong earnings report, with major tech companies (Alphabet, Microsoft, Amazon, Meta, Apple) set to report earnings this week. These hyperscalers are investing heavily in AI infrastructure and cloud computing, with combined capex of ~$700 billion expected this year. Strong earnings results and signs of AI adoption could drive further gains in AI and semiconductor stocks.",
#    'keywords': 'AI stocks, earnings reports, Magnificent Seven, hyperscalers, AI adoption, semiconductor demand, cloud computing, capital expenditure',
#    'insights': [{'ticker': 'GOOG',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Positioned as the most diversified AI company with leading foundational model (Gemini), AI chips (TPUs), large cloud division, and Waymo autonomous driving business. Stock has soared over the past year and is now the most valuable hyperscaler.'},
#     {'ticker': 'GOOGL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Positioned as the most diversified AI company with leading foundational model (Gemini), AI chips (TPUs), large cloud division, and Waymo autonomous driving business. Stock has soared over the past year and is now the most valuable hyperscaler.'},
#     {'ticker': 'MSFT',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Seen as early AI leader with strong recent results. Investors should focus on cloud growth and AI adoption signals through Copilot and Azure OpenAI integrations, despite previous concerns about weak Copilot adoption.'},
#     {'ticker': 'AMZN',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Major hyperscaler investing heavily in AI compute and cloud infrastructure with ~$700 billion combined capex planned. Earnings report expected this week could signal strong AI adoption.'},
#     {'ticker': 'META',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'One of the biggest hyperscalers investing heavily in AI compute and cloud computing infrastructure. Earnings report expected this week could demonstrate AI adoption progress.'},
#     {'ticker': 'AAPL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Major hyperscaler with significant AI infrastructure investments. Earnings report on April 30 could provide insights into AI adoption and capex plans.'},
#     {'ticker': 'INTC',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Blew past Q1 estimates and provided strong Q2 guidance. Report confirmed CPU demand surge due to agentic AI, lifting the entire semiconductor sector.'},
#     {'ticker': 'NVDA',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Major chip supplier to hyperscalers. Strong earnings from big tech companies could drive further semiconductor sector gains and continued chip demand.'},
#     {'ticker': 'AMD',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Lifted by Intel's strong report signaling CPU demand surge from agentic AI. Benefits from increased chip demand across the sector."},
#     {'ticker': 'TSM',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Jumped 5% following Intel's report signaling strong chip demand. Major supplier benefiting from AI-driven semiconductor demand."},
#     {'ticker': 'ARM',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Lifted by double digits following Intel's strong earnings report confirming CPU demand surge from agentic AI."},
#     {'ticker': 'MU',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Major chip supplier to hyperscalers. Benefits from strong AI adoption and continued demand for semiconductor components.'},
#     {'ticker': 'SOXX',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Gained 5% following Intel's report. Holds top AI chip stocks and benefits from broad semiconductor sector strength driven by AI demand."}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': '5610a6a5004cdbc4bc094795d2ec9c5218f1795f556140511496c319a1418349',
#    'title': '3 AI Stocks Crushing Nvidia This Year',
#    'author': 'Keithen Drury',
#    'published_utc': '2026-05-03T10:30:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/05/03/3-ai-stocks-crushing-nvidia-this-year/?source=iedfolrf0000001',
#    'tickers': 'NVDA, CRWV, NBIS, APLD',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F867608%2Fperson-looking-at-computer-screen-in-shock.jpg&w=1200&op=resize',
#    'description': 'CoreWeave, Nebius, and Applied Digital have significantly outperformed Nvidia in 2026, with gains of 65%, 80%, and 37% respectively. All three companies provide AI infrastructure services and are backed by strong growth projections, though they remain unprofitable unlike Nvidia. The article notes these stocks carry higher risk due to their focus on growth over current profitability.',
#    'keywords': 'AI stocks, GPU computing infrastructure, cloud computing, data centers, AI training, growth stocks, profitability',
#    'insights': [{'ticker': 'NVDA',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'While Nvidia has underperformed compared to the three featured stocks with only 7% gains, it remains profitable and is a major shareholder in CoreWeave and Nebius, indicating confidence in the AI infrastructure space. The article positions it as a safer but less exciting investment.'},
#     {'ticker': 'CRWV',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Stock up 65% in 2026 with projected 143% revenue growth in 2026 and 89% in 2027. Provides GPU computing infrastructure for AI training with major hyperscaler clients. Nvidia's significant ownership stake validates the investment thesis."},
#     {'ticker': 'NBIS',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Stock up 80% in 2026 with exceptional projected growth of 523% in 2026 and 206% in 2027. Offers full-stack AI-first cloud computing infrastructure. Also a Nvidia holding, indicating strong confidence in the business model.'},
#     {'ticker': 'APLD',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Stock up 37% in 2026 with 139% revenue growth in the most recent quarter. Operates a successful data center landlord model for cloud companies. Despite Nvidia selling its stake in Q4, the company continues to deliver strong performance.'}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': '0c6d418765bc56a9cc3323656510e365933b360a7313fbaaf92bb7c32017a146',
#    'title': '2 AI Stocks With 85% and 70% Upside to Buy During a Software Bear Market',
#    'author': 'Geoffrey Seiler',
#    'published_utc': '2026-04-26T01:05:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/25/2-ai-stocks-with-85-and-70-upside-to-buy-during-so/?source=iedfolrf0000001',
#    'tickers': 'NOW, CRM, PLTR, BABA',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F867029%2Fgettyimages-1489971344.jpg&w=1200&op=resize',
#    'description': "While SaaS stocks have been hammered due to AI concerns, ServiceNow and Salesforce are well-positioned to thrive as AI orchestration platforms. ServiceNow's CMDB serves as the heart of customer infrastructure, while Salesforce's data mastery positions it as an ideal AI agent launch platform. Both stocks offer significant upside potential despite sector headwinds.",
#    'keywords': 'AI stocks, SaaS bear market, software stocks, AI orchestration, agentic AI, configuration management database, data governance',
#    'insights': [{'ticker': 'NOW',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Company is well-positioned as an AI orchestration layer with its CMDB at the center of customer infrastructure. Revenue growth around 20% with potential 85% upside based on 10x P/S valuation multiple.'},
#     {'ticker': 'CRM',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Proactively positioned for agentic AI era with Data 360 and Informatica acquisition creating a master data platform. Projected 11% CAGR through 2030 with 70% upside potential based on 6x P/S valuation.'},
#     {'ticker': 'PLTR',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'Mentioned as one of few SaaS companies to see growth acceleration due to AI tailwinds, but no detailed analysis provided in the article.'},
#     {'ticker': 'BABA',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'Referenced for a study showing 75% of AI-generated code failed within a year, used as supporting evidence for the counter-argument against AI replacing software companies.'}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': 'c8f8ba99fefbd44e66dd75d67b4ad8eb02abc57a05ab48d9e4d9172db22daeda',
#    'title': "2 AI Stocks I Don't Like (Including Palantir) and 1 I Love",
#    'author': 'Daniel Sparks',
#    'published_utc': '2026-04-12T02:31:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/11/2-ai-stocks-i-dont-like-and-1-i-love/?source=iedfolrf0000001',
#    'tickers': 'PLTR, SNOW, AMZN',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F865293%2Fcomparing-palantir-snowflake-amazon.jpg&w=1200&op=resize',
#    'description': 'Despite recent software stock declines, analyst Daniel Sparks argues that popular AI stocks Palantir and Snowflake remain overvalued with stretched valuations. He favors Amazon instead, citing its massive cloud computing business growing at its fastest pace in years, reasonable valuation at 33x earnings, and strong operational cash flow of $139.5 billion, making it better positioned to capitalize on AI opportunities.',
#    'keywords': 'AI stocks, valuation, software stocks, cloud computing, profitability, capital expenditures',
#    'insights': [{'ticker': 'PLTR',
#      'sentiment': 'negative',
#      'sentiment_reasoning': "Despite exceptional 70% YoY revenue growth and strong business performance, the stock's valuation is unjustifiable with a P/E ratio over 200 and forward P/E near 100. The market is pricing in flawless execution, leaving significant downside risk if customer growth decelerates."},
#     {'ticker': 'SNOW',
#      'sentiment': 'negative',
#      'sentiment_reasoning': 'While the company shows strong revenue growth of 30% YoY, it remains unprofitable with a $1.44 billion operating loss in fiscal 2026. Heavy stock-based compensation continues to weigh on profitability, yet the $42 billion market cap has already priced in a swing to substantial profitability that could be years away.'},
#     {'ticker': 'AMZN',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'AWS cloud computing segment grew 24% YoY to $35.6 billion with a $142.4 billion run rate. The company trades at a sensible 33x earnings with $139.5 billion in trailing twelve-month operating cash flow (up 20% YoY), providing a resilient, diversified business well-positioned for AI opportunities despite high capital expenditure requirements.'}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': 'b8a71d99a7f1b69d31250d6519f463740889e55c05abd9948a80d3a85224f62d',
#    'title': 'Anthropic Needs More AI Compute -- Here Are My Top 8 Stocks to Own',
#    'author': 'Jose Najarro',
#    'published_utc': '2026-04-15T04:02:51Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/15/anthropic-needs-more-ai-compute-here-are-my-top-8/?source=iedfolrf0000001',
#    'tickers': 'CRWV, NVDA, MSFT, GOOG, GOOGL, AMZN, AVGO, MRVL, MU',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F865665%2Fnew-cc-2026-04-10t174950795.png&w=1200&op=resize',
#    'description': 'Anthropic has signed a multi-year agreement with CoreWeave to secure additional AI compute capacity. The article discusses CoreWeave and other AI-related stocks as investment opportunities in the growing AI infrastructure sector.',
#    'keywords': 'AI compute, infrastructure, Anthropic, CoreWeave, semiconductor, AI stocks',
#    'insights': [{'ticker': 'CRWV',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'CoreWeave secured a multi-year contract with Anthropic for AI compute services, demonstrating strong demand for its infrastructure offerings. Stock showed positive movement (+6.29%) on the news.'},
#     {'ticker': 'NVDA',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'As a leading semiconductor company supplying AI chips, Nvidia benefits from increased AI compute demand driven by companies like Anthropic expanding their infrastructure needs.'},
#     {'ticker': 'MSFT',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Major AI player with significant investments in AI infrastructure and compute capabilities; benefits from growing demand in the AI sector.'},
#     {'ticker': 'GOOG',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Large technology company with substantial AI initiatives and compute infrastructure investments; positioned to benefit from AI sector growth.'},
#     {'ticker': 'GOOGL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Large technology company with substantial AI initiatives and compute infrastructure investments; positioned to benefit from AI sector growth.'},
#     {'ticker': 'AMZN',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'AWS provides cloud compute services that support AI workloads; benefits from increased demand for AI infrastructure and compute resources.'},
#     {'ticker': 'AVGO',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Semiconductor company supplying networking and infrastructure components essential for AI data centers and compute systems.'},
#     {'ticker': 'MRVL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Semiconductor manufacturer providing data center and AI infrastructure chips; benefits from expansion of AI compute capacity.'},
#     {'ticker': 'MU',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Memory and storage semiconductor supplier critical for AI infrastructure; strong demand from AI compute expansion initiatives.'}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': '0dba9b1f8f0805001906c3ad701b3b70780f658f00a1798717e689a9570861d0',
#    'title': "Stocks Rallied After President Donald Trump's Ceasefire in Iran. Here's How to Invest Now.",
#    'author': 'Adria Cimino',
#    'published_utc': '2026-04-11T09:06:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/11/stocks-rallied-after-president-donald-trumps-cease/?source=iedfolrf0000001',
#    'tickers': 'AMZN, JNJ, NVDA, KO',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F864618%2Fgettyimages-903626078.jpg&w=1200&op=resize',
#    'description': "Following President Trump's announcement of a two-week ceasefire suspension in Iran, all three major stock indexes jumped more than 2.5% on April 8, 2026. The article recommends a long-term investment strategy focused on quality companies with strong competitive positions, dividend stocks (particularly Dividend Kings), and undervalued AI stocks trading at reasonable valuations.",
#    'keywords': 'ceasefire, Iran, stock market rally, geopolitical uncertainty, quality stocks, dividend stocks, AI stocks, valuation, long-term investing',
#    'insights': [{'ticker': 'AMZN',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Highlighted as a quality company with demonstrated ability to handle tough markets and deliver significant returns over 20 years. Recommended as a strong addition to portfolios during uncertain times.'},
#     {'ticker': 'JNJ',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Cited as a healthcare quality company with proven track record of managing difficult markets and delivering long-term returns to investors.'},
#     {'ticker': 'NVDA',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Described as a leading AI chip designer with broad product portfolio positioned to power AI's future. Trading at 21x forward earnings (lowest in a year), presented as a 'no-brainer buy' for growth investors at current valuations."},
#     {'ticker': 'KO',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Recommended as a well-known Dividend King example, offering passive income through consistent dividend increases for 50+ years, suitable for uncertain market conditions.'}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': '8e840e66ee9769f91b27a2e661a9311c7dbbaea09712f3d444c0b552a44ded33',
#    'title': 'The Best Artificial Intelligence (AI) Growth Stocks to Buy as the Nasdaq Hits a New All-Time High',
#    'author': 'Geoffrey Seiler',
#    'published_utc': '2026-04-25T04:15:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/25/the-best-artificial-intelligence-ai-growth-stocks/?source=iedfolrf0000001',
#    'tickers': 'NVDA, GOOG, GOOGL, META',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F865881%2Fgettyimages-2078917109.jpg&w=1200&op=resize',
#    'description': 'With the Nasdaq hitting new all-time highs, three AI stocks are highlighted as strong buys: Nvidia has evolved into a complete end-to-end AI infrastructure provider with GPUs, CPUs, DPUs, and LPUs; Alphabet offers the complete AI package with custom TPUs, cloud computing, and distribution advantages; and Meta is leveraging AI to enhance user engagement and monetization across its social platforms while developing custom AI chips.',
#    'keywords': 'artificial intelligence, AI stocks, Nasdaq all-time high, GPU, AI infrastructure, custom chips, data center, AI growth',
#    'insights': [{'ticker': 'NVDA',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Described as the company at the center of AI infrastructure build-out with evolving capabilities beyond GPUs to include CPUs, DPUs, and LPUs, enabling complete server rack solutions for various AI workloads.'},
#     {'ticker': 'GOOG',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Characterized as 'the whole package' with hardware, cloud computing, foundational AI models, custom TPUs with cost advantages, and strong distribution through Chrome, Android, and search dominance."},
#     {'ticker': 'GOOGL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Characterized as 'the whole package' with hardware, cloud computing, foundational AI models, custom TPUs with cost advantages, and strong distribution through Chrome, Android, and search dominance."},
#     {'ticker': 'META',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Praised for effectively using AI to drive growth through its social media flywheel, improving ad targeting and monetization, while smartly redirecting resources from metaverse to AI infrastructure and custom chips.'}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': 'bd48e254543baede55ee2502d0f570fa51703d80d29618a8fdcd1d832aeaa1c5',
#    'title': "Prediction: AI Stocks Will Soar After This Earnings Season and Here's Why",
#    'author': 'Adria Cimino',
#    'published_utc': '2026-04-29T08:10:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/29/prediction-ai-stocks-will-soar-after-this-earnings/?source=iedfolrf0000001',
#    'tickers': 'TSM, ASML, INTC, NVDA, AMZN, PLTR',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F867492%2Fan-ai-powered-robotic-finger-and-a-human-finger-touch.jpg&w=1200&op=resize',
#    'description': 'AI stocks, which faced headwinds earlier in 2026 due to high valuations and geopolitical concerns, are poised to rebound strongly during earnings season. Recent positive earnings reports from semiconductor and cloud companies, combined with improved geopolitical conditions and mounting evidence of sustained AI demand, suggest the AI growth story is real and durable.',
#    'keywords': 'AI stocks, earnings season, semiconductor demand, valuations, geopolitical risk, cloud services, AI infrastructure',
#    'insights': [{'ticker': 'TSM',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'TSMC reported strong chip demand from customers serving AI companies, indicating robust ongoing demand for AI infrastructure and validating the strength of the AI growth narrative.'},
#     {'ticker': 'ASML',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "ASML's positive earnings report on AI chip demand supports the thesis that AI infrastructure investment is real and sustainable."},
#     {'ticker': 'INTC',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Intel's positive earnings message about AI chip demand aligns with the broader narrative of strong and continuing AI infrastructure investment."},
#     {'ticker': 'NVDA',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'As a top AI chip designer, Nvidia benefits from the predicted AI stock rebound driven by sustained demand and improved market conditions, though previously faced valuation concerns at 50x forward earnings.'},
#     {'ticker': 'AMZN',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Amazon's shareholder letter highlighted strong AI-driven cloud service adoption and described its chips business as 'on fire,' indicating broad growth opportunities from AI expansion."},
#     {'ticker': 'PLTR',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'While mentioned as an AI software company, Palantir is cited as an example of extreme valuation concerns (285x forward earnings) that contributed to investor skepticism, though the article suggests this skepticism may be waning.'}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': '2291c0d59982dc2f0ead1ce4d173afc04288a74a6002bb76e71e06cfa4dab86b',
#    'title': "Why the Nasdaq's Artificial Intelligence (AI) Rally Could Be Just Getting Started: 2 Best Growth Stocks to Buy",
#    'author': 'Geoffrey Seiler',
#    'published_utc': '2026-04-22T00:12:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/21/why-the-nasdaqs-artificial-intelligence-ai-rally-c/?source=iedfolrf0000001',
#    'tickers': 'GOOG, GOOGL, AMZN',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F865884%2Fgettyimages-1472292349.jpg&w=1200&op=resize',
#    'description': 'The article argues that the AI rally is far from over as the market shifts back toward growth stocks. Alphabet and Amazon are highlighted as top AI investment opportunities due to their comprehensive AI infrastructure, custom chip development, and competitive advantages in cloud computing and AI model deployment.',
#    'keywords': 'artificial intelligence, AI rally, growth stocks, custom chips, cloud computing, Nasdaq, TPUs, agentic AI',
#    'insights': [{'ticker': 'GOOG',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Positioned as having the most complete AI stack with seventh-generation TPUs, world-class Gemini AI model, strong distribution advantages, and recent acquisition of cloud security provider Wiz. Cited as a top AI stock for both current rally and long-term growth.'},
#     {'ticker': 'GOOGL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Positioned as having the most complete AI stack with seventh-generation TPUs, world-class Gemini AI model, strong distribution advantages, and recent acquisition of cloud security provider Wiz. Cited as a top AI stock for both current rally and long-term growth.'},
#     {'ticker': 'AMZN',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Recognized as the largest cloud infrastructure provider with custom chips (Trainium, Graviton) generating $20 billion run-rate business. Strong positioning in agentic AI, accelerating cloud revenue growth, and impressive operating leverage in e-commerce through AI and automation.'}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': 'fc65810fe0c62471b3456dec23ce2ad2bdca535f7312c7d4f0135a721aa9ae9f',
#    'title': 'Top 3 Stocks I Would Buy After This Massive Rally',
#    'author': 'Jose Najarro',
#    'published_utc': '2026-04-16T02:15:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/15/top-3-stocks-i-would-buy-after-this-massive-market/?source=iedfolrf0000001',
#    'tickers': 'NVDA, AVGO, MSFT, GOOG, GOOGL, MRVL, META, SNPS',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F865668%2Fnew-cc-2026-04-14t183713564.png&w=1200&op=resize',
#    'description': 'Jose Najarro discusses investment opportunities in AI and semiconductor stocks following a recent market rally. The article highlights how the semiconductor sector continues to deliver strong returns driven by AI innovations, with focus on major tech companies in this space.',
#    'keywords': 'semiconductor stocks, AI investments, market rally, tech stocks, stock recommendations',
#    'insights': [{'ticker': 'NVDA',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Mentioned as a key AI stock with recent updates; included in author's portfolio and recommended by The Motley Fool; semiconductor sector highlighted as providing strong returns"},
#     {'ticker': 'AVGO',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Semiconductor company recommended by The Motley Fool; benefits from AI-driven semiconductor market growth'},
#     {'ticker': 'MSFT',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Major tech company in AI space; included in author's portfolio and recommended by The Motley Fool"},
#     {'ticker': 'GOOG',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Tech leader with AI investments; included in author's portfolio and recommended by The Motley Fool"},
#     {'ticker': 'GOOGL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Tech leader with AI investments; included in author's portfolio and recommended by The Motley Fool"},
#     {'ticker': 'MRVL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Semiconductor company benefiting from AI innovations; included in author's portfolio and recommended by The Motley Fool"},
#     {'ticker': 'META',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Tech company with AI focus; included in author's portfolio and recommended by The Motley Fool"},
#     {'ticker': 'SNPS',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Semiconductor design software company; included in author's portfolio and recommended by The Motley Fool; supports AI chip development"}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': '49cd1a56cbf1f221f6d4111926a1e4e1013bbf520079532c546af2509840aebb',
#    'title': "The First 5 AI Stocks I'd Buy If I Started From Scratch",
#    'author': 'Keithen Drury',
#    'published_utc': '2026-04-15T23:33:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/15/the-first-5-ai-stocks-id-buy-if-i-started-from-scr/?source=iedfolrf0000001',
#    'tickers': 'NVDA, AVGO, MSFT, GOOG, GOOGL, NBIS',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F865279%2Fperson-looking-at-a-laptop-at-a-desk.jpg&w=1200&op=resize',
#    'description': 'An analyst recommends five AI stocks for a portfolio starting from scratch: Nvidia and Broadcom as semiconductor suppliers benefiting from AI infrastructure buildout; Microsoft and Alphabet as cloud computing providers with usage-based AI revenue models; and Nebius as a high-risk, high-reward GPU-focused neocloud company experiencing rapid growth.',
#    'keywords': 'AI stocks, semiconductors, cloud computing, GPU computing, AI infrastructure, data centers, hyperscalers',
#    'insights': [{'ticker': 'NVDA',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Positioned as a top pick due to its dominant role in AI chip design and sales. Benefits from the 'pick-and-shovel' play on AI buildout with continuous revenue from replacement units needed due to hardware burnout under extreme workloads."},
#     {'ticker': 'AVGO',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Recommended as a first buy alongside Nvidia. Profits from designing and selling semiconductor chips and systems for AI infrastructure deployment, with years of growth ahead from continuous hardware replacement needs.'},
#     {'ticker': 'MSFT',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Well-positioned as an AI hyperscaler with Azure cloud platform. Usage-based business model generates increasing cash flows as AI adoption grows, with established infrastructure advantage.'},
#     {'ticker': 'GOOG',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Strong positioning through Google Cloud platform with usage-based revenue model. Additional upside potential from Gemini generative AI model if it becomes a top subscription service offering.'},
#     {'ticker': 'GOOGL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Strong positioning through Google Cloud platform with usage-based revenue model. Additional upside potential from Gemini generative AI model if it becomes a top subscription service offering.'},
#     {'ticker': 'NBIS',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Highest risk but highest reward pick. Experiencing incredible growth with expected annual run rate increase from $1.25B to $7-9B. Highest upside potential if profitability is achieved, though currently unprofitable with negative gross margin.'}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': '2103b7060d9065b9364a3250e5b31c6eebe314e129e123d0ae0b31a3aa506457',
#    'title': '2 Millionaire-Maker Artificial Intelligence (AI) Stocks to Buy and Hold',
#    'author': 'Marc Guberti',
#    'published_utc': '2026-04-26T17:24:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/26/2-millionaire-maker-artificial-intelligence-ai-sto/?source=iedfolrf0000001',
#    'tickers': 'MU, AMZN',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F865909%2Fgettyimages-1408715370-1201x739-6da57a5.jpg&w=1200&op=resize',
#    'description': 'The article recommends Micron Technology and Amazon as two AI stocks positioned for long-term growth. Micron produces memory chips essential for AI infrastructure with impressive sequential revenue growth and a 30.6% projected CAGR for the AI industry through 2033. Amazon leverages AI across its businesses including AWS, which achieved its fastest revenue growth in 13 quarters at 24% year-over-year, while the company maintains strong cash reserves of $86.8 billion for future AI investments.',
# ...
#     {'ticker': 'ORCL',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': "Mentioned as having signed to fill one of Applied Digital's new data center facilities, indicating business partnership but no direct investment recommendation or analysis provided."},
#     {'ticker': 'ORCLpD',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': "Mentioned as having signed to fill one of Applied Digital's new data center facilities, indicating business partnership but no direct investment recommendation or analysis provided."},
#     {'ticker': 'CRWV',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': "Mentioned as a cloud company that fully rents Applied Digital's first AI data center in North Dakota, but is a private company with no ticker and no direct analysis provided."}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': 'ec41ddb3353ce6cd9c87be91f50820665670412e8d521e1eb8d2b1f2596c2198',
#    'title': 'Nvidia, AMD, and Other AI Chip Stocks Are Swooning. Blame OpenAI.',
#    'author': 'Danny Vena, Cpa',
#    'published_utc': '2026-04-28T18:31:05Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/28/nvidia-amd-and-other-ai-chip-stocks-are-swooning-b/?source=iedfolrf0000001',
#    'tickers': 'NVDA, AMD, ORCL, ORCLpD, GOOG, GOOGL, MSFT',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F867554%2Fthe-nvidia-logo-superimposed-over-a-picture-of-the-companys-headquarters-building.png&w=1200&op=resize',
#    'description': "AI chip stocks tumbled after reports that OpenAI's growth is slowing, with the company missing internal targets for user and revenue growth. However, the article argues the sell-off is overdone, as demand for AI is being redistributed among competing platforms rather than declining overall. With strong current revenue growth and attractive valuations, the broader AI market remains healthy.",
#    'keywords': 'OpenAI, AI chip stocks, growth slowdown, market correction, competition, AI demand redistribution',
#    'insights': [{'ticker': 'NVDA',
#      'sentiment': 'negative',
#      'sentiment_reasoning': 'Stock down 3% on OpenAI growth concerns; however, current revenue growth of 73% YoY and attractive valuation at 25x forward earnings suggest the sell-off is overdone.'},
#     {'ticker': 'AMD',
#      'sentiment': 'negative',
#      'sentiment_reasoning': 'Stock down 4% on OpenAI news; trading at 48x forward earnings (pricier than peers), though current revenue growth of 34% YoY remains solid.'},
#     {'ticker': 'ORCL',
#      'sentiment': 'negative',
#      'sentiment_reasoning': 'Stock down 4% alongside other AI chip stocks; however, 22% revenue growth and attractive 22x forward earnings valuation suggest overreaction.'},
#     {'ticker': 'ORCLpD',
#      'sentiment': 'negative',
#      'sentiment_reasoning': 'Stock down 4% alongside other AI chip stocks; however, 22% revenue growth and attractive 22x forward earnings valuation suggest overreaction.'},
#     {'ticker': 'GOOG',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'Google Gemini has captured 750 million monthly active users, benefiting from AI demand redistribution as users find tools suited to their needs.'},
#     {'ticker': 'GOOGL',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': 'Google Gemini has captured 750 million monthly active users, benefiting from AI demand redistribution as users find tools suited to their needs.'},
#     {'ticker': 'MSFT',
#      'sentiment': 'neutral',
#      'sentiment_reasoning': "Copilot has 150 million users, participating in the broader AI market growth despite OpenAI's slowdown."}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': '5682bac7c7c62a1cb5d4b97fe58dd8dad9db6168277ceb1b5707f1b4f3141412',
#    'title': 'Got $1,000? Here Are Three Incredible AI Stocks to Get Started',
#    'author': 'Keithen Drury',
#    'published_utc': '2026-05-03T17:30:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/05/03/got-1000-here-are-three-incredible-ai-stocks-to/?source=iedfolrf0000001',
#    'tickers': 'NVDA, GOOG, GOOGL, NBIS',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F867606%2Fperson-looking-at-a-screen-with-lots-of-data-for-artificial-intelligeince-ai-applicaitons.jpg&w=1200&op=resize',
#    'description': 'The article recommends three AI stocks for beginner investors with $1,000: Nvidia, a semiconductor giant benefiting from massive AI computing demand with 73% YoY revenue growth; Alphabet, leveraging AI through Google Cloud (63% YoY growth) and Gemini integration; and Nebius, a high-growth neocloud company expecting 523% revenue growth in 2026, though with higher risk.',
#    'keywords': 'AI stocks, artificial intelligence investing, semiconductor, cloud computing, GPU, data centers, revenue growth',
#    'insights': [{'ticker': 'NVDA',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Strong 73% YoY revenue growth with expected 77% growth next quarter; dominant position in GPU market for AI model training; multi-year growth trend expected to continue as hyperscalers increase data center spending.'},
#     {'ticker': 'GOOG',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Multiple revenue streams from AI including Gemini model, Google Search integration, and Google Cloud with 63% YoY revenue growth; significant capital expenditure investments in data center expansion supporting long-term growth.'},
#     {'ticker': 'GOOGL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Multiple revenue streams from AI including Gemini model, Google Search integration, and Google Cloud with 63% YoY revenue growth; significant capital expenditure investments in data center expansion supporting long-term growth.'},
#     {'ticker': 'NBIS',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Exceptional growth trajectory with expected 523% revenue growth in 2026 and 206% in 2027; annual run rate expected to grow from $1.25B to $7-9B; however, characterized as high-risk, high-reward with more uncertainty than competitors.'}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': '7f4159565a3f4c1e81aaf9ca67b9fa7165118169c71bda8b190fa5fb2d88378e',
#    'title': 'Agentic AI Is the Next Big Thing in AI. Here Are the 5 Best Stocks to Capitalize on It.',
#    'author': 'Keithen Drury',
#    'published_utc': '2026-04-11T23:31:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/11/agentic-ai-is-the-next-big-thing-for-ai-here-are-t/?source=iedfolrf0000001',
#    'tickers': 'NVDA, AVGO, AMZN, MSFT, GOOG, GOOGL',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F863872%2Fperson-looking-at-wall-street-suit-stocks-finance.jpg&w=1200&op=resize',
#    'description': 'As agentic AI—software that can independently perform complex tasks—expands beyond coding into broader economy applications, demand for AI computing power will surge. The article identifies five stocks positioned to benefit: chipmakers Nvidia and Broadcom for hardware, and cloud infrastructure leaders Amazon Web Services, Microsoft Azure, and Google Cloud for computing capacity. All five stocks are currently down at least 10% from all-time highs, presenting potential buying opportunities.',
#    'keywords': 'agentic AI, AI computing hardware, cloud infrastructure, GPUs, ASICs, data centers, AI demand',
#    'insights': [{'ticker': 'NVDA',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Described as 'probably the most obvious pick' with GPUs being the primary computing units for AI workloads. Expected to deliver massive revenue growth and be among the best-performing investments over the next five years."},
#     {'ticker': 'AVGO',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Praised for its custom ASIC approach that excels at specific tasks at lower costs. Expected to put up massive revenue growth and be among the best-performing investments over the next five years.'},
#     {'ticker': 'AMZN',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'AWS showed strong growth of 24% year-over-year (best quarter in over three years) with massive backlogs of AI computing capacity demand. Positioned as a leader in cloud infrastructure for agentic AI expansion.'},
#     {'ticker': 'MSFT',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Azure grew revenue by 39% with huge backlogs of business for AI computing capacity. Identified as one of the big three cloud providers seeing massive success and future growth.'},
#     {'ticker': 'GOOG',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Google Cloud achieved impressive 48% revenue growth with massive backlogs of AI computing demand. Positioned as a leader in cloud infrastructure benefiting from agentic AI expansion.'},
#     {'ticker': 'GOOGL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Google Cloud achieved impressive 48% revenue growth with massive backlogs of AI computing demand. Positioned as a leader in cloud infrastructure benefiting from agentic AI expansion.'}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': '6441c77e8cbaa7aa027a11a32227ed7cbfbdfcc3c8cba1fbfc1e5e5f5675f76d',
#    'title': '3 ETFs Beating the Market in 2026 and Why They Could Keep Going',
#    'author': 'David Dierking',
#    'published_utc': '2026-04-13T06:30:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/13/3-etfs-beating-market-in-2026-why-could-keep-going/?source=iedfolrf0000001',
#    'tickers': 'SCHD, XOP, EWY',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F863162%2Fgettyimages-1293582790.jpg&w=1200&op=resize',
#    'description': 'A market rotation away from tech and growth stocks in 2026 has created opportunities in value, dividend, energy, and international stocks. Three ETFs are highlighted as having strong performance potential: the Schwab U.S. Dividend Equity ETF (SCHD), which rebounded after years of underperformance; the State Street SPDR S&P Oil & Gas Exploration & Production ETF (XOP), benefiting from energy independence and geopolitical factors; and the iShares MSCI South Korea ETF (EWY), positioned to benefit from semiconductor demand in the AI supply chain.',
#    'keywords': 'market rotation, dividend stocks, energy stocks, international stocks, ETFs, AI supply chain, semiconductors, value investing',
#    'insights': [{'ticker': 'SCHD',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "After underperforming from 2023-2025, the ETF has rebounded strongly in 2026 with a 12.4% YTD return. Its heavy positioning in energy and consumer staples stocks is now paying off, and it's positioned to outperform if economic concerns persist."},
#     {'ticker': 'XOP',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Up 43.4% YTD with strong structural tailwinds from U.S. energy independence and geopolitical factors. E&P companies trade at attractive valuations (11x forward P/E) with long-term infrastructure capex cycles supporting continued growth.'},
#     {'ticker': 'EWY',
#      'sentiment': 'positive',
#      'sentiment_reasoning': "Up 30.8% YTD with exposure to semiconductor leaders Samsung and SK Hynix, which are critical to the AI supply chain. Despite a 180% rise since early 2025, South Korea's 17x earnings valuation suggests further upside potential if AI demand continues."}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan},
#   {'id': '108bd43bff51f2b6939b10aeb33fffe00bd0f2abbee80ba19ed9994758dfd465',
#    'title': "The Great Rotation Has Crushed Growth Stocks. History Says That's Usually When You Should Be Buying Them.",
#    'author': 'John Ballard',
#    'published_utc': '2026-04-18T20:10:00Z',
#    'article_url': 'https://www.fool.com/investing/2026/04/18/great-rotation-growth-stocks-history-says-buying/?source=iedfolrf0000001',
#    'tickers': 'NVDA, MSFT, GOOG, GOOGL, IVW',
#    'image_url': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F864785%2Fgrowth-investing-chart.jpg&w=1200&op=resize',
#    'description': "Following the 'Great Rotation' that has shifted investor focus from growth to defensive stocks, the article argues this presents a buying opportunity in quality tech stocks. Nvidia, Microsoft, and Alphabet are highlighted as attractive investments with strong AI growth prospects and reasonable valuations, supported by historical data showing growth stocks outperform over long-term horizons.",
#    'keywords': 'Great Rotation, growth stocks, artificial intelligence, tech stocks, market dip, long-term investing',
#    'insights': [{'ticker': 'NVDA',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Central to AI investment cycle with $1 trillion in cumulative purchase orders for chips, 71% revenue growth expected, 55% profit margin, and strong competitive moat. Trading at reasonable 18x forward earnings with 38% annual earnings growth forecast.'},
#     {'ticker': 'MSFT',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Down 30% from recent highs but showing strong fundamentals with 26% cloud revenue growth, 15 million paid Copilot seats, and 39% Azure growth. Positioned to extend productivity software dominance through AI infrastructure at attractive 22x forward earnings.'},
#     {'ticker': 'GOOG',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Generating strong double-digit advertising and cloud growth with $73 billion annual free cash flow. Gemini AI integration across products showing strong early results. Trading at reasonable 25x forward earnings with significant long-term growth potential.'},
#     {'ticker': 'GOOGL',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Generating strong double-digit advertising and cloud growth with $73 billion annual free cash flow. Gemini AI integration across products showing strong early results. Trading at reasonable 25x forward earnings with significant long-term growth potential.'},
#     {'ticker': 'IVW',
#      'sentiment': 'positive',
#      'sentiment_reasoning': 'Historical data shows nearly doubled returns versus Value ETF over 10 years despite 12-24% drawdowns, supporting thesis that growth stocks are optimal for long-term investors with 10+ year horizons.'}],
#    'publisher.name': 'The Motley Fool',
#    'publisher.homepage_url': 'https://www.fool.com/',
#    'publisher.logo_url': 'https://s3.massive.com/public/assets/news/logos/themotleyfool.svg',
#    'publisher.favicon_url': 'https://s3.massive.com/public/assets/news/favicons/themotleyfool.ico',
#    'amp_url': nan}]}

# %%
print("=== Recent News ===")                                                                                                                                        
news = get_ticker_news('GOOGL', limit=3)                                                                                                                            
print(f"Ticker: {news['ticker']}")                                                                                                                                  
print(f"News count: {news['news_count']}")                                                                                                                          
print()                                                                                                                                                             
for i, item in enumerate(news['news'], 1):                                                                                                                          
    print(f"{i}. {item['title']}")                                                                                                                                  
    print(f"   Publisher: {item['publisher']}")                                                                                                                     
    print(f"   Published: {item['published']}")                                                                                                                     
    if item.get('summary'):                                                                                                                                         
        print(f"   Summary: {item['summary'][:100]}...")                                                                                                            
    print()
# Out:
# === Recent News ===
# Ticker: GOOG
# News count: 3
#
# 1. AMD stock surges as the chipmaker forecasts continued AI growth
#    Publisher: Yahoo Finance Video
#    Published: 2026-05-06T20:05:00Z
#    Summary: Advanced Micro Devices (AMD) stock surges higher on Wednesday after blowing past first quarter earni...
#
# 2. Anthropic to rent all AI capacity at SpaceX's Colossus data center
#    Publisher: Yahoo Finance
#    Published: 2026-05-06T18:03:27Z
#    Summary: Anthropic says it will rent all of the compute capacity from SpaceX's massive Colossus 1 data center...
#
# 3. The Best AI Stocks for Growth Investors to Buy in 2026
#    Publisher: Motley Fool
#    Published: 2026-05-06T20:36:00Z
#    Summary: These tech behemoths are seeing impressive gains from their artificial intelligence (AI) investments...

# %%
# Cell 10: Test search_companies - Placeholder                                                                                                                      
print("="*80)                                                                                                                                                       
print("9. search_companies() - no filter")                                                                                                                                
print("TRANSFORMATION: None - placeholder for company database")                                                                                                    
print("="*80)                                                                                                                                                       
                                                                                                                                                                    
companies = search_companies()                                                                                                                                
companies
# Out:
# ================================================================================
# 9. search_companies() - no filter
# TRANSFORMATION: None - placeholder for company database
# ================================================================================
# Downloading marketcap database...
# ✓ Loaded 10813 companies from marketcap
# Downloading pe_ratio database...
# ✓ Loaded 10813 companies from pe_ratio
# Downloading dividend database...
# ✓ Loaded 10813 companies from dividend
# Downloading margin database...
# ✓ Loaded 10813 companies from margin
#
# Merging databases...
# ✓ Added P/E ratio column
# ✓ Added Dividend yield column
# ✓ Added Operating margin column
#
# Final columns: ['Rank', 'Name', 'Symbol', 'marketcap', 'price (USD)', 'country', 'pe_ratio_ttm', 'dividend_yield_ttm', 'operating_margin_ttm']
# {'available_columns': ['Rank',
#                        'Name',
#                        'Symbol',
#                        'marketcap',
#                        'price (USD)',
#                        'country',
#                        'pe_ratio_ttm',
#                        'dividend_yield_ttm',
#                        'operating_margin_ttm'],
#  'databases_loaded': {'dividend': 10813,
#                       'margin': 10813,
#                       'marketcap': 10813,
#                       'pe_ratio': 10813},
#  'message': 'All databases merged with 10813 unique companies',
#  'status': 'success',
#  'total_companies': 10813}
# /Users/realmistic/Documents/stocks-scoring-agent/notebooks/../stocks_agent/tools.py:721: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   div_df['dividend_yield_ttm'] = div_df['dividend_yield_ttm'] / 100.0
# /Users/realmistic/Documents/stocks-scoring-agent/notebooks/../stocks_agent/tools.py:729: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   margin_df['operating_margin_ttm'] = margin_df['operating_margin_ttm']/100.0
# {'count': 50,
#  'data': [{'Rank': 1,
#    'Name': 'NVIDIA',
#    'Symbol': 'NVDA',
#    'marketcap': 5051308310528,
#    'price (USD)': 207.83,
#    'country': 'United States',
#    'pe_ratio_ttm': 42.1562,
#    'dividend_yield_ttm': 0.0192465,
#    'operating_margin_ttm': 65.62},
#   {'Rank': 2,
#    'Name': 'Alphabet (Google)',
#    'Symbol': 'GOOG',
#    'marketcap': 4787296796672,
#    'price (USD)': 395.14,
#    'country': 'United States',
#    'pe_ratio_ttm': 36.2181,
#    'dividend_yield_ttm': 0.212583,
#    'operating_margin_ttm': 39.6},
#   {'Rank': 3,
#    'Name': 'Apple',
#    'Symbol': 'AAPL',
#    'marketcap': 4222761828352,
#    'price (USD)': 287.51,
#    'country': 'United States',
#    'pe_ratio_ttm': 36.3018,
#    'dividend_yield_ttm': 0.36172699999999997,
#    'operating_margin_ttm': 31.89},
#   {'Rank': 4,
#    'Name': 'Microsoft',
#    'Symbol': 'MSFT',
#    'marketcap': 3075074949120,
#    'price (USD)': 413.96,
#    'country': 'United States',
#    'pe_ratio_ttm': 25.808,
#    'dividend_yield_ttm': 0.8406610000000001,
#    'operating_margin_ttm': 47.97},
#   {'Rank': 5,
#    'Name': 'Amazon',
#    'Symbol': 'AMZN',
#    'marketcap': 2958097383424,
#    'price (USD)': 274.99,
#    'country': 'United States',
#    'pe_ratio_ttm': 37.7215,
#    'dividend_yield_ttm': 0.0,
#    'operating_margin_ttm': 13.57},
#   {'Rank': 6,
#    'Name': 'TSMC',
#    'Symbol': 'TSM',
#    'marketcap': 2175694929920,
#    'price (USD)': 419.5,
#    'country': 'Taiwan',
#    'pe_ratio_ttm': 39.5613,
#    'dividend_yield_ttm': 0.8088200000000001,
#    'operating_margin_ttm': 53.6},
#   {'Rank': 7,
#    'Name': 'Broadcom',
#    'Symbol': 'AVGO',
#    'marketcap': 2014317248512,
#    'price (USD)': 425.44,
#    'country': 'United States',
#    'pe_ratio_ttm': 80.5758,
#    'dividend_yield_ttm': 0.582926,
#    'operating_margin_ttm': 41.84},
#   {'Rank': 8,
#    'Name': 'Saudi Aramco',
#    'Symbol': '2222.SR',
#    'marketcap': 1741129613706,
#    'price (USD)': 7.1975,
#    'country': 'Saudi Arabia',
#    'pe_ratio_ttm': 16.9608,
#    'dividend_yield_ttm': 4.93785,
#    'operating_margin_ttm': 40.49},
#   {'Rank': 9,
#    'Name': 'Meta Platforms (Facebook)',
#    'Symbol': 'META',
#    'marketcap': 1555748880384,
#    'price (USD)': 612.88,
#    'country': 'United States',
#    'pe_ratio_ttm': 25.5686,
#    'dividend_yield_ttm': 0.342645,
#    'operating_margin_ttm': 43.33},
#   {'Rank': 10,
#    'Name': 'Tesla',
#    'Symbol': 'TSLA',
#    'marketcap': 1497519751168,
#    'price (USD)': 398.73,
#    'country': 'United States',
#    'pe_ratio_ttm': 337.907,
#    'dividend_yield_ttm': 0.0,
#    'operating_margin_ttm': 5.92},
#   {'Rank': 11,
#    'Name': 'Samsung',
#    'Symbol': '005930.KS',
#    'marketcap': 1206638625388,
#    'price (USD)': 183.755,
#    'country': 'South Korea',
#    'pe_ratio_ttm': 49.1933,
#    'dividend_yield_ttm': 0.47694400000000003,
#    'operating_margin_ttm': 14.83},
#   {'Rank': 12,
#    'Name': 'Walmart',
#    'Symbol': 'WMT',
#    'marketcap': 1036866486272,
#    'price (USD)': 130.08,
#    'country': 'United States',
#    'pe_ratio_ttm': 47.4745,
#    'dividend_yield_ttm': 0.7326260000000001,
#    'operating_margin_ttm': 4.13},
#   {'Rank': 13,
#    'Name': 'Berkshire Hathaway',
#    'Symbol': 'BRK-B',
#    'marketcap': 1013354594304,
#    'price (USD)': 469.83,
#    'country': 'United States',
#    'pe_ratio_ttm': 13.6881,
#    'dividend_yield_ttm': 0.0,
#    'operating_margin_ttm': 18.63},
#   {'Rank': 14,
#    'Name': 'Eli Lilly',
#    'Symbol': 'LLY',
#    'marketcap': 880193306624,
#    'price (USD)': 987.05,
#    'country': 'United States',
#    'pe_ratio_ttm': 42.8697,
#    'dividend_yield_ttm': 0.631174,
#    'operating_margin_ttm': 39.47},
#   {'Rank': 15,
#    'Name': 'JPMorgan Chase',
#    'Symbol': 'JPM',
#    'marketcap': 843778097152,
#    'price (USD)': 314.9,
#    'country': 'United States',
#    'pe_ratio_ttm': 15.7057,
#    'dividend_yield_ttm': 1.87361,
#    'operating_margin_ttm': 39.79},
#   {'Rank': 16,
#    'Name': 'SK Hynix',
#    'Symbol': '000660.KS',
#    'marketcap': 783803164850,
#    'price (USD)': 1105.98,
#    'country': 'South Korea',
#    'pe_ratio_ttm': 31.7384,
#    'dividend_yield_ttm': 0.182446,
#    'operating_margin_ttm': 52.89},
#   {'Rank': 17,
#    'Name': 'Micron Technology',
#    'Symbol': 'MU',
#    'marketcap': 751736258560,
#    'price (USD)': 666.59,
#    'country': 'United States',
#    'pe_ratio_ttm': 31.062,
#    'dividend_yield_ttm': 0.07425849999999999,
#    'operating_margin_ttm': 25.82},
#   {'Rank': 18,
#    'Name': 'AMD',
#    'Symbol': 'AMD',
#    'marketcap': 687038857216,
#    'price (USD)': 421.39,
#    'country': 'United States',
#    'pe_ratio_ttm': 157.824,
#    'dividend_yield_ttm': 0.0,
#    'operating_margin_ttm': 11.95},
#   {'Rank': 19,
#    'Name': 'Exxon Mobil',
#    'Symbol': 'XOM',
#    'marketcap': 616312209408,
#    'price (USD)': 148.69,
#    'country': 'United States',
#    'pe_ratio_ttm': 22.2257,
#    'dividend_yield_ttm': 2.71706,
#    'operating_margin_ttm': 12.74},
#   {'Rank': 20,
#    'Name': 'Visa',
#    'Symbol': 'V',
#    'marketcap': 606275895296,
#    'price (USD)': 318.8,
#    'country': 'United States',
#    'pe_ratio_ttm': 29.9062,
#    'dividend_yield_ttm': 0.790464,
#    'operating_margin_ttm': 59.72},
#   {'Rank': 21,
#    'Name': 'ASML',
#    'Symbol': 'ASML',
#    'marketcap': 595370049536,
#    'price (USD)': 1544.74,
#    'country': 'Netherlands',
#    'pe_ratio_ttm': 53.8297,
#    'dividend_yield_ttm': 0.567798,
#    'operating_margin_ttm': 34.91},
#   {'Rank': 22,
#    'Name': 'Intel',
#    'Symbol': 'INTC',
#    'marketcap': 567988256768,
#    'price (USD)': 113.01,
#    'country': 'United States',
#    'pe_ratio_ttm': -1412.62,
#    'dividend_yield_ttm': 0.0,
#    'operating_margin_ttm': 2.94},
#   {'Rank': 23,
#    'Name': 'Oracle',
#    'Symbol': 'ORCL',
#    'marketcap': 558039236608,
#    'price (USD)': 194.03,
#    'country': 'United States',
#    'pe_ratio_ttm': 35.1504,
#    'dividend_yield_ttm': 1.03077,
#    'operating_margin_ttm': 24.66},
#   {'Rank': 24,
#    'Name': 'Tencent',
#    'Symbol': 'TCEHY',
#    'marketcap': 550573375488,
#    'price (USD)': 60.88,
#    'country': 'China',
#    'pe_ratio_ttm': 18.3328,
#    'dividend_yield_ttm': 0.941196,
#    'operating_margin_ttm': 34.51},
#   {'Rank': 25,
#    'Name': 'Johnson & Johnson',
#    'Symbol': 'JNJ',
#    'marketcap': 540709060608,
#    'price (USD)': 224.62,
#    'country': 'United States',
#    'pe_ratio_ttm': 20.1659,
#    'dividend_yield_ttm': 2.31502,
#    'operating_margin_ttm': 34.58},
#   {'Rank': 26,
#    'Name': 'Costco',
#    'Symbol': 'COST',
#    'marketcap': 441767034880,
#    'price (USD)': 995.75,
#    'country': 'United States',
#    'pe_ratio_ttm': 51.7004,
#    'dividend_yield_ttm': 0.391665,
#    'operating_margin_ttm': 3.93},
#   {'Rank': 27,
#    'Name': 'Mastercard',
#    'Symbol': 'MA',
#    'marketcap': 434626068480,
#    'price (USD)': 491.89,
#    'country': 'United States',
#    'pe_ratio_ttm': 29.7035,
#    'dividend_yield_ttm': 0.6627500000000001,
#    'operating_margin_ttm': 56.65},
#   {'Rank': 28,
#    'Name': 'Caterpillar',
#    'Symbol': 'CAT',
#    'marketcap': 426936500224,
#    'price (USD)': 926.93,
#    'country': 'United States',
#    'pe_ratio_ttm': 48.9921,
#    'dividend_yield_ttm': 0.651613,
#    'operating_margin_ttm': 17.07},
#   {'Rank': 29,
#    'Name': 'Bank of America',
#    'Symbol': 'BAC',
#    'marketcap': 380377268224,
#    'price (USD)': 53.6,
#    'country': 'United States',
#    'pe_ratio_ttm': 13.8144,
#    'dividend_yield_ttm': 2.05224,
#    'operating_margin_ttm': 33.32},
#   {'Rank': 30,
#    'Name': 'China Construction Bank',
#    'Symbol': '601939.SS',
#    'marketcap': 375350818458,
#    'price (USD)': 1.43483,
#    'country': 'China',
#    'pe_ratio_ttm': 7.44658,
#    'dividend_yield_ttm': 3.9928,
#    'operating_margin_ttm': 49.29},
#   {'Rank': 31,
#    'Name': 'Netflix',
#    'Symbol': 'NFLX',
#    'marketcap': 371687161856,
#    'price (USD)': 88.27,
#    'country': 'United States',
#    'pe_ratio_ttm': 34.1999,
#    'dividend_yield_ttm': 0.0,
#    'operating_margin_ttm': 28.15},
#   {'Rank': 32,
#    'Name': 'Lam Research',
#    'Symbol': 'LRCX',
#    'marketcap': 371632209920,
#    'price (USD)': 297.17,
#    'country': 'United States',
#    'pe_ratio_ttm': 60.6469,
#    'dividend_yield_ttm': 0.339873,
#    'operating_margin_ttm': 34.1},
#   {'Rank': 33,
#    'Name': 'Chevron',
#    'Symbol': 'CVX',
#    'marketcap': 366061322240,
#    'price (USD)': 185.16,
#    'country': 'United States',
#    'pe_ratio_ttm': 27.7186,
#    'dividend_yield_ttm': 3.7319099999999996,
#    'operating_margin_ttm': 11.36},
#   {'Rank': 34,
#    'Name': 'AbbVie',
#    'Symbol': 'ABBV',
#    'marketcap': 362649354240,
#    'price (USD)': 205.03,
#    'country': 'United States',
#    'pe_ratio_ttm': 85.731,
#    'dividend_yield_ttm': 3.2873200000000002,
#    'operating_margin_ttm': 10.78},
#   {'Rank': 35,
#    'Name': 'Cisco',
#    'Symbol': 'CSCO',
#    'marketcap': 361968205824,
#    'price (USD)': 91.64,
#    'country': 'United States',
#    'pe_ratio_ttm': 32.042,
#    'dividend_yield_ttm': 1.80052,
#    'operating_margin_ttm': 19.59},
#   {'Rank': 36,
#    'Name': 'Agricultural Bank of China',
#    'Symbol': '601288.SS',
#    'marketcap': 351515177517,
#    'price (USD)': 1.00438,
#    'country': 'China',
#    'pe_ratio_ttm': 9.59293,
#    'dividend_yield_ttm': 3.56683,
#    'operating_margin_ttm': 45.4},
#   {'Rank': 37,
#    'Name': 'Alibaba',
#    'Symbol': 'BABA',
#    'marketcap': 349014720512,
#    'price (USD)': 141.44,
#    'country': 'China',
#    'pe_ratio_ttm': 25.2318,
#    'dividend_yield_ttm': 1.41403,
#    'operating_margin_ttm': 12.43},
#   {'Rank': 38,
#    'Name': 'Procter & Gamble',
#    'Symbol': 'PG',
#    'marketcap': 344399773696,
#    'price (USD)': 147.9,
#    'country': 'United States',
#    'pe_ratio_ttm': 21.4038,
#    'dividend_yield_ttm': 2.8803199999999998,
#    'operating_margin_ttm': 23.92},
#   {'Rank': 39,
#    'Name': 'Coca-Cola',
#    'Symbol': 'KO',
#    'marketcap': 340885700608,
#    'price (USD)': 79.23,
#    'country': 'United States',
#    'pe_ratio_ttm': 25.977,
#    'dividend_yield_ttm': 2.60003,
#    'operating_margin_ttm': 33.37},
#   {'Rank': 40,
#    'Name': 'Applied Materials',
#    'Symbol': 'AMAT',
#    'marketcap': 340157038592,
#    'price (USD)': 428.62,
#    'country': 'United States',
#    'pe_ratio_ttm': 43.6922,
#    'dividend_yield_ttm': 0.42928499999999997,
#    'operating_margin_ttm': 32.68},
#   {'Rank': 41,
#    'Name': 'Roche',
#    'Symbol': 'RO.SW',
#    'marketcap': 337939043938,
#    'price (USD)': 424.751,
#    'country': 'Switzerland',
#    'pe_ratio_ttm': 20.7834,
#    'dividend_yield_ttm': 3.21428,
#    'operating_margin_ttm': 26.78},
#   {'Rank': 42,
#    'Name': 'UnitedHealth',
#    'Symbol': 'UNH',
#    'marketcap': 333568540672,
#    'price (USD)': 367.28,
#    'country': 'United States',
#    'pe_ratio_ttm': 27.6537,
#    'dividend_yield_ttm': 2.4068799999999997,
#    'operating_margin_ttm': 3.28},
#   {'Rank': 43,
#    'Name': 'Home Depot',
#    'Symbol': 'HD',
#    'marketcap': 321766719488,
#    'price (USD)': 323.05,
#    'country': 'United States',
#    'pe_ratio_ttm': 22.6384,
#    'dividend_yield_ttm': 2.85714,
#    'operating_margin_ttm': 12.16},
#   {'Rank': 44,
#    'Name': 'Palantir',
#    'Symbol': 'PLTR',
#    'marketcap': 320736362496,
#    'price (USD)': 133.79,
#    'country': 'United States',
#    'pe_ratio_ttm': 193.723,
#    'dividend_yield_ttm': 0.0,
#    'operating_margin_ttm': 37.03},
#   {'Rank': 45,
#    'Name': 'General Electric',
#    'Symbol': 'GE',
#    'marketcap': 319540232192,
#    'price (USD)': 305.83,
#    'country': 'United States',
#    'pe_ratio_ttm': 37.2056,
#    'dividend_yield_ttm': 0.506818,
#    'operating_margin_ttm': 21.8},
#   {'Rank': 46,
#    'Name': 'ICBC',
#    'Symbol': '1398.HK',
#    'marketcap': 316091621707,
#    'price (USD)': 0.886886,
#    'country': 'China',
#    'pe_ratio_ttm': 6.61549,
#    'dividend_yield_ttm': 4.83758,
#    'operating_margin_ttm': 0.0},
#   {'Rank': 47,
#    'Name': 'HSBC',
#    'Symbol': 'HSBC',
#    'marketcap': 313469206528,
#    'price (USD)': 91.4,
#    'country': 'United Kingdom',
#    'pe_ratio_ttm': 11.7935,
#    'dividend_yield_ttm': 4.10284,
#    'operating_margin_ttm': 45.16},
#   {'Rank': 48,
#    'Name': 'CATL',
#    'Symbol': '300750.SZ',
#    'marketcap': 311589388930,
#    'price (USD)': 67.3489,
#    'country': 'China',
#    'pe_ratio_ttm': 58.4672,
#    'dividend_yield_ttm': 1.72907,
#    'operating_margin_ttm': 20.85},
#   {'Rank': 49,
#    'Name': 'Morgan Stanley',
#    'Symbol': 'MS',
#    'marketcap': 307012796416,
#    'price (USD)': 193.35,
#    'country': 'United States',
#    'pe_ratio_ttm': 18.7355,
#    'dividend_yield_ttm': 1.55159,
#    'operating_margin_ttm': 33.28},
#   {'Rank': 50,
#    'Name': 'GE Vernova',
#    'Symbol': 'GEV',
#    'marketcap': 300686934016,
#    'price (USD)': 1118.96,
#    'country': 'United States',
#    'pe_ratio_ttm': 62.061,
#    'dividend_yield_ttm': 0.134053,
#    'operating_margin_ttm': 7.42}]}

# %%
# Cell 11: Test get_top_value_companies - Placeholder                                                                                                               
print("="*80)                                                                                                                                                       
print("10. get_top_value_companies(limit=5)")                                                                                                                       
print("TRANSFORMATION: None - placeholder for screener API")                                                                                                        
print("="*80)   
value = get_top_value_companies(limit=5)                                                                                                                            
value
# Out:
# ================================================================================
# 10. get_top_value_companies(limit=5)
# TRANSFORMATION: None - placeholder for screener API
# ================================================================================
# {'count': 5,
#  'data': [{'Rank': 8,
#    'Name': 'Saudi Aramco',
#    'Symbol': '2222.SR',
#    'marketcap': 1741129613706,
#    'price (USD)': 7.1975,
#    'country': 'Saudi Arabia',
#    'pe_ratio_ttm': 16.9608,
#    'dividend_yield_ttm': 4.93785,
#    'operating_margin_ttm': 40.49},
#   {'Rank': 15,
#    'Name': 'JPMorgan Chase',
#    'Symbol': 'JPM',
#    'marketcap': 843778097152,
#    'price (USD)': 314.9,
#    'country': 'United States',
#    'pe_ratio_ttm': 15.7057,
#    'dividend_yield_ttm': 1.87361,
#    'operating_margin_ttm': 39.79},
#   {'Rank': 19,
#    'Name': 'Exxon Mobil',
#    'Symbol': 'XOM',
#    'marketcap': 616312209408,
#    'price (USD)': 148.69,
#    'country': 'United States',
#    'pe_ratio_ttm': 22.2257,
#    'dividend_yield_ttm': 2.71706,
#    'operating_margin_ttm': 12.74},
#   {'Rank': 24,
#    'Name': 'Tencent',
#    'Symbol': 'TCEHY',
#    'marketcap': 550573375488,
#    'price (USD)': 60.88,
#    'country': 'China',
#    'pe_ratio_ttm': 18.3328,
#    'dividend_yield_ttm': 0.941196,
#    'operating_margin_ttm': 34.51},
#   {'Rank': 25,
#    'Name': 'Johnson & Johnson',
#    'Symbol': 'JNJ',
#    'marketcap': 540709060608,
#    'price (USD)': 224.62,
#    'country': 'United States',
#    'pe_ratio_ttm': 20.1659,
#    'dividend_yield_ttm': 2.31502,
#    'operating_margin_ttm': 34.58}]}

# %%
# Cell 12: Test get_top_growth_companies - Placeholder                                                                                                              
print("="*80)                                                                                                                                                       
print("11. get_top_growth_companies(limit=5)")                                                                                                                      
print("TRANSFORMATION: None - placeholder for growth screening")                                                                                                    
print("="*80)                                                                                                                                                       
                                                                                                                                                                    
growth = get_top_growth_companies(limit=5)                                                                                                                          
growth
# Out:
# ================================================================================
# 11. get_top_growth_companies(limit=5)
# TRANSFORMATION: None - placeholder for growth screening
# ================================================================================
# {'count': 5,
#  'data': [{'Rank': 1,
#    'Name': 'NVIDIA',
#    'Symbol': 'NVDA',
#    'marketcap': 5051308310528,
#    'price (USD)': 207.83,
#    'country': 'United States',
#    'pe_ratio_ttm': 42.1562,
#    'dividend_yield_ttm': 0.0192465,
#    'operating_margin_ttm': 65.62},
#   {'Rank': 2,
#    'Name': 'Alphabet (Google)',
#    'Symbol': 'GOOG',
#    'marketcap': 4787296796672,
#    'price (USD)': 395.14,
#    'country': 'United States',
#    'pe_ratio_ttm': 36.2181,
#    'dividend_yield_ttm': 0.212583,
#    'operating_margin_ttm': 39.6},
#   {'Rank': 3,
#    'Name': 'Apple',
#    'Symbol': 'AAPL',
#    'marketcap': 4222761828352,
#    'price (USD)': 287.51,
#    'country': 'United States',
#    'pe_ratio_ttm': 36.3018,
#    'dividend_yield_ttm': 0.36172699999999997,
#    'operating_margin_ttm': 31.89},
#   {'Rank': 4,
#    'Name': 'Microsoft',
#    'Symbol': 'MSFT',
#    'marketcap': 3075074949120,
#    'price (USD)': 413.96,
#    'country': 'United States',
#    'pe_ratio_ttm': 25.808,
#    'dividend_yield_ttm': 0.8406610000000001,
#    'operating_margin_ttm': 47.97},
#   {'Rank': 5,
#    'Name': 'Amazon',
#    'Symbol': 'AMZN',
#    'marketcap': 2958097383424,
#    'price (USD)': 274.99,
#    'country': 'United States',
#    'pe_ratio_ttm': 37.7215,
#    'dividend_yield_ttm': 0.0,
#    'operating_margin_ttm': 13.57}]}

# %%
# Cell 13: Test ticker normalization (FB -> META)                                                                                                                   
print("="*80)                                                                                                                                                       
print("12. BONUS: Ticker Normalization")                                                                                                                            
print("TRANSFORMATION: Maps deprecated tickers (FB -> META)")                                                                                                       
print("="*80)                                                                                                                                                       
                                                                                                                                                                    
from stocks_agent.tools import normalize_ticker                                                                                                                     
                                                                                                                                                                    
print(f"normalize_ticker('FB')    -> {normalize_ticker('FB')}")                                                                                                     
print(f"normalize_ticker('GOOGL') -> {normalize_ticker('GOOGL')}")                                                                                                  
print(f"normalize_ticker('AAPL')  -> {normalize_ticker('AAPL')}")                                                                                                   
                                                                                                                                                                    
print("\nTest FB -> META in get_company_info:")                                                                                                                     
fb_info = get_company_info('FB')                                                                                                                                    
print(f"Input: 'FB'")                                                                                                                                               
print(f"Output ticker: '{fb_info['ticker']}'")                                                                                                                      
fb_info
# Out:
# ================================================================================
# 12. BONUS: Ticker Normalization
# TRANSFORMATION: Maps deprecated tickers (FB -> META)
# ================================================================================
# normalize_ticker('FB')    -> META
# normalize_ticker('GOOGL') -> GOOG
# normalize_ticker('AAPL')  -> AAPL
#
# Test FB -> META in get_company_info:
# Input: 'FB'
# Output ticker: 'FB'
# {'ticker': 'FB',
#  'company': {'longBusinessSummary': 'The index measures the performance of this Dynamic Buffer Strategy based on the S&P 500 Index using a long position in the S&P 500 Index along with three different S&P 500 Index options that have one day to expiration. Under normal circumstances, the fund will invest at least 80% of its total assets in components of the index or in instruments with similar economic characteristics. The fund is non-diversified.',
#   'companyOfficers': [],
#   'region': 'US',
#   'fullExchangeName': 'Cboe US'},
#  'price': {'previousClose': 43.9098,
#   'open': 44.36,
#   'dayLow': 44.185,
#   'dayHigh': 44.185,
#   'regularMarketDayRange': '44.185 - 44.185',
#   'fiftyTwoWeekLow': 39.91,
#   'fiftyTwoWeekHigh': 46.01,
#   'fiftyTwoWeekRange': '39.91 - 46.01',
#   'allTimeHigh': 46.01,
#   'allTimeLow': 39.91},
#  'market': {'volume': 184,
#   'averageVolume': 455,
#   'averageVolume10days': 320,
#   'trailingPegRatio': None},
#  'averages': {'fiftyDayAverage': 42.77512,
#   'twoHundredDayAverage': 41.926376,
#   'fiftyDayAverageChange': 1.4098816,
#   'twoHundredDayAverageChange': 2.258625}}

# %%
# Cell 14: Test search_reddit_x_sentiment - NEW Week 1 function                                                                                                     
print("="*80)                                                                                                                                                       
print("12. search_reddit_x_sentiment('NVDA AI chip demand', 'NVDA')")                                                                                              
print("TRANSFORMATION: Searches Reddit/X for sentiment using x.ai API")                                                                                            
print("                Returns structured data with raw sources for debugging")                                                                                    
print("="*80)                                                                                                                                                       
                                                                                                                                                                    
sentiment_result = search_reddit_x_sentiment('NVDA AI chip demand', 'NVDA')                                                                                       
print(f"Summary: {sentiment_result['summary']}")                                                                                                                   
print(f"Overall sentiment: {sentiment_result['overall_sentiment']}")                                                                                               
print(f"Confidence: {sentiment_result['confidence']}")                                                                                                             
print(f"Total messages: {sentiment_result['total_messages']}")                                                                                                     
                                                                                                                                                                    
if 'error' in sentiment_result:                                                                                                                                    
    print(f"\nNote: {sentiment_result['error']}")                                                                                                                   
    print("To test with real data, set XAI_API_KEY in your .envrc file")                                                                                           
                                                                                                                                                                    
# Show full result                                                                                                                                                 
sentiment_result
# Out:
# ================================================================================
# 12. search_reddit_x_sentiment('NVDA AI chip demand', 'NVDA')
# TRANSFORMATION: Searches Reddit/X for sentiment using x.ai API
#                 Returns structured data with raw sources for debugging
# ================================================================================
# Summary: Sentiment analysis for 'NVDA AI chip demand' - API response received
# Overall sentiment: neutral
# Confidence: 0.7
# Total messages: 1
# {'summary': "Sentiment analysis for 'NVDA AI chip demand' - API response received",
#  'sources': [{'platform': 'x',
#    'url': 'https://x.com/example',
#    'title': 'Example post',
#    'snippet': '{\n  "summary": "Overall sentiment is positive. Discussions highlight surging demand for NVIDIA\'s AI chips (H100, H200, Blackwell), driven by hyperscaler orders, with frequent mentions of supply constr...',
#    'full_text': '{\n  "summary": "Overall sentiment is positive. Discussions highlight surging demand for NVIDIA\'s AI chips (H100, H200, Blackwell), driven by hyperscaler orders, with frequent mentions of supply constraints and strong growth projections for $NVDA. Minor neutral/negative notes on valuation and potential China/export risks appear but do not dominate.",\n  "raw_messages": [\n    {\n      "platform": "X",\n      "content": "NVIDIA AI chip demand is insane right now—MSFT, GOOG, AMZN all ramping orders for Blackwell. $NVDA supply can\'t keep up, this is the real deal.",\n      "sentiment": "positive",\n      "timestamp": "2024-10-02"\n    },\n    {\n      "platform": "Reddit",\n      "content": "Just read the latest supply chain notes on r/stocks—NVDA H100/H200 demand still outstripping production by 2x. Earnings beat incoming.",\n      "sentiment": "positive",\n      "timestamp": "2024-10-01"\n    },\n    {\n      "platform": "X",\n      "content": "$NVDA AI revenue guidance looks conservative again. Demand from sovereign AI and data centers is massive, shorts are going to get crushed.",\n      "sentiment": "positive",\n      "timestamp": "2024-09-30"\n    },\n    {\n      "platform": "Reddit",\n      "content": "Blackwell ramp is delayed per some analysts but demand is so high NVDA is selling every chip they can make. Still bullish long term.",\n      "sentiment": "positive",\n      "timestamp": "2024-09-29"\n    },\n    {\n      "platform": "X",\n      "content": "Reminder: NVDA isn\'t just hype. Real AI chip orders from every major cloud provider continue to accelerate. Position size accordingly.",\n      "sentiment": "positive",\n      "timestamp": "2024-09-28"\n    },\n    {\n      "platform": "Reddit",\n      "content": "Posted in r/wallstreetbets: NVDA demand metrics from Taiwan suppliers show no slowdown. This pullback is a gift before next leg up.",\n      "sentiment": "positive",\n      "timestamp": "2024-09-27"\n    },\n    {\n      "platform": "X",\n      "content": "Some worry on export curbs to China but AI chip demand from US/Europe/Middle East is more than enough to offset. $NVDA stays strong.",\n      "sentiment": "neutral",\n      "timestamp": "2024-09-26"\n    },\n    {\n      "platform": "Reddit",\n      "content": "NVDA valuation feels stretched at these levels even with AI tailwinds. Demand is real but multiples price in perfection.",\n      "sentiment": "neutral",\n      "timestamp": "2024-09-25"\n    },\n    {\n      "platform": "X",\n      "content": "NVIDIA just can\'t make enough AI GPUs. Every earnings call the story is the same: demand >> supply. $NVDA to 150+ soon.",\n      "sentiment": "positive",\n      "timestamp": "2024-09-24"\n    },\n    {\n      "platform": "Reddit",\n      "content": "Saw a note from a semi analyst—NVDA\'s AI chip backlog is record high. No signs of demand destruction yet despite higher interest rates.",\n      "sentiment": "positive",\n      "timestamp": "2024-09-23"\n    }\n  ],\n  "confidence": 65\n}',
#    'sentiment': 'neutral',
#    'timestamp': '2026-05-06T23:04:12.426588',
#    'score': 0}],
#  'overall_sentiment': 'neutral',
#  'confidence': 0.7,
#  'total_messages': 1,
#  'raw_api_response': '{\n  "summary": "Overall sentiment is positive. Discussions highlight surging demand for NVIDIA\'s AI chips (H100, H200, Blackwell), driven by hyperscaler orders, with frequent mentions of supply constraints and strong growth projections for $NVDA. Minor neutral/negative notes on valuation and potential China/export risks appear but do not dominate.",\n  "raw_messages": [\n    {\n      "platform": "X",\n      "content": "NVIDIA AI chip demand is insane right now—MSFT, GOOG, AMZN all ramping orders for Blackwell. $NVDA supply can\'t keep up, this is the real deal.",\n      "sentiment": "positive",\n      "timestamp": "2024-10-02"\n    },\n    {\n      "platform": "Reddit",\n      "content": "Just read the latest supply chain notes on r/stocks—NVDA H100/H200 demand still outstripping production by 2x. Earnings beat incoming.",\n      "sentiment": "positive",\n      "timestamp": "2024-10-01"\n    },\n    {\n      "platform": "X",\n      "content": "$NVDA AI revenue guidance looks conservative again. Demand from sovereign AI and data centers is massive, shorts are going to get crushed.",\n      "sentiment": "positive",\n      "timestamp": "2024-09-30"\n    },\n    {\n      "platform": "Reddit",\n      "content": "Blackwell ramp is delayed per some analysts but demand is so high NVDA is selling every chip they can make. Still bullish long term.",\n      "sentiment": "positive",\n      "timestamp": "2024-09-29"\n    },\n    {\n      "platform": "X",\n      "content": "Reminder: NVDA isn\'t just hype. Real AI chip orders from every major cloud provider continue to accelerate. Position size accordingly.",\n      "sentiment": "positive",\n      "timestamp": "2024-09-28"\n    },\n    {\n      "platform": "Reddit",\n      "content": "Posted in r/wallstreetbets: NVDA demand metrics from Taiwan suppliers show no slowdown. This pullback is a gift before next leg up.",\n      "sentiment": "positive",\n      "timestamp": "2024-09-27"\n    },\n    {\n      "platform": "X",\n      "content": "Some worry on export curbs to China but AI chip demand from US/Europe/Middle East is more than enough to offset. $NVDA stays strong.",\n      "sentiment": "neutral",\n      "timestamp": "2024-09-26"\n    },\n    {\n      "platform": "Reddit",\n      "content": "NVDA valuation feels stretched at these levels even with AI tailwinds. Demand is real but multiples price in perfection.",\n      "sentiment": "neutral",\n      "timestamp": "2024-09-25"\n    },\n    {\n      "platform": "X",\n      "content": "NVIDIA just can\'t make enough AI GPUs. Every earnings call the story is the same: demand >> supply. $NVDA to 150+ soon.",\n      "sentiment": "positive",\n      "timestamp": "2024-09-24"\n    },\n    {\n      "platform": "Reddit",\n      "content": "Saw a note from a semi analyst—NVDA\'s AI chip backlog is record high. No signs of demand destruction yet despite higher interest rates.",\n      "sentiment": "positive",\n      "timestamp": "2024-09-23"\n    }\n  ],\n  "confidence": 65\n}'}

# %% [markdown]
# # 1) Testing Agents
#
# **⚠️ IMPORTANT:** Before running agent tests, make sure you've run **Cell 1.5** above to load your API keys!

# %%
# SimpleAgent: No memory, treats each question independently
from stocks_agent.simple_agent import SimpleAgent

# old before May 2026: "gpt-4o-mini"

simple = SimpleAgent(model="gpt-5.4-mini")
print("✓ SimpleAgent initialized")
# Out:
# ✓ SimpleAgent initialized

# %%
# Test basic query
response = await simple.ask("What's AAPL's PE ratio?")
print(response)
# Out:
# 🤖 Model: gpt-5.4-mini
#
# AAPL’s **trailing P/E ratio is 34.77** and its **forward P/E is 30.04**.
#
# 🔧 Tools called: 1
#    1. get_company_info({"ticker":"AAPL"})

# %%
# Test another query (no memory - won't remember AAPL)
response = await simple.ask("What about the earnings?")
print(response)  # Won't know you meant AAPL
# Out:
# 🤖 Model: gpt-5.4-mini
#
# Which stock ticker do you mean?
#
# If you want, I can pull:
# - next earnings date
# - recent EPS history
# - analyst EPS estimates and revisions
# - earnings surprise trend
# - recent earnings-related news
#
# Just send the ticker symbol, like `AAPL` or `TSLA`.

# %%
# Test another query - more extended question
response = await simple.ask("Recent news and sentiment on AAPL? EPS trend and analysts change in sentiment")
print(response)
# Out:
# 🤖 Model: gpt-5.4-mini
#
# Here’s a concise read on **AAPL recent news, sentiment, EPS trend, and analyst revisions** as of **May 6, 2026**.
#
# ## Recent news / catalysts
# - Apple’s stock hit a **new record close** at **$287.51** on May 6, 2026, which suggests momentum remains strong. citeturn0search0
# - Recent coverage is broadly positive around:
#   - **strong March-quarter results**,
#   - a **new $100B buyback authorization**,
#   - a **4% dividend increase**,
#   - and continued optimism around **AI features / services growth**. citeturn0search0turn0search6turn0search8
# - Main concerns in the news flow are:
#   - **China competition**,
#   - **valuation**,
#   - and some legal / settlement headlines. citeturn0search0turn0search7turn0search8
#
# ## Sentiment
# - Social sentiment from Reddit/X is **net positive**, with bullish themes around:
#   - earnings beats,
#   - AI momentum,
#   - services growth,
#   - buybacks,
#   - and analyst upgrades. citeturn0search4
# - The negative side is mostly about:
#   - **Huawei / China share pressure**,
#   - and **high valuation**. citeturn0search4
#
# ## EPS trend
# Apple’s analyst EPS estimates have been moving **upward** across all major periods:
#
# - **Current quarter (0q):** 1.89077 vs 1.73489 30 days ago
# - **Next quarter (+1q):** 2.00723 vs 1.97480 30 days ago
# - **Current year (0y):** 8.76584 vs 8.49816 30 days ago
# - **Next year (+1y):** 9.61862 vs 9.35511 30 days ago citeturn0search1
#
# That means analysts have been **raising estimates**, especially for the current quarter and full-year numbers. citeturn0search1turn0search2
#
# ## Analyst sentiment changes
# - Apple currently has **42 analyst opinions** with a **buy** consensus and **recommendation mean of 1.92**. citeturn0search2turn0search3
# - Target prices:
#   - **Low:** $215
#   - **Mean:** $303.38
#   - **Median:** $310
#   - **High:** $355 citeturn0search2turn0search3
# - Revisions have been **net positive**:
#   - **0q:** 22 upgrades / 0 downgrades in the last 30 days
#   - **0y:** 28 upgrades / 0 downgrades in the last 30 days
#   - **+1y:** 25 upgrades / 2 downgrades in the last 30 days citeturn0search2
#
# ## Quick interpretation
# - **Bullish:** rising EPS estimates, strong analyst support, record stock price, buybacks, and positive sentiment. citeturn0search1turn0search2turn0search4turn0search6
# - **Bearish / watch items:** valuation is rich, China remains a risk, and near-term upside may depend on whether Apple can keep proving AI/services growth. citeturn0search0turn0search3turn0search4
#
# If you want, I can also turn this into a **bull vs bear case table** or compare **AAPL vs MSFT / NVDA / GOOGL** on valuation and sentiment.
#
# 🔧 Tools called: 5
#    1. get_ticker_news({"ticker":"AAPL","limit":10})
#    2. get_eps_trend({"ticker":"AAPL"})
#    3. get_earnings_analysis({"ticker":"AAPL"})
#    4. get_company_info({"ticker":"AAPL"})
#    5. search_reddit_x_sentiment({"query":"AAPL Apple recent sentiment news analysts","ticker":"AAPL","num_results":10})

# %%
# ConversationAgent: Remembers context, auto-tracks tickers, handles follow-ups
  # Cell 1: Import and initialize ConversationAgent
from stocks_agent.conversation_agent import ConversationAgent

conv = ConversationAgent(track_tickers=True, model="gpt-5.4-mini")
print("✓ ConversationAgent initialized")
# Out:
# ✓ ConversationAgent initialized

# %%
# Conv agent: Ask the same question about AAPL

response = await conv.ask("Recent news and sentiment on AAPL? EPS trend and analysts change in sentiment")
print(response)
# Out:
# Here’s a quick read on **AAPL** based on the latest available data:
#
# ### Recent news / sentiment
# Sentiment looks **constructive to positive** overall. Apple’s stock hit a **record close of $287.51 on May 6, 2026**, and recent coverage is focused on:
# - strong March-quarter results,
# - a large **$100B buyback**,
# - a **4% dividend increase**,
# - and ongoing discussion about chip-supply diversification and AI-related positioning. citeturn0search0
#
# There are also some **headline risks / mixed themes** in the news flow:
# - legal settlement headlines tied to AI capability claims,
# - and broader market chatter that Apple may need to prove more in the coming weeks to sustain sentiment. citeturn0search0
#
# ### EPS trend
# EPS estimates have been **moving up** across all key periods:
#
# - **Current quarter (0q):** 1.89077 vs 1.73489 30 days ago
# - **Next quarter (+1q):** 2.00723 vs 1.97480 30 days ago
# - **Current year (0y):** 8.76584 vs 8.49816 30 days ago
# - **Next year (+1y):** 9.61862 vs 9.35511 30 days ago citeturn0search1
#
# That suggests analysts have been **raising expectations**, especially for the near term and full-year outlook. citeturn0search1turn0search2
#
# ### Analyst sentiment changes
# Analyst sentiment is still **bullish overall**:
# - **42 analysts**
# - **Consensus recommendation: Buy**
# - **Mean target: $303.38**
# - **Median target: $310**
# - **Range: $215 to $355**
# - Current price in the dataset: **$287.51** citeturn0search2
#
# ### EPS revisions
# Revisions have been **net positive**:
# - **0q:** 22 upward revisions in the last 7 days, 0 downward
# - **0y:** 27 upward revisions in the last 7 days, 0 downward
# - **+1q:** 18 up vs 4 down in the last 7 days
# - **+1y:** 23 up vs 3 down in the last 7 days citeturn0search2
#
# ### Bottom line
# The setup is **positive**:
# - news flow is supportive,
# - EPS estimates are trending higher,
# - and analyst sentiment remains favorable. citeturn0search0turn0search1turn0search2
#
# The main thing to watch is whether Apple can keep delivering enough growth to justify the elevated expectations, especially with the stock already near record highs. citeturn0search0turn0search2
#
# If you want, I can also break this down into:
# 1. **bull case vs bear case**, or
# 2. **valuation vs peers** for AAPL.
#
# 🔧 Tools called: 3
#    1. get_ticker_news({"ticker":"AAPL","limit":10})
#    2. get_eps_trend({"ticker":"AAPL"})
#    3. get_earnings_analysis({"ticker":"AAPL"})

# %%
response = await conv.ask("Follow-up: what are the competitors trends?")
print(response)
# Out:
# 💡 Auto-context: Analyzing AAPL
#
# For **AAPL**, the main competitor trends look like this:
#
# - **Smartphones:** Apple is still strong, but competitors have been pushing **foldables** and other form-factor innovation earlier. Recent coverage suggests Apple is **late to foldables**, with a foldable iPhone expected later in 2026, while rivals have already established the category. At the same time, Apple has been **gaining share in China**, which is a positive sign against Android rivals. citeturn0search0turn0search2turn0search1
# - **AI / on-device intelligence:** Competitors like **Google, Microsoft, Meta, and Amazon** are spending aggressively on AI infrastructure and models. Apple’s approach is more capital-light: it’s leaning on partnerships, including Google’s Gemini, rather than building everything in-house. That makes Apple look more conservative, but also potentially more efficient. citeturn0search4turn0search3
# - **Semiconductors / mobile chips:** **Qualcomm** is being watched as a beneficiary of AI smartphone chip demand, including reported OpenAI-related collaboration. That suggests the mobile hardware ecosystem is shifting toward AI-capable devices, which could pressure Apple to keep accelerating its own AI roadmap. citeturn0search7
# - **PCs and tablets:** Apple’s Mac and iPad businesses face ongoing competition from Windows OEMs and Android tablet makers, but the bigger trend is that Apple’s **ecosystem and services** remain the key moat rather than pure hardware innovation. citeturn0search0turn0search4
# - **Wearables / ecosystem:** Apple still appears well-positioned because of its installed base and retention. Recent commentary emphasizes that the real competitive advantage is **brand loyalty and ecosystem lock-in**, not just product launches. citeturn0search8turn0search0
#
# **Bottom line:** competitors are trending faster in **AI hardware and foldables**, but Apple is trending well in **ecosystem strength, China share, and services growth**. So the competitive picture is mixed: Apple may be behind on some product cycles, but it still has one of the strongest consumer moats in tech. citeturn0search1turn0search2turn0search4turn0search8
#
# If you want, I can also break this down by **specific competitors** like **Samsung, Google, Microsoft, and Qualcomm**.
#
# 🔧 Tools called: 3
#    1. search_companies({"query":null,"ticker":"AAPL","min_market_cap":null,"max_market_cap":null,"min_pe":null,"max_pe":null,"min_dividend":null,"max_dividend":null,"min_margin":null,"max_margin":null,"country":null,"limit":10})
#    2. get_company_info({"ticker":"AAPL"})
#    3. search_news_by_query({"query":"Apple competitors trends iPhone smartphone PC wearables services", "num_results":10})

# %%
# get the internal context:
tickers = conv.get_tickers()
print(f"Tickers discussed: {tickers}")
print(f"Current ticker: {conv.current_ticker}")
# Out:
# Tickers discussed: {'AAPL'}
# Current ticker: AAPL

# %%
# StructuredAgent: Returns both text analysis + structured data dict for programmatic use

from stocks_agent.structured_agent import StructuredAgent
import json
structured = StructuredAgent(model="gpt-5.4-mini")
print("✓ StructuredAgent initialized")
# Out:
# ✓ StructuredAgent initialized

# %%
# Analyze AAPL
text, data = await structured.analyze('AAPL')

# show the resulting text
print("="*80)
print("TEXT RESPONSE:")
print(text)
# Out:
# ================================================================================
# TEXT RESPONSE:
# 🤖 Model: gpt-5.4-mini
#
# Apple is a large-cap Technology company in Consumer Electronics with a broad ecosystem spanning iPhone, Mac, iPad, wearables, services, and payments. The company remains highly profitable, with a trailing P/E of 34.8, forward P/E of 30.0, PEG of 2.49, and price-to-book of 47.9. Those valuation multiples indicate the market is still pricing in durable earnings power and continued services-led growth, but they also leave little room for disappointment.
#
# EPS trends are improving. The current quarter estimate is 1.89077 versus 1.73107 ninety days ago, and the full-year estimate has also risen from 8.45978 to 8.76584 over the same window. Next-quarter and next-year estimates show similar upward drift, which suggests analysts have been incrementally more constructive on Apple’s earnings outlook.
#
# Analyst sentiment is positive. The consensus recommendation is buy, with 42 analysts covering the name and a mean recommendation score of 1.91667. The mean target price is 303.38, implying modest upside from the current price of 287.51. That target is not dramatically above the market price, so the stock appears to be viewed as a quality compounder rather than a deep-value opportunity.
#
# Price momentum is positive, but the stock is close to its 52-week high. Over the last three months, Apple has gained enough to sit just 0.18% below the period high and 17.11% above the period low. That places the shares in a strong uptrend, though the proximity to highs means near-term upside may depend on continued execution and favorable catalysts.
#
# Recent news flow is active, with five recent items in the feed. The themes skew toward Apple’s record-high stock performance and broader technology-sector momentum, alongside commentary about the smartphone era and AI-driven hardware transitions. The headlines suggest investor attention is centered on Apple’s ability to defend its ecosystem leadership as the market looks toward the next computing cycle.
#
# Overall, Apple screens as a high-quality, momentum-supported large cap with improving earnings estimates and constructive analyst sentiment. The valuation is best described as fair rather than cheap or expensive under the provided rule set, because the stock is only modestly below its 52-week high. The setup remains fundamentally strong, but the current price already reflects a substantial amount of optimism.
#
# 🔧 Tools called: 4
#    1. get_company_info({"ticker":"AAPL"})
#    2. get_eps_trend({"ticker":"AAPL"})
#    3. get_historical_prices({"ticker":"AAPL","period":"3mo","interval":"1d"})
#    4. get_ticker_news({"ticker":"AAPL","limit":5})

# %%
print("\n" + "="*80)
print("STRUCTURED DATA:")
print(json.dumps(data, indent=2, default=str))
# Out:
# ================================================================================
# STRUCTURED DATA:
# {
#   "ticker": "AAPL",
#   "company_name": "Apple Inc.",
#   "sector": "Technology",
#   "industry": "Consumer Electronics",
#   "pe_ratio": 34.765415,
#   "forward_pe": 30.039297,
#   "peg_ratio": 2.4891,
#   "price_to_book": 47.93431,
#   "current_price": 287.51,
#   "target_price": 303.3762,
#   "eps_trend_direction": "improving",
#   "analyst_sentiment": "buy",
#   "analyst_count": 42,
#   "recommendation_mean": 1.91667,
#   "distance_from_high_pct": -0.1805329361093102,
#   "distance_from_low_pct": 17.10725273859253,
#   "valuation_summary": "fair",
#   "momentum": "positive",
#   "news_count": 5,
#   "analysis_summary": "Apple is a large-cap Technology company in Consumer Electronics with a broad ecosystem spanning iPhone, Mac, iPad, wearables, services, and payments. The company remains highly profitable, with a trailing P/E of 34.8, forward P/E of 30.0, PEG of 2.49, and price-to-book of 47.9. Those valuation multiples indicate the market is still pricing in durable earnings power and continued services-led growth, but they also leave little room for disappointment.\n\nEPS trends are improving. The current quarter estimate is 1.89077 versus 1.73107 ninety days ago, and the full-year estimate has also risen from 8.45978 to 8.76584 over the same window. Next-quarter and next-year estimates show similar upward drift, which suggests analysts have been incrementally more constructive on Apple\u2019s earnings outlook.\n\nAnalyst sentiment is positive. The consensus recommendation is buy, with 42 analysts covering the name and a mean recommendation score of 1.91667. The mean target price is 303.38, implying modest upside from the current price of 287.51. That target is not dramatically above the market price, so the stock appears to be viewed as a quality compounder rather than a deep-value opportunity.\n\nPrice momentum is positive, but the stock is close to its 52-week high. Over the last three months, Apple has gained enough to sit just 0.18% below the period high and 17.11% above the period low. That places the shares in a strong uptrend, though the proximity to highs means near-term upside may depend on continued execution and favorable catalysts.\n\nRecent news flow is active, with five recent items in the feed. The themes skew toward Apple\u2019s record-high stock performance and broader technology-sector momentum, alongside commentary about the smartphone era and AI-driven hardware transitions. The headlines suggest investor attention is centered on Apple\u2019s ability to defend its ecosystem leadership as the market looks toward the next computing cycle.\n\nOverall, Apple screens as a high-quality, momentum-supported large cap with improving earnings estimates and constructive analyst sentiment. The valuation is best described as fair rather than cheap or expensive under the provided rule set, because the stock is only modestly below its 52-week high. The setup remains fundamentally strong, but the current price already reflects a substantial amount of optimism."
# }
