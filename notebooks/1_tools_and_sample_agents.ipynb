# %% [markdown]
# # Stocks Research Agent
#
# This notebook defines a set of tools (skills) and tries it for a sample agent

# %% [markdown]
# # 0) IMPORTS

# %%
# Setup autoreload - automatically reload modules when they change
# %load_ext autoreload
# %autoreload 2

# %%
# Verify environment setup
import os
import sys

print(f"Python version: {sys.version}")
print(f"Python executable: {sys.executable}")
print(f"\nEnvironment variables loaded:")
print(f"OPENAI_API_KEY: {'✓ Set' if os.getenv('OPENAI_API_KEY') else '✗ Not set'}")
print(f"POLYGON_API_KEY: {'✓ Set' if os.getenv('POLYGON_API_KEY') else '✗ Not set'}")
# Out:
# Python version: 3.12.7 (main, Oct  1 2024, 02:05:46) [Clang 16.0.0 (clang-1600.0.26.3)]
# Python executable: /Users/realmistic/Documents/stocks-scoring-agent/.venv/bin/python
#
# Environment variables loaded:
# OPENAI_API_KEY: ✓ Set
# POLYGON_API_KEY: ✓ Set

# %%
# Import key libraries
import yfinance as yf
import pandas as pd
from openai import OpenAI

from pprint import pprint

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# # 1) AGENT TOOLS

# %% [markdown]
# ## 1.0 Ticker (Stock) Info - > many useful stats, incl. some of the important ratios

# %%
from typing import Any

def get_company_info(ticker: str) -> dict[str, Any]:
    """
    Get comprehensive company information and fundamental data for a stock ticker.
    
    Returns key metrics organized by category:
    - Company basics: website, industry, sector, employees, officers
    - Price data: current, previous close, day range, 52-week range
    - Market metrics: market cap, volume, beta, PE ratios
    - Valuation: margins, book value, price ratios
    - Ownership: insider/institutional holdings, short interest
    - Analyst data: EPS estimates, targets, recommendations
    - Financial health: cash, returns, growth rates
    
    Args:
        ticker: Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')
    
    Returns:
        Dictionary with ticker and organized company information
    """
    try:
        ticker_obj = yf.Ticker(ticker)
        info = ticker_obj.get_info()

        if not info:
            return {"ticker": ticker, "error": "No company info available"}

        # Define the key fields to extract (organized by category)
        key_fields = {
            # Company basics
            "company": ["website", "industry", "sector", "longBusinessSummary",
                        "fullTimeEmployees", "companyOfficers", "region", "fullExchangeName"],

            # Price data
            "price": ["currentPrice", "previousClose", "open", "dayLow", "dayHigh",
                    "regularMarketDayRange", "fiftyTwoWeekLow", "fiftyTwoWeekHigh",
                    "fiftyTwoWeekRange", "allTimeHigh", "allTimeLow"],

            # Market metrics
            "market": ["marketCap", "volume", "averageVolume", "averageVolume10days",
                    "beta", "trailingPE", "forwardPE", "trailingPegRatio"],

            # Moving averages
            "averages": ["fiftyDayAverage", "twoHundredDayAverage",
                        "fiftyDayAverageChange", "twoHundredDayAverageChange"],

            # Valuation ratios
            "valuation": ["priceToSalesTrailing12Months", "priceToBook", "bookValue",
                        "profitMargins", "grossMargins", "ebitdaMargins", "operatingMargins"],

            # Ownership & short interest
            "ownership": ["sharesOutstanding", "floatShares", "sharesPercentSharesOut",
                        "heldPercentInsiders", "heldPercentInstitutions",
                        "sharesShort", "shortRatio", "shortPercentOfFloat"],

            # EPS & earnings
            "earnings": ["trailingEps", "forwardEps", "earningsQuarterlyGrowth",
                        "earningsGrowth", "revenueGrowth", "epsTrailingTwelveMonths",
                        "epsForward", "epsCurrentYear"],

            # Analyst targets & recommendations
            "analyst": ["targetHighPrice", "targetLowPrice", "targetMeanPrice",
                        "targetMedianPrice", "recommendationMean", "recommendationKey",
                        "numberOfAnalystOpinions", "averageAnalystRating"],

            # Financial health
            "financial": ["totalCash", "totalCashPerShare", "totalDebt", "totalRevenue",
                        "freeCashflow", "operatingCashflow", "returnOnAssets",
                        "returnOnEquity", "debtToEquity", "currentRatio", "quickRatio"]
        }

        # Extract data by category
        result = {"ticker": ticker}

        for category, fields in key_fields.items():
            category_data = {}
            for field in fields:
                if field in info:
                    category_data[field] = info[field]
            if category_data:
                result[category] = category_data

        return result

    except Exception as e:
        return {"ticker": ticker, "error": f"Failed to get company info: {str(e)}"}

# %%
# Get all company info
info = get_company_info("TSLA")
pprint(info)
# Out:
# {'analyst': {'averageAnalystRating': '2.3 - Buy',
#              'numberOfAnalystOpinions': 41,
#              'recommendationKey': 'buy',
#              'recommendationMean': 2.34043,
#              'targetHighPrice': 600.0,
#              'targetLowPrice': 123.0,
#              'targetMeanPrice': 420.54633,
#              'targetMedianPrice': 460.0},
#  'averages': {'fiftyDayAverage': 398.3,
#               'fiftyDayAverageChange': 8.130005,
#               'twoHundredDayAverage': 415.6944,
#               'twoHundredDayAverageChange': -9.264404},
#  'company': {'companyOfficers': [{'age': 54,
#                                   'exercisedValue': 0,
#                                   'fiscalYear': 2025,
#                                   'maxAge': 1,
#                                   'name': 'Mr. Elon R. Musk',
#                                   'title': 'Co-Founder, Technoking of Tesla, '
#                                            'CEO & Director',
#                                   'unexercisedValue': 129602732032,
#                                   'yearBorn': 1971},
#                                  {'age': 47,
#                                   'exercisedValue': 15033838,
#                                   'fiscalYear': 2025,
#                                   'maxAge': 1,
#                                   'name': 'Mr. Vaibhav  Taneja',
#                                   'title': 'Chief Financial Officer',
#                                   'totalPay': 403000,
#                                   'unexercisedValue': 417696224,
#                                   'yearBorn': 1978},
#                                  {'age': 45,
#                                   'exercisedValue': 4548562,
#                                   'fiscalYear': 2025,
#                                   'maxAge': 1,
#                                   'name': 'Mr. Xiaotong  Zhu',
#                                   'title': 'Senior Vice President of APAC & '
#                                            'Global Vehicle Manufacturing',
#                                   'totalPay': 376322,
#                                   'unexercisedValue': 808327104,
#                                   'yearBorn': 1980},
#                                  {'exercisedValue': 0,
#                                   'fiscalYear': 2025,
#                                   'maxAge': 1,
#                                   'name': 'Travis  Axelrod',
#                                   'title': 'Head of Investor Relations',
#                                   'unexercisedValue': 0},
#                                  {'exercisedValue': 0,
#                                   'fiscalYear': 2025,
#                                   'maxAge': 1,
#                                   'name': 'Mr. Brandon  Ehrhart',
#                                   'title': 'General Counsel & Corporate '
#                                            'Secretary',
#                                   'unexercisedValue': 0},
#                                  {'exercisedValue': 0,
#                                   'fiscalYear': 2025,
#                                   'maxAge': 1,
#                                   'name': 'Mr. Franz  von Holzhausen',
#                                   'title': 'Chief Designer',
#                                   'unexercisedValue': 0},
#                                  {'exercisedValue': 0,
#                                   'fiscalYear': 2025,
#                                   'maxAge': 1,
#                                   'name': 'Ms. Roxanne  Inskip-Kaye',
#                                   'title': 'Head of Operations - Electric '
#                                            'Vehicle Business',
#                                   'unexercisedValue': 0},
#                                  {'age': 62,
#                                   'exercisedValue': 0,
#                                   'fiscalYear': 2025,
#                                   'maxAge': 1,
#                                   'name': 'Mr. John  Walker',
#                                   'title': 'Vice President of Sales - North '
#                                            'America',
#                                   'totalPay': 121550,
#                                   'unexercisedValue': 0,
#                                   'yearBorn': 1963},
#                                  {'exercisedValue': 0,
#                                   'fiscalYear': 2025,
#                                   'maxAge': 1,
#                                   'name': 'Mr. Rodney D. Westmoreland Jr.',
#                                   'title': 'Director of Construction '
#                                            'Management',
#                                   'unexercisedValue': 0},
#                                  {'exercisedValue': 0,
#                                   'fiscalYear': 2025,
#                                   'maxAge': 1,
#                                   'name': 'Mr. Lars  Moravy',
#                                   'title': 'Vice President of Vehicle '
#                                            'Engineering',
#                                   'unexercisedValue': 0}],
#              'fullExchangeName': 'NasdaqGS',
#              'fullTimeEmployees': 134785,
#              'industry': 'Auto Manufacturers',
#              'longBusinessSummary': 'Tesla, Inc. designs, develops, '
#                                     'manufactures, leases, and sells electric '
#                                     'vehicles, and energy generation and '
#                                     'storage systems in the United States, '
#                                     'China, and internationally. The company '
#                                     'operates in two segments, Automotive; and '
#                                     'Energy Generation and Storage. The '
#                                     'company offers electric vehicles, as well '
#                                     'as sells automotive regulatory credits; '
#                                     'and non-warranty maintenance services and '
#                                     'collision, automotive insurance services, '
#                                     'as well as part sales and retail '
#                                     'merchandise sale. It also provides sedans '
#                                     'and sport utility vehicles through direct '
#                                     'and used vehicle sales, a network of '
#                                     'Tesla Superchargers, and in-app upgrades; '
#                                     'purchase financing and leasing services; '
#                                     'services for electric vehicles through '
#                                     'its company-owned service locations and '
#                                     'Tesla mobile service technicians; and '
#                                     'vehicle limited warranties and extended '
#                                     'service plans. In addition, the company '
#                                     'engages in the design, manufacture, '
#                                     'installation, sale, and leasing of solar '
#                                     'energy generation and energy storage '
#                                     'products, and related services to '
#                                     'residential, commercial, and industrial '
#                                     'customers and utilities through its '
#                                     'website, stores, and galleries, as well '
#                                     'as through a network of channel partners. '
#                                     'Further, it provides services and repairs '
#                                     'to its energy product customers, '
#                                     'including under warranty and extended '
#                                     'service plans; and various financing '
#                                     'options to its residential customers; '
#                                     'lithium-ion battery energy storage '
#                                     'products, such as Powerwall and Megapack; '
#                                     'energy generation products, including '
#                                     'solar panels and solar roof; self-driving '
#                                     'development and artificial intelligence '
#                                     'software, vehicle control and '
#                                     'infotainment software, and battery and '
#                                     'powertrain. The company was formerly '
#                                     'known as Tesla Motors, Inc. and changed '
#                                     'its name to Tesla, Inc. in February 2017. '
#                                     'Tesla, Inc. was incorporated in 2003 and '
#                                     'is headquartered in Austin, Texas.',
#              'region': 'US',
#              'sector': 'Consumer Cyclical',
#              'website': 'https://www.tesla.com'},
#  'earnings': {'earningsGrowth': 0.083,
#               'earningsQuarterlyGrowth': 0.166,
#               'epsCurrentYear': 2.05937,
#               'epsForward': 2.49995,
#               'epsTrailingTwelveMonths': 1.1,
#               'forwardEps': 2.49995,
#               'revenueGrowth': 0.158,
#               'trailingEps': 1.1},
#  'financial': {'currentRatio': 2.043,
#                'debtToEquity': 18.738,
#                'freeCashflow': 5251999744,
#                'operatingCashflow': 16528000000,
#                'quickRatio': 1.43,
#                'returnOnAssets': 0.022330001,
#                'returnOnEquity': 0.04901,
#                'totalCash': 44743000064,
#                'totalCashPerShare': 11.913,
#                'totalDebt': 15889999872,
#                'totalRevenue': 97878999040},
#  'market': {'averageVolume': 58965338,
#             'averageVolume10days': 49458150,
#             'beta': 1.798,
#             'forwardPE': 162.57526,
#             'marketCap': 1526438821888,
#             'trailingPE': 369.4818,
#             'trailingPegRatio': 5.5963,
#             'volume': 62460127},
#  'ownership': {'floatShares': 2815891530,
#                'heldPercentInsiders': 0.11111,
#                'heldPercentInstitutions': 0.44926,
#                'sharesOutstanding': 3755723871,
#                'sharesPercentSharesOut': 0.020499999,
#                'sharesShort': 76947758,
#                'shortPercentOfFloat': 0.023,
#                'shortRatio': 1.48},
#  'price': {'allTimeHigh': 498.83,
#            'allTimeLow': 0.998667,
#            'currentPrice': 406.43,
#            'dayHigh': 406.68,
#            'dayLow': 386.76,
#            'fiftyTwoWeekHigh': 498.83,
#            'fiftyTwoWeekLow': 288.77,
#            'fiftyTwoWeekRange': '288.77 - 498.83',
#            'open': 399.46,
#            'previousClose': 399.15,
#            'regularMarketDayRange': '386.76 - 406.68'},
#  'ticker': 'TSLA',
#  'valuation': {'bookValue': 21.897,
#                'ebitdaMargins': 0.11334,
#                'grossMargins': 0.19065,
#                'operatingMargins': 0.04203,
#                'priceToBook': 18.56099,
#                'priceToSalesTrailing12Months': 15.595161,
#                'profitMargins': 0.03946}}

# %%
# Access specific categories
if "error" not in info:
    # Company basics
    print("\n=== Company Info ===")
    print(f"Industry: {info['company']['industry']}")
    print(f"Sector: {info['company']['sector']}")
    print(f"Employees: {info['company']['fullTimeEmployees']:,}")
    print(f"Website: {info['company']['website']}")

    # Current price & targets
    print("\n=== Price & Targets ===")
    print(f"Current: ${info['price']['currentPrice']:.2f}")
    print(f"52-Week Range: {info['price']['fiftyTwoWeekRange']}")
    print(f"Analyst Target (Mean): ${info['analyst']['targetMeanPrice']:.2f}")
    print(f"Recommendation: {info['analyst']['recommendationKey']}")

    # Key metrics
    print("\n=== Key Metrics ===")
    print(f"Market Cap: ${info['market']['marketCap']:,.0f}")
    print(f"Forward P/E: {info['market']['forwardPE']:.2f}")
    print(f"Profit Margin: {info['valuation']['profitMargins']:.2%}")

    # Ownership
    print("\n=== Ownership ===")
    print(f"Insider: {info['ownership']['heldPercentInsiders']:.2%}")
    print(f"Institutional: {info['ownership']['heldPercentInstitutions']:.2%}")
    print(f"Short Interest: {info['ownership']['shortRatio']}")

    # Growth
    print("\n=== Growth ===")
    print(f"Revenue Growth: {info['earnings']['revenueGrowth']:.2%}")
    print(f"Earnings Growth: {info['earnings']['earningsGrowth']:.2%}")

# Convert a category to DataFrame
if "analyst" in info:
    df = pd.DataFrame([info["analyst"]])
    print(df)
# Out:
# === Company Info ===
# Industry: Auto Manufacturers
# Sector: Consumer Cyclical
# Employees: 134,785
# Website: https://www.tesla.com
#
# === Price & Targets ===
# Current: $406.43
# 52-Week Range: 288.77 - 498.83
# Analyst Target (Mean): $420.55
# Recommendation: buy
#
# === Key Metrics ===
# Market Cap: $1,526,438,821,888
# Forward P/E: 162.58
# Profit Margin: 3.95%
#
# === Ownership ===
# Insider: 11.11%
# Institutional: 44.93%
# Short Interest: 1.48
#
# === Growth ===
# Revenue Growth: 15.80%
# Earnings Growth: 8.30%
#    targetHighPrice  targetLowPrice  targetMeanPrice  targetMedianPrice  \
# 0            600.0           123.0        420.54633              460.0
#
#    recommendationMean recommendationKey  numberOfAnalystOpinions  \
# 0             2.34043               buy                       41
#
#   averageAnalystRating
# 0            2.3 - Buy

# %% [markdown]
# ## 1.1 EPS trend

# %%
from typing import Any

def get_eps_trend(ticker: str) -> dict[str, Any]:
    """
    Get the EPS (Earnings Per Share) trend for a given stock ticker - showing how analyst consensus has changed over time for different periods (quarterly, yearly)
    and diffent points in the past (current, 7daysAgo, 30daysAgo, etc.).
    Index: 0q (This Quarter),  +1q (Next Quarter),  0y (This Year),  +1y (Next Year) 
    and columns showing estimates from different points in the past (current, 7daysAgo, 30daysAgo, etc.). 

    Args:
        ticker: Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')
    
    Returns:
        Dictionary with ticker and EPS trend data
    """

    try:
        ticker_obj = yf.Ticker(ticker)
        result = ticker_obj.get_eps_trend()

        if isinstance(result, pd.DataFrame):
            if result.empty:
                return {"ticker": ticker, "error": "No EPS trend data available"}
            result['period']=result.index # create a new column 'period' from the index
            return {"ticker": ticker, "data": result.to_dict(orient='records')}

        # Fallback: wrap unexpected types
        if isinstance(result, dict):
            return {"ticker": ticker, "data": [result]}

        raise TypeError(f"Unexpected return type from get_eps_trend: {type(result)}")

    except Exception as e:
        return {"ticker": ticker, "error": f"Failed to get EPS trend: {str(e)}"}

# %%
r = get_eps_trend("TSLA")
# raw output to be used by an agent
print(r)
# pretty output for human consumption
print(f"\nFormatted output for ticker {r['ticker']}:")
print(pd.DataFrame(r['data']))
# Out:
# {'ticker': 'TSLA', 'data': [{'current': 0.45414, '7daysAgo': 0.45396, '30daysAgo': 0.45396, '60daysAgo': 0.44637, '90daysAgo': 0.46212, 'period': '0q'}, {'current': 0.5375, '7daysAgo': 0.5393, '30daysAgo': 0.5393, '60daysAgo': 0.53175, '90daysAgo': 0.5405, 'period': '+1q'}, {'current': 2.05937, '7daysAgo': 2.04967, '30daysAgo': 2.04835, '60daysAgo': 2.03873, '90daysAgo': 2.08858, 'period': '0y'}, {'current': 2.49995, '7daysAgo': 2.50462, '30daysAgo': 2.50969, '60daysAgo': 2.77175, '90daysAgo': 2.81043, 'period': '+1y'}]}
#
# Formatted output for ticker TSLA:
#    current  7daysAgo  30daysAgo  60daysAgo  90daysAgo period
# 0  0.45414   0.45396    0.45396    0.44637    0.46212     0q
# 1  0.53750   0.53930    0.53930    0.53175    0.54050    +1q
# 2  2.05937   2.04967    2.04835    2.03873    2.08858     0y
# 3  2.49995   2.50462    2.50969    2.77175    2.81043    +1y

# %% [markdown]
# ## 1.2 Earnings dates, previous EPS actual vs. predicted and surprise; next expected earnings date

# %%
from typing import Any

def get_earnings_dates(ticker: str) -> dict[str, Any]:
    """
    Get earnings call dates for a stock ticker.
    
    Returns historical earnings data including:
    - Expected EPS
    - Actual EPS  
    - Surprise percentage
    - Earnings dates from multiple quarters and years
    - Next earnings call date
    
    Args:
        ticker: Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')

    Returns:
        Dictionary with ticker and earnings dates data, surprise (%) - how reported earnings compared to expectations
    """
    try:
        ticker_obj = yf.Ticker(ticker)
        result = ticker_obj.get_earnings_dates()

        if isinstance(result, pd.DataFrame):
            if result.empty:
                return {"ticker": ticker, "error": "No earnings data available"}

            # Normalize common datetime-like columns to yyyy-mm-dd strings
            result.index = pd.to_datetime(result.index, errors="coerce").strftime("%Y-%m-%d")
            
            # Include the index (dates) as a column before converting to dict
            result = result.reset_index().rename(columns={"index": "date"})
            return {"ticker": ticker, "data": result.to_dict(orient='records')}

        # Unexpected type fallback
        raise TypeError(f"Unexpected return type from get_earnings_dates: {type(result)}")

    except Exception as e:
        return {"ticker": ticker, "error": f"Failed to get earnings dates: {str(e)}"}

# %%
r = get_earnings_dates("TSLA")
# raw output to be used by an agent
print(r)
# pretty output for human consumption
print(f"\nFormatted output for ticker {r['ticker']}:")
print(pd.DataFrame(r['data']))
# Out:
# {'ticker': 'TSLA', 'data': [{'Earnings Date': '2026-07-22', 'EPS Estimate': 0.45, 'Reported EPS': nan, 'Surprise(%)': nan}, {'Earnings Date': '2026-04-22', 'EPS Estimate': 0.2, 'Reported EPS': 0.13, 'Surprise(%)': -36.54}, {'Earnings Date': '2026-01-28', 'EPS Estimate': 0.45, 'Reported EPS': 0.5, 'Surprise(%)': 10.96}, {'Earnings Date': '2025-10-22', 'EPS Estimate': 0.56, 'Reported EPS': 0.5, 'Surprise(%)': -10.53}, {'Earnings Date': '2025-07-23', 'EPS Estimate': 0.3, 'Reported EPS': 0.33, 'Surprise(%)': 10.49}, {'Earnings Date': '2025-04-22', 'EPS Estimate': 0.41, 'Reported EPS': 0.27, 'Surprise(%)': -34.89}, {'Earnings Date': '2025-01-29', 'EPS Estimate': 0.77, 'Reported EPS': 0.73, 'Surprise(%)': -4.83}, {'Earnings Date': '2024-10-23', 'EPS Estimate': 0.6, 'Reported EPS': 0.72, 'Surprise(%)': 20.49}, {'Earnings Date': '2024-07-23', 'EPS Estimate': 0.62, 'Reported EPS': 0.52, 'Surprise(%)': -16.15}, {'Earnings Date': '2024-04-23', 'EPS Estimate': 0.49, 'Reported EPS': 0.45, 'Surprise(%)': -8.14}, {'Earnings Date': '2024-01-24', 'EPS Estimate': 0.74, 'Reported EPS': 0.71, 'Surprise(%)': -4.1}, {'Earnings Date': '2023-10-18', 'EPS Estimate': 0.73, 'Reported EPS': 0.66, 'Surprise(%)': -9.81}, {'Earnings Date': '2023-07-19', 'EPS Estimate': 0.82, 'Reported EPS': 0.91, 'Surprise(%)': 11.12}, {'Earnings Date': '2023-04-19', 'EPS Estimate': 0.85, 'Reported EPS': 0.85, 'Surprise(%)': -0.43}, {'Earnings Date': '2023-01-25', 'EPS Estimate': 1.11, 'Reported EPS': 1.19, 'Surprise(%)': 7.2}, {'Earnings Date': '2022-10-19', 'EPS Estimate': 1.0, 'Reported EPS': 1.05, 'Surprise(%)': 5.23}, {'Earnings Date': '2022-07-20', 'EPS Estimate': 0.6, 'Reported EPS': 0.76, 'Surprise(%)': 26.89}, {'Earnings Date': '2022-04-20', 'EPS Estimate': 0.75, 'Reported EPS': 1.07, 'Surprise(%)': 42.31}, {'Earnings Date': '2022-01-26', 'EPS Estimate': 0.79, 'Reported EPS': 0.85, 'Surprise(%)': 6.88}, {'Earnings Date': '2021-10-20', 'EPS Estimate': 0.54, 'Reported EPS': 0.62, 'Surprise(%)': 15.22}, {'Earnings Date': '2021-07-26', 'EPS Estimate': 0.32, 'Reported EPS': 0.48, 'Surprise(%)': 49.86}, {'Earnings Date': '2021-04-26', 'EPS Estimate': 0.26, 'Reported EPS': 0.31, 'Surprise(%)': 19.42}, {'Earnings Date': '2021-01-27', 'EPS Estimate': 0.35, 'Reported EPS': 0.27, 'Surprise(%)': -23.91}, {'Earnings Date': '2020-10-21', 'EPS Estimate': 0.2, 'Reported EPS': 0.25, 'Surprise(%)': 25.78}, {'Earnings Date': '2020-07-22', 'EPS Estimate': -0.01, 'Reported EPS': 0.15, 'Surprise(%)': 1460.77}]}
#
# Formatted output for ticker TSLA:
#    Earnings Date  EPS Estimate  Reported EPS  Surprise(%)
# 0     2026-07-22          0.45           NaN          NaN
# 1     2026-04-22          0.20          0.13       -36.54
# 2     2026-01-28          0.45          0.50        10.96
# 3     2025-10-22          0.56          0.50       -10.53
# 4     2025-07-23          0.30          0.33        10.49
# 5     2025-04-22          0.41          0.27       -34.89
# 6     2025-01-29          0.77          0.73        -4.83
# 7     2024-10-23          0.60          0.72        20.49
# 8     2024-07-23          0.62          0.52       -16.15
# 9     2024-04-23          0.49          0.45        -8.14
# 10    2024-01-24          0.74          0.71        -4.10
# 11    2023-10-18          0.73          0.66        -9.81
# 12    2023-07-19          0.82          0.91        11.12
# 13    2023-04-19          0.85          0.85        -0.43
# 14    2023-01-25          1.11          1.19         7.20
# 15    2022-10-19          1.00          1.05         5.23
# 16    2022-07-20          0.60          0.76        26.89
# 17    2022-04-20          0.75          1.07        42.31
# 18    2022-01-26          0.79          0.85         6.88
# 19    2021-10-20          0.54          0.62        15.22
# 20    2021-07-26          0.32          0.48        49.86
# 21    2021-04-26          0.26          0.31        19.42
# 22    2021-01-27          0.35          0.27       -23.91
# 23    2020-10-21          0.20          0.25        25.78
# 24    2020-07-22         -0.01          0.15      1460.77

# %% [markdown]
# ## 1.3 More of EPS/Growth stats and Analysts estimates

# %%
from typing import Any

def get_earnings_analysis(ticker: str) -> dict[str, Any]:
    """
    Get comprehensive earnings and EPS analysis data for a stock ticker.
    
    Combines multiple analyst data sources:
    1. Earnings Estimates - Consensus EPS estimates (avg, low, high, year-ago, analyst count)
    2. EPS Revisions - How analysts have revised estimates (up/down last 7/30 days)
    3. Growth Estimates - Expected earnings growth vs index benchmark
    4. Earnings History - Historical actual vs estimated EPS with surprise %
    
    Period notation:
    - 0q: Current fiscal quarter
    - +1q: Next fiscal quarter
    - 0y: Current fiscal year
    - +1y: Next fiscal year
    - LTG: Long-term growth (growth estimates only)
    
    Args:
        ticker: Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')
    
    Returns:
        Dictionary with ticker and all earnings analysis data
    """
    try:
        ticker_obj = yf.Ticker(ticker)
        result = {
            "ticker": ticker,
            "earnings_estimates": None,
            "eps_revisions": None,
            "growth_estimates": None,
            "earnings_history": None
        }

        # 1. Get earnings estimates
        try:
            earnings_est = ticker_obj.get_earnings_estimate()
            if isinstance(earnings_est, pd.DataFrame) and not earnings_est.empty:
                earnings_est = earnings_est.reset_index().rename(columns={"index": "period"})
                result["earnings_estimates"] = earnings_est.to_dict(orient='records')
        except Exception as e:
            result["earnings_estimates"] = {"error": str(e)}

        # 2. Get EPS revisions
        try:
            eps_rev = ticker_obj.get_eps_revisions()
            if isinstance(eps_rev, pd.DataFrame) and not eps_rev.empty:
                eps_rev = eps_rev.reset_index().rename(columns={"index": "period"})
                result["eps_revisions"] = eps_rev.to_dict(orient='records')
        except Exception as e:
            result["eps_revisions"] = {"error": str(e)}

        # 3. Get growth estimates
        try:
            growth_est = ticker_obj.get_growth_estimates()
            if isinstance(growth_est, pd.DataFrame) and not growth_est.empty:
                growth_est = growth_est.reset_index().rename(columns={"index": "period"})
                result["growth_estimates"] = growth_est.to_dict(orient='records')
        except Exception as e:
            result["growth_estimates"] = {"error": str(e)}

        # 4. Get earnings history
        try:
            earnings_hist = ticker_obj.get_earnings_history()
            if isinstance(earnings_hist, pd.DataFrame) and not earnings_hist.empty:
                earnings_hist = earnings_hist.reset_index().rename(columns={"index": "quarter"})
                result["earnings_history"] = earnings_hist.to_dict(orient='records')
        except Exception as e:
            result["earnings_history"] = {"error": str(e)}

        # Check if we got any data at all
        has_data = any(
            result[key] is not None and not isinstance(result[key], dict) or (isinstance(result[key], dict) and "error" not in result[key])
            for key in ["earnings_estimates", "eps_revisions", "growth_estimates", "earnings_history"]
        )

        if not has_data:
            return {"ticker": ticker, "error": "No earnings analysis data available"}

        return result

    except Exception as e:
        return {"ticker": ticker, "error": f"Failed to get earnings analysis: {str(e)}"}

# %%
# Get comprehensive earnings analysis
analysis = get_earnings_analysis("TSLA")
pprint(analysis)
# Out:
# {'earnings_estimates': [{'avg': 0.45414,
#                          'growth': 0.1353,
#                          'high': 0.59,
#                          'low': 0.26483,
#                          'numberOfAnalysts': 25,
#                          'period': '0q',
#                          'yearAgoEps': 0.4},
#                         {'avg': 0.5375,
#                          'growth': 0.075,
#                          'high': 0.83,
#                          'low': 0.29981,
#                          'numberOfAnalysts': 25,
#                          'period': '+1q',
#                          'yearAgoEps': 0.5},
#                         {'avg': 2.05937,
#                          'growth': 0.24059999,
#                          'high': 3.19,
#                          'low': 1.35491,
#                          'numberOfAnalysts': 34,
#                          'period': '0y',
#                          'yearAgoEps': 1.66},
#                         {'avg': 2.49995,
#                          'growth': 0.2139,
#                          'high': 3.65,
#                          'low': 1.464,
#                          'numberOfAnalysts': 30,
#                          'period': '+1y',
#                          'yearAgoEps': 2.05937}],
#  'earnings_history': [{'epsActual': 0.4,
#                        'epsDifference': -0.004,
#                        'epsEstimate': 0.40391,
#                        'quarter': Timestamp('2025-06-30 00:00:00'),
#                        'surprisePercent': -0.0097},
#                       {'epsActual': 0.5,
#                        'epsDifference': -0.06,
#                        'epsEstimate': 0.55885,
#                        'quarter': Timestamp('2025-09-30 00:00:00'),
#                        'surprisePercent': -0.105299994},
#                       {'epsActual': 0.5,
#                        'epsDifference': 0.05,
#                        'epsEstimate': 0.45061,
#                        'quarter': Timestamp('2025-12-31 00:00:00'),
#                        'surprisePercent': 0.1096},
#                       {'epsActual': 0.41,
#                        'epsDifference': 0.06,
#                        'epsEstimate': 0.34999,
#                        'quarter': Timestamp('2026-03-31 00:00:00'),
#                        'surprisePercent': 0.1715}],
#  'eps_revisions': [{'downLast30days': 1,
#                     'downLast7Days': 0,
#                     'period': '0q',
#                     'upLast30days': 2,
#                     'upLast7days': 1},
#                    {'downLast30days': 1,
#                     'downLast7Days': 0,
#                     'period': '+1q',
#                     'upLast30days': 1,
#                     'upLast7days': 1},
#                    {'downLast30days': 2,
#                     'downLast7Days': 0,
#                     'period': '0y',
#                     'upLast30days': 1,
#                     'upLast7days': 1},
#                    {'downLast30days': 3,
#                     'downLast7Days': 1,
#                     'period': '+1y',
#                     'upLast30days': 0,
#                     'upLast7days': 0}],
#  'growth_estimates': [{'indexTrend': 0.2598,
#                        'period': '0q',
#                        'stockTrend': 0.1353},
#                       {'indexTrend': 0.2024,
#                        'period': '+1q',
#                        'stockTrend': 0.075},
#                       {'indexTrend': 0.23020001,
#                        'period': '0y',
#                        'stockTrend': 0.24059999},
#                       {'indexTrend': 0.1694,
#                        'period': '+1y',
#                        'stockTrend': 0.2139},
#                       {'indexTrend': 0.122,
#                        'period': 'LTG',
#                        'stockTrend': nan}],
#  'ticker': 'TSLA'}

# %% [markdown]
# ## 1.4 Daily historical prices (Open, High, Low, Close, Volume)

# %%
from typing import Any

def get_historical_prices(ticker: str, period: str = "2y", interval: str = "1d") -> dict[str, Any]:
    """
    Get historical price data for a stock ticker.
    
    Returns OHLCV (Open, High, Low, Close, Volume) data for the specified period.
    
    Args:
        ticker: Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')
        period: Time period to fetch (default: "2y")
                Valid periods: 1d, 5d, 1mo, 3mo, 6mo, 1y, 2y, 5y, 10y, ytd, max
        interval: Data interval (default: "1d")
                Valid intervals: 1m, 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo
    
    Returns:
        Dictionary with ticker and historical price data
    """
    try:
        ticker_obj = yf.Ticker(ticker)
        result = ticker_obj.history(period=period, interval=interval)

        if isinstance(result, pd.DataFrame):
            if result.empty:
                return {"ticker": ticker, "error": f"No historical data available for {ticker}"}

            # Convert datetime index to date strings for cleaner output
            result = result.copy()
            result.index = result.index.date
            result = result.reset_index().rename(columns={"index": "Date"})

            return {
                "ticker": ticker,
                "period": period,
                "interval": interval,
                "data": result.to_dict(orient='records')
            }

        raise TypeError(f"Unexpected return type from history: {type(result)}")

    except Exception as e:
        return {"ticker": ticker, "error": f"Failed to get historical prices: {str(e)}"}

# %%
from pprint import pprint
# Get 2 years of daily data (default)
prices = get_historical_prices("TSLA", period="5d", interval="1d")
pprint(prices)
# Out:
# {'data': [{'Close': 408.95001220703125,
#            'Date': datetime.date(2026, 6, 8),
#            'Dividends': 0.0,
#            'High': 412.94000244140625,
#            'Low': 394.7200012207031,
#            'Open': 396.3299865722656,
#            'Stock Splits': 0.0,
#            'Volume': 50328800},
#           {'Close': 396.67999267578125,
#            'Date': datetime.date(2026, 6, 9),
#            'Dividends': 0.0,
#            'High': 418.5,
#            'Low': 384.239990234375,
#            'Open': 411.0299987792969,
#            'Stock Splits': 0.0,
#            'Volume': 59940200},
#           {'Close': 381.5899963378906,
#            'Date': datetime.date(2026, 6, 10),
#            'Dividends': 0.0,
#            'High': 397.0899963378906,
#            'Low': 380.1499938964844,
#            'Open': 391.5400085449219,
#            'Stock Splits': 0.0,
#            'Volume': 49695600},
#           {'Close': 399.1499938964844,
#            'Date': datetime.date(2026, 6, 11),
#            'Dividends': 0.0,
#            'High': 399.5400085449219,
#            'Low': 380.6600036621094,
#            'Open': 388.2799987792969,
#            'Stock Splits': 0.0,
#            'Volume': 45324300},
#           {'Close': 406.42999267578125,
#            'Date': datetime.date(2026, 6, 12),
#            'Dividends': 0.0,
#            'High': 406.67999267578125,
#            'Low': 386.760009765625,
#            'Open': 399.489990234375,
#            'Stock Splits': 0.0,
#            'Volume': 63514500}],
#  'interval': '1d',
#  'period': '5d',
#  'ticker': 'TSLA'}

# %% [markdown]
# ## 1.5 Ticker news (Yahoo Finance)

# %%
from typing import Any

def get_ticker_news(ticker: str, count: int = 10) -> dict[str, Any]:
    """
    Get recent news articles for a stock ticker from Yahoo Finance.
    
    Returns key information including title, description, summary, publication date,
    and canonical URL for each news article.
    
    Args:
        ticker: Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')
        count: Maximum number of news articles to return (default: 10)
    
    Returns:
        Dictionary with ticker and news data
    """
    try:
        ticker_obj = yf.Ticker(ticker)
        news_raw = ticker_obj.get_news()

        if not news_raw:
            return {"ticker": ticker, "error": "No news available"}

        # Convert to DataFrame to extract content
        news_df = pd.DataFrame(news_raw)

        if 'content' not in news_df.columns:
            return {"ticker": ticker, "error": "Unexpected news data format"}

        # Extract content and convert to DataFrame
        content_df = pd.DataFrame(news_df['content'].tolist())

        # Select only the important fields
        important_fields = ['title', 'description', 'summary', 'pubDate', 'canonicalUrl']

        # Filter to only existing fields
        available_fields = [f for f in important_fields if f in content_df.columns]
        news_filtered = content_df[available_fields]

        # Limit to requested count
        news_filtered = news_filtered.head(count)

        return {
            "ticker": ticker,
            "count": len(news_filtered),
            "data": news_filtered.to_dict(orient='records')
        }

    except Exception as e:
        return {"ticker": ticker, "error": f"Failed to get news: {str(e)}"}

# %%
# Get 10 most recent news articles (default)
news = get_ticker_news("TSLA", count=2)
pprint(news)
# Out:
# {'count': 2,
#  'data': [{'canonicalUrl': {'lang': 'en-US',
#                             'region': 'US',
#                             'site': 'finance',
#                             'url': 'https://finance.yahoo.com/markets/article/elon-musk-becomes-worlds-first-trillionaire-143438765.html'},
#            'description': '',
#            'pubDate': '2026-06-05T14:34:38Z',
#            'summary': "Elon Musk is officially the world's first trillionaire "
#                       "following SpaceX's stock debut today, with the "
#                       "company's IPO price valuing his stake at nearly $870 "
#                       'billion on paper.',
#            'title': "Elon Musk becomes world's first trillionaire"},
#           {'canonicalUrl': {'lang': 'en-US',
#                             'region': 'US',
#                             'site': 'finance',
#                             'url': 'https://finance.yahoo.com/video/what-spacexs-ipo-means-for-investors-and-the-future-of-innovation-150517020.html'},
#            'description': '<p>Laffer Tengler Investments CEO & CIO Nancy '
#                           'Tengler joins Yahoo Finance Executive Editor Brian '
#                           'Sozzi on Opening Bid to discuss the broader '
#                           'implications of the SpaceX (<a target="_blank" '
#                           'rel="" class="link" '
#                           'href="https://finance.yahoo.com/quote/SPCX/" '
#                           'data-i13n="cpos:1;pos:1">SPCX</a>) IPO, from its '
#                           "impact on investors to what the company's public "
#                           'debut could mean for innovation, markets, and '
#                           'society.</p>',
#            'pubDate': '2026-06-12T15:05:17Z',
#            'summary': 'Laffer Tengler Investments CEO & CIO Nancy Tengler '
#                       'joins Yahoo Finance Executive Editor Brian Sozzi on '
#                       'Opening Bid to discuss the broader implications of the '
#                       'SpaceX (SPCX) IPO, from its impact on investors to what '
#                       "the company's public debut could mean for innovation, "
#                       'markets, and society.',
#            'title': "What SpaceX's IPO means for investors and the future of "
#                     'innovation'}],
#  'ticker': 'TSLA'}

# %% [markdown]
# ## 1.6 Ticker news macro (Massive.com (ex. Polygon.io) - 5000 recent news + minsearch RAG)

# %%
from typing import Any
import requests
import pandas as pd
import os
from datetime import datetime, timezone
from minsearch import Index
from tqdm import tqdm

# Global variable to store the news index (built once, reused)
_news_index = None
_news_documents = None

def build_polygon_news_index(api_calls: int = 5, news_per_call: int = 1000) -> dict[str, Any]:
    """
    Fetch news from Polygon.io (Massive.com) and build a searchable index.
    
    This should be called once to fetch and index news. The index is stored
    globally and reused by search functions.
    
    Args:
        api_calls: Number of API calls to make (default: 5, fetches ~5000 articles)
        news_per_call: Number of news articles per API call (max: 1000)
    
    Returns:
        Dictionary with status and article count
    """
    global _news_index, _news_documents

    try:
        api_key = os.getenv('POLYGON_API_KEY')
        if not api_key:
            return {"error": "POLYGON_API_KEY not found in environment"}

        now = datetime.now(timezone.utc).strftime("%Y-%m-%d")
        all_news = None
        max_date = now

        print(f"Fetching {api_calls * news_per_call} news articles...")

        for i in tqdm(range(api_calls), desc="API calls"):
            url = f"https://api.massive.com/v2/reference/news?order=desc&limit={news_per_call}&sort=published_utc&published_utc.lt={max_date}&apiKey={api_key}"

            try:
                r = requests.get(url, timeout=10)
                r.raise_for_status()
                data = r.json()

                if 'results' not in data:
                    print(f"No 'results' in response. Keys: {data.keys()}")
                    continue

                cur = pd.json_normalize(data['results'])

                if all_news is None:
                    all_news = cur
                else:
                    all_news = pd.concat([all_news, cur], ignore_index=True)

                max_date = cur.published_utc.min()

            except requests.exceptions.RequestException as e:
                print(f"API call {i+1} failed: {e}")
                continue

        if all_news is None or all_news.empty:
            return {"error": "Failed to fetch news articles"}

        # Convert to documents
        _news_documents = all_news.to_dict(orient='records')

        # Preprocess documents
        print("Preprocessing documents...")
        for doc in tqdm(_news_documents, desc="Converting fields"):
            if isinstance(doc.get('tickers'), list):
                doc['tickers'] = ', '.join(doc['tickers'])
            if isinstance(doc.get('keywords'), list):
                doc['keywords'] = ', '.join(doc['keywords'])

            for field in ['title', 'description', 'author', 'article_url']:
                if doc.get(field) is None:
                    doc[field] = ''
                elif not isinstance(doc.get(field), str):
                    doc[field] = str(doc[field])

        # Build index
        print("Building search index...")
        _news_index = Index(
            text_fields=["title", "description", "keywords", "author", "tickers", "article_url"],
            keyword_fields=["published_utc", "publisher.name"]
        )
        _news_index.fit(_news_documents)

        return {
            "status": "success",
            "articles_indexed": len(_news_documents),
            "message": f"Index built with {len(_news_documents)} articles"
        }

    except Exception as e:
        return {"error": f"Failed to build news index: {str(e)}"}

# %%
def search_news_by_ticker(ticker: str, num_results: int = 30) -> dict[str, Any]:
    """
    Search indexed news articles for a specific stock ticker.
    
    Searches across title, description, keywords, and tickers with boosting
    that prioritizes ticker matches.
    
    Args:
        ticker: Stock ticker symbol (e.g., 'TSLA', 'AAPL', 'GOOGL')
        num_results: Maximum number of results to return (default: 30)
    
    Returns:
        Dictionary with ticker and matching news articles
    """
    global _news_index

    if _news_index is None:
        return {
            "ticker": ticker,
            "error": "News index not built. Call build_polygon_news_index() first."
        }

    try:
        results = _news_index.search(
            query=ticker,
            num_results=num_results,
            boost_dict={
                'tickers': 5.0,      # Highest boost for ticker field
                'title': 3.0,        # High boost for title
                'description': 1.5,  # Medium boost for description
                'keywords': 1.0      # Standard boost for keywords
            }
        )

        return {
            "ticker": ticker,
            "count": len(results),
            "data": results
        }

    except Exception as e:
        return {"ticker": ticker, "error": f"Search failed: {str(e)}"}


def search_news_by_query(query: str, num_results: int = 30) -> dict[str, Any]:
    """
    Search indexed news articles by free-text query.
    
    Searches across title, description, keywords, and tickers with boosting
    that prioritizes description and keyword matches.
    
    Args:
        query: Search query (e.g., 'Tesla competitors EV market', 'AI robotics')
        num_results: Maximum number of results to return (default: 30)
    
    Returns:
        Dictionary with query and matching news articles
    """
    global _news_index

    if _news_index is None:
        return {
            "query": query,
            "error": "News index not built. Call build_polygon_news_index() first."
        }

    try:
        results = _news_index.search(
            query=query,
            num_results=num_results,
            boost_dict={
                'tickers': 1.0,       # Standard boost for ticker field
                'title': 3.0,         # High boost for title
                'description': 5.0,   # Highest boost for description
                'keywords': 5.0       # Highest boost for keywords
            }
        )

        return {
            "query": query,
            "count": len(results),
            "data": results
        }

    except Exception as e:
        return {"query": query, "error": f"Search failed: {str(e)}"}

# %%
# USAGE EXAMPLE
# Step 1: Build the index once (takes a few minutes)
result = build_polygon_news_index(api_calls=5)
pprint(result)
# Out:
# Fetching 5000 news articles...
# API calls: 100%|██████████| 5/5 [00:06<00:00,  1.20s/it]
# API call 5 failed: 429 Client Error: Too Many Requests for url: https://api.massive.com/v2/reference/news?order=desc&limit=1000&sort=published_utc&published_utc.lt=2026-05-25T08:52:00Z&apiKey=ChTGkHcZ52m1DGD_KCgVOUwbV3iJ61_X
# Preprocessing documents...
# Converting fields: 100%|██████████| 4000/4000 [00:00<00:00, 1170939.14it/s]
# Building search index...
# {'articles_indexed': 4000,
#  'message': 'Index built with 4000 articles',
#  'status': 'success'}

# %%
# Step 2: Search by ticker
tsla_news = search_news_by_ticker("TSLA", num_results=10)
print(f"\nFound {tsla_news['count']} articles for {tsla_news['ticker']}")
for i, article in enumerate(tsla_news['data'][:5], 1):
    print(f"{i}. {article['title']}")
    print(f"   Published: {article['published_utc']}")
    print(f"   Tickers: {article['tickers']}")
    print(f"   Description: {article['description']}")
    print(f"   Article URL: {article['article_url']}")
# Out:
# Found 10 articles for TSLA
# 1. Is Tesla Stock Your Ticket to Becoming a Millionaire?
#    Published: 2026-05-31T08:34:00Z
#    Tickers: TSLA
#    Description: While Tesla's stock has delivered exceptional historical returns (22,250% over 15 years), the article argues it is not a reliable millionaire-maker opportunity today. The company faces slowing growth, rising inventory, and intense EV competition. CEO Elon Musk is pivoting toward autonomous driving and humanoid robots, requiring $25+ billion in capital expenditures, but success is uncertain. Tesla's extremely high P/E ratio of 402 reflects lofty market expectations that may be difficult to meet.
#    Article URL: https://www.fool.com/investing/2026/05/31/tesla-stock-your-ticket-to-becoming-a-millionaire/?source=iedfolrf0000001
# 2. At a $1.2 Trillion Market Cap, Is Tesla Stock Overvalued or Undervalued Right Now?
#    Published: 2026-06-08T16:15:00Z
#    Tickers: TSLA
#    Description: Tesla trades at an extremely high valuation with a P/E ratio of 357 and a forward P/E of 114x based on 2028 earnings estimates. While bulls believe the company will evolve into a high-margin autonomous driving and robotics business, the analyst concludes the stock is overvalued given current fundamentals as an EV maker facing lower growth and competition, with significant uncertainty around self-driving technology and humanoid robot commercialization.
#    Article URL: https://www.fool.com/investing/2026/06/08/trillion-market-cap-tesla-stock-overvalue-cheap/?source=iedfolrf0000001
# 3. Will SpaceX Merge With Tesla? The Answer Might Be Hiding in Plain Sight.
#    Published: 2026-06-08T17:17:00Z
#    Tickers: TSLA
#    Description: SpaceX's updated S-1 IPO filing contains revised language suggesting the company may issue significant equity for future transactions, sparking speculation about a potential merger with Tesla. The article argues that combining the two companies could create synergies in AI development, with Tesla's battery technology and autonomous capabilities complementing SpaceX's orbital infrastructure and computational needs.
#    Article URL: https://www.fool.com/investing/2026/06/08/will-spacex-merge-with-tesla-the-answer-might-be-h/?source=iedfolrf0000001
# 4. Elon Musk Net Worth Could Top $1 Trillion With SpaceX IPO: Make $100 Million A Day And It Would Take This Long To Catch Him
#    Published: 2026-06-08T18:43:59Z
#    Tickers: TSLA
#    Description: Elon Musk's net worth could exceed $1 trillion following SpaceX's anticipated IPO at a $1.75 trillion valuation. Currently worth $703 billion, Musk owns approximately 44% of SpaceX. A prediction market shows a 91% chance he becomes the world's first trillionaire before 2027. Additionally, a new Tesla compensation package could add nearly $1 trillion if certain milestones are reached.
#    Article URL: https://www.benzinga.com/markets/ipos/26/06/53070716/elon-musk-net-worth-could-top-1-trillion-with-spacex-ipo-make-100-million-a-day-and-it-would-take-th?utm_source=benzinga_taxonomy&utm_medium=rss_feed_free&utm_content=taxonomy_rss&utm_campaign=channel
# 5. Could Buying SpaceX Stock At Its IPO Set You Up for Life? (Hint: Yes.)
#    Published: 2026-05-28T09:30:00Z
#    Tickers: TSLA
#    Description: SpaceX is expected to hold its IPO this summer, with Elon Musk planning to reserve 30% of shares for retail investors. Despite a lofty $1.5-2 trillion valuation based on future growth potential rather than current profits, the company's pioneering reusable rocket technology, Starship development, and Starlink's $15-16 billion annual operating income position it for decades of scalable expansion and new revenue opportunities.
#    Article URL: https://www.fool.com/investing/2026/05/28/could-buying-spacex-stock-at-its-ipo-set-you-up-fo/?source=iedfolrf0000001

# %%
# Step 3: Search by query
query = "Tesla competitors EV margins autonomy AI robotics"
results = search_news_by_query(query, num_results=25)
print(f"\nFound {results['count']} articles for query: '{results['query']}'")
for i, article in enumerate(results['data'][:5], 1):
    print(f"{i}. {article['title']}")
    print(f"   Published: {article['published_utc']}")
    print(f"   Tickers: {article['tickers']}")
    print(f"   Description: {article['description']}")
    print(f"   Article URL: {article['article_url']}")
# Out:
# Found 25 articles for query: 'Tesla competitors EV margins autonomy AI robotics'
# 1. EV Sales Skyrocket: Tesla Stock Surges On 67% European Boom, Blockbuster SpaceX IPO Rumors
#    Published: 2026-05-27T15:40:06Z
#    Tickers: TSLA, BYDDY, GELHY
#    Description: Tesla stock gained 1.11% on Wednesday, driven by strong European EV sales growth (67.2% year-over-year in April) and speculation about a potential future merger with SpaceX. The SpaceX IPO is expected on Nasdaq under ticker SPCX following its merger with xAI, valued at $1.25 trillion. Tesla continues expanding beyond traditional auto manufacturing into AI, robotics, and energy sectors, with the next earnings catalyst expected on July 22.
#    Article URL: https://www.benzinga.com/markets/tech/26/05/52813754/ev-sales-skyrocket-tesla-stock-surges-on-67-european-boom-blockbuster-spacex-ipo-rumors?utm_source=benzinga_taxonomy&utm_medium=rss_feed_free&utm_content=taxonomy_rss&utm_campaign=channel
# 2. Why Tesla Robotaxi Dreams Can’t Rescue Today’s Weak Fundamentals
#    Published: 2026-05-28T12:36:00Z
#    Tickers: TSLA, F, FpB, FpC, FpD, GM, BIDU, NIO, LI, XPEV, BYDDY
#    Description: Tesla's valuation of $1.3 trillion is heavily dependent on unproven robotaxi and AI technologies, with roughly $1.25 trillion assigned to businesses that don't yet exist. The company faces near-term headwinds including stagnant vehicle deliveries, compressed margins (17-18%), declining regulatory credit revenue, and intensifying competition from legacy automakers and Chinese EV makers. Without successful autonomy deployment, Tesla would be valued as a mature automaker worth $50-100 billion, representing a 90%+ downside from current levels.
#    Article URL: https://www.investing.com/analysis/why-tesla-robotaxi-dreams-cant-rescue-todays-weak-fundamentals-200681092
# 3. Should Investors Sell Tesla Stock to Buy SpaceX?
#    Published: 2026-06-06T18:05:00Z
#    Tickers: TSLA, GM
#    Description: A potential SpaceX IPO could fundamentally reshape how investors value Tesla stock. For years, Tesla commanded a premium valuation as investors' primary public market vehicle for investing in Elon Musk's technological ambitions. However, a public SpaceX listing would provide investors with an alternative Musk-led company to evaluate, potentially challenging Tesla's valuation premium. While Tesla faces declining EV sales and competition, SpaceX operates in industries with fewer competitors and greater infrastructure opportunities. The article suggests Tesla's valuation may shift from rewarding long-term possibility to demanding measurable execution, though investors could ultimately choose to own both companies.
#    Article URL: https://www.fool.com/investing/2026/06/06/should-investors-sell-tesla-stock-to-buy-spacex/?source=iedfolrf0000001
# 4. Tesla’s European Recovery Is Real, But BYD Defines the Limit
#    Published: 2026-05-27T07:07:00Z
#    Tickers: TSLA, BYDDY
#    Description: Tesla shows genuine recovery in European EV registrations with three consecutive months of year-on-year growth, including a 46.5% rebound in April 2026 to 10,654 units. However, BYD's dominance—registering 27,008 units in the same month with a broader product portfolio—defines structural competitive limits. Tesla's recovery is driven by fuel-price-driven EV demand, base effects, and regulatory approvals (FSD in Netherlands), but BYD's aggressive European expansion and lower-priced offerings pose sustained competitive pressure despite BYD's domestic margin compression.
#    Article URL: https://www.investing.com/analysis/teslas-european-recovery-is-real-but-byd-defines-the-limit-200680993
# 5. 2 Monster EV Stocks Chasing a $10 Trillion AI Opportunity
#    Published: 2026-05-29T09:30:00Z
#    Tickers: TSLA, RIVN, UBER
#    Description: The article highlights how EV companies are positioned to capitalize on a $10 trillion robotaxi market opportunity powered by AI advances. Tesla and Rivian are identified as the two best-positioned EV stocks to benefit from the emerging autonomous taxi market, which is expected to scale globally by 2030. Tesla has established self-driving capabilities and a $20 billion capex plan for AI investments, while Rivian is positioned as a supplier to robotaxi providers, including a $1.25 billion deal with Uber for 50,000 vehicles.
#    Article URL: https://www.fool.com/investing/2026/05/29/2-monster-ev-stocks-worth-owning-while-the-sector/?source=iedfolrf0000001

# %% [markdown]
# ## 1.7 Macro stats (market cap) - 10k companies (several csvs to save and query)
#
#   Key features:
#   - ✅ Loads and merges all 4 databases (10k+ companies)
#   - ✅ Unified search across market cap, P/E, dividend, and operating margin
#   - ✅ Pre-built filters for value and growth investing strategies
#   - ✅ Cache all databases for fast repeated queries
#   - ✅ Multiple search criteria can be combined
#   - ✅ Country filtering

# %%
from typing import Any, Optional
import requests
import pandas as pd
from io import StringIO

# Global variables to cache the databases
_companies_marketcap_db = None
_companies_pe_db = None
_companies_dividend_db = None
_companies_margin_db = None
_unified_db = None

def load_all_companies_databases(force_refresh: bool = False) -> dict[str, Any]:
    """
    Download and load all company databases from companiesmarketcap.com.
    
    Loads 4 databases:
    1. Market Cap - Top companies by market capitalization
    2. P/E Ratio - Top companies by price-to-earnings ratio
    3. Dividend Yield - Top companies by dividend yield percentage
    4. Operating Margin - Top companies by operating margin percentage
    
    The databases are cached globally and merged by ticker symbol for unified searching.
    Use force_refresh=True to re-download.
    
    Args:
        force_refresh: If True, re-download all databases even if cached
    
    Returns:
        Dictionary with status and database info
    """
    global _companies_marketcap_db, _companies_pe_db, _companies_dividend_db
    global _companies_margin_db, _unified_db

    # Return cached data if available
    if _unified_db is not None and not force_refresh:
        df = pd.DataFrame(_unified_db)
        return {
            "status": "loaded_from_cache",
            "total_companies": len(_unified_db),
            "available_columns": list(df.columns),
            "message": f"All databases loaded from cache"
        }

    try:
        databases = {
            "marketcap": "https://companiesmarketcap.com/usd/?download=csv",
            "pe_ratio": "https://companiesmarketcap.com/top-companies-by-pe-ratio/?download=csv",
            "dividend": "https://companiesmarketcap.com/top-companies-by-dividend-yield/?download=csv",
            "margin": "https://companiesmarketcap.com/top-companies-by-operating-margin/?download=csv"
        }

        loaded = {}

        for name, url in databases.items():
            print(f"Downloading {name} database...")
            try:
                response = requests.get(url, timeout=30)
                response.raise_for_status()
                csv_data = StringIO(response.text)
                df = pd.read_csv(csv_data)
                loaded[name] = df
                print(f"✓ Loaded {len(df)} companies from {name}")
            except Exception as e:
                print(f"✗ Failed to load {name}: {e}")
                loaded[name] = None

        # Store individual databases
        _companies_marketcap_db = loaded["marketcap"]
        _companies_pe_db = loaded["pe_ratio"]
        _companies_dividend_db = loaded["dividend"]
        _companies_margin_db = loaded["margin"]

        # Merge all databases by Symbol for unified view
        print("\nMerging databases...")

        # Start with market cap as base
        unified = loaded["marketcap"].copy()

        # Merge P/E ratio - only keep pe_ratio_ttm column
        if loaded["pe_ratio"] is not None and 'pe_ratio_ttm' in loaded["pe_ratio"].columns:
            pe_df = loaded["pe_ratio"][['Symbol', 'pe_ratio_ttm']]
            unified = unified.merge(pe_df, on='Symbol', how='left')
            print(f"✓ Added P/E ratio column")

        # Merge Dividend yield - only keep dividend_yield_ttm column
        if loaded["dividend"] is not None and 'dividend_yield_ttm' in loaded["dividend"].columns:
            div_df = loaded["dividend"][['Symbol', 'dividend_yield_ttm']]
            # Convert percentage to decimal
            div_df['dividend_yield_ttm'] = div_df['dividend_yield_ttm'] / 100.0 
            unified = unified.merge(div_df, on='Symbol', how='left')
            print(f"✓ Added Dividend yield column")

        # Merge Operating margin - only keep operating_margin_ttm column
        if loaded["margin"] is not None and 'operating_margin_ttm' in loaded["margin"].columns:
            margin_df = loaded["margin"][['Symbol', 'operating_margin_ttm']]
            # Convert percentage to decimal
            margin_df['operating_margin_ttm'] = margin_df['operating_margin_ttm']/100.0
            unified = unified.merge(margin_df, on='Symbol', how='left')
            print(f"✓ Added Operating margin column")

        print(f"\nFinal columns: {list(unified.columns)}")

        _unified_db = unified.to_dict(orient='records')

        return {
            "status": "success",
            "databases_loaded": {
                "marketcap": len(loaded["marketcap"]) if loaded["marketcap"] is not None else 0,
                "pe_ratio": len(loaded["pe_ratio"]) if loaded["pe_ratio"] is not None else 0,
                "dividend": len(loaded["dividend"]) if loaded["dividend"] is not None else 0,
                "margin": len(loaded["margin"]) if loaded["margin"] is not None else 0
            },
            "total_companies": len(_unified_db),
            "available_columns": list(unified.columns),
            "message": f"All databases merged with {len(_unified_db)} unique companies"
        }

    except Exception as e:
        return {"error": f"Failed to load databases: {str(e)}"}


def get_available_columns() -> dict[str, Any]:
    """
    Get list of available columns in the unified database.
    
    Returns:
        Dictionary with available column names
    """
    global _unified_db

    if _unified_db is None:
        return {"error": "Database not loaded. Call load_all_companies_databases() first."}

    df = pd.DataFrame(_unified_db)
    return {
        "columns": list(df.columns),
        "total_columns": len(df.columns)
    }


def search_companies(
    query: Optional[str] = None,
    ticker: Optional[str] = None,
    min_market_cap: Optional[float] = None,
    max_market_cap: Optional[float] = None,
    min_pe: Optional[float] = None,
    max_pe: Optional[float] = None,
    min_dividend: Optional[float] = None,
    max_dividend: Optional[float] = None,
    min_margin: Optional[float] = None,
    max_margin: Optional[float] = None,
    country: Optional[str] = None,
    limit: int = 50
) -> dict[str, Any]:
    """
    Search companies across all databases with comprehensive filtering.
    
    Args:
        query: Search by company name (case-insensitive partial match)
        ticker: Search by exact ticker symbol
        min_market_cap: Minimum market cap in USD
        max_market_cap: Maximum market cap in USD
        min_pe: Minimum P/E ratio
        max_pe: Maximum P/E ratio
        min_dividend: Minimum dividend yield (%)
        max_dividend: Maximum dividend yield (%)
        min_margin: Minimum operating margin (%)
        max_margin: Maximum operating margin (%)
        country: Filter by country (e.g., 'USA', 'China')
        limit: Maximum number of results (default: 50)
    
    Returns:
        Dictionary with matching companies and all available metrics
    """
    global _unified_db

    if _unified_db is None:
        return {"error": "Database not loaded. Call load_all_companies_databases() first."}

    try:
        df = pd.DataFrame(_unified_db)

        # Apply filters
        if ticker:
            df = df[df['Symbol'].str.upper() == ticker.upper()]

        if query:
            df = df[df['Name'].str.contains(query, case=False, na=False)]

        if min_market_cap is not None:
            df = df[df['marketcap'] >= min_market_cap]

        if max_market_cap is not None:
            df = df[df['marketcap'] <= max_market_cap]

        if 'pe_ratio_ttm' in df.columns:
            if min_pe is not None:
                df = df[pd.to_numeric(df['pe_ratio_ttm'], errors='coerce') >= min_pe]
            if max_pe is not None:
                df = df[pd.to_numeric(df['pe_ratio_ttm'], errors='coerce') <= max_pe]

        if 'dividend_yield_ttm' in df.columns:
            if min_dividend is not None:
                df = df[pd.to_numeric(df['dividend_yield_ttm'], errors='coerce') >= min_dividend]
            if max_dividend is not None:
                df = df[pd.to_numeric(df['dividend_yield_ttm'], errors='coerce') <= max_dividend]

        if 'operating_margin_ttm' in df.columns:
            if min_margin is not None:
                df = df[pd.to_numeric(df['operating_margin_ttm'], errors='coerce') >= min_margin]
            if max_margin is not None:
                df = df[pd.to_numeric(df['operating_margin_ttm'], errors='coerce') <= max_margin]

        if country:
            df = df[df['country'].str.upper() == country.upper()]

        # Limit results
        df = df.head(limit)

        if df.empty:
            return {
                "count": 0,
                "message": "No companies found matching criteria"
            }

        return {
            "count": len(df),
            "data": df.to_dict(orient='records')
        }

    except Exception as e:
        return {"error": f"Search failed: {str(e)}"}


def get_top_value_companies(
    min_dividend: float = 2.0/100.0, # 2%
    max_pe: float = 25,
    min_margin: float = 10/100.0, # 10%
    min_market_cap: float = 1_000_000_000,
    limit: int = 50
) -> dict[str, Any]:
    """
    Find potential value companies based on fundamental criteria.
    
    Default criteria:
    - Dividend yield >= 2%
    - P/E ratio <= 25
    - Operating margin >= 10%
    - Market cap >= $1B
    
    Args:
        min_dividend: Minimum dividend yield %
        max_pe: Maximum P/E ratio
        min_margin: Minimum operating margin %
        min_market_cap: Minimum market cap
        limit: Maximum results
    
    Returns:
        Dictionary with companies meeting value criteria
    """
    return search_companies(
        min_dividend=min_dividend,
        max_pe=max_pe,
        min_margin=min_margin,
        min_market_cap=min_market_cap,
        limit=limit
    )


def get_top_growth_companies(
    min_margin: float = 20/100.0, # 20%
    max_pe: Optional[float] = None,
    min_market_cap: float = 1_000_000_000,
    limit: int = 50
) -> dict[str, Any]:
    """
    Find potential growth companies based on fundamental criteria.
    
    Default criteria:
    - Operating margin >= 20% (high profitability)
    - Market cap >= $1B
    
    Args:
        min_margin: Minimum operating margin %
        max_pe: Maximum P/E ratio (optional)
        min_market_cap: Minimum market cap
        limit: Maximum results
    
    Returns:
        Dictionary with companies meeting growth criteria
    """
    return search_companies(
        min_margin=min_margin,
        max_pe=max_pe,
        min_market_cap=min_market_cap,
        limit=limit
    )

# %%
# USAGE EXAMPLE

# Load databases
result = load_all_companies_databases(force_refresh=True)
pprint(result)

# Search for value stocks
value_stocks = get_top_value_companies(min_dividend=3.0/100.0, max_pe=20, min_margin=15/100.0, limit=25)
print(f"\nFound {value_stocks['count']} value stocks")

if "data" in value_stocks:
    df = pd.DataFrame(value_stocks['data'])
    print(df[['Name', 'Symbol', 'marketcap', 'pe_ratio_ttm', 'dividend_yield_ttm', 'operating_margin_ttm']])
# Out:
# Downloading marketcap database...
# ✓ Loaded 10862 companies from marketcap
# Downloading pe_ratio database...
# ✓ Loaded 10862 companies from pe_ratio
# Downloading dividend database...
# ✓ Loaded 10862 companies from dividend
# Downloading margin database...
# ✓ Loaded 10862 companies from margin
#
# Merging databases...
# ✓ Added P/E ratio column
# ✓ Added Dividend yield column
# ✓ Added Operating margin column
#
# Final columns: ['Rank', 'Name', 'Symbol', 'marketcap', 'price (USD)', 'country', 'pe_ratio_ttm', 'dividend_yield_ttm', 'operating_margin_ttm']
# {'available_columns': ['Rank',
#                        'Name',
#                        'Symbol',
#                        'marketcap',
#                        'price (USD)',
#                        'country',
#                        'pe_ratio_ttm',
#                        'dividend_yield_ttm',
#                        'operating_margin_ttm'],
#  'databases_loaded': {'dividend': 10862,
#                       'margin': 10862,
#                       'marketcap': 10862,
#                       'pe_ratio': 10862},
#  'message': 'All databases merged with 10862 unique companies',
#  'status': 'success',
#  'total_companies': 10862}
#
# Found 25 value stocks
#                           Name     Symbol      marketcap  pe_ratio_ttm  \
# 0                 Saudi Aramco    2222.SR  1752036719406      17.06710
# 1               JPMorgan Chase        JPM   859372847104      15.27270
# 2                      Tencent      TCEHY   532555956224      16.96310
# 3      China Construction Bank  601939.SS   413704429797       8.25725
# 4              Bank of America        BAC   397551009792      13.62690
# 5   Agricultural Bank of China  601288.SS   351741776857       9.26415
# 6               Morgan Stanley         MS   337602052096      19.22110
# 7                          KLA       KLAC   332499288064       7.09009
# 8                         HSBC       HSBC   317824925696      13.00280
# 9                Goldman Sachs         GS   313519144960      19.25070
# 10               Bank of China  601988.SS   299544201309       9.04092
# 11        Royal Bank Of Canada         RY   277293203456      18.89550
# 12                     Alibaba       BABA   270670299136      19.98170
# 13                 Wells Fargo        WFC   256229670912      12.74500
# 14                     L'Oréal      OR.PA   241182788108       0.00000
# 15             Kweichow Moutai  600519.SS   238692444626      17.11560
# 16                   Citigroup          C   238490828800      17.05980
# 17                       Shell       SHEL   237583958016      14.16830
# 18        SoftBank Group Corp.     9984.T   230248041360      12.13050
# 19                      Hermès     RMS.PA   205915776464       0.00000
# 20                     Verizon         VZ   200886140928      11.75000
# 21               TotalEnergies        TTE   195509305344      12.90030
# 22                Novo Nordisk        NVO   194346958848      10.30640
# 23       Toronto Dominion Bank         TD   193835139072      13.42800
# 24                   Santander        SAN   184815747072      10.42880
#
#     dividend_yield_ttm  operating_margin_ttm
# 0             4.906060                 40.49
# 1             1.846610                 39.94
# 2             0.972505                 32.62
# 3             1.727380                 47.00
# 4             1.973650                 34.46
# 5             3.584110                 43.65
# 6             1.863060                 34.05
# 7             3.017790                 41.11
# 8             3.520370                 44.07
# 9             1.453370                 37.53
# 10            1.730180                 45.09
# 11            1.167870                 39.31
# 12            1.785550                 12.43
# 13            2.156210                 30.50
# 14            1.873600                 19.30
# 15            3.975530                 67.24
# 16            1.713800                 23.31
# 17            2.534360                 11.14
# 18            0.173322                 23.53
# 19            1.077150                 42.33
# 20            5.741570                 16.51
# 21            3.372360                 13.70
# 22            4.199230                 42.23
# 23            1.322110                 40.67
# 24            1.147990                 32.27
# /var/folders/_6/616g1v7j04jdsf8gy64v_t640000gn/T/ipykernel_85541/3381459230.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   div_df['dividend_yield_ttm'] = div_df['dividend_yield_ttm'] / 100.0
# /var/folders/_6/616g1v7j04jdsf8gy64v_t640000gn/T/ipykernel_85541/3381459230.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   margin_df['operating_margin_ttm'] = margin_df['operating_margin_ttm']/100.0

# %%
# RAW DATA in the combined database
# checking the unified database of al
df = pd.DataFrame(_unified_db)

# %%
df.head()
# Out:
#    Rank               Name Symbol      marketcap  price (USD)        country  \
# 0     1             NVIDIA   NVDA  4969906831360       205.19  United States
# 1     2  Alphabet (Google)   GOOG  4367737946112       358.16  United States
# 2     3              Apple   AAPL  4275929874432       291.13  United States
# 3     4          Microsoft   MSFT  2902586556416       390.74  United States
# 4     5             Amazon   AMZN  2566108479488       238.55  United States
#
#    pe_ratio_ttm  dividend_yield_ttm  operating_margin_ttm
# 0       41.5811            0.019513                 65.62
# 1       27.1492            0.233687                 46.31
# 2       34.9825            0.362063                 31.89
# 3       22.9649            0.684827                 48.54
# 4       27.8559            0.000000                 13.57

# %% [markdown]
# # 2) Building an agent

# %% [markdown]
# ## 2.0) A completely FREE agent based on the Qwen3 model with function calling (via Ollama)
# * https://docs.ollama.com/capabilities/tool-calling#python : "Single-shot vs. Thinking tool calling"
# * https://ollama.com/library/qwen3:32b : "Expertise in agent capabilities"
# * https://qwen.ai/blog?id=qwen3  "Qwen3 excels in tool calling capabilities"

# %%
from ollama import chat, ChatResponse

# %%
# # only Yahoo finance
available_functions = {
  'get_company_info': get_company_info,
  'get_eps_trend': get_eps_trend,
  'get_earnings_dates': get_earnings_dates,
  'get_earnings_analysis': get_earnings_analysis,
  'get_historical_prices': get_historical_prices,
  'get_ticker_news': get_ticker_news
}
# # directly pass the function as part of the tools list
# response = chat(model='qwen3', messages=messages, tools=available_functions.values(), think=True)

# %%
messages = [{'role': 'user', 'content': 'What are the news, available EPS stats, and historical trend in the last 7 days for TSLA?'}]

# %%
while True:
    response: ChatResponse = chat(
        model='qwen3:32b',
        messages=messages,
        tools=[get_company_info, get_eps_trend, get_earnings_dates, get_earnings_analysis, get_historical_prices, get_ticker_news],
        think=True,
    )
    messages.append(response.message)
    print("Thinking: ", response.message.thinking)
    print("Content: ", response.message.content)
    if response.message.tool_calls:
        for tc in response.message.tool_calls:
            if tc.function.name in available_functions:
                print(f"Calling {tc.function.name} with arguments {tc.function.arguments}")
                result = available_functions[tc.function.name](**tc.function.arguments)
                print(f"Result: {result}")
                # add the tool result to the messages
                messages.append({'role': 'tool', 'tool_name': tc.function.name, 'content': str(result)})
    else:
        # end the loop when there are no more tool calls
        break
  # continue the loop with the updated messages
# Out:
# Thinking:  Okay, let's tackle the user's query. They want news, available EPS stats, and the historical trend for TSLA in the last 7 days.
#
# First, I need to break down the request into parts. The user mentioned three things: news, EPS stats, and a 7-day trend. Looking at the available tools, there's a function called get_ticker_news that fetches recent news articles. For EPS, there's get_eps_trend and get_earnings_analysis. The historical trend might involve historical prices, but the user specifically mentioned EPS trend.
#
# The get_eps_trend function shows how analyst consensus has changed over time, including different periods like quarterly and yearly. The user wants the last 7 days, so that function should work. Also, get_earnings_analysis provides comprehensive EPS data, including revisions and estimates. Maybe both functions are needed here to cover all aspects of EPS stats.
#
# For the news, get_ticker_news with TSLA and a count (default is 10, which is probably okay). For the EPS, call get_eps_trend with TSLA. For the historical trend, maybe the user wants the historical EPS changes, so get_eps_trend is the right choice. The 7-day trend is covered by the columns in get_eps_trend, which includes data points like 7daysAgo.
#
# I should check if the functions require any other parameters. The get_eps_trend only needs the ticker. Similarly, get_ticker_news needs the ticker and optionally the count. The user didn't specify a count, so default to 10.
#
# So the plan is to call get_ticker_news for TSLA, get_eps_trend for TSLA, and maybe get_earnings_analysis for more EPS details. But the user asked for "available EPS stats," which might include both the trend and the analysis. However, to avoid overcomplicating, maybe start with the get_eps_trend and get_earnings_analysis. Wait, but the user also mentioned "historical trend in the last 7 days," which is exactly what get_eps_trend provides with the 7daysAgo column.
#
# Therefore, the necessary function calls are get_ticker_news, get_eps_trend, and possibly get_earnings_analysis. But the user might not need all three. Let me see: get_earnings_analysis includes revisions and growth estimates, which might complement the trend. But the user's question is about "available EPS stats," which could be covered by get_eps_trend and get_earnings_analysis. However, to keep it concise, perhaps call get_eps_trend and get_earnings_analysis.
#
# Wait, the user also said "historical trend in the last 7 days," which the get_eps_trend function's 7daysAgo column would handle. So three function calls: news, eps trend, and earnings analysis. But the user might need just the trend and the analysis. Alternatively, maybe the get_earnings_analysis includes the trend? No, the get_eps_trend is specifically for the trend over time.
#
# In conclusion, the user needs three pieces of information: news, EPS stats (which includes the trend and analysis), and the historical trend. So the functions to call are get_ticker_news, get_eps_trend, and get_earnings_analysis for TSLA. Each of these functions will provide the necessary data to answer the user's query comprehensively.
#
# Content:
# Calling get_ticker_news with arguments {'ticker': 'TSLA', 'count': 10}
# Result: {'ticker': 'TSLA', 'count': 10, 'data': [{'title': "Elon Musk becomes world's first trillionaire", 'description': '', 'summary': "Elon Musk is officially the world's first trillionaire following SpaceX's stock debut today, with the company's IPO price valuing his stake at nearly $870 billion on paper.", 'pubDate': '2026-06-05T14:34:38Z', 'canonicalUrl': {'url': 'https://finance.yahoo.com/markets/article/elon-musk-becomes-worlds-first-trillionaire-143438765.html', 'site': 'finance', 'region': 'US', 'lang': 'en-US'}}, {'title': "What SpaceX's IPO means for investors and the future of innovation", 'description': '<p>Laffer Tengler Investments CEO & CIO Nancy Tengler joins Yahoo Finance Executive Editor Brian Sozzi on Opening Bid to discuss the broader implications of the SpaceX (<a target="_blank" rel="" class="link" href="https://finance.yahoo.com/quote/SPCX/" data-i13n="cpos:1;pos:1">SPCX</a>) IPO, from its impact on investors to what the company\'s public debut could mean for innovation, markets, and society.</p>', 'summary': "Laffer Tengler Investments CEO & CIO Nancy Tengler joins Yahoo Finance Executive Editor Brian Sozzi on Opening Bid to discuss the broader implications of the SpaceX (SPCX) IPO, from its impact on investors to what the company's public debut could mean for innovation, markets, and society.", 'pubDate': '2026-06-12T15:05:17Z', 'canonicalUrl': {'url': 'https://finance.yahoo.com/video/what-spacexs-ipo-means-for-investors-and-the-future-of-innovation-150517020.html', 'site': 'finance', 'region': 'US', 'lang': 'en-US'}}, {'title': "Why SpaceX's IPO sets Elon Musk to become the world's first trillionaire", 'description': '<p>SpaceX (<a target="_blank" rel="" class="link" href="https://finance.yahoo.com/quote/SPCX/" data-i13n="slk:SPCX;cpos:1;pos:1">SPCX</a>) CEO Elon Musk was propelled to trillionaire status — the first-ever in history — on Friday as SpaceX\'s initial public offering (IPO) became the latest addition to his publicly traded corporate empire.</p>\n<p>Morning Brief host Julie Hyman is joined by Yahoo Finance Senior Reporter Pras Subramanian and Trustless Media Founder Zack Guzman to discuss.</p>', 'summary': "SpaceX (SPCX) CEO Elon Musk was propelled to trillionaire status — the first-ever in history — on Friday as SpaceX's initial public offering (IPO) became the latest addition to his publicly traded corporate empire. Morning Brief host Julie Hyman is joined by Yahoo Finance Senior Reporter Pras Subramanian and Trustless Media Founder Zack Guzman to discuss.", 'pubDate': '2026-06-12T15:00:00Z', 'canonicalUrl': {'url': 'https://finance.yahoo.com/video/why-spacexs-ipo-sets-elon-150000999.html', 'site': 'finance', 'region': 'US', 'lang': 'en-US'}}, {'title': "Gary Black Predicts TSLA Selling Ahead Of SpaceX IPO—Ross Gerber Says Investors Treating It Like 'Free Money'", 'description': '', 'summary': 'The upcoming SpaceX IPO, which is scheduled to kick off on Friday, June 12, could result in Tesla Inc. investors exiting their positions in the EV giant, according to investor Gary Black of The Future Fund LLC. Investors To ‘Lighten’...', 'pubDate': '2026-06-13T12:31:16Z', 'canonicalUrl': {'url': 'https://finance.yahoo.com/markets/stocks/articles/gary-black-predicts-tsla-selling-123116556.html', 'site': 'finance', 'region': 'US', 'lang': 'en-US'}}, {'title': 'ArcBest Expands Tesla Semi Fleet As EV Trials Meet Core Freight Goals', 'description': '', 'summary': "ArcBest's ABF Freight unit is expanding its electric trucking program with new Tesla Semi trucks beyond its initial California and Nevada pilot route. This move shifts the Tesla Semi use from a limited trial to broader deployment across more of ArcBest's network. Early feedback points to a positive driver experience and solid operational performance for the electric trucks. For investors following NasdaqGS:ARCB, this development adds another piece to the story around how the company is...", 'pubDate': '2026-06-13T12:10:55Z', 'canonicalUrl': ...
# Calling get_eps_trend with arguments {'ticker': 'TSLA'}
# Result: {'ticker': 'TSLA', 'data': [{'current': 0.45414, '7daysAgo': 0.45396, '30daysAgo': 0.45396, '60daysAgo': 0.44637, '90daysAgo': 0.46212, 'period': '0q'}, {'current': 0.5375, '7daysAgo': 0.5393, '30daysAgo': 0.5393, '60daysAgo': 0.53175, '90daysAgo': 0.5405, 'period': '+1q'}, {'current': 2.05937, '7daysAgo': 2.04967, '30daysAgo': 2.04835, '60daysAgo': 2.03873, '90daysAgo': 2.08858, 'period': '0y'}, {'current': 2.49995, '7daysAgo': 2.50462, '30daysAgo': 2.50969, '60daysAgo': 2.77175, '90daysAgo': 2.81043, 'period': '+1y'}]}
# Calling get_earnings_analysis with arguments {'ticker': 'TSLA'}
# Result: {'ticker': 'TSLA', 'earnings_estimates': [{'period': '0q', 'avg': 0.45414, 'low': 0.26483, 'high': 0.59, 'yearAgoEps': 0.4, 'numberOfAnalysts': 25, 'growth': 0.1353}, {'period': '+1q', 'avg': 0.5375, 'low': 0.29981, 'high': 0.83, 'yearAgoEps': 0.5, 'numberOfAnalysts': 25, 'growth': 0.075}, {'period': '0y', 'avg': 2.05937, 'low': 1.35491, 'high': 3.19, 'yearAgoEps': 1.66, 'numberOfAnalysts': 34, 'growth': 0.24059999}, {'period': '+1y', 'avg': 2.49995, 'low': 1.464, 'high': 3.65, 'yearAgoEps': 2.05937, 'numberOfAnalysts': 30, 'growth': 0.2139}], 'eps_revisions': [{'period': '0q', 'upLast7days': 1, 'upLast30days': 2, 'downLast30days': 1, 'downLast7Days': 0}, {'period': '+1q', 'upLast7days': 1, 'upLast30days': 1, 'downLast30days': 1, 'downLast7Days': 0}, {'period': '0y', 'upLast7days': 1, 'upLast30days': 1, 'downLast30days': 2, 'downLast7Days': 0}, {'period': '+1y', 'upLast7days': 0, 'upLast30days': 0, 'downLast30days': 3, 'downLast7Days': 1}], 'growth_estimates': [{'period': '0q', 'stockTrend': 0.1353, 'indexTrend': 0.2598}, {'period': '+1q', 'stockTrend': 0.075, 'indexTrend': 0.2024}, {'period': '0y', 'stockTrend': 0.24059999, 'indexTrend': 0.23020001}, {'period': '+1y', 'stockTrend': 0.2139, 'indexTrend': 0.1694}, {'period': 'LTG', 'stockTrend': nan, 'indexTrend': 0.122}], 'earnings_history': [{'quarter': Timestamp('2025-06-30 00:00:00'), 'epsActual': 0.4, 'epsEstimate': 0.40391, 'epsDifference': -0.004, 'surprisePercent': -0.0097}, {'quarter': Timestamp('2025-09-30 00:00:00'), 'epsActual': 0.5, 'epsEstimate': 0.55885, 'epsDifference': -0.06, 'surprisePercent': -0.105299994}, {'quarter': Timestamp('2025-12-31 00:00:00'), 'epsActual': 0.5, 'epsEstimate': 0.45061, 'epsDifference': 0.05, 'surprisePercent': 0.1096}, {'quarter': Timestamp('2026-03-31 00:00:00'), 'epsActual': 0.41, 'epsEstimate': 0.34999, 'epsDifference': 0.06, 'surprisePercent': 0.1715}]}
# Thinking:  Okay, let's start by breaking down what the user is asking for. They want the news, available EPS stats, and the historical trend in the last 7 days for TSLA.
#
# First, I need to check the news. The tool response for get_ticker_news provided 10 articles. The most recent ones are about SpaceX's IPO and Elon Musk becoming a trillionaire, which is significant because it's related to Tesla. The news articles mention that Tesla's stock recovered and closed higher on the day of the SpaceX IPO. There's also a discussion about the impact of SpaceX's IPO on Tesla's market position, potentially pushing it out of the "Magnificent Seven." These points are important to highlight as they relate to current events affecting Tesla.
#
# Next, the EPS stats. The get_eps_trend function shows the EPS estimates over different periods. The current estimates for the current quarter (0q) are 0.45414, and 7 days ago it was 0.45396. There's a slight increase. For the next quarter (+1q), the current estimate is 0.5375, which is a bit lower than 7 days ago. The annual estimates (0y and +1y) show an increase as well. This data suggests that while there are minor fluctuations, the overall trend is positive, especially for the annual periods.
#
# The get_earnings_analysis provides more depth. The earnings estimates for each period have averages, lows, highs, and growth rates. For the current quarter, the average estimate is 0.45414, with a growth rate of 13.53% compared to the year-ago. The revisions show that there have been some upward adjustments in the last 7 and 30 days for most periods, except for the +1y period, which had a downward revision in the last 7 days. The growth estimates compared to the index are slightly lower, which might indicate that while Tesla is growing, it's not outpacing the market as much as in previous periods.
#
# Looking at the earnings history, the actual EPS for recent quarters sometimes missed estimates, but there were surprises in the positive direction in other quarters. For example, in Q4 2025, the actual EPS was higher than estimated, leading to a positive surprise. However, in Q3 2025, there was a significant negative surprise. This mixed performance is important to note as it shows inconsistency in meeting expectations.
#
# Putting this all together, the user is likely interested in understanding the current state of Tesla's earnings and how recent events like the SpaceX IPO are influencing its stock. The news highlights the market's reaction to Musk's new venture, which could affect investor sentiment. The EPS data shows a generally positive trend but with some volatility and mixed performance in recent quarters. The revisions and growth estimates suggest that analysts are cautiously optimistic but with some downward adjustments for future periods.
#
# I need to present this information clearly, starting with the recent news to set the context, followed by the EPS trends and analysis, and conclude with the historical performance. It's important to mention the key points from each tool response and how they interrelate, especially the impact of SpaceX on Tesla's market position and stock price.
#
# Content:  ### TSLA News Highlights (June 5-13, 2026)
# 1. **Elon Musk's Trillionaire Status**
#    SpaceX's IPO made Musk the world's first trillionaire, with his stake valued at ~$870B. This event has sparked discussions about Tesla's market position as SpaceX's valuation surpassed Tesla's ($1.8T vs. $2.1T).
#
# 2. **Market Reactions**
#    - Tesla (TSLA) closed **2% higher** on June 12, 2026, as investors reacted to the SpaceX IPO.
#    - SpaceX (SPCX) surged **19%** in its debut, reaching a $2.1T valuation, outpacing Tesla and Meta.
#    - Analysts debate whether the "Magnificent Seven" tech stock label still applies now that SpaceX has entered the market.
#
# 3. **Industry Impact**
#    - **ArcBest** expanded its Tesla Semi fleet, signaling growing adoption of electric trucks.
#    - Some investors fear Tesla could lose market share to SpaceX, while others argue Tesla remains a core holding for passive funds.
#
# ---
#
# ### EPS Trends (Last 7 Days)
# | Period       | Current Estimate | 7 Days Ago | Change vs. 7 Days Ago |
# |--------------|------------------|------------|------------------------|
# | **This Quarter (0q)** | 0.45414        | 0.45396    | **+0.00002** (+0.004%) |
# | **Next Quarter (+1q)**| 0.5375         | 0.5393     | **-0.0018** (-0.33%)   |
# | **This Year (0y)**    | 2.05937        | 2.04967    | **+0.0097** (+0.47%)   |
# | **Next Year (+1y)**   | 2.49995        | 2.50462    | **-0.0047** (-0.19%)   |
#
# - **Key Insight**: The 7-day EPS trend shows **minor fluctuations**, with slight upward revisions for the current and annual periods but downward adjustments for the next quarter and year.
#
# ---
#
# ### Earnings Analysis
# #### 1. **Earnings Estimates**
# - **Current Quarter (0q)**:
#   - **Avg Estimate**: $0.454 (up 13.5% YoY).
#   - **Range**: $0.265 (low) to $0.59 (high).
#   - **Analyst Consensus**: 25 analysts tracked.
#
# - **Next Year (+1y)**:
#   - **Avg Estimate**: $2.50 (growth: 21.4%).
#   - **Downside Risk**: 30 analysts project a range of $1.46 (low) to $3.65 (high).
#
# #### 2. **EPS Revisions**
# - **Upward Revisions**:
#   - 1 revision up in the last 7 days for **0q** and **+1q**.
# - **Downward Revisions**:
#   - **+1y** saw 1 downward revision in the last 7 days (from 2.50462 to 2.49995).
#
# #### 3. **Growth vs. Index**
# | Period       | Tesla Growth | Market Index Trend |
# |--------------|--------------|--------------------|
# | 0q           | 13.5%        | 25.98%             |
# | +1q          | 7.5%         | 20.24%             |
# | 0y           | 24.1%        | 23.0%              |
# | +1y          | 21.4%        | 16.9%              |
#
# - **Takeaway**: Tesla's growth estimates are **slightly below the broader market index** for most periods, indicating analysts expect slower growth relative to the tech sector average.
#
# ---
#
# ### Historical Earnings Performance (Last 4 Quarters)
# | Quarter       | Actual EPS | Estimated EPS | Surprise % |
# |---------------|------------|---------------|------------|
# | **Q2 2025**   | $0.40      | $0.40391      | -0.97%     |
# | **Q3 2025**   | $0.50      | $0.55885      | **-10.5%** |
# | **Q4 2025**   | $0.50      | $0.45061      | **+10.96%**|
# | **Q1 2026**   | $0.41      | $0.34999      | **+17.15%**|
#
# - **Mixed Results**: Tesla underperformed in Q2 2025 and Q3 2025 but outperformed estimates in Q4 2025 and Q1 2026.
#
# ---
#
# ### Summary
# - **News Impact**: SpaceX's IPO has created a "trillionaire" narrative for Elon Musk but may dilute Tesla's market focus.
# - **EPS Trends**: Analysts show cautious optimism, with slight upward revisions for the current quarter but downward adjustments for longer-term periods.
# - **Historical Performance**: Tesla has shown inconsistent earnings surprises, with recent quarters showing improvement.
#
# **Investor Takeaway**: While Tesla's near-term EPS estimates are stable, long-term growth projections (e.g., +1y) are slightly negative, and the broader market may outperform Tesla's growth trajectory.

# %% [markdown]
# ## 2.1) Simple agent - no memory
# * PAID Agent: based on OpenAI's technology for function calling: https://developers.openai.com/api/docs/guides/function-calling
# * and using gpt-5.4-mini model (no thinking)
# * you can use tool search (available from gpt-5.4), if you have many tools available (https://developers.openai.com/api/docs/guides/tools-tool-search)

# %%
# 
# !uv  pip list | grep openai
# Out:
# Using Python 3.12.7 environment at: /Users/realmistic/Documents/stocks-scoring-agent/.venv
# openai                    2.13.0
# openai-agents             0.6.3

# %%
import agents
print(f"📦 Version: {agents.__version__}")
# Out:
# 📦 Version: 0.6.3

# %%
from agents import Agent, Runner

agent = Agent(name="Assistant", instructions="You are a helpful assistant")

result = await Runner.run(agent, "Write a haiku about recursion in programming.")
print(result.final_output)
# Out:
# Within self it dwells,
# Calls its name until the end—
# Loops in timeless code.

# %%
from agents import function_tool

# in case we need WebSearch 
from agents import WebSearchTool

# %%
stock_agent = Agent(
    name='stock_agent',
    instructions="you're a helful assistant. Try to use all defined tools before going into the WebSearchTool",
    model='gpt-5.4-mini',
    tools=[ 
           WebSearchTool(), 
           function_tool(get_company_info),
           function_tool(get_eps_trend),
           function_tool(get_earnings_dates),
           function_tool(get_earnings_analysis),
           function_tool(get_historical_prices),
           function_tool(get_ticker_news),
           function_tool(search_news_by_ticker),
           function_tool(search_news_by_query),
           function_tool(search_companies),
           function_tool(get_top_value_companies),
           function_tool(get_top_growth_companies),
           ] 
)

# %%
from agents import Runner

runner = Runner()

results = await runner.run(stock_agent, 
                           input="EPS trend for TSLA and the latest earnings call date and results, news sentiment")

# %%
print(results.final_output)
# Out:
# Here’s a quick TSLA earnings snapshot as of **June 13, 2026**:
#
# ### EPS trend
# **Analyst EPS estimates for TSLA have been mostly stable to slightly lower at the outer years, with a small bump in the current quarter.**
# - **Current quarter (0q):** 0.454 vs 0.454 a week ago, 0.454 a month ago, 0.446 two months ago, 0.462 three months ago
# - **Next quarter (+1q):** 0.538 vs 0.539 a week ago
# - **Current year (0y):** 2.059 vs 2.050 a week ago, 2.048 a month ago
# - **Next year (+1y):** 2.500 vs 2.505 a week ago, 2.510 a month ago, down from 2.772 two months ago and 2.810 three months ago
#
# ### Latest earnings call date and result
# **Most recent reported earnings date:** **April 22, 2026**
# - **EPS estimate:** 0.20
# - **Reported EPS:** 0.13
# - **Surprise:** **-36.54%**
#
# ### Next earnings date
# **Next scheduled earnings date:** **July 22, 2026**
# - **EPS estimate:** 0.45
#
# ### Earnings context
# Recent quarters have been mixed:
# - **Jan. 28, 2026:** beat, 0.50 vs 0.45 estimate
# - **Apr. 22, 2026:** miss, 0.13 vs 0.20 estimate
# - **Oct. 22, 2025:** miss, 0.50 vs 0.56 estimate
# - **Jul. 23, 2025:** beat, 0.33 vs 0.30 estimate
#
# ### News sentiment
# Recent TSLA-related news sentiment looks **mixed to mildly positive**, but a lot of the attention is actually on **SpaceX / Elon Musk**, not Tesla’s core fundamentals. Highlights:
# - **Positive/constructive:** TSLA rose after SpaceX’s historic debut; ArcBest expanding Tesla Semi fleet
# - **Mixed/negative-leaning:** some stories suggest investors may sell TSLA to fund SpaceX exposure
# - **Overall tone:** near-term sentiment appears **headline-driven and moderately supportive**, but not strongly conviction-building for TSLA itself
#
# If you want, I can also turn this into a **bullish/bearish earnings thesis** or a **table with quarter-by-quarter EPS history**.

# %%
results.raw_responses
# Out:
# [ModelResponse(output=[ResponseFunctionToolCall(arguments='{"ticker":"TSLA"}', call_id='call_qZD7Zq53tiwkLuEkdQGsmTYb', name='get_eps_trend', type='function_call', id='fc_09ff9f55f9006dc9006a2dbaf112a881928679c50a34134d98', status='completed'), ResponseFunctionToolCall(arguments='{"ticker":"TSLA"}', call_id='call_cjIz2m9mihnuyMHfi4GmxjYM', name='get_earnings_dates', type='function_call', id='fc_09ff9f55f9006dc9006a2dbaf112b88192991717f0b53b3355', status='completed'), ResponseFunctionToolCall(arguments='{"ticker":"TSLA","count":8}', call_id='call_9wKHBjsaTti7WDbCz5pkmsHX', name='get_ticker_news', type='function_call', id='fc_09ff9f55f9006dc9006a2dbaf112c0819299831d8af74d35ba', status='completed'), ResponseFunctionToolCall(arguments='{"ticker":"TSLA"}', call_id='call_eyDVCkcLiNa6MPF9fnDzB7S4', name='get_earnings_analysis', type='function_call', id='fc_09ff9f55f9006dc9006a2dbaf112c881928878a0a32daa37fa', status='completed')], usage=Usage(requests=1, input_tokens=6209, input_tokens_details=InputTokensDetails(cached_tokens=6016), output_tokens=94, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=6303, request_usage_entries=[]), response_id='resp_09ff9f55f9006dc9006a2dbaf0108c819287bd64a52ade6c99'),
#  ModelResponse(output=[ResponseOutputMessage(id='msg_09ff9f55f9006dc9006a2dbaf39ebc819282b193e6e883e4b4', content=[ResponseOutputText(annotations=[], text='Here’s a quick TSLA earnings snapshot as of **June 13, 2026**:\n\n### EPS trend\n**Analyst EPS estimates for TSLA have been mostly stable to slightly lower at the outer years, with a small bump in the current quarter.**  \n- **Current quarter (0q):** 0.454 vs 0.454 a week ago, 0.454 a month ago, 0.446 two months ago, 0.462 three months ago  \n- **Next quarter (+1q):** 0.538 vs 0.539 a week ago  \n- **Current year (0y):** 2.059 vs 2.050 a week ago, 2.048 a month ago  \n- **Next year (+1y):** 2.500 vs 2.505 a week ago, 2.510 a month ago, down from 2.772 two months ago and 2.810 three months ago\n\n### Latest earnings call date and result\n**Most recent reported earnings date:** **April 22, 2026**  \n- **EPS estimate:** 0.20  \n- **Reported EPS:** 0.13  \n- **Surprise:** **-36.54%**\n\n### Next earnings date\n**Next scheduled earnings date:** **July 22, 2026**  \n- **EPS estimate:** 0.45\n\n### Earnings context\nRecent quarters have been mixed:\n- **Jan. 28, 2026:** beat, 0.50 vs 0.45 estimate\n- **Apr. 22, 2026:** miss, 0.13 vs 0.20 estimate\n- **Oct. 22, 2025:** miss, 0.50 vs 0.56 estimate\n- **Jul. 23, 2025:** beat, 0.33 vs 0.30 estimate\n\n### News sentiment\nRecent TSLA-related news sentiment looks **mixed to mildly positive**, but a lot of the attention is actually on **SpaceX / Elon Musk**, not Tesla’s core fundamentals. Highlights:\n- **Positive/constructive:** TSLA rose after SpaceX’s historic debut; ArcBest expanding Tesla Semi fleet\n- **Mixed/negative-leaning:** some stories suggest investors may sell TSLA to fund SpaceX exposure\n- **Overall tone:** near-term sentiment appears **headline-driven and moderately supportive**, but not strongly conviction-building for TSLA itself\n\nIf you want, I can also turn this into a **bullish/bearish earnings thesis** or a **table with quarter-by-quarter EPS history**.', type='output_text', logprobs=[])], role='assistant', status='completed', type='message', phase='final_answer')], usage=Usage(requests=1, input_tokens=9819, input_tokens_details=InputTokensDetails(cached_tokens=6016), output_tokens=545, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=10364, request_usage_entries=[]), response_id='resp_09ff9f55f9006dc9006a2dbaf344408192a550a7dacf324d6f')]

# %%
results.new_items
# Out:
# [ToolCallItem(agent=Agent(name='stock_agent', handoff_description=None, tools=[WebSearchTool(user_location=None, filters=None, search_context_size='medium'), FunctionTool(name='get_company_info', description='Get comprehensive company information and fundamental data for a stock ticker.\n\nReturns key metrics organized by category:\n- Company basics: website, industry, sector, employees, officers\n- Price data: current, previous close, day range, 52-week range\n- Market metrics: market cap, volume, beta, PE ratios\n- Valuation: margins, book value, price ratios\n- Ownership: insider/institutional holdings, short interest\n- Analyst data: EPS estimates, targets, recommendations\n- Financial health: cash, returns, growth rates', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_company_info_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11e892ac0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_eps_trend', description='Get the EPS (Earnings Per Share) trend for a given stock ticker - showing how analyst consensus has changed over time for different periods (quarterly, yearly)\nand diffent points in the past (current, 7daysAgo, 30daysAgo, etc.).\nIndex: 0q (This Quarter),  +1q (Next Quarter),  0y (This Year),  +1y (Next Year) \nand columns showing estimates from different points in the past (current, 7daysAgo, 30daysAgo, etc.). ', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_eps_trend_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11961cf40>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_dates', description='Get earnings call dates for a stock ticker.\n\nReturns historical earnings data including:\n- Expected EPS\n- Actual EPS  \n- Surprise percentage\n- Earnings dates from multiple quarters and years\n- Next earnings call date', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_dates_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee40e0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_analysis', description='Get comprehensive earnings and EPS analysis data for a stock ticker.\n\nCombines multiple analyst data sources:\n1. Earnings Estimates - Consensus EPS estimates (avg, low, high, year-ago, analyst count)\n2. EPS Revisions - How analysts have revised estimates (up/down last 7/30 days)\n3. Growth Estimates - Expected earnings growth vs index benchmark\n4. Earnings History - Historical actual vs estimated EPS with surprise %\n\nPeriod notation:\n- 0q: Current fiscal quarter\n- +1q: Next fiscal quarter\n- 0y: Current fiscal year\n- +1y: Next fiscal year\n- LTG: Long-term growth (growth estimates only)', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_analysis_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee49a0>, strict_json_schema=True, is_enabled=True, tool_inpu ...
#  ToolCallItem(agent=Agent(name='stock_agent', handoff_description=None, tools=[WebSearchTool(user_location=None, filters=None, search_context_size='medium'), FunctionTool(name='get_company_info', description='Get comprehensive company information and fundamental data for a stock ticker.\n\nReturns key metrics organized by category:\n- Company basics: website, industry, sector, employees, officers\n- Price data: current, previous close, day range, 52-week range\n- Market metrics: market cap, volume, beta, PE ratios\n- Valuation: margins, book value, price ratios\n- Ownership: insider/institutional holdings, short interest\n- Analyst data: EPS estimates, targets, recommendations\n- Financial health: cash, returns, growth rates', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_company_info_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11e892ac0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_eps_trend', description='Get the EPS (Earnings Per Share) trend for a given stock ticker - showing how analyst consensus has changed over time for different periods (quarterly, yearly)\nand diffent points in the past (current, 7daysAgo, 30daysAgo, etc.).\nIndex: 0q (This Quarter),  +1q (Next Quarter),  0y (This Year),  +1y (Next Year) \nand columns showing estimates from different points in the past (current, 7daysAgo, 30daysAgo, etc.). ', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_eps_trend_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11961cf40>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_dates', description='Get earnings call dates for a stock ticker.\n\nReturns historical earnings data including:\n- Expected EPS\n- Actual EPS  \n- Surprise percentage\n- Earnings dates from multiple quarters and years\n- Next earnings call date', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_dates_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee40e0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_analysis', description='Get comprehensive earnings and EPS analysis data for a stock ticker.\n\nCombines multiple analyst data sources:\n1. Earnings Estimates - Consensus EPS estimates (avg, low, high, year-ago, analyst count)\n2. EPS Revisions - How analysts have revised estimates (up/down last 7/30 days)\n3. Growth Estimates - Expected earnings growth vs index benchmark\n4. Earnings History - Historical actual vs estimated EPS with surprise %\n\nPeriod notation:\n- 0q: Current fiscal quarter\n- +1q: Next fiscal quarter\n- 0y: Current fiscal year\n- +1y: Next fiscal year\n- LTG: Long-term growth (growth estimates only)', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_analysis_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee49a0>, strict_json_schema=True, is_enabled=True, tool_inpu ...
#  ToolCallItem(agent=Agent(name='stock_agent', handoff_description=None, tools=[WebSearchTool(user_location=None, filters=None, search_context_size='medium'), FunctionTool(name='get_company_info', description='Get comprehensive company information and fundamental data for a stock ticker.\n\nReturns key metrics organized by category:\n- Company basics: website, industry, sector, employees, officers\n- Price data: current, previous close, day range, 52-week range\n- Market metrics: market cap, volume, beta, PE ratios\n- Valuation: margins, book value, price ratios\n- Ownership: insider/institutional holdings, short interest\n- Analyst data: EPS estimates, targets, recommendations\n- Financial health: cash, returns, growth rates', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_company_info_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11e892ac0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_eps_trend', description='Get the EPS (Earnings Per Share) trend for a given stock ticker - showing how analyst consensus has changed over time for different periods (quarterly, yearly)\nand diffent points in the past (current, 7daysAgo, 30daysAgo, etc.).\nIndex: 0q (This Quarter),  +1q (Next Quarter),  0y (This Year),  +1y (Next Year) \nand columns showing estimates from different points in the past (current, 7daysAgo, 30daysAgo, etc.). ', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_eps_trend_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11961cf40>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_dates', description='Get earnings call dates for a stock ticker.\n\nReturns historical earnings data including:\n- Expected EPS\n- Actual EPS  \n- Surprise percentage\n- Earnings dates from multiple quarters and years\n- Next earnings call date', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_dates_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee40e0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_analysis', description='Get comprehensive earnings and EPS analysis data for a stock ticker.\n\nCombines multiple analyst data sources:\n1. Earnings Estimates - Consensus EPS estimates (avg, low, high, year-ago, analyst count)\n2. EPS Revisions - How analysts have revised estimates (up/down last 7/30 days)\n3. Growth Estimates - Expected earnings growth vs index benchmark\n4. Earnings History - Historical actual vs estimated EPS with surprise %\n\nPeriod notation:\n- 0q: Current fiscal quarter\n- +1q: Next fiscal quarter\n- 0y: Current fiscal year\n- +1y: Next fiscal year\n- LTG: Long-term growth (growth estimates only)', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_analysis_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee49a0>, strict_json_schema=True, is_enabled=True, tool_inpu ...
#  ToolCallItem(agent=Agent(name='stock_agent', handoff_description=None, tools=[WebSearchTool(user_location=None, filters=None, search_context_size='medium'), FunctionTool(name='get_company_info', description='Get comprehensive company information and fundamental data for a stock ticker.\n\nReturns key metrics organized by category:\n- Company basics: website, industry, sector, employees, officers\n- Price data: current, previous close, day range, 52-week range\n- Market metrics: market cap, volume, beta, PE ratios\n- Valuation: margins, book value, price ratios\n- Ownership: insider/institutional holdings, short interest\n- Analyst data: EPS estimates, targets, recommendations\n- Financial health: cash, returns, growth rates', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_company_info_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11e892ac0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_eps_trend', description='Get the EPS (Earnings Per Share) trend for a given stock ticker - showing how analyst consensus has changed over time for different periods (quarterly, yearly)\nand diffent points in the past (current, 7daysAgo, 30daysAgo, etc.).\nIndex: 0q (This Quarter),  +1q (Next Quarter),  0y (This Year),  +1y (Next Year) \nand columns showing estimates from different points in the past (current, 7daysAgo, 30daysAgo, etc.). ', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_eps_trend_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11961cf40>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_dates', description='Get earnings call dates for a stock ticker.\n\nReturns historical earnings data including:\n- Expected EPS\n- Actual EPS  \n- Surprise percentage\n- Earnings dates from multiple quarters and years\n- Next earnings call date', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_dates_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee40e0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_analysis', description='Get comprehensive earnings and EPS analysis data for a stock ticker.\n\nCombines multiple analyst data sources:\n1. Earnings Estimates - Consensus EPS estimates (avg, low, high, year-ago, analyst count)\n2. EPS Revisions - How analysts have revised estimates (up/down last 7/30 days)\n3. Growth Estimates - Expected earnings growth vs index benchmark\n4. Earnings History - Historical actual vs estimated EPS with surprise %\n\nPeriod notation:\n- 0q: Current fiscal quarter\n- +1q: Next fiscal quarter\n- 0y: Current fiscal year\n- +1y: Next fiscal year\n- LTG: Long-term growth (growth estimates only)', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_analysis_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee49a0>, strict_json_schema=True, is_enabled=True, tool_inpu ...
#  ToolCallOutputItem(agent=Agent(name='stock_agent', handoff_description=None, tools=[WebSearchTool(user_location=None, filters=None, search_context_size='medium'), FunctionTool(name='get_company_info', description='Get comprehensive company information and fundamental data for a stock ticker.\n\nReturns key metrics organized by category:\n- Company basics: website, industry, sector, employees, officers\n- Price data: current, previous close, day range, 52-week range\n- Market metrics: market cap, volume, beta, PE ratios\n- Valuation: margins, book value, price ratios\n- Ownership: insider/institutional holdings, short interest\n- Analyst data: EPS estimates, targets, recommendations\n- Financial health: cash, returns, growth rates', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_company_info_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11e892ac0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_eps_trend', description='Get the EPS (Earnings Per Share) trend for a given stock ticker - showing how analyst consensus has changed over time for different periods (quarterly, yearly)\nand diffent points in the past (current, 7daysAgo, 30daysAgo, etc.).\nIndex: 0q (This Quarter),  +1q (Next Quarter),  0y (This Year),  +1y (Next Year) \nand columns showing estimates from different points in the past (current, 7daysAgo, 30daysAgo, etc.). ', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_eps_trend_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11961cf40>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_dates', description='Get earnings call dates for a stock ticker.\n\nReturns historical earnings data including:\n- Expected EPS\n- Actual EPS  \n- Surprise percentage\n- Earnings dates from multiple quarters and years\n- Next earnings call date', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_dates_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee40e0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_analysis', description='Get comprehensive earnings and EPS analysis data for a stock ticker.\n\nCombines multiple analyst data sources:\n1. Earnings Estimates - Consensus EPS estimates (avg, low, high, year-ago, analyst count)\n2. EPS Revisions - How analysts have revised estimates (up/down last 7/30 days)\n3. Growth Estimates - Expected earnings growth vs index benchmark\n4. Earnings History - Historical actual vs estimated EPS with surprise %\n\nPeriod notation:\n- 0q: Current fiscal quarter\n- +1q: Next fiscal quarter\n- 0y: Current fiscal year\n- +1y: Next fiscal year\n- LTG: Long-term growth (growth estimates only)', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_analysis_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee49a0>, strict_json_schema=True, is_enabled=True, too ...
#  ToolCallOutputItem(agent=Agent(name='stock_agent', handoff_description=None, tools=[WebSearchTool(user_location=None, filters=None, search_context_size='medium'), FunctionTool(name='get_company_info', description='Get comprehensive company information and fundamental data for a stock ticker.\n\nReturns key metrics organized by category:\n- Company basics: website, industry, sector, employees, officers\n- Price data: current, previous close, day range, 52-week range\n- Market metrics: market cap, volume, beta, PE ratios\n- Valuation: margins, book value, price ratios\n- Ownership: insider/institutional holdings, short interest\n- Analyst data: EPS estimates, targets, recommendations\n- Financial health: cash, returns, growth rates', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_company_info_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11e892ac0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_eps_trend', description='Get the EPS (Earnings Per Share) trend for a given stock ticker - showing how analyst consensus has changed over time for different periods (quarterly, yearly)\nand diffent points in the past (current, 7daysAgo, 30daysAgo, etc.).\nIndex: 0q (This Quarter),  +1q (Next Quarter),  0y (This Year),  +1y (Next Year) \nand columns showing estimates from different points in the past (current, 7daysAgo, 30daysAgo, etc.). ', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_eps_trend_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11961cf40>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_dates', description='Get earnings call dates for a stock ticker.\n\nReturns historical earnings data including:\n- Expected EPS\n- Actual EPS  \n- Surprise percentage\n- Earnings dates from multiple quarters and years\n- Next earnings call date', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_dates_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee40e0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_analysis', description='Get comprehensive earnings and EPS analysis data for a stock ticker.\n\nCombines multiple analyst data sources:\n1. Earnings Estimates - Consensus EPS estimates (avg, low, high, year-ago, analyst count)\n2. EPS Revisions - How analysts have revised estimates (up/down last 7/30 days)\n3. Growth Estimates - Expected earnings growth vs index benchmark\n4. Earnings History - Historical actual vs estimated EPS with surprise %\n\nPeriod notation:\n- 0q: Current fiscal quarter\n- +1q: Next fiscal quarter\n- 0y: Current fiscal year\n- +1y: Next fiscal year\n- LTG: Long-term growth (growth estimates only)', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_analysis_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee49a0>, strict_json_schema=True, is_enabled=True, too ...
#  ToolCallOutputItem(agent=Agent(name='stock_agent', handoff_description=None, tools=[WebSearchTool(user_location=None, filters=None, search_context_size='medium'), FunctionTool(name='get_company_info', description='Get comprehensive company information and fundamental data for a stock ticker.\n\nReturns key metrics organized by category:\n- Company basics: website, industry, sector, employees, officers\n- Price data: current, previous close, day range, 52-week range\n- Market metrics: market cap, volume, beta, PE ratios\n- Valuation: margins, book value, price ratios\n- Ownership: insider/institutional holdings, short interest\n- Analyst data: EPS estimates, targets, recommendations\n- Financial health: cash, returns, growth rates', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_company_info_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11e892ac0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_eps_trend', description='Get the EPS (Earnings Per Share) trend for a given stock ticker - showing how analyst consensus has changed over time for different periods (quarterly, yearly)\nand diffent points in the past (current, 7daysAgo, 30daysAgo, etc.).\nIndex: 0q (This Quarter),  +1q (Next Quarter),  0y (This Year),  +1y (Next Year) \nand columns showing estimates from different points in the past (current, 7daysAgo, 30daysAgo, etc.). ', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_eps_trend_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11961cf40>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_dates', description='Get earnings call dates for a stock ticker.\n\nReturns historical earnings data including:\n- Expected EPS\n- Actual EPS  \n- Surprise percentage\n- Earnings dates from multiple quarters and years\n- Next earnings call date', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_dates_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee40e0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_analysis', description='Get comprehensive earnings and EPS analysis data for a stock ticker.\n\nCombines multiple analyst data sources:\n1. Earnings Estimates - Consensus EPS estimates (avg, low, high, year-ago, analyst count)\n2. EPS Revisions - How analysts have revised estimates (up/down last 7/30 days)\n3. Growth Estimates - Expected earnings growth vs index benchmark\n4. Earnings History - Historical actual vs estimated EPS with surprise %\n\nPeriod notation:\n- 0q: Current fiscal quarter\n- +1q: Next fiscal quarter\n- 0y: Current fiscal year\n- +1y: Next fiscal year\n- LTG: Long-term growth (growth estimates only)', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_analysis_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee49a0>, strict_json_schema=True, is_enabled=True, too ...
#  ToolCallOutputItem(agent=Agent(name='stock_agent', handoff_description=None, tools=[WebSearchTool(user_location=None, filters=None, search_context_size='medium'), FunctionTool(name='get_company_info', description='Get comprehensive company information and fundamental data for a stock ticker.\n\nReturns key metrics organized by category:\n- Company basics: website, industry, sector, employees, officers\n- Price data: current, previous close, day range, 52-week range\n- Market metrics: market cap, volume, beta, PE ratios\n- Valuation: margins, book value, price ratios\n- Ownership: insider/institutional holdings, short interest\n- Analyst data: EPS estimates, targets, recommendations\n- Financial health: cash, returns, growth rates', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_company_info_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11e892ac0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_eps_trend', description='Get the EPS (Earnings Per Share) trend for a given stock ticker - showing how analyst consensus has changed over time for different periods (quarterly, yearly)\nand diffent points in the past (current, 7daysAgo, 30daysAgo, etc.).\nIndex: 0q (This Quarter),  +1q (Next Quarter),  0y (This Year),  +1y (Next Year) \nand columns showing estimates from different points in the past (current, 7daysAgo, 30daysAgo, etc.). ', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_eps_trend_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11961cf40>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_dates', description='Get earnings call dates for a stock ticker.\n\nReturns historical earnings data including:\n- Expected EPS\n- Actual EPS  \n- Surprise percentage\n- Earnings dates from multiple quarters and years\n- Next earnings call date', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_dates_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee40e0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_analysis', description='Get comprehensive earnings and EPS analysis data for a stock ticker.\n\nCombines multiple analyst data sources:\n1. Earnings Estimates - Consensus EPS estimates (avg, low, high, year-ago, analyst count)\n2. EPS Revisions - How analysts have revised estimates (up/down last 7/30 days)\n3. Growth Estimates - Expected earnings growth vs index benchmark\n4. Earnings History - Historical actual vs estimated EPS with surprise %\n\nPeriod notation:\n- 0q: Current fiscal quarter\n- +1q: Next fiscal quarter\n- 0y: Current fiscal year\n- +1y: Next fiscal year\n- LTG: Long-term growth (growth estimates only)', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_analysis_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee49a0>, strict_json_schema=True, is_enabled=True, too ...
#  MessageOutputItem(agent=Agent(name='stock_agent', handoff_description=None, tools=[WebSearchTool(user_location=None, filters=None, search_context_size='medium'), FunctionTool(name='get_company_info', description='Get comprehensive company information and fundamental data for a stock ticker.\n\nReturns key metrics organized by category:\n- Company basics: website, industry, sector, employees, officers\n- Price data: current, previous close, day range, 52-week range\n- Market metrics: market cap, volume, beta, PE ratios\n- Valuation: margins, book value, price ratios\n- Ownership: insider/institutional holdings, short interest\n- Analyst data: EPS estimates, targets, recommendations\n- Financial health: cash, returns, growth rates', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_company_info_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11e892ac0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_eps_trend', description='Get the EPS (Earnings Per Share) trend for a given stock ticker - showing how analyst consensus has changed over time for different periods (quarterly, yearly)\nand diffent points in the past (current, 7daysAgo, 30daysAgo, etc.).\nIndex: 0q (This Quarter),  +1q (Next Quarter),  0y (This Year),  +1y (Next Year) \nand columns showing estimates from different points in the past (current, 7daysAgo, 30daysAgo, etc.). ', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_eps_trend_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11961cf40>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_dates', description='Get earnings call dates for a stock ticker.\n\nReturns historical earnings data including:\n- Expected EPS\n- Actual EPS  \n- Surprise percentage\n- Earnings dates from multiple quarters and years\n- Next earnings call date', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_dates_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee40e0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_analysis', description='Get comprehensive earnings and EPS analysis data for a stock ticker.\n\nCombines multiple analyst data sources:\n1. Earnings Estimates - Consensus EPS estimates (avg, low, high, year-ago, analyst count)\n2. EPS Revisions - How analysts have revised estimates (up/down last 7/30 days)\n3. Growth Estimates - Expected earnings growth vs index benchmark\n4. Earnings History - Historical actual vs estimated EPS with surprise %\n\nPeriod notation:\n- 0q: Current fiscal quarter\n- +1q: Next fiscal quarter\n- 0y: Current fiscal year\n- +1y: Next fiscal year\n- LTG: Long-term growth (growth estimates only)', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_analysis_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee49a0>, strict_json_schema=True, is_enabled=True, tool ...

# %%
pprint(results.new_items[0])
# Out:
# ToolCallItem(agent=Agent(name='stock_agent',
#                          handoff_description=None,
#                          tools=[WebSearchTool(user_location=None,
#                                               filters=None,
#                                               search_context_size='medium'),
#                                 FunctionTool(name='get_company_info',
#                                              description='Get comprehensive '
#                                                          'company information '
#                                                          'and fundamental data '
#                                                          'for a stock ticker.\n'
#                                                          '\n'
#                                                          'Returns key metrics '
#                                                          'organized by '
#                                                          'category:\n'
#                                                          '- Company basics: '
#                                                          'website, industry, '
#                                                          'sector, employees, '
#                                                          'officers\n'
#                                                          '- Price data: '
#                                                          'current, previous '
#                                                          'close, day range, '
#                                                          '52-week range\n'
#                                                          '- Market metrics: '
#                                                          'market cap, volume, '
#                                                          'beta, PE ratios\n'
#                                                          '- Valuation: '
#                                                          'margins, book value, '
#                                                          'price ratios\n'
#                                                          '- Ownership: '
#                                                          'insider/institutional '
#                                                          'holdings, short '
#                                                          'interest\n'
#                                                          '- Analyst data: EPS '
#                                                          'estimates, targets, '
#                                                          'recommendations\n'
#                                                          '- Financial health: '
#                                                          'cash, returns, '
#                                                          'growth rates',
#                                              params_json_schema={'additionalProperties': False,
#                                                                  'properties': {'ticker': {'description': 'Stock '
#                                                                                                           'ticker '
#                                                                                                           'symbol '
#                                                                                                           '(e.g., '
#                                                                                                           "'AAPL', "
#                                                                                                           "'GOOGL', "
#                                                                                                           "'MSFT')",
#                                                                                            'title': 'Ticker',
#                                                                                            'type': 'string'}},
#                                                                  'required': ['ticker'],
#                                                                  'title': 'get_company_info_args',
#                                                                  'type': 'object'},
#                                              on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11e892ac0>,
#                                              strict_json_schema=True,
#                                              is_enabled=True,
#                                              tool_input_guardrails=None,
#                                              tool_output_guardrails=None),
#                                 FunctionTool(name='get_eps_trend',
#                                              description='Get the EPS '
#                                                          '(Earnings Per Share) '
#                                                          'trend for a given '
#                                                          'stock ticker - '
#                                                          'showing how analyst '
#                                                          'consensus has '
#                                                          'changed over time '
#                                                          'for different '
#                                                          'periods (quarterly, '
#                                                          'yearly)\n'
#                                                          'and diffent points '
#                                                          'in the past '
#                                                          '(current, 7daysAgo, '
#                                                          '30daysAgo, etc.).\n'
#                                                          'Index: 0q (This '
#                                                          'Quarter),  +1q (Next '
#                                                          'Quarter),  0y (This '
#                                                          'Year),  +1y (Next '
#                                                          'Year) \n'
#                                                          'and columns showing '
#                                                          'estimates from '
#                                                          'different points in '
#                                                          'the past (current, '
#                                                          '7daysAgo, 30daysAgo, '
#                                                          'etc.). ',
#                                              params_json_schema={'additionalProperties': False,
#                                                                  'properties': {'ticker': {'description': 'Stock '
#                                                                                                           'ticker '
#                                                                                                           'symbol '
#                                                                                                           '(e.g., '
#                                                                                                           "'AAPL', "
#                                                                                                           "'GOOGL', "
#                                                                                                           "'MSFT')",
#                                                                                            'title': 'Ticker',
#                                                                                            'type': 'string'}},
#                                                                  'required': ['ticker'],
#                                                                  'title': 'get_eps_trend_args',
#                                                                  'type': 'object'},
#                                              on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11961cf40>,
#                                              strict_json_schema=True,
#                                              is_enabled=True,
#                                              tool_input_guardrails=None,
#                                              tool_output_guardrails=None),
#                                 FunctionTool(name='get_earnings_dates',
#                                              description='Get earnings call '
#                                                          'dates for a stock '
#                                                          'ticker.\n'
#                                                          '\n'
#                                                          'Returns historical '
#                                                          'earnings data '
#                                                          'including:\n'
#                                                          '- Expected EPS\n'
#                                                          '- Actual EPS  \n'
#                                                          '- Surprise '
#                                                          'percentage\n'
#                                                          '- Earnings dates '
#                                                          'from multiple '
#                                                          'quarters and years\n'
#                                                          '- Next earnings call '
#                                                          'date',
#                                              params_json_schema={'additionalProperties': False,
#                                                                  'properties': {'ticker': {'description': 'Stock '
#                                                                                                           'ticker '
#                                                                                                           'symbol '
#                                                                                                           '(e.g., '
#                                                                                                           "'AAPL', "
#                                                                                                           "'GOOGL', "
#                                                                                                           "'MSFT')",
#                                                                                            'title': 'Ticker',
#                                                                                            'type': 'string'}},
#                                                                  'required': ['ticker'],
#                                                                  'title': 'get_earnings_dates_args',
#                                                                  'type': 'object'},
#                                              on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee40e0>,
#                                              strict_json_schema=True,
#                                              is_enabled=True,
#                                              tool_input_guardrails=None,
#                                              tool_output_guardrails=None),
#                                 FunctionTool(name='get_earnings_analysis',
#                                              description='Get comprehensive '
#                                                          'earnings and EPS '
#                                                          'analysis data for a '
#                                                          'stock ticker.\n'
#                                                          '\n'
#                                                          'Combines multiple '
#                                                          'analyst data '
#                                                          'sources:\n'
#                                                          '1. Earnings '
#                                                          'Estimates - '
#                                                          'Consensus EPS '
#                                                          'estimates (avg, low, '
#                                                          'high, year-ago, '
#                                                          'analyst count)\n'
#                                                          '2. EPS Revisions - '
#                                                          'How analysts have '
#                                                          'revised estimates '
#                                                          '(up/down last 7/30 '
#                                                          'days)\n'
#                                                          '3. Growth Estimates '
#                                                          '- Expected earnings '
#                                                          'growth vs index '
#                                                          'benchmark\n'
#                                                          '4. Earnings History '
#                                                          '- Historical actual '
#                                                          'vs estimated EPS '
#                                                          'with surprise %\n'
#                                                          '\n'
#                                                          'Period notation:\n'
#                                                          '- 0q: Current fiscal '
#                                                          'quarter\n'
#                                                          '- +1q: Next fiscal '
#                                                          'quarter\n'
#                                                          '- 0y: Current fiscal '
#                                                          'year\n'
#                                                          '- +1y: Next fiscal '
#                                                          'year\n'
#                                                          '- LTG: Long-term '
#                                                          'growth (growth '
#                                                          'estimates only)',
#                                              params_json_schema={'additionalProperties': False,
#                                                                  'properties': {'ticker': {'description': 'Stock '
#                                                                                                           'ticker '
#                                                                                                           'symbol '
#                                                                                                           '(e.g., '
#                                                                                                           "'AAPL', "
#                                                                                                           "'GOOGL', "
#                                                                                                           "'MSFT')",
#                                                                                            'title': 'Ticker',
#                                                                                            'type': 'string'}},
#                                                                  'required': ['ticker'],
#                                                                  'title': 'get_earnings_analysis_args',
#                                                                  'type': 'object'},
#                                              on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee49a0>,
#                                              strict_json_schema=True,
#                                              is_enabled=True,
#                                              tool_input_guardrails=None,
#                                              tool_output_guardrails=None),
#                                 FunctionTool(name='get_historical_prices',
#                                              description='Get historical price '
#                                                          'data for a stock '
#                                                          'ticker.\n'
#                                                          '\n'
#                                                          'Returns OHLCV (Open, '
#                                                          'High, Low, Close, '
#                                                          'Volume) data for the '
#                                                          'specified period.',
#                                              params_json_schema={'additionalProperties': False,
#                                                                  'properties': {'interval': {'default': '1d',
#                                                                                              'description': 'Data '
#                                                                                                             'interval '
#                                                                                                             '(default: '
#                                                                                                             '"1d")\n'
#                                                                                                             '    '
#                                                                                                             'Valid '
#                                                                                                             'intervals: '
#                                                                                                             '1m, '
#                                                                                                             '2m, '
#                                                                                                             '5m, '
#                                                                                                             '15m, '
#                                                                                                             '30m, '
#                                                                                                             '60m, '
#                                                                                                             '90m, '
#                                                                                                             '1h, '
#                                                                                                             '1d, '
#                                                                                                             '5d, '
#                                                                                                             '1wk, '
#                                                                                                             '1mo, '
#                                                                                                             '3mo',
#                                                                                              'title': 'Interval',
#                                                                                              'type': 'string'},
#                                                                                 'period': {'default': '2y',
#                                                                                            'description': 'Time '
#                                                                                                           'period '
#                                                                                                           'to '
#                                                                                                           'fetch '
#                                                                                                           '(default: '
#                                                                                                           '"2y")\n'
#                                                                                                           '    '
#                                                                                                           'Valid '
#                                                                                                           'periods: '
#                                                                                                           '1d, '
#                                                                                                           '5d, '
#                                                                                                           '1mo, '
#                                                                                                           '3mo, '
#                                                                                                           '6mo, '
#                                                                                                           '1y, '
#                                                                                                           '2y, '
#                                                                                                           '5y, '
#                                                                                                           '10y, '
#                                                                                                           'ytd, '
#                                                                                                           'max',
#                                                                                            'title': 'Period',
#                                                                                            'type': 'string'},
#                                                                                 'ticker': {'description': 'Stock '
#                                                                                                           'ticker '
#                                                                                                           'symbol '
#                                                                                                           '(e.g., '
#                                                                                                           "'AAPL', "
#                                                                                                           "'GOOGL', "
#                                                                                                           "'MSFT')",
#                                                                                            'title': 'Ticker',
#                                                                                            'type': 'string'}},
#                                                                  'required': ['ticker',
#                                                                               'period',
#                                                                               'interval'],
#                                                                  'title': 'get_historical_prices_args',
#                                                                  'type': 'object'},
#                                              on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee4ea0>,
#                                              strict_json_schema=True,
#                                              is_enabled=True,
#                                              tool_input_guardrails=None,
#                                              tool_output_guardrails=None),
#                                 FunctionTool(name='get_ticker_news',
#                                              description='Get recent news '
#                                                          'articles for a stock '
#                                                          'ticker from Yahoo '
#                                                          'Finance.\n'
#                                                          '\n'
#                                                          'Returns key '
#                                                          'information '
#                                                          'including title, '
#                                                          'description, '
#                                                          'summary, publication '
#                                                          'date,\n'
#                                                          'and canonical URL '
#                                                          'for each news '
#                                                          'article.',
#                                              params_json_schema={'additionalProperties': False,
#                                                                  'properties': {'count': {'default': 10,
#                                                                                           'description': 'Maximum '
#                                                                                                          'number '
#                                                                                                          'of '
#                                                                                                          'news '
#                                                                                                          'articles '
#                                                                                                          'to '
#                                                                                                          'return '
#                                                                                                          '(default: '
#                                                                                                          '10)',
#                                                                                           'title': 'Count',
#                                                                                           'type': 'integer'},
#                                                                                 'ticker': {'description': 'Stock '
#                                                                                                           'ticker '
#                                                                                                           'symbol '
#                                                                                                           '(e.g., '
#                                                                                                           "'AAPL', "
#                                                                                                           "'GOOGL', "
#                                                                                                           "'MSFT')",
#                                                                                            'title': 'Ticker',
#                                                                                            'type': 'string'}},
#                                                                  'required': ['ticker',
#                                                                               'count'],
#                                                                  'title': 'get_ticker_news_args',
#                                                                  'type': 'object'},
#                                              on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11961cd60>,
#                                              strict_json_schema=True,
#                                              is_enabled=True,
#                                              tool_input_guardrails=None,
#                                              tool_output_guardrails=None),
#                                 FunctionTool(name='search_news_by_ticker',
#                                              description='Search indexed news '
#                                                          'articles for a '
#                                                          'specific stock '
#                                                          'ticker.\n'
#                                                          '\n'
#                                                          'Searches across '
#                                                          'title, description, '
#                                                          'keywords, and '
#                                                          'tickers with '
#                                                          'boosting\n'
#                                                          'that prioritizes '
#                                                          'ticker matches.',
#                                              params_json_schema={'additionalProperties': False,
#                                                                  'properties': {'num_results': {'default': 30,
#                                                                                                 'description': 'Maximum '
#                                                                                                                'number '
#                                                                                                                'of '
#                                                                                                                'results '
#                                                                                                                'to '
#                                                                                                                'return '
#                                                                                                                '(default: '
#                                                                                                                '30)',
#                                                                                                 'title': 'Num '
#                                                                                                          'Results',
#                                                                                                 'type': 'integer'},
#                                                                                 'ticker': {'description': 'Stock '
#                                                                                                           'ticker '
#                                                                                                           'symbol '
#                                                                                                           '(e.g., '
#                                                                                                           "'TSLA', "
#                                                                                                           "'AAPL', "
#                                                                                                           "'GOOGL')",
#                                                                                            'title': 'Ticker',
#                                                                                            'type': 'string'}},
#                                                                  'required': ['ticker',
#                                                                               'num_results'],
#                                                                  'title': 'search_news_by_ticker_args',
#                                                                  'type': 'object'},
#                                              on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee4a40>,
#                                              strict_json_schema=True,
#                                              is_enabled=True,
#                                              tool_input_guardrails=None,
#                                              tool_output_guardrails=None),
#                                 FunctionTool(name='search_news_by_query',
#                                              description='Search indexed news '
#                                                          'articles by '
#                                                          'free-text query.\n'
#                                                          '\n'
#                                                          'Searches across '
#                                                          'title, description, '
#                                                          'keywords, and '
#                                                          'tickers with '
#                                                          'boosting\n'
#                                                          'that prioritizes '
#                                                          'description and '
#                                                          'keyword matches.',
#                                              params_json_schema={'additionalProperties': False,
#                                                                  'properties': {'num_results': {'default': 30,
#                                                                                                 'description': 'Maximum '
#                                                                                                                'number '
#                                                                                                                'of '
#                                                                                                                'results '
#                                                                                                                'to '
#                                                                                                                'return '
#                                                                                                                '(default: '
#                                                                                                                '30)',
#                                                                                                 'title': 'Num '
#                                                                                                          'Results',
#                                                                                                 'type': 'integer'},
#                                                                                 'query': {'description': 'Search '
#                                                                                                          'query '
#                                                                                                          '(e.g., '
#                                                                                                          "'Tesla "
#                                                                                                          'competitors '
#                                                                                                          'EV '
#                                                                                                          "market', "
#                                                                                                          "'AI "
#                                                                                                          "robotics')",
#                                                                                           'title': 'Query',
#                                                                                           'type': 'string'}},
#                                                                  'required': ['query',
#                                                                               'num_results'],
#                                                                  'title': 'search_news_by_query_args',
#                                                                  'type': 'object'},
#                                              on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee4400>,
#                                              strict_json_schema=True,
#                                              is_enabled=True,
#                                              tool_input_guardrails=None,
#                                              tool_output_guardrails=None),
#                                 FunctionTool(name='search_companies',
#                                              description='Search companies '
#                                                          'across all databases '
#                                                          'with comprehensive '
#                                                          'filtering.',
#                                              params_json_schema={'additionalProperties': False,
#                                                                  'properties': {'country': {'anyOf': [{'type': 'string'},
#                                                                                                       {'type': 'null'}],
#                                                                                             'description': 'Filter '
#                                                                                                            'by '
#                                                                                                            'country '
#                                                                                                            '(e.g., '
#                                                                                                            "'USA', "
#                                                                                                            "'China')",
#                                                                                             'title': 'Country'},
#                                                                                 'limit': {'default': 50,
#                                                                                           'description': 'Maximum '
#                                                                                                          'number '
#                                                                                                          'of '
#                                                                                                          'results '
#                                                                                                          '(default: '
#                                                                                                          '50)',
#                                                                                           'title': 'Limit',
#                                                                                           'type': 'integer'},
#                                                                                 'max_dividend': {'anyOf': [{'type': 'number'},
#                                                                                                            {'type': 'null'}],
#                                                                                                  'description': 'Maximum '
#                                                                                                                 'dividend '
#                                                                                                                 'yield '
#                                                                                                                 '(%)',
#                                                                                                  'title': 'Max '
#                                                                                                           'Dividend'},
#                                                                                 'max_margin': {'anyOf': [{'type': 'number'},
#                                                                                                          {'type': 'null'}],
#                                                                                                'description': 'Maximum '
#                                                                                                               'operating '
#                                                                                                               'margin '
#                                                                                                               '(%)',
#                                                                                                'title': 'Max '
#                                                                                                         'Margin'},
#                                                                                 'max_market_cap': {'anyOf': [{'type': 'number'},
#                                                                                                              {'type': 'null'}],
#                                                                                                    'description': 'Maximum '
#                                                                                                                   'market '
#                                                                                                                   'cap '
#                                                                                                                   'in '
#                                                                                                                   'USD',
#                                                                                                    'title': 'Max '
#                                                                                                             'Market '
#                                                                                                             'Cap'},
#                                                                                 'max_pe': {'anyOf': [{'type': 'number'},
#                                                                                                      {'type': 'null'}],
#                                                                                            'description': 'Maximum '
#                                                                                                           'P/E '
#                                                                                                           'ratio',
#                                                                                            'title': 'Max '
#                                                                                                     'Pe'},
#                                                                                 'min_dividend': {'anyOf': [{'type': 'number'},
#                                                                                                            {'type': 'null'}],
#                                                                                                  'description': 'Minimum '
#                                                                                                                 'dividend '
#                                                                                                                 'yield '
#                                                                                                                 '(%)',
#                                                                                                  'title': 'Min '
#                                                                                                           'Dividend'},
#                                                                                 'min_margin': {'anyOf': [{'type': 'number'},
#                                                                                                          {'type': 'null'}],
#                                                                                                'description': 'Minimum '
#                                                                                                               'operating '
#                                                                                                               'margin '
#                                                                                                               '(%)',
#                                                                                                'title': 'Min '
#                                                                                                         'Margin'},
#                                                                                 'min_market_cap': {'anyOf': [{'type': 'number'},
#                                                                                                              {'type': 'null'}],
#                                                                                                    'description': 'Minimum '
#                                                                                                                   'market '
#                                                                                                                   'cap '
#                                                                                                                   'in '
#                                                                                                                   'USD',
#                                                                                                    'title': 'Min '
#                                                                                                             'Market '
#                                                                                                             'Cap'},
#                                                                                 'min_pe': {'anyOf': [{'type': 'number'},
#                                                                                                      {'type': 'null'}],
#                                                                                            'description': 'Minimum '
#                                                                                                           'P/E '
#                                                                                                           'ratio',
# ...
#                                                                                                           'symbol',
#                                                                                            'title': 'Ticker'}},
#                                                                  'required': ['query',
#                                                                               'ticker',
#                                                                               'min_market_cap',
#                                                                               'max_market_cap',
#                                                                               'min_pe',
#                                                                               'max_pe',
#                                                                               'min_dividend',
#                                                                               'max_dividend',
#                                                                               'min_margin',
#                                                                               'max_margin',
#                                                                               'country',
#                                                                               'limit'],
#                                                                  'title': 'search_companies_args',
#                                                                  'type': 'object'},
#                                              on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee4720>,
#                                              strict_json_schema=True,
#                                              is_enabled=True,
#                                              tool_input_guardrails=None,
#                                              tool_output_guardrails=None),
#                                 FunctionTool(name='get_top_value_companies',
#                                              description='Find potential value '
#                                                          'companies based on '
#                                                          'fundamental '
#                                                          'criteria.\n'
#                                                          '\n'
#                                                          'Default criteria:\n'
#                                                          '- Dividend yield >= '
#                                                          '2%\n'
#                                                          '- P/E ratio <= 25\n'
#                                                          '- Operating margin '
#                                                          '>= 10%\n'
#                                                          '- Market cap >= $1B',
#                                              params_json_schema={'additionalProperties': False,
#                                                                  'properties': {'limit': {'default': 50,
#                                                                                           'description': 'Maximum '
#                                                                                                          'results',
#                                                                                           'title': 'Limit',
#                                                                                           'type': 'integer'},
#                                                                                 'max_pe': {'default': 25,
#                                                                                            'description': 'Maximum '
#                                                                                                           'P/E '
#                                                                                                           'ratio',
#                                                                                            'title': 'Max '
#                                                                                                     'Pe',
#                                                                                            'type': 'number'},
#                                                                                 'min_dividend': {'default': 0.02,
#                                                                                                  'description': 'Minimum '
#                                                                                                                 'dividend '
#                                                                                                                 'yield '
#                                                                                                                 '%',
#                                                                                                  'title': 'Min '
#                                                                                                           'Dividend',
#                                                                                                  'type': 'number'},
#                                                                                 'min_margin': {'default': 0.1,
#                                                                                                'description': 'Minimum '
#                                                                                                               'operating '
#                                                                                                               'margin '
#                                                                                                               '%',
#                                                                                                'title': 'Min '
#                                                                                                         'Margin',
#                                                                                                'type': 'number'},
#                                                                                 'min_market_cap': {'default': 1000000000,
#                                                                                                    'description': 'Minimum '
#                                                                                                                   'market '
#                                                                                                                   'cap',
#                                                                                                    'title': 'Min '
#                                                                                                             'Market '
#                                                                                                             'Cap',
#                                                                                                    'type': 'number'}},
#                                                                  'required': ['min_dividend',
#                                                                               'max_pe',
#                                                                               'min_margin',
#                                                                               'min_market_cap',
#                                                                               'limit'],
#                                                                  'title': 'get_top_value_companies_args',
#                                                                  'type': 'object'},
#                                              on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee5120>,
#                                              strict_json_schema=True,
#                                              is_enabled=True,
#                                              tool_input_guardrails=None,
#                                              tool_output_guardrails=None),
#                                 FunctionTool(name='get_top_growth_companies',
#                                              description='Find potential '
#                                                          'growth companies '
#                                                          'based on fundamental '
#                                                          'criteria.\n'
#                                                          '\n'
#                                                          'Default criteria:\n'
#                                                          '- Operating margin '
#                                                          '>= 20% (high '
#                                                          'profitability)\n'
#                                                          '- Market cap >= $1B',
#                                              params_json_schema={'additionalProperties': False,
#                                                                  'properties': {'limit': {'default': 50,
#                                                                                           'description': 'Maximum '
#                                                                                                          'results',
#                                                                                           'title': 'Limit',
#                                                                                           'type': 'integer'},
#                                                                                 'max_pe': {'anyOf': [{'type': 'number'},
#                                                                                                      {'type': 'null'}],
#                                                                                            'description': 'Maximum '
#                                                                                                           'P/E '
#                                                                                                           'ratio '
#                                                                                                           '(optional)',
#                                                                                            'title': 'Max '
#                                                                                                     'Pe'},
#                                                                                 'min_margin': {'default': 0.2,
#                                                                                                'description': 'Minimum '
#                                                                                                               'operating '
#                                                                                                               'margin '
#                                                                                                               '%',
#                                                                                                'title': 'Min '
#                                                                                                         'Margin',
#                                                                                                'type': 'number'},
#                                                                                 'min_market_cap': {'default': 1000000000,
#                                                                                                    'description': 'Minimum '
#                                                                                                                   'market '
#                                                                                                                   'cap',
#                                                                                                    'title': 'Min '
#                                                                                                             'Market '
#                                                                                                             'Cap',
#                                                                                                    'type': 'number'}},
#                                                                  'required': ['min_margin',
#                                                                               'max_pe',
#                                                                               'min_market_cap',
#                                                                               'limit'],
#                                                                  'title': 'get_top_growth_companies_args',
#                                                                  'type': 'object'},
#                                              on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee5300>,
#                                              strict_json_schema=True,
#                                              is_enabled=True,
#                                              tool_input_guardrails=None,
#                                              tool_output_guardrails=None)],
#                          mcp_servers=[],
#                          mcp_config={},
#                          instructions="you're a helful assistant. Try to use "
#                                       'all defined tools before going into the '
#                                       'WebSearchTool',
#                          prompt=None,
#                          handoffs=[],
#                          model='gpt-5.4-mini',
#                          model_settings=ModelSettings(temperature=None,
#                                                       top_p=None,
#                                                       frequency_penalty=None,
#                                                       presence_penalty=None,
#                                                       tool_choice=None,
#                                                       parallel_tool_calls=None,
#                                                       truncation=None,
#                                                       max_tokens=None,
#                                                       reasoning=None,
#                                                       verbosity=None,
#                                                       metadata=None,
#                                                       store=None,
#                                                       prompt_cache_retention=None,
#                                                       include_usage=None,
#                                                       response_include=None,
#                                                       top_logprobs=None,
#                                                       extra_query=None,
#                                                       extra_body=None,
#                                                       extra_headers=None,
#                                                       extra_args=None),
#                          input_guardrails=[],
#                          output_guardrails=[],
#                          output_type=None,
#                          hooks=None,
#                          tool_use_behavior='run_llm_again',
#                          reset_tool_choice=True),
#              raw_item=ResponseFunctionToolCall(arguments='{"ticker":"TSLA"}', call_id='call_qZD7Zq53tiwkLuEkdQGsmTYb', name='get_eps_trend', type='function_call', id='fc_09ff9f55f9006dc9006a2dbaf112a881928679c50a34134d98', status='completed'),
#              type='tool_call_item')

# %%
# DEBUG: print everything for inspection (5k lines)
# from pprint import pprint
# pprint(vars(results))

# %%
# Write a wrapper functions to extract tool calls, outputs, and final message
                                                                                                                                                                
def get_tool_calls(results):                                                                                                                                       
    """Extract just the tool calls"""                                                                                                                              
    calls = []                                                                                                                                                     
    for response in results.raw_responses:                                                                                                                         
        for output in response.output:                                                                                                                             
            if hasattr(output, 'name') and hasattr(output, 'arguments'):                                                                                           
                calls.append({                                                                                                                                     
                    'name': output.name,                                                                                                                           
                    'arguments': output.arguments                                                                                                                  
                })                                                                                                                                                 
    return calls                                                                                                                                                   
                                                                                                                                                                    
def get_tool_outputs(results):                                                                                                                                     
    """Extract tool outputs with their names"""                                                                                                                    
    # Get tool calls from raw_responses                                                                                                                            
    calls = []                                                                                                                                                     
    for response in results.raw_responses:                                                                                                                         
        for output in response.output:                                                                                                                             
            if hasattr(output, 'name'):                                                                                                                            
                calls.append(output.name)                                                                                                                          
                                                                                                                                                                    
    # Get outputs from new_items                                                                                                                                   
    outputs = []                                                                                                                                                   
    for item in results.new_items:                                                                                                                                 
        if item.type == 'tool_call_output_item':                                                                                                                   
            outputs.append(item.output)                                                                                                                            
                                                                                                                                                                    
    return list(zip(calls, outputs))                                                                                                                               
                                                                                                                                                                    
def get_final_message(results):                                                                                                                                    
    """Get the final text response"""                                                                                                                              
    # Method 1: Use final_output                                                                                                                                   
    if results.final_output:                                                                                                                                       
        return results.final_output                                                                                                                                
                                                                                                                                                                    
    # Method 2: Extract from raw_responses                                                                                                                         
    for response in results.raw_responses:                                                                                                                         
        for output in response.output:                                                                                                                             
            if hasattr(output, 'content'):                                                                                                                         
                for content in output.content:                                                                                                                     
                    if hasattr(content, 'text'):                                                                                                                   
                        return content.text

# %%
# Usage:                                                                                                                                                           
calls = get_tool_calls(results)                                                                                                                                    
tool_outputs = get_tool_outputs(results)                                                                                                                           
final_msg = get_final_message(results)                                                                                                                             
                                                                                                                                                                    
print("=" * 70)                                                                                                                                                    
print("TOOL CALLS")                                                                                                                                                
print("=" * 70)                                                                                                                                                    
for i, call in enumerate(calls, 1):                                                                                                                                
    print(f"\n{i}. {call['name']}({call['arguments']})")                                                                                                           
                                                                                                                                                                    
print("\n" + "=" * 70)                                                                                                                                             
print("TOOL OUTPUTS")                                                                                                                                              
print("=" * 70)                                                                                                                                                    
for i, (name, output) in enumerate(tool_outputs, 1):                                                                                                               
    print(f"\n{i}. {name}")                                                                                                                                        
    print(f"   Output keys: {list(output.keys()) if isinstance(output, dict) else type(output)}")                                                                  
    if isinstance(output, dict) and 'ticker' in output:                                                                                                            
        print(f"   Ticker: {output['ticker']}")                                                                                                                    
        if 'data' in output:                                                                                                                                       
            data = output['data']                                                                                                                                  
            if isinstance(data, list):                                                                                                                             
                print(f"   Data items: {len(data)}")                                                                                                               
                                                                                                                                                                    
print("\n" + "=" * 70)                                                                                                                                             
print("FINAL MESSAGE")                                                                                                                                             
print("=" * 70)                                                                                                                                                    
print(f"\nLength: {len(final_msg) if final_msg else 0} characters")                                                                                                
if final_msg:                                                                                                                                                      
    # Print first 500 chars                                                                                                                                        
    print(f"\nPreview:\n{final_msg[:500]}...")
# Out:
# ======================================================================
# TOOL CALLS
# ======================================================================
#
# 1. get_eps_trend({"ticker":"TSLA"})
#
# 2. get_earnings_dates({"ticker":"TSLA"})
#
# 3. get_ticker_news({"ticker":"TSLA","count":8})
#
# 4. get_earnings_analysis({"ticker":"TSLA"})
#
# ======================================================================
# TOOL OUTPUTS
# ======================================================================
#
# 1. get_eps_trend
#    Output keys: ['ticker', 'data']
#    Ticker: TSLA
#    Data items: 4
#
# 2. get_earnings_dates
#    Output keys: ['ticker', 'data']
#    Ticker: TSLA
#    Data items: 25
#
# 3. get_ticker_news
#    Output keys: ['ticker', 'count', 'data']
#    Ticker: TSLA
#    Data items: 8
#
# 4. get_earnings_analysis
#    Output keys: ['ticker', 'earnings_estimates', 'eps_revisions', 'growth_estimates', 'earnings_history']
#    Ticker: TSLA
#
# ======================================================================
# FINAL MESSAGE
# ======================================================================
#
# Length: 1813 characters
#
# Preview:
# Here’s a quick TSLA earnings snapshot as of **June 13, 2026**:
#
# ### EPS trend
# **Analyst EPS estimates for TSLA have been mostly stable to slightly lower at the outer years, with a small bump in the current quarter.**
# - **Current quarter (0q):** 0.454 vs 0.454 a week ago, 0.454 a month ago, 0.446 two months ago, 0.462 three months ago
# - **Next quarter (+1q):** 0.538 vs 0.539 a week ago
# - **Current year (0y):** 2.059 vs 2.050 a week ago, 2.048 a month ago
# - **Next year (+1y):** 2.500 vs 2....

# %%
# Clean extraction                                                                                                                                                 
print("📋 TOOLS CALLED:")                                                                                                                                          
for resp in results.raw_responses:                                                                                                                                 
    for out in resp.output:                                                                                                                                        
        if hasattr(out, 'name'):                                                                                                                                   
            print(f"  • {out.name}({out.arguments})")                                                                                                              
                                                                                                                                                                    
print(f"\n📊 OUTPUTS: {len(results.new_items)} items")                                                                                                             
for item in results.new_items:                                                                                                                                     
    if item.type == 'tool_call_output_item':                                                                                                                       
        ticker = item.output.get('ticker', 'N/A')                                                                                                                  
        print(f"  • Ticker: {ticker}, Keys: {list(item.output.keys())}")                                                                                           
                                                                                                                                                                    
print(f"\n💬 FINAL OUTPUT: {len(results.final_output)} chars")                                                                                                     
print(results.final_output[:300] + "..." if len(results.final_output) > 300 else results.final_output)
# Out:
# 📋 TOOLS CALLED:
#   • get_eps_trend({"ticker":"TSLA"})
#   • get_earnings_dates({"ticker":"TSLA"})
#   • get_ticker_news({"ticker":"TSLA","count":8})
#   • get_earnings_analysis({"ticker":"TSLA"})
#
# 📊 OUTPUTS: 9 items
#   • Ticker: TSLA, Keys: ['ticker', 'data']
#   • Ticker: TSLA, Keys: ['ticker', 'data']
#   • Ticker: TSLA, Keys: ['ticker', 'count', 'data']
#   • Ticker: TSLA, Keys: ['ticker', 'earnings_estimates', 'eps_revisions', 'growth_estimates', 'earnings_history']
#
# 💬 FINAL OUTPUT: 1813 chars
# Here’s a quick TSLA earnings snapshot as of **June 13, 2026**:
#
# ### EPS trend
# **Analyst EPS estimates for TSLA have been mostly stable to slightly lower at the outer years, with a small bump in the current quarter.**
# - **Current quarter (0q):** 0.454 vs 0.454 a week ago, 0.454 a month ago, 0.446 t...

# %%
def get_usage_info_gpt_5_4_mini(result: RunResult):
    """Extract usage info from RunResult."""

    # https://developers.openai.com/api/docs/pricing
    # for 5.4-mini: $0.75 per 1M input tokens, $4.50 per 1M output tokens
    # for 5.4: $2.5 per 1M input tokens, $15 per 1M output tokens
    # for 5.5: $5 per 1M input tokens, $30 per 1M output tokens

    INPUT_PRICE = 0.75 / 1_000_000
    OUTPUT_PRICE = 4.50 / 1_000_000

    if hasattr(result, 'context_wrapper') and hasattr(result.context_wrapper, 'usage'):
        usage = result.context_wrapper.usage
        return {
            "requests": usage.requests,
            "input_tokens": usage.input_tokens,
            "output_tokens": usage.output_tokens,
            "total_tokens": usage.total_tokens,
            "request_usage_entries": [
                {
                    "input_tokens": entry.input_tokens,
                    "output_tokens": entry.output_tokens,
                    "total_tokens": entry.total_tokens 
                }
                for entry in usage.request_usage_entries
            ],
            "cost_usd": (
                usage.input_tokens * INPUT_PRICE +
                usage.output_tokens * OUTPUT_PRICE
            )
        }
    else:
        return {"error": "Usage information not available in the provided RunResult."}

# %%
pprint(get_usage_info_gpt_5_4_mini(results))
# Out:
# {'cost_usd': 0.0148965,
#  'input_tokens': 16028,
#  'output_tokens': 639,
#  'request_usage_entries': [{'input_tokens': 6209,
#                             'output_tokens': 94,
#                             'total_tokens': 6303},
#                            {'input_tokens': 9819,
#                             'output_tokens': 545,
#                             'total_tokens': 10364}],
#  'requests': 2,
#  'total_tokens': 16667}

# %% [markdown]
# ## 2.2) Agent with a Memory (passing context - RunResult)

# %%
# let's build a wrapper for calls AND PASS THE CONTEXT FOR NEXT QUESTIONS
                                                                                                                                                                
from typing import Optional                                                                                                                                        
from agents import Runner                                                                                                                                          
from agents.result import RunResult                                                                                                                                
from IPython.display import display, Markdown, HTML                                                                                                                
                                                                                                                                                                    
runner = Runner()                                                                                                                                                  
                                                                                                                                                                    
async def ask(agent, question: str, context: Optional[RunResult] = None) -> RunResult:                                                                             
    """Async ask with rich notebook output."""                                                                                                                     
                                                                                                                                                                    
    # Question header                                                                                                                                              
    display(HTML(f"<h3>❓ {question}</h3>"))                                                                                                                       
                                                                                                                                                                    
    # Run agent                                                                                                                                                    
    if context:                                                                                                                                                    
        results = await runner.run(agent, input=question, context=context.new_items)                                                                               
    else:                                                                                                                                                          
        results = await runner.run(agent, input=question)                                                                                                          
                                                                                                                                                                    
    # Show tools                                                                                                                                                   
    tools_html = "<div style='padding: 10px; border-radius: 5px;'>"                                                                     
    tools_html += "<b>🔧 Tools Called:</b><br>"                                                                                                                    
    tool_count = 0                                                                                                                                                 
    for resp in results.raw_responses:                                                                                                                             
        for out in resp.output:                                                                                                                                    
            if hasattr(out, 'name'):                                                                                                                               
                tool_count += 1                                                                                                                                    
                tools_html += f"&nbsp;&nbsp;{tool_count}. <code>{out.name}({out.arguments})</code><br>"                                                            
                                                                                                                                                                    
    if tool_count == 0:                                                                                                                                            
        tools_html += "&nbsp;&nbsp;<i>(No tools called)</i><br>"                                                                                                   
    tools_html += "</div>"                                                                                                                                         
                                                                                                                                                                    
    display(HTML(tools_html))                                                                                                                                      
                                                                                                                                                                    
    # Show response as markdown                                                                                                                                    
    display(Markdown("### 💬 Response:"))                                                                                                                          
    display(Markdown(results.final_output))                                                                                                                        
                                                                                                                                                                    
    return results

# %%
# Usage:
r1 = await ask(stock_agent, "What's TSLA's EPS trend and surprise historical?")
# Out:
# <h3>❓ What's TSLA's EPS trend and surprise historical?</h3>
# <div style='padding: 10px; border-radius: 5px;'><b>🔧 Tools Called:</b><br>&nbsp;&nbsp;1. <code>get_eps_trend({"ticker":"TSLA"})</code><br>&nbsp;&nbsp;2. <code>get_earnings_dates({"ticker":"TSLA"})</code><br></div>
# ### 💬 Response:
# Here’s TSLA’s EPS trend and earnings surprise history.
#
# **EPS trend**
# - **Current quarter (0q):** 0.45414
#   - 7 days ago: 0.45396
#   - 30 days ago: 0.45396
#   - 60 days ago: 0.44637
#   - 90 days ago: 0.46212
# - **Next quarter (+1q):** 0.5375
#   - 7 days ago: 0.5393
#   - 30 days ago: 0.5393
#   - 60 days ago: 0.53175
#   - 90 days ago: 0.5405
# - **Current year (0y):** 2.05937
#   - 7 days ago: 2.04967
#   - 30 days ago: 2.04835
#   - 60 days ago: 2.03873
#   - 90 days ago: 2.08858
# - **Next year (+1y):** 2.49995
#   - 7 days ago: 2.50462
#   - 30 days ago: 2.50969
#   - 60 days ago: 2.77175
#   - 90 days ago: 2.81043
#
# **Earnings surprise history**
# Most recent reported quarters:
# - **2026-04-22:** estimate 0.20, reported 0.13, surprise **-36.54%**
# - **2026-01-28:** estimate 0.45, reported 0.50, surprise **+10.96%**
# - **2025-10-22:** estimate 0.56, reported 0.50, surprise **-10.53%**
# - **2025-07-23:** estimate 0.30, reported 0.33, surprise **+10.49%**
# - **2025-04-22:** estimate 0.41, reported 0.27, surprise **-34.89%**
# - **2025-01-29:** estimate 0.77, reported 0.73, surprise **-4.83%**
#
# **Quick take**
# - TSLA’s **short-term EPS estimates are fairly stable** for the current quarter, slightly lower for the next quarter versus 90 days ago.
# - The **next-year estimate has come down a lot** from 60–90 days ago.
# - Earnings surprises have been **volatile**, with both sizable beats and misses.
#
# If you want, I can also turn this into a simple table or add analyst revisions and growth estimates.

# %%
# $0.013 per call
pprint(get_usage_info_gpt_5_4_mini(r1))
# Out:
# {'cost_usd': 0.01312575,
#  'input_tokens': 13793,
#  'output_tokens': 618,
#  'request_usage_entries': [{'input_tokens': 6203,
#                             'output_tokens': 55,
#                             'total_tokens': 6258},
#                            {'input_tokens': 7590,
#                             'output_tokens': 563,
#                             'total_tokens': 8153}],
#  'requests': 2,
#  'total_tokens': 14411}

# %%
r2 = await ask(stock_agent, "Find similar stocks to TSLA on vertical, market cap and P/E ratio", context=r1)
# Out:
# <h3>❓ Find similar stocks to TSLA on vertical, market cap and P/E ratio</h3>
# <div style='padding: 10px; border-radius: 5px;'><b>🔧 Tools Called:</b><br>&nbsp;&nbsp;1. <code>search_companies({"query":null,"ticker":null,"min_market_cap":null,"max_market_cap":null,"min_pe":null,"max_pe":null,"min_dividend":null,"max_dividend":null,"min_margin":null,"max_margin":null,"country":"USA","limit":100})</code><br>&nbsp;&nbsp;2. <code>get_company_info({"ticker":"TSLA"})</code><br>&nbsp;&nbsp;3. <code>search_companies({"query":null,"ticker":null,"min_market_cap":100000000000,"max_market_cap":3000000000000,"min_pe":50,"max_pe":500,"min_dividend":null,"max_dividend":null,"min_margin":null,"max_margin":null,"country":"USA","limit":20})</code><br>&nbsp;&nbsp;4. <code>search_companies({"query":null,"ticker":null,"min_market_cap":50000000000,"max_market_cap":3000000000000,"min_pe":20,"max_pe":500,"min_dividend":null,"max_dividend":null,"min_margin":null,"max_margin":null,"country":"USA","limit":20})</code><br></div>
# ### 💬 Response:
# Tesla is a bit unusual, so there aren’t many close matches that line up on all three of **vertical, market cap, and P/E**.
#
# ### Tesla profile
# - **Vertical/industry:** Auto Manufacturers
# - **Sector:** Consumer Cyclical
# - **Market cap:** about **$1.53T**
# - **Trailing P/E:** about **369**
# - **Forward P/E:** about **163**
#
# ### Closest “similar” public stocks by business model / market profile
# These are the names I’d look at first:
#
# 1. **Rivian (RIVN)**
#    - EV automaker, closest pure-play comparison on vertical
#    - Much smaller market cap and typically negative earnings, so P/E is often not meaningful
#
# 2. **Lucid Group (LCID)**
#    - EV automaker, similar vertical
#    - Also much smaller, often no meaningful P/E
#
# 3. **Ferrari (RACE)**
#    - Auto manufacturer with premium branding and high margins
#    - More mature, but it’s one of the few auto names with a premium valuation
#
# 4. **BYD (BYDDY / 1211.HK)**
#    - Major EV and battery manufacturer
#    - Scale and business mix are closer to Tesla than most automakers, though market cap and listing differ
#
# 5. **NIO (NIO)**
#    - EV manufacturer
#    - Similar EV theme, but valuation and profitability profile differ a lot
#
# ### If you want the closest match on **market cap + P/E**
# Tesla’s valuation is so far above most auto companies that a truly close public comp is hard to find. For a **similar market-cap / high-multiple growth stock** rather than a similar automaker, companies like **NVDA, MSFT, AMZN, GOOGL** are closer on size/valuation style, but not on vertical.
#
# ### Practical takeaway
# If your goal is:
# - **Vertical match:** RIVN, LCID, NIO, BYD
# - **Premium auto valuation / profitability:** RACE, BYD
# - **Similar “mega-cap growth + high multiple” profile:** NVDA, AMZN, MSFT, GOOGL
#
# If you want, I can build you a **ranked comparison table** with:
# - vertical similarity
# - market cap
# - trailing/forward P/E
# - margins
# - revenue growth
#
# and make it more precise.

# %%
# $0.031 per call -- longer context
pprint(get_usage_info_gpt_5_4_mini(r2))
# Out:
# {'cost_usd': 0.0313965,
#  'input_tokens': 37278,
#  'output_tokens': 764,
#  'request_usage_entries': [{'input_tokens': 6208,
#                             'output_tokens': 75,
#                             'total_tokens': 6283},
#                            {'input_tokens': 6311,
#                             'output_tokens': 20,
#                             'total_tokens': 6331},
#                            {'input_tokens': 8143,
#                             'output_tokens': 82,
#                             'total_tokens': 8225},
#                            {'input_tokens': 8253,
#                             'output_tokens': 82,
#                             'total_tokens': 8335},
#                            {'input_tokens': 8363,
#                             'output_tokens': 505,
#                             'total_tokens': 8868}],
#  'requests': 5,
#  'total_tokens': 38042}

# %%
r3 = await ask(stock_agent, "What's Google's EPS trend vs. big 7 companies?")
# Out:
# <h3>❓ What's Google's EPS trend vs. big 7 companies?</h3>
# <div style='padding: 10px; border-radius: 5px;'><b>🔧 Tools Called:</b><br>&nbsp;&nbsp;1. <code>get_eps_trend({"ticker":"GOOGL"})</code><br>&nbsp;&nbsp;2. <code>get_company_info({"ticker":"GOOGL"})</code><br>&nbsp;&nbsp;3. <code>search_companies({"query":null,"ticker":"AAPL","min_market_cap":null,"max_market_cap":null,"min_pe":null,"max_pe":null,"min_dividend":null,"max_dividend":null,"min_margin":null,"max_margin":null,"country":null,"limit":1})</code><br>&nbsp;&nbsp;4. <code>search_companies({"query":null,"ticker":"MSFT","min_market_cap":null,"max_market_cap":null,"min_pe":null,"max_pe":null,"min_dividend":null,"max_dividend":null,"min_margin":null,"max_margin":null,"country":null,"limit":1})</code><br>&nbsp;&nbsp;5. <code>search_companies({"query":null,"ticker":"AMZN","min_market_cap":null,"max_market_cap":null,"min_pe":null,"max_pe":null,"min_dividend":null,"max_dividend":null,"min_margin":null,"max_margin":null,"country":null,"limit":1})</code><br>&nbsp;&nbsp;6. <code>search_companies({"query":null,"ticker":"META","min_market_cap":null,"max_market_cap":null,"min_pe":null,"max_pe":null,"min_dividend":null,"max_dividend":null,"min_margin":null,"max_margin":null,"country":null,"limit":1})</code><br>&nbsp;&nbsp;7. <code>search_companies({"query":null,"ticker":"NVDA","min_market_cap":null,"max_market_cap":null,"min_pe":null,"max_pe":null,"min_dividend":null,"max_dividend":null,"min_margin":null,"max_margin":null,"country":null,"limit":1})</code><br>&nbsp;&nbsp;8. <code>search_companies({"query":null,"ticker":"TSLA","min_market_cap":null,"max_market_cap":null,"min_pe":null,"max_pe":null,"min_dividend":null,"max_dividend":null,"min_margin":null,"max_margin":null,"country":null,"limit":1})</code><br>&nbsp;&nbsp;9. <code>search_companies({"query":null,"ticker":"AVGO","min_market_cap":null,"max_market_cap":null,"min_pe":null,"max_pe":null,"min_dividend":null,"max_dividend":null,"min_margin":null,"max_margin":null,"country":null,"limit":1})</code><br></div>
# ### 💬 Response:
# Here’s **Google/Alphabet (GOOGL)** EPS trend versus the other “Big 7” names I checked.
#
# ### Alphabet EPS trend
# - **Current quarter (0q):** 2.87
# - **Next quarter (+1q):** 3.00
# - **Current year (0y):** 14.22
# - **Next year (+1y):** 14.46
#
# Recent trend for Alphabet:
# - Estimates are **basically flat to slightly up** over the last 90 days for near-term quarters.
# - The bigger move is in the **full-year estimate**, which jumped from about **11.46–11.46** (60–90 days ago) to **14.22** now, suggesting a meaningful upward revision in annual EPS expectations.
#
# ### Big 7 snapshot
# Using the available company data, here’s a quick comparison of valuation/scale context:
#
# - **NVDA:** market cap $4.97T, P/E 41.6
# - **AAPL:** market cap $4.28T, P/E 35.0
# - **GOOGL:** market cap $4.39T, P/E 27.5
# - **MSFT:** market cap $2.90T, P/E 23.0
# - **AMZN:** market cap $2.57T, P/E 27.9
# - **META:** market cap $1.44T, P/E 20.3
# - **AVGO:** market cap $1.82T, P/E 72.2
# - **TSLA:** market cap $1.53T, P/E 335.6
#
# ### Takeaway
# Alphabet’s EPS trend looks **solid and improving**, especially on the annual estimate side, but its **near-term quarterly revisions are very stable**. On valuation, GOOGL sits **below AAPL/NVDA/AVGO/TSLA on P/E**, and **above MSFT/META**.
#
# If you want, I can turn this into a **side-by-side EPS trend table for all 7 companies**.

# %%
pprint(get_usage_info_gpt_5_4_mini(r3))
# Out:
# {'cost_usd': 0.0163395,
#  'input_tokens': 15798,
#  'output_tokens': 998,
#  'request_usage_entries': [{'input_tokens': 6204,
#                             'output_tokens': 558,
#                             'total_tokens': 6762},
#                            {'input_tokens': 9594,
#                             'output_tokens': 440,
#                             'total_tokens': 10034}],
#  'requests': 2,
#  'total_tokens': 16796}

# %%
r4 = await ask(stock_agent, "Compare BIG 7 companies on valuations, analysts sentiment, investors demand, and growth prospects", context=r3)
# Out:
# <h3>❓ Compare BIG 7 companies on valuations, analysts sentiment, investors demand, and growth prospects</h3>
# <div style='padding: 10px; border-radius: 5px;'><b>🔧 Tools Called:</b><br>&nbsp;&nbsp;1. <code>search_companies({"query":null,"ticker":"AAPL","min_market_cap":null,"max_market_cap":null,"min_pe":null,"max_pe":null,"min_dividend":null,"max_dividend":null,"min_margin":null,"max_margin":null,"country":null,"limit":1})</code><br>&nbsp;&nbsp;2. <code>search_companies({"query":null,"ticker":"MSFT","min_market_cap":null,"max_market_cap":null,"min_pe":null,"max_pe":null,"min_dividend":null,"max_dividend":null,"min_margin":null,"max_margin":null,"country":null,"limit":1})</code><br>&nbsp;&nbsp;3. <code>search_companies({"query":null,"ticker":"AMZN","min_market_cap":null,"max_market_cap":null,"min_pe":null,"max_pe":null,"min_dividend":null,"max_dividend":null,"min_margin":null,"max_margin":null,"country":null,"limit":1})</code><br>&nbsp;&nbsp;4. <code>search_companies({"query":null,"ticker":"GOOGL","min_market_cap":null,"max_market_cap":null,"min_pe":null,"max_pe":null,"min_dividend":null,"max_dividend":null,"min_margin":null,"max_margin":null,"country":null,"limit":1})</code><br>&nbsp;&nbsp;5. <code>search_companies({"query":null,"ticker":"META","min_market_cap":null,"max_market_cap":null,"min_pe":null,"max_pe":null,"min_dividend":null,"max_dividend":null,"min_margin":null,"max_margin":null,"country":null,"limit":1})</code><br>&nbsp;&nbsp;6. <code>search_companies({"query":null,"ticker":"NVDA","min_market_cap":null,"max_market_cap":null,"min_pe":null,"max_pe":null,"min_dividend":null,"max_dividend":null,"min_margin":null,"max_margin":null,"country":null,"limit":1})</code><br>&nbsp;&nbsp;7. <code>search_companies({"query":null,"ticker":"TSLA","min_market_cap":null,"max_market_cap":null,"min_pe":null,"max_pe":null,"min_dividend":null,"max_dividend":null,"min_margin":null,"max_margin":null,"country":null,"limit":1})</code><br>&nbsp;&nbsp;8. <code>get_earnings_analysis({"ticker":"AAPL"})</code><br>&nbsp;&nbsp;9. <code>get_earnings_analysis({"ticker":"MSFT"})</code><br>&nbsp;&nbsp;10. <code>get_earnings_analysis({"ticker":"AMZN"})</code><br>&nbsp;&nbsp;11. <code>get_earnings_analysis({"ticker":"META"})</code><br>&nbsp;&nbsp;12. <code>get_earnings_analysis({"ticker":"NVDA"})</code><br>&nbsp;&nbsp;13. <code>get_earnings_analysis({"ticker":"TSLA"})</code><br>&nbsp;&nbsp;14. <code>get_earnings_analysis({"ticker":"GOOGL"})</code><br></div>
# ### 💬 Response:
# Here’s a compact comparison of the **“Big 7”**: **AAPL, MSFT, AMZN, GOOGL, META, NVDA, TSLA** based on the data I pulled.
#
# ## Quick take
# - **Cheapest on earnings:** **MSFT** and **META**
# - **Most expensive:** **TSLA** by far, then **NVDA** and **AAPL**
# - **Strongest growth momentum:** **NVDA**, then **GOOGL** and **META**
# - **Best analyst sentiment / revisions:** **NVDA** clearly stands out
# - **Best investor demand by size/scale:** **NVDA** and **AAPL** have the largest market caps, with **MSFT** close behind
#
# ## Side-by-side snapshot
#
# | Company | Market Cap | P/E (TTM) | Dividend Yield | Operating Margin | Analyst Growth Outlook | Analyst Revisions |
# |---|---:|---:|---:|---:|---:|---|
# | **NVDA** | $4.97T | 41.6x | 0.02% | 65.6% | Very strong | Very bullish |
# | **AAPL** | $4.28T | 35.0x | 0.36% | 31.9% | Solid | Positive |
# | **MSFT** | $2.90T | 23.0x | 0.68% | 48.5% | Strong | Mixed near-term |
# | **AMZN** | $2.57T | 27.9x | 0.0% | 13.6% | Good, but next quarter soft | Positive overall |
# | **GOOGL** | n/a from search result | n/a | n/a | n/a | Strong | Slightly mixed |
# | **META** | $1.44T | 20.3x | 0.37% | 42.2% | Strong | Mixed near-term |
# | **TSLA** | $1.53T | 335.6x | 0.0% | 5.9% | Moderate | Weak / cautious |
#
# ## Valuations
# - **Most reasonable valuation:** **META** and **MSFT**
#   - META at about **20.3x earnings**
#   - MSFT at about **23.0x**
# - **Middle of the pack:** **AMZN**
#   - **27.9x**, with lower current margin profitability
# - **Rich valuations:** **AAPL** and **NVDA**
#   - AAPL: **35.0x**
#   - NVDA: **41.6x**
# - **Extreme valuation:** **TSLA**
#   - **335.6x**, which implies a lot of future growth is already priced in
#
# ## Analyst sentiment
# Using EPS estimates and recent revision patterns:
#
# - **NVDA:** strongest by far
#   - Huge upward revisions across 7 and 30 days
#   - Forecast growth far above the market
# - **MSFT:** still positive, but near-term revisions were more mixed
# - **AAPL:** solid, with broad estimate upgrades over the last 30 days
# - **AMZN:** positive for the year, but next-quarter expectations are softer
# - **GOOGL:** constructive but not as strong as NVDA / META
# - **META:** long-term earnings growth remains strong, but near-term revisions were uneven
# - **TSLA:** analyst revisions are weak and sentiment is cautious
#
# ## Investor demand
# If by “investor demand” you mean **scale, institutional attention, and market appetite**:
# - **NVDA** and **AAPL** are the most heavily demanded by sheer scale
# - **MSFT** is also in elite demand territory
# - **TSLA** attracts strong attention, but that’s more speculative than fundamental
# - **META** and **AMZN** look well-supported by institutions, though smaller than the mega-cap leaders
#
# ## Growth prospects
# Best-looking growth profiles from the data:
#
# 1. **NVDA**
#    - EPS growth: roughly **+88%** this year, **+42%** next year
#    - Best-in-class momentum
# 2. **GOOGL**
#    - Strong current-year growth, though next year is much more muted
# 3. **META**
#    - Very strong earnings base and good profitability
# 4. **MSFT**
#    - Steady, high-quality growth with strong margins
# 5. **AMZN**
#    - Good year-ahead growth, but near-term EPS growth is softer
# 6. **AAPL**
#    - Solid but more moderate growth
# 7. **TSLA**
#    - Growth exists, but profitability is much weaker and valuation is very demanding
#
# ## Bottom line
# - **Best overall blend of valuation + quality:** **MSFT** and **META**
# - **Best growth stock:** **NVDA**
# - **Best “blue-chip giant” with strong fundamentals:** **MSFT**
# - **Most expensive / highest risk-reward:** **TSLA**
# - **Most balanced mega-cap:** **AAPL**, though not cheap
#
# If you want, I can turn this into a **ranked scorecard** with weights like:
# **valuation 40% / analyst sentiment 25% / investor demand 15% / growth 20%**.

# %%
# $0.028 per call -- longer context
pprint(get_usage_info_gpt_5_4_mini(r4))
# Out:
# {'cost_usd': 0.028179750000000003,
#  'input_tokens': 26899,
#  'output_tokens': 1779,
#  'request_usage_entries': [{'input_tokens': 6210,
#                             'output_tokens': 524,
#                             'total_tokens': 6734},
#                            {'input_tokens': 7397,
#                             'output_tokens': 146,
#                             'total_tokens': 7543},
#                            {'input_tokens': 13292,
#                             'output_tokens': 1109,
#                             'total_tokens': 14401}],
#  'requests': 3,
#  'total_tokens': 28678}

# %%
r5 = await ask(stock_agent, "Get most volatile stock from the previous context in the last 7 days with the largest price swings and news sentiment", context=r4)
# Out:
# <h3>❓ Get most volatile stock from the previous context in the last 7 days with the largest price swings and news sentiment</h3>
# <div style='padding: 10px; border-radius: 5px;'><b>🔧 Tools Called:</b><br>&nbsp;&nbsp;1. <code>search_companies({"query":null,"ticker":null,"min_market_cap":null,"max_market_cap":null,"min_pe":null,"max_pe":null,"min_dividend":null,"max_dividend":null,"min_margin":null,"max_margin":null,"country":"USA","limit":50})</code><br>&nbsp;&nbsp;2. <code>search_news_by_query({"query":"market volatility stock biggest price swings news sentiment last 7 days USA","num_results":20})</code><br>&nbsp;&nbsp;3. <code>get_company_info({"ticker":"BE"})</code><br>&nbsp;&nbsp;4. <code>get_historical_prices({"ticker":"BE","period":"7d","interval":"1d"})</code><br>&nbsp;&nbsp;5. <code>get_ticker_news({"ticker":"BE","count":5})</code><br></div>
# ### 💬 Response:
# The most volatile stock I found from the recent context is **Bloom Energy (NYSE: BE)**.
#
# Why BE stands out:
# - **Very large 7-day price swings:** it moved from a **low of about $230.60** on June 10, 2026 to a **high of about $295.69** on June 4, 2026, with multiple big daily ranges in between.
# - **High volatility profile:** beta is **3.746**, which is extremely high.
# - **News sentiment is mostly positive, but mixed with volatility:** recent news is broadly bullish on AI data-center demand, possible S&P 500 inclusion, and analyst optimism, which has likely fueled the sharp moves. citeturn0search0
#
# Recent BE news sentiment:
# - Positive catalyst: **Bloom Energy’s S&P 500 buzz and Wyoming AI project progress**.
# - Positive catalyst: **bullish moves during the market rebound**.
# - Positive catalyst: **analysts remain optimistic**.
# - Positive catalyst: **stock jumped on expectations of major AI data-center deals**. citeturn0search0turn0search1
#
# If you want, I can also give you:
# 1. the **top 5 most volatile stocks** from the same context, or
# 2. a **volatility ranking with exact 7-day swing percentages**.

# %%
# $0.036 cost for this call (with context)
pprint(get_usage_info_gpt_5_4_mini(r5))
# Out:
# {'cost_usd': 0.036019499999999996,
#  'input_tokens': 45014,
#  'output_tokens': 502,
#  'request_usage_entries': [{'input_tokens': 6215,
#                             'output_tokens': 124,
#                             'total_tokens': 6339},
#                            {'input_tokens': 17791,
#                             'output_tokens': 81,
#                             'total_tokens': 17872},
#                            {'input_tokens': 21008,
#                             'output_tokens': 297,
#                             'total_tokens': 21305}],
#  'requests': 3,
#  'total_tokens': 45516}

# %%
# Not working, as there is no VERTICAL stored in the database to compare with. The agent will fallback to WebSearchTool, which is not ideal for this type of query.
r6 = await ask(stock_agent, "Show top 10 growth companies in biotech sector")
# Out:
# <h3>❓ Show top 10 growth companies in biotech sector</h3>
# <div style='padding: 10px; border-radius: 5px;'><b>🔧 Tools Called:</b><br>&nbsp;&nbsp;1. <code>get_top_growth_companies({"min_margin":0.2,"max_pe":null,"min_market_cap":1000000000,"limit":50})</code><br>&nbsp;&nbsp;2. <code>search_companies({"query":null,"ticker":null,"min_market_cap":1000000000,"max_market_cap":null,"min_pe":null,"max_pe":null,"min_dividend":null,"max_dividend":null,"min_margin":0.2,"max_margin":null,"country":null,"limit":50})</code><br></div>
# ### 💬 Response:
# I can do that, but I need to clarify one thing: the tools I have can rank **growth companies globally** or search companies by sector/filters, but they don’t directly return “top growth companies in biotech” as a pre-filtered list.
#
# From the data available, here are the **biotech / pharma names that appear as strong growth candidates** in the current set I queried:
#
# 1. **Eli Lilly (LLY)** — market cap ~$1.01T, operating margin 43.07%
# 2. **Johnson & Johnson (JNJ)** — market cap ~$580B, operating margin 34.58%
# 3. **AbbVie (ABBV)** — market cap ~$402B, operating margin 10.78%
# 4. **Roche (RO.SW)** — market cap ~$334B, operating margin 26.78%
#
# If you want, I can next try to build a **more accurate top 10 biotech growth list** by:
# - searching biotech companies specifically,
# - filtering by market cap and operating margin,
# - and then ranking them by growth-oriented fundamentals.
#
# If that’s what you want, I’ll do it.

# %%
# same $0.017 per call (with no passed context)
pprint(get_usage_info_gpt_5_4_mini(r6))
# Out:
# {'cost_usd': 0.017590500000000002,
#  'input_tokens': 21204,
#  'output_tokens': 375,
#  'request_usage_entries': [{'input_tokens': 6202,
#                             'output_tokens': 134,
#                             'total_tokens': 6336},
#                            {'input_tokens': 15002,
#                             'output_tokens': 241,
#                             'total_tokens': 15243}],
#  'requests': 2,
#  'total_tokens': 21579}

# %% [markdown]
# ## 2.3) Agents with explicit context of a ticker (current_ticker) and a history

# %%
# automated context tracking and conversation history
class Conversation:                                                                                                                                                
    def __init__(self, agent, runner):                                                                                                                             
        self.agent = agent                                                                                                                                         
        self.runner = runner                                                                                                                                       
        self.history = []                                                                                                                                          
        self.current_ticker = None                                                                                                                                 
                                                                                                                                                                    
    async def ask(self, question: str) -> RunResult:                                                                                                               
        """Ask with automatic context and ticker tracking."""                                                                                                      
                                                                                                                                                                    
        # Extract ticker from question if present                                                                                                                  
        import re                                                                                                                                                  
        ticker_match = re.search(r'\b([A-Z]{1,5})\b', question)                                                                                                    
        if ticker_match:                                                                                                                                           
            self.current_ticker = ticker_match.group(1)                                                                                                            
                                                                                                                                                                    
        # Add ticker to question if we have context and it's not mentioned                                                                                         
        if self.current_ticker and self.current_ticker not in question.upper():                                                                                    
            question = f"{question} (for {self.current_ticker})"                                                                                                   
                                                                                                                                                                    
        print(f"\n{'='*70}")                                                                                                                                       
        print(f"❓ {question}")                                                                                                                                    
        if self.current_ticker:                                                                                                                                    
            print(f"🏷️  Ticker: {self.current_ticker}")                                                                                                           
        print('='*70)                                                                                                                                              
                                                                                                                                                                    
        # Run with context from previous question                                                                                                                  
        context = self.history[-1].new_items if self.history else None                                                                                             
                                                                                                                                                                    
        if context:                                                                                                                                                
            results = await self.runner.run(self.agent, input=question, context=context)                                                                           
        else:                                                                                                                                                      
            results = await self.runner.run(self.agent, input=question)                                                                                            

        # Show cost
        usage_info = get_usage_info_gpt_5_4_mini(results)
        print(f"\n💰 Cost: ${usage_info['cost_usd']:.6f}")

        # Show tools                                                                                                                                               
        print("\n🔧 Tools Called:")                                                                                                                                
        tool_count = 0                                                                                                                                             
        for resp in results.raw_responses:                                                                                                                         
            for out in resp.output:                                                                                                                                
                if hasattr(out, 'name'):                                                                                                                           
                    tool_count += 1                                                                                                                                
                    print(f"  {tool_count}. {out.name}({out.arguments})")                                                                                          
                                                                                                                                                                    
        if tool_count == 0:                                                                                                                                        
            print("  (No tools called)")                                                                                                                           
                                                                                                                                                                    
        # Extract ticker from results if not already set                                                                                                           
        if not self.current_ticker:                                                                                                                                
            for item in results.new_items:                                                                                                                         
                if item.type == 'tool_call_output_item' and isinstance(item.output, dict):                                                                         
                    if 'ticker' in item.output:                                                                                                                    
                        self.current_ticker = item.output['ticker']                                                                                                
                        break                                                                                                                                      
                                                                                                                                                                    
        # Show response                                                                                                                                            
        print(f"\n{'='*70}")                                                                                                                                       
        print("💬 Response:")                                                                                                                                      
        print('='*70)                                                                                                                                              
        print(results.final_output)                                                                                                                                
        print()                                                                                                                                                    
                                                                                                                                                                    
        self.history.append(results)                                                                                                                               
        return results                                                                                                                                             
                                                                                                                                                                    
    def reset(self):                                                                                                                                               
        """Clear conversation history."""                                                                                                                          
        self.history = []                                                                                                                                          
        self.current_ticker = None

# %%
convo = Conversation(stock_agent, runner)   

await convo.ask("What's TSLA's EPS trend and surprise historical?")
# Out:
# ======================================================================
# ❓ What's TSLA's EPS trend and surprise historical?
# 🏷️  Ticker: TSLA
# ======================================================================
#
# 💰 Cost: $0.013144
#
# 🔧 Tools Called:
#   1. get_eps_trend({"ticker":"TSLA"})
#   2. get_earnings_dates({"ticker":"TSLA"})
#
# ======================================================================
# 💬 Response:
# ======================================================================
# Here’s TSLA’s **EPS trend** and **earnings surprise history**:
#
# ### EPS trend
# - **Current quarter (0q):** 0.45414
#   - 7 days ago: 0.45396
#   - 30 days ago: 0.45396
#   - 60 days ago: 0.44637
#   - 90 days ago: 0.46212
#
# - **Next quarter (+1q):** 0.5375
#   - 7 days ago: 0.5393
#   - 30 days ago: 0.5393
#   - 60 days ago: 0.53175
#   - 90 days ago: 0.5405
#
# - **Current year (0y):** 2.05937
#   - 7 days ago: 2.04967
#   - 30 days ago: 2.04835
#   - 60 days ago: 2.03873
#   - 90 days ago: 2.08858
#
# - **Next year (+1y):** 2.49995
#   - 7 days ago: 2.50462
#   - 30 days ago: 2.50969
#   - 60 days ago: 2.77175
#   - 90 days ago: 2.81043
#
# ### Surprise history
# Recent reported quarters:
# - **2026-04-22:** estimate 0.20, reported 0.13, surprise **-36.54%**
# - **2026-01-28:** estimate 0.45, reported 0.50, surprise **+10.96%**
# - **2025-10-22:** estimate 0.56, reported 0.50, surprise **-10.53%**
# - **2025-07-23:** estimate 0.30, reported 0.33, surprise **+10.49%**
# - **2025-04-22:** estimate 0.41, reported 0.27, surprise **-34.89%**
# - **2025-01-29:** estimate 0.77, reported 0.73, surprise **-4.83%**
#
# ### Quick read
# - TSLA’s **near-term EPS estimates are fairly stable** for the current and next quarter.
# - The **next-year EPS estimate has been drifting down** over the last 90 days.
# - Recent earnings surprises have been **mixed**, with a few big beats and misses.
#
# If you want, I can also turn this into a **table**, or give you a **bullish/bearish take** on what the trend suggests.
# RunResult(input="What's TSLA's EPS trend and surprise historical?", new_items=[ToolCallItem(agent=Agent(name='stock_agent', handoff_description=None, tools=[WebSearchTool(user_location=None, filters=None, search_context_size='medium'), FunctionTool(name='get_company_info', description='Get comprehensive company information and fundamental data for a stock ticker.\n\nReturns key metrics organized by category:\n- Company basics: website, industry, sector, employees, officers\n- Price data: current, previous close, day range, 52-week range\n- Market metrics: market cap, volume, beta, PE ratios\n- Valuation: margins, book value, price ratios\n- Ownership: insider/institutional holdings, short interest\n- Analyst data: EPS estimates, targets, recommendations\n- Financial health: cash, returns, growth rates', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_company_info_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11e892ac0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_eps_trend', description='Get the EPS (Earnings Per Share) trend for a given stock ticker - showing how analyst consensus has changed over time for different periods (quarterly, yearly)\nand diffent points in the past (current, 7daysAgo, 30daysAgo, etc.).\nIndex: 0q (This Quarter),  +1q (Next Quarter),  0y (This Year),  +1y (Next Year) \nand columns showing estimates from different points in the past (current, 7daysAgo, 30daysAgo, etc.). ', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_eps_trend_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11961cf40>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_dates', description='Get earnings call dates for a stock ticker.\n\nReturns historical earnings data including:\n- Expected EPS\n- Actual EPS  \n- Surprise percentage\n- Earnings dates from multiple quarters and years\n- Next earnings call date', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_dates_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee40e0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_analysis', description='Get comprehensive earnings and EPS analysis data for a stock ticker.\n\nCombines multiple analyst data sources:\n1. Earnings Estimates - Consensus EPS estimates (avg, low, high, year-ago, analyst count)\n2. EPS Revisions - How analysts have revised estimates (up/down last 7/30 days)\n3. Growth Estimates - Expected earnings growth vs index benchmark\n4. Earnings History - Historical actual vs estimated EPS with surprise %\n\nPeriod notation:\n- 0q: Current fiscal quarter\n- +1q: Next fiscal quarter\n- 0y: Current fiscal year\n- +1y: Next fiscal year\n- LTG: Long-term growth (growth estimates only)', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_analysis_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_in ...

# %%
await convo.ask("What about analysts predictions of growth vs. index?")
# Out:
# ======================================================================
# ❓ What about analysts predictions of growth vs. index? (for TSLA)
# 🏷️  Ticker: TSLA
# ======================================================================
#
# 💰 Cost: $0.011039
#
# 🔧 Tools Called:
#   1. get_earnings_analysis({"ticker":"TSLA"})
#
# ======================================================================
# 💬 Response:
# ======================================================================
# For **TSLA**, analysts currently expect **growth vs. the index** to look like this:
#
# - **Current quarter (0q):** TSLA **13.5%** vs index **26.0%**
# - **Next quarter (+1q):** TSLA **7.5%** vs index **20.2%**
# - **Current year (0y):** TSLA **24.1%** vs index **23.0%**
# - **Next year (+1y):** TSLA **21.4%** vs index **16.9%**
# - **Long-term growth (LTG):** TSLA not available here vs index **12.2%**
#
# Quick read:
# - **Near term:** TSLA is expected to grow **slower than the index**.
# - **Full-year and next year:** TSLA is expected to grow **a bit faster than the index**.
#
# If you want, I can also break down **EPS revisions**, **recent surprise history**, or **analyst target prices** for TSLA.
# RunResult(input='What about analysts predictions of growth vs. index? (for TSLA)', new_items=[ToolCallItem(agent=Agent(name='stock_agent', handoff_description=None, tools=[WebSearchTool(user_location=None, filters=None, search_context_size='medium'), FunctionTool(name='get_company_info', description='Get comprehensive company information and fundamental data for a stock ticker.\n\nReturns key metrics organized by category:\n- Company basics: website, industry, sector, employees, officers\n- Price data: current, previous close, day range, 52-week range\n- Market metrics: market cap, volume, beta, PE ratios\n- Valuation: margins, book value, price ratios\n- Ownership: insider/institutional holdings, short interest\n- Analyst data: EPS estimates, targets, recommendations\n- Financial health: cash, returns, growth rates', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_company_info_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11e892ac0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_eps_trend', description='Get the EPS (Earnings Per Share) trend for a given stock ticker - showing how analyst consensus has changed over time for different periods (quarterly, yearly)\nand diffent points in the past (current, 7daysAgo, 30daysAgo, etc.).\nIndex: 0q (This Quarter),  +1q (Next Quarter),  0y (This Year),  +1y (Next Year) \nand columns showing estimates from different points in the past (current, 7daysAgo, 30daysAgo, etc.). ', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_eps_trend_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11961cf40>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_dates', description='Get earnings call dates for a stock ticker.\n\nReturns historical earnings data including:\n- Expected EPS\n- Actual EPS  \n- Surprise percentage\n- Earnings dates from multiple quarters and years\n- Next earnings call date', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_dates_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee40e0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_analysis', description='Get comprehensive earnings and EPS analysis data for a stock ticker.\n\nCombines multiple analyst data sources:\n1. Earnings Estimates - Consensus EPS estimates (avg, low, high, year-ago, analyst count)\n2. EPS Revisions - How analysts have revised estimates (up/down last 7/30 days)\n3. Growth Estimates - Expected earnings growth vs index benchmark\n4. Earnings History - Historical actual vs estimated EPS with surprise %\n\nPeriod notation:\n- 0q: Current fiscal quarter\n- +1q: Next fiscal quarter\n- 0y: Current fiscal year\n- +1y: Next fiscal year\n- LTG: Long-term growth (growth estimates only)', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_analysis_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool. ...

# %%
await convo.ask("Show extended analysis of competitors and strategic positioning?")
# Out:
# ======================================================================
# ❓ Show extended analysis of competitors and strategic positioning? (for TSLA)
# 🏷️  Ticker: TSLA
# ======================================================================
#
# 💰 Cost: $0.046536
#
# 🔧 Tools Called:
#   1. get_company_info({"ticker":"TSLA"})
#   2. get_earnings_analysis({"ticker":"TSLA"})
#   3. get_eps_trend({"ticker":"TSLA"})
#   4. get_earnings_dates({"ticker":"TSLA"})
#   5. get_ticker_news({"ticker":"TSLA","count":8})
#   6. search_news_by_ticker({"ticker":"TSLA","num_results":10})
#   7. get_historical_prices({"ticker":"TSLA","period":"1y","interval":"1d"})
#   8. get_top_growth_companies({"min_margin":0.2,"max_pe":null,"min_market_cap":1000000000,"limit":20})
#   9. get_top_value_companies({"min_dividend":0.02,"max_pe":25,"min_margin":0.1,"min_market_cap":1000000000,"limit":20})
#
# ======================================================================
# 💬 Response:
# ======================================================================
# Here’s an extended, investor-style read on **TSLA’s competitors and strategic positioning** based on the latest available data I pulled.
#
# ## 1) Where Tesla stands right now
#
# Tesla is still a very large company by market cap, at about **$1.53T**, but its current fundamentals look more like a high-expectation growth story than a classic auto company: **trailing P/E ~369**, **forward P/E ~163**, **price/sales ~15.6**, and **operating margin ~4.2%**. Revenue growth is still positive, but profitability is modest relative to the valuation. citeturn0companyinfo
#
# That tension matters because Tesla’s current market price is essentially pricing in more than just EV sales: it’s pricing in future gains from autonomy, software, robotics, and energy. The analyst consensus also reflects that ambiguity: **41 analysts**, mean target about **$420.5**, median **$460**, with a wide range from **$123 to $600**. citeturn0companyinfo
#
# ## 2) Strategic positioning: Tesla is not just an automaker
#
# Tesla’s business is now a mix of:
# - **Automotive**
# - **Energy generation and storage**
# - **Software / autonomy / AI**
# - **Services and charging infrastructure** citeturn0companyinfo
#
# That gives Tesla a broader strategic base than most automakers. The real “Tesla thesis” is that the company can use EV manufacturing as the cash-generating platform while the upside comes from:
# 1. **Autonomous driving software**
# 2. **Robotaxi economics**
# 3. **Humanoid robotics**
# 4. **Energy storage and grid services** citeturn0companyinfoturn0earningsanalysis
#
# In other words, Tesla is positioned less like Ford or GM and more like a hybrid of:
# - carmaker,
# - industrial hardware platform,
# - and speculative AI/software company. citeturn0companyinfoturn0earningsanalysis
#
# ## 3) Competitive landscape by segment
#
# ### A. EV / automotive competition
# Tesla’s core auto business faces pressure from established OEMs and EV-first challengers. While I don’t have direct competitor company profiles in this run, the strategic issue is clear from Tesla’s own metrics: margins are thin for a company priced like a software platform. Operating margin around **4%** suggests the auto segment is still under strong pricing and competition pressure. citeturn0companyinfo
#
# ### B. The real “competitor” is margin quality
# Tesla’s competitors are not just other EV makers. The more important comparison is against companies with:
# - much higher operating margins,
# - more durable pricing power,
# - and lower valuation risk.
#
# For example, in the broader “growth” universe, companies like **NVIDIA**, **Alphabet**, **Microsoft**, and **Meta** combine scale with much stronger operating margins. Tesla’s margin profile is far weaker than those businesses, which helps explain why TSLA’s valuation looks aggressive. citeturn0growthcompaniesturn0companyinfo
#
# ### C. Energy storage as a strategic moat
# Tesla’s energy storage business is one of its strongest strategic differentiators because it gives the company a second industrial growth lane beyond passenger cars. That matters if EV demand becomes more competitive or cyclical. The challenge is that the market still tends to value Tesla mainly on future autonomy/AI optionality rather than the energy segment alone. citeturn0companyinfo
#
# ## 4) Earnings quality and momentum
#
# The earnings setup is mixed.
#
# - Current-year EPS estimate: **$2.06**
# - Next-year EPS estimate: **$2.50**
# - Current-quarter EPS estimate: **$0.45**
# - Next-quarter EPS estimate: **$0.54** citeturn0earningsanalysis
#
# That implies earnings are expected to grow, but not nearly fast enough to make the valuation feel “cheap.” Analysts have also been somewhat cautious lately: for **next year**, revisions over the last 30 days show **3 downward revisions** and **0 upward revisions**. citeturn0earningsanalysisturn0epstrend
#
# At the same time, Tesla’s recent earnings history has been volatile:
# - **2026-04-22**: EPS estimate **0.20**, reported **0.13**, surprise **-36.54%**
# - **2026-01-28**: estimate **0.45**, reported **0.50**, surprise **+10.96%** citeturn0earningsdates
#
# So the trend is not broken, but it is uneven.
#
# ## 5) Stock performance context
#
# Tesla’s stock has been volatile but strong over the last year. It traded around **$325.31** on **2025-06-13** and closed around **$406.43** on **2026-06-12**. During that year it also reached highs near **$498.83**. citeturn0historicalpricesturn0companyinfo
#
# So the market has already rewarded Tesla for a lot of optimism, and recent price action suggests investors are still trading on future narrative rather than near-term fundamentals. citeturn0historicalpricesturn0companyinfo
#
# ## 6) What the latest news suggests
#
# Recent Tesla-related news in the feed is dominated by:
# - valuation debate,
# - speculation around Elon Musk’s broader empire,
# - and Tesla Semi / future product narrative. citeturn0tickernewsturn0searchnewsbyticker
#
# A few themes stand out:
#
# - Some commentary views Tesla as **overvalued** at its current market cap, given its EV growth and margin profile. citeturn0searchnewsbyticker
# - Other pieces frame Tesla as strategically stronger because of **FSD, AI, Optimus, and battery tech**. citeturn0searchnewsbyticker
# - The broader Musk ecosystem, especially the SpaceX IPO chatter, may influence sentiment and capital flows around TSLA even if it does not change Tesla’s core operations. citeturn0tickernewsturn0searchnewsbyticker
#
# ## 7) Key strengths vs. weaknesses
#
# ### Strengths
# - Strong brand and global recognition. citeturn0companyinfo
# - Vertical integration in EV manufacturing and charging. citeturn0companyinfo
# - Optionality in autonomy, robotics, and energy storage. citeturn0companyinfoturn0earningsanalysis
# - Large cash balance of about **$44.7B** with **current ratio ~2.0**. citeturn0companyinfo
#
# ### Weaknesses
# - Very rich valuation relative to current earnings. citeturn0companyinfo
# - Thin operating margin for the size of the company. citeturn0companyinfo
# - Earnings revisions have softened for the next year. citeturn0earningsanalysisturn0epstrend
# - Tesla still depends heavily on execution in areas that are not yet fully proven commercially at scale. citeturn0earningsanalysisturn0companyinfo
#
# ## 8) Bottom-line strategic view
#
# **Tesla’s strategic position is best described as “category-defining, but not yet fully category-justified by earnings.”**
# It has a stronger platform than a normal automaker, but its valuation assumes success across several future businesses that are still partly optionality rather than proven profit engines. citeturn0companyinfoturn0earningsanalysis
#
# ### My take:
# - **Bull case:** Tesla compounds into a software + energy + autonomy platform, and the current valuation becomes plausible. citeturn0companyinfoturn0earningsanalysis
# - **Bear case:** Tesla remains a good industrial company but struggles to justify a trillion-dollar-plus multiple without faster margin expansion. citeturn0companyinfoturn0earningsanalysis
#
# If you want, I can next turn this into one of these formats:
# 1. **Tesla vs. top competitors table**
# 2. **Bull / bear / base case valuation thesis**
# 3. **SWOT analysis**
# 4. **Moat analysis with auto, energy, AI, and robotics buckets**
# RunResult(input='Show extended analysis of competitors and strategic positioning? (for TSLA)', new_items=[ToolCallItem(agent=Agent(name='stock_agent', handoff_description=None, tools=[WebSearchTool(user_location=None, filters=None, search_context_size='medium'), FunctionTool(name='get_company_info', description='Get comprehensive company information and fundamental data for a stock ticker.\n\nReturns key metrics organized by category:\n- Company basics: website, industry, sector, employees, officers\n- Price data: current, previous close, day range, 52-week range\n- Market metrics: market cap, volume, beta, PE ratios\n- Valuation: margins, book value, price ratios\n- Ownership: insider/institutional holdings, short interest\n- Analyst data: EPS estimates, targets, recommendations\n- Financial health: cash, returns, growth rates', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_company_info_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11e892ac0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_eps_trend', description='Get the EPS (Earnings Per Share) trend for a given stock ticker - showing how analyst consensus has changed over time for different periods (quarterly, yearly)\nand diffent points in the past (current, 7daysAgo, 30daysAgo, etc.).\nIndex: 0q (This Quarter),  +1q (Next Quarter),  0y (This Year),  +1y (Next Year) \nand columns showing estimates from different points in the past (current, 7daysAgo, 30daysAgo, etc.). ', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_eps_trend_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11961cf40>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_dates', description='Get earnings call dates for a stock ticker.\n\nReturns historical earnings data including:\n- Expected EPS\n- Actual EPS  \n- Surprise percentage\n- Earnings dates from multiple quarters and years\n- Next earnings call date', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_dates_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee40e0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_analysis', description='Get comprehensive earnings and EPS analysis data for a stock ticker.\n\nCombines multiple analyst data sources:\n1. Earnings Estimates - Consensus EPS estimates (avg, low, high, year-ago, analyst count)\n2. EPS Revisions - How analysts have revised estimates (up/down last 7/30 days)\n3. Growth Estimates - Expected earnings growth vs index benchmark\n4. Earnings History - Historical actual vs estimated EPS with surprise %\n\nPeriod notation:\n- 0q: Current fiscal quarter\n- +1q: Next fiscal quarter\n- 0y: Current fiscal year\n- +1y: Next fiscal year\n- LTG: Long-term growth (growth estimates only)', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_analysis_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_fu ...

# %%
await convo.ask("How is it doing against car manufacturers?")
# Out:
# ======================================================================
# ❓ How is it doing against car manufacturers? (for TSLA)
# 🏷️  Ticker: TSLA
# ======================================================================
#
# 💰 Cost: $0.012970
#
# 🔧 Tools Called:
#   1. get_company_info({"ticker":"TSLA"})
#   2. search_companies({"query":null,"ticker":null,"min_market_cap":1000000000,"max_market_cap":null,"min_pe":null,"max_pe":null,"min_dividend":null,"max_dividend":null,"min_margin":null,"max_margin":null,"country":"USA","limit":20})
#
# ======================================================================
# 💬 Response:
# ======================================================================
# Against **traditional car manufacturers**, TSLA looks **much more expensive on valuation**, but **stronger on margins and growth** than most automakers.
#
# ### Quick read
# - **TSLA P/E:** about **369x trailing** and **163x forward**
# - **Profit margin:** about **4.0%**
# - **Operating margin:** about **4.2%**
# - **Revenue growth:** about **15.8%**
# - **Market cap:** about **$1.53T**
#
# That combination usually means the market is pricing TSLA more like a **growth/tech company** than a normal auto manufacturer.
#
# ### What that implies vs carmakers
# Compared with legacy auto makers, TSLA generally:
# - trades at a **far higher valuation multiple**
# - has **higher growth expectations**
# - has a **much stronger balance sheet** than many peers
# - but still has **thin automotive margins** relative to the valuation
#
# ### In plain English
# If you’re comparing it to Ford, GM, Toyota, BMW, Mercedes, etc., TSLA is usually:
# - **not cheap**
# - **not the highest-margin automaker**
# - but **much more richly valued** because investors expect faster growth and optionality from software, autonomy, energy, and AI
#
# ### One important caveat
# I wasn’t able to pull a peer list from the company screener, so I can’t give you a clean side-by-side table from that tool alone. If you want, I can still do one of these next:
# 1. **Compare TSLA to specific automakers** like F, GM, TM, HMC, BYDDF, BMWYY, MBGYY
# 2. **Rank TSLA vs major automakers by valuation/margins/growth**
# 3. **Compare TSLA only to EV makers** instead of all auto manufacturers
# RunResult(input='How is it doing against car manufacturers? (for TSLA)', new_items=[ToolCallItem(agent=Agent(name='stock_agent', handoff_description=None, tools=[WebSearchTool(user_location=None, filters=None, search_context_size='medium'), FunctionTool(name='get_company_info', description='Get comprehensive company information and fundamental data for a stock ticker.\n\nReturns key metrics organized by category:\n- Company basics: website, industry, sector, employees, officers\n- Price data: current, previous close, day range, 52-week range\n- Market metrics: market cap, volume, beta, PE ratios\n- Valuation: margins, book value, price ratios\n- Ownership: insider/institutional holdings, short interest\n- Analyst data: EPS estimates, targets, recommendations\n- Financial health: cash, returns, growth rates', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_company_info_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11e892ac0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_eps_trend', description='Get the EPS (Earnings Per Share) trend for a given stock ticker - showing how analyst consensus has changed over time for different periods (quarterly, yearly)\nand diffent points in the past (current, 7daysAgo, 30daysAgo, etc.).\nIndex: 0q (This Quarter),  +1q (Next Quarter),  0y (This Year),  +1y (Next Year) \nand columns showing estimates from different points in the past (current, 7daysAgo, 30daysAgo, etc.). ', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_eps_trend_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11961cf40>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_dates', description='Get earnings call dates for a stock ticker.\n\nReturns historical earnings data including:\n- Expected EPS\n- Actual EPS  \n- Surprise percentage\n- Earnings dates from multiple quarters and years\n- Next earnings call date', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_dates_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee40e0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_analysis', description='Get comprehensive earnings and EPS analysis data for a stock ticker.\n\nCombines multiple analyst data sources:\n1. Earnings Estimates - Consensus EPS estimates (avg, low, high, year-ago, analyst count)\n2. EPS Revisions - How analysts have revised estimates (up/down last 7/30 days)\n3. Growth Estimates - Expected earnings growth vs index benchmark\n4. Earnings History - Historical actual vs estimated EPS with surprise %\n\nPeriod notation:\n- 0q: Current fiscal quarter\n- +1q: Next fiscal quarter\n- 0y: Current fiscal year\n- +1y: Next fiscal year\n- LTG: Long-term growth (growth estimates only)', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_analysis_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._ ...

# %%
await convo.ask("What about Google? Give me a comparative analysis similar to Tesla.")
# Out:
# ======================================================================
# ❓ What about Google? Give me a comparative analysis similar to Tesla. (for TSLA)
# 🏷️  Ticker: TSLA
# ======================================================================
#
# 💰 Cost: $0.035053
#
# 🔧 Tools Called:
#   1. get_company_info({"ticker":"GOOGL"})
#   2. get_eps_trend({"ticker":"GOOGL"})
#   3. get_earnings_dates({"ticker":"GOOGL"})
#   4. get_earnings_analysis({"ticker":"GOOGL"})
#   5. get_historical_prices({"ticker":"GOOGL","period":"1y","interval":"1d"})
#   6. get_ticker_news({"ticker":"GOOGL","count":5})
#
# ======================================================================
# 💬 Response:
# ======================================================================
# Here’s a **GOOGL comparative snapshot** in the same style I’d use for TSLA.
#
# ## Alphabet (GOOGL): quick read
#
# **Business quality:**
# Alphabet is a very different profile from Tesla: it’s a **large, highly profitable, cash-generative platform business** with search, YouTube, Google Cloud, and “Other Bets.” It has much less balance-sheet and execution volatility than TSLA, but also usually less “upside optionality” from a single product cycle. It’s more of a **quality compounder** than a high-beta turnaround story.
#
# ## Valuation vs. performance
#
# - **Current price:** about **$359.68**
# - **52-week range:** **$162.00 to $408.61**
# - **Market cap:** about **$4.39T**
# - **Trailing P/E:** **27.5**
# - **Forward P/E:** **24.8**
# - **Operating margin:** **36.1%**
# - **Profit margin:** **37.9%**
# - **ROE:** **38.9%**
#
# That combination says: Alphabet is **expensive in absolute terms, but not crazy for its profitability and growth**. Compared with TSLA, GOOGL is far more grounded in current earnings power.
#
# ## Earnings and revisions
#
# Recent analyst EPS trend looks **stable to slightly improving**:
#
# - Current quarter EPS estimate: **2.87**
# - Next quarter: **3.00**
# - Current year: **14.22**
# - Next year: **14.46**
#
# Revision activity is a bit mixed, but not alarming:
# - More downward than upward revisions in the last 7–30 days for near-term periods
# - Full-year growth expectations remain solid
#
# ### Earnings history
# Alphabet has been consistently beating expectations:
# - **2026-04-29:** EPS estimate **2.63**, reported **5.11** — a huge beat
# - **2026-02-04:** estimate **2.64**, reported **2.82**
# - **2025-10-29:** estimate **2.26**, reported **2.87**
#
# That suggests execution has been strong, especially recently.
#
# ## Growth profile
#
# - **Revenue growth:** **21.8%**
# - **Earnings growth:** **82%**
# - **Quarterly EPS growth estimate:** about **24%**
# - **Next-year EPS growth estimate:** only about **1.7%**
#
# That last point matters: near-term growth is strong, but the **outer-year growth rate is flattening**, which may be why the stock has been sensitive to valuation changes.
#
# ## Balance sheet / cash flow
#
# - **Cash:** about **$126.8B**
# - **Debt:** about **$95.9B**
# - **Free cash flow:** about **$27.9B**
# - **Operating cash flow:** about **$174.4B**
# - **Current ratio:** **1.92**
#
# Alphabet remains financially very strong. This is one of the biggest differences versus TSLA: Alphabet has a **much cleaner cash engine and lower operational fragility**.
#
# ## Technical / price action
#
# Over the last year, GOOGL has had a strong run, moving from roughly **$174** a year ago to about **$360** now. That’s a big re-rating.
#
# Recent action is still constructive overall, but the stock is below the recent highs around the **$400+** area, so it’s not in a straight-line breakout.
#
# ## Analyst sentiment
#
# - **Mean target:** about **$432.83**
# - **Median target:** **$430**
# - **Recommendation:** **Strong Buy**
# - **Analyst opinions:** **53**
#
# Wall Street is still generally constructive.
#
# ## Comparative takeaway vs. TSLA
#
# If you’re comparing **GOOGL vs TSLA**:
#
# ### GOOGL tends to win on:
# - Profitability
# - Cash flow
# - Balance sheet strength
# - Consistency
# - Lower execution risk
#
# ### TSLA tends to win on:
# - Higher narrative-driven upside
# - More leverage to new product cycles
# - More optionality if a big AI/autonomy/robotics thesis works out
#
# ### My bottom line
# - **GOOGL = higher-quality, lower-drama compounder**
# - **TSLA = higher-upside, higher-risk strategic bet**
#
# If you want, I can also give you a **side-by-side TSLA vs GOOGL table** across valuation, growth, margins, cash flow, and analyst sentiment.
# RunResult(input='What about Google? Give me a comparative analysis similar to Tesla. (for TSLA)', new_items=[ToolCallItem(agent=Agent(name='stock_agent', handoff_description=None, tools=[WebSearchTool(user_location=None, filters=None, search_context_size='medium'), FunctionTool(name='get_company_info', description='Get comprehensive company information and fundamental data for a stock ticker.\n\nReturns key metrics organized by category:\n- Company basics: website, industry, sector, employees, officers\n- Price data: current, previous close, day range, 52-week range\n- Market metrics: market cap, volume, beta, PE ratios\n- Valuation: margins, book value, price ratios\n- Ownership: insider/institutional holdings, short interest\n- Analyst data: EPS estimates, targets, recommendations\n- Financial health: cash, returns, growth rates', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_company_info_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11e892ac0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_eps_trend', description='Get the EPS (Earnings Per Share) trend for a given stock ticker - showing how analyst consensus has changed over time for different periods (quarterly, yearly)\nand diffent points in the past (current, 7daysAgo, 30daysAgo, etc.).\nIndex: 0q (This Quarter),  +1q (Next Quarter),  0y (This Year),  +1y (Next Year) \nand columns showing estimates from different points in the past (current, 7daysAgo, 30daysAgo, etc.). ', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_eps_trend_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x11961cf40>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_dates', description='Get earnings call dates for a stock ticker.\n\nReturns historical earnings data including:\n- Expected EPS\n- Actual EPS  \n- Surprise percentage\n- Earnings dates from multiple quarters and years\n- Next earnings call date', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_dates_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create_function_tool.<locals>._on_invoke_tool at 0x122ee40e0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None), FunctionTool(name='get_earnings_analysis', description='Get comprehensive earnings and EPS analysis data for a stock ticker.\n\nCombines multiple analyst data sources:\n1. Earnings Estimates - Consensus EPS estimates (avg, low, high, year-ago, analyst count)\n2. EPS Revisions - How analysts have revised estimates (up/down last 7/30 days)\n3. Growth Estimates - Expected earnings growth vs index benchmark\n4. Earnings History - Historical actual vs estimated EPS with surprise %\n\nPeriod notation:\n- 0q: Current fiscal quarter\n- +1q: Next fiscal quarter\n- 0y: Current fiscal year\n- +1y: Next fiscal year\n- LTG: Long-term growth (growth estimates only)', params_json_schema={'properties': {'ticker': {'description': "Stock ticker symbol (e.g., 'AAPL', 'GOOGL', 'MSFT')", 'title': 'Ticker', 'type': 'string'}}, 'required': ['ticker'], 'title': 'get_earnings_analysis_args', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function function_tool.<locals>._create ...

# %% [markdown]
# ## 2.4) Stuctured output analysis

# %%
# STEP 1: Define simple Pydantic model with 5 main things
from pydantic import BaseModel, Field
from typing import Optional
from enum import Enum

class TrendDirection(str, Enum):
    IMPROVING = "improving"
    DECLINING = "declining" 
    STABLE = "stable"

class ValuationLevel(str, Enum):
    CHEAP = "cheap"
    FAIR = "fair"
    EXPENSIVE = "expensive"

class Recommendation(str, Enum):
    BUY = "buy"
    HOLD = "hold"
    SELL = "sell"

# 🎯 Simple model mapping 5 key metrics to our function tools
class SimpleStockAnalysis(BaseModel):
    """5 key metrics automatically mapped from function calls"""
    ticker: str = Field(description="Stock ticker symbol")
    company_name: str = Field(description="Company name")
    
    # 1. EPS Trend (from get_eps_trend, get_earnings_analysis)
    eps_current_estimate: Optional[float] = Field(description="Current quarter EPS estimate")
    eps_trend_direction: TrendDirection = Field(description="EPS trend direction")
    
    # 2. Price & Valuation (from get_company_info)
    current_price: Optional[float] = Field(description="Current stock price")
    pe_ratio: Optional[float] = Field(description="P/E ratio")
    distance_from_52w_high_pct: Optional[float] = Field(description="Distance from 52-week high %")
    valuation_level: ValuationLevel = Field(description="Valuation assessment")
    
    # 3. Analyst Sentiment (from get_earnings_analysis)
    analyst_revisions_net_7d: Optional[int] = Field(description="Net analyst revisions last 7 days")
    analyst_sentiment: TrendDirection = Field(description="Overall analyst sentiment")
    
    # 4. News & Market Activity (from get_ticker_news, get_historical_prices)
    recent_news_count: Optional[int] = Field(description="Number of recent news articles")
    news_sentiment_score: Optional[float] = Field(ge=-1, le=1, description="News sentiment (-1 to 1)")
    
    # 5. Investment Summary
    investment_thesis: str = Field(description="One-sentence investment summary")
    recommendation: Recommendation = Field(description="Buy/Hold/Sell recommendation")
    confidence_score: int = Field(ge=1, le=10, description="Confidence 1-10")

print("✅ Step 1 Complete: Pydantic model defined!")
# Out:
# ✅ Step 1 Complete: Pydantic model defined!

# %%
# STEP 2: Build agent that outputs structured data
from agents import Agent, function_tool, WebSearchTool

structured_agent = Agent(
    name='structured_stock_agent',
    model='gpt-5.4-mini',  # Use gpt-5.4-mini for structured outputs
    instructions="""You are a stock analyst. Use the available tools to gather data, then provide a structured analysis.
    
    For each stock analysis:
    1. Get company info (price, PE ratio, 52-week high/low)
    2. Get EPS trends and analyst data 
    3. Get recent news
    4. Analyze the sentiment and trends
    5. Provide clear buy/hold/sell recommendation
    
    Be concise but thorough in your analysis.""",
    tools=[
        function_tool(get_company_info),
        function_tool(get_eps_trend), 
        function_tool(get_earnings_analysis),
        function_tool(get_ticker_news),
        WebSearchTool()
    ],
    output_type=SimpleStockAnalysis  # 🎯 This is the magic line!
)

print("✅ Step 2 Complete: Agent with structured output created!")
# Out:
# ✅ Step 2 Complete: Agent with structured output created!

# %%
# STEP 3: Run analysis & get structured JSON data
from agents import Runner

async def get_structured_analysis(ticker: str) -> tuple[dict, float]:
    """Get structured analysis and cost."""
    runner = Runner()
    
    result = await runner.run(
        structured_agent, 
        f"Analyze {ticker} stock comprehensively using all available tools"
    )
    
    # Show tools called
    print("\n🔧 Tools Called:")
    tool_count = 0
    for resp in result.raw_responses:
        for out in resp.output:
            if hasattr(out, 'name'):
                tool_count += 1
                print(f"  {tool_count}. {out.name}({out.arguments})")
    
    if tool_count == 0:
        print("  (No tools called)")
    # Get cost
    cost = get_usage_info_gpt_5_4_mini(result)['cost_usd']
    
    # The structured output is automatically in result.final_output
    structured_data = result.final_output
    
    return structured_data, cost

# Test with TSLA
data, cost = await get_structured_analysis('TSLA')

print(f"✅ Step 3 Complete: Structured data retrieved!")
print(f"💰 Cost: ${cost:.6f}")
print(f"📊 Data type: {type(data)}")
# Out:
# 🔧 Tools Called:
#   1. get_company_info({"ticker":"TSLA"})
#   2. get_eps_trend({"ticker":"TSLA"})
#   3. get_earnings_analysis({"ticker":"TSLA"})
#   4. get_ticker_news({"ticker":"TSLA","count":5})
# ✅ Step 3 Complete: Structured data retrieved!
# 💰 Cost: $0.012565
# 📊 Data type: <class '__main__.SimpleStockAnalysis'>

# %%
# STEP 4.1: Print structured data as clean JSON - Option 1: Use Pydantic's built-in JSON serialization (BEST)
import json

print("✅ Step 4: Clean JSON Output")
print("=" * 50)

# Option 1: Use Pydantic's built-in JSON serialization (BEST)
print(data.model_dump_json(indent=2))

# Option 2: Convert to dict first, then use json.dumps
# print(json.dumps(data.model_dump(), indent=2))

print("=" * 50)
# Out:
# ✅ Step 4: Clean JSON Output
# ==================================================
# {
#   "ticker": "TSLA",
#   "company_name": "Tesla, Inc.",
#   "eps_current_estimate": 0.45414,
#   "eps_trend_direction": "improving",
#   "current_price": 406.43,
#   "pe_ratio": 162.57526,
#   "distance_from_52w_high_pct": 18.54,
#   "valuation_level": "expensive",
#   "analyst_revisions_net_7d": 2,
#   "analyst_sentiment": "improving",
#   "recent_news_count": 10,
#   "news_sentiment_score": 0.2,
#   "investment_thesis": "Tesla is a market leader in EVs, software/AI for vehicles and energy storage with strong revenue growth and healthy cash, but its multiples are historically high versus fundamentals and near-term investor behavior may be affected by Elon Musk/SpaceX liquidity events—attractive for growth-focused investors who accept valuation and execution risk.",
#   "recommendation": "hold",
#   "confidence_score": 6
# }
# ==================================================

# %%
# STEP 4.2: Print structured data as clean JSON - Option 2: Convert to dict

from pprint import pprint

# Convert to dict and pretty print
pprint(data.model_dump())
# Out:
# {'analyst_revisions_net_7d': 2,
#  'analyst_sentiment': <TrendDirection.IMPROVING: 'improving'>,
#  'company_name': 'Tesla, Inc.',
#  'confidence_score': 6,
#  'current_price': 406.43,
#  'distance_from_52w_high_pct': 18.54,
#  'eps_current_estimate': 0.45414,
#  'eps_trend_direction': <TrendDirection.IMPROVING: 'improving'>,
#  'investment_thesis': 'Tesla is a market leader in EVs, software/AI for '
#                       'vehicles and energy storage with strong revenue growth '
#                       'and healthy cash, but its multiples are historically '
#                       'high versus fundamentals and near-term investor '
#                       'behavior may be affected by Elon Musk/SpaceX liquidity '
#                       'events—attractive for growth-focused investors who '
#                       'accept valuation and execution risk.',
#  'news_sentiment_score': 0.2,
#  'pe_ratio': 162.57526,
#  'recent_news_count': 10,
#  'recommendation': <Recommendation.HOLD: 'hold'>,
#  'ticker': 'TSLA',
#  'valuation_level': <ValuationLevel.EXPENSIVE: 'expensive'>}

# %%
# The output is already structured as a Pydantic model, so we can directly pretty print it

# compare vs class definition: 
# 🎯 Simple model mapping 5 key metrics to our function tools
# class SimpleStockAnalysis(BaseModel):
#     """5 key metrics automatically mapped from function calls"""
#     ticker: str = Field(description="Stock ticker symbol")
#     company_name: str = Field(description="Company name")
    
#     # 1. EPS Trend (from get_eps_trend, get_earnings_analysis)
#     eps_current_estimate: Optional[float] = Field(description="Current quarter EPS estimate")
#     eps_trend_direction: TrendDirection = Field(description="EPS trend direction")
    
#     # 2. Price & Valuation (from get_company_info)
#     current_price: Optional[float] = Field(description="Current stock price")
#     pe_ratio: Optional[float] = Field(description="P/E ratio")
#     distance_from_52w_high_pct: Optional[float] = Field(description="Distance from 52-week high %")
#     valuation_level: ValuationLevel = Field(description="Valuation assessment")
    
#     # 3. Analyst Sentiment (from get_earnings_analysis)
#     analyst_revisions_net_7d: Optional[int] = Field(description="Net analyst revisions last 7 days")
#     analyst_sentiment: TrendDirection = Field(description="Overall analyst sentiment")
    
#     # 4. News & Market Activity (from get_ticker_news, get_historical_prices)
#     recent_news_count: Optional[int] = Field(description="Number of recent news articles")
#     news_sentiment_score: Optional[float] = Field(ge=-1, le=1, description="News sentiment (-1 to 1)")
    
#     # 5. Investment Summary
#     investment_thesis: str = Field(description="One-sentence investment summary")
#     recommendation: Recommendation = Field(description="Buy/Hold/Sell recommendation")
#     confidence_score: int = Field(ge=1, le=10, description="Confidence 1-10")
pprint(data)
# Out:
# SimpleStockAnalysis(ticker='TSLA', company_name='Tesla, Inc.', eps_current_estimate=0.45414, eps_trend_direction=<TrendDirection.IMPROVING: 'improving'>, current_price=406.43, pe_ratio=162.57526, distance_from_52w_high_pct=18.54, valuation_level=<ValuationLevel.EXPENSIVE: 'expensive'>, analyst_revisions_net_7d=2, analyst_sentiment=<TrendDirection.IMPROVING: 'improving'>, recent_news_count=10, news_sentiment_score=0.2, investment_thesis='Tesla is a market leader in EVs, software/AI for vehicles and energy storage with strong revenue growth and healthy cash, but its multiples are historically high versus fundamentals and near-term investor behavior may be affected by Elon Musk/SpaceX liquidity events—attractive for growth-focused investors who accept valuation and execution risk.', recommendation=<Recommendation.HOLD: 'hold'>, confidence_score=6)
